# %% [markdown]
# ### Goal
#
# Test for overrepresentation of protein domains in genes associated with high number of CNEs (defined by counting CNEs in windows of various sizes around each gene).
#
# ### Input
#
# - gene_IPR.tsv: protein domain information for all genes (generated with find_closest_gene.ipynb)
# - all_IPR_desc.tsv: protein domain info (IDs and descriptions)
# - all_species_nearby_cnes.pickle: Dictionary of nearby CNEs generated with find_nearby_cnes.ipynb.
#
#
# ### Output
#
# - species_ID + '_nearby_cne_counts.tsv': dataframes of CNE counts around every gene for all distance thresholds
# - species_ID + '_overrep_domains_' + str(dist) + '_kb.tsv' : dataframes of overrepresented protein domains and p-values (one file per species and distance threshold)
# - multi_threshold_score.tsv : dataframe of protein domains most commonly overrrepresented across multiple distance thresholds and species

# %%
import sys
import scipy.stats as stats
import pandas as pd
import glob
import statistics
import collections
import pickle
import os

# %%
species_list = ['apis', 'aaeg', 'aamp', 'amel', 'alic', 'anas', 'cscu', 'cdip', 'csec', 'cfel', 'dmel', 
                'eaff', 'gocc', 'hazt', 'lpol', 'ahyp', 'obir', 'phum', 'pvan', 'ptri', 'smim', 
                'smar', 'tpal', 'tcas']

# %% [markdown]
# #### Load protein domain info

# %%
gene_IPR_file = "../../overrep_domains/new_parse_gff/avg/gene_IPR.tsv"
gene_IPR_df = pd.read_csv(gene_IPR_file, sep="\t")
gene_IPR_df
# Out:
#         species               gene_id     IPR_id
# 0          phum  gene-Phum_PHUM625480     no_IPR
# 1          phum  gene-Phum_PHUM625380     no_IPR
# 2          phum  gene-Phum_PHUM625280  IPR002110
# 3          phum  gene-Phum_PHUM625280  IPR020683
# 4          phum  gene-Phum_PHUM625280  IPR036770
# ...         ...                   ...        ...
# 1919966    cscu     gene-LOC111617813  IPR038441
# 1919967    cscu     gene-LOC111617813  IPR016177
# 1919968    cscu     gene-LOC111617814  IPR001878
# 1919969    cscu     gene-LOC111617812  IPR027806
# 1919970    cscu     gene-LOC111617811     no_IPR
#
# [1919971 rows x 3 columns]

# %%
all_IPRS_desc = pd.read_csv("../avg/all_IPR_desc.tsv", sep="\t")
all_IPRS_desc
# Out:
#           IPR_id                                        description
# 0      IPR003961                               Fibronectin type III
# 1            NaN                                                NaN
# 2      IPR036116                   Fibronectin type III superfamily
# 3      IPR003598                           Immunoglobulin subtype 2
# 4      IPR007110                         Immunoglobulin-like domain
# ...          ...                                                ...
# 13988  IPR036269  Rho termination factor, N-terminal domain supe...
# 13989  IPR011112                 Rho termination factor, N-terminal
# 13990  IPR026104      Zinc finger C2HC domain-containing protein 1C
# 13991  IPR019757  Peptidase S26A, signal peptidase I, lysine act...
# 13992  IPR031745                                  Vps53, C-terminal
#
# [13993 rows x 2 columns]

# %% [markdown]
# #### Load nearby CNE data (from find_nearby_CNEs.ipynb)

# %%
nearby_cne_file = 'all_species_nearby_cnes.pickle'

# %%
with open(nearby_cne_file, 'rb') as handle:
    nearby_cne_dict = pickle.load(handle)

# %% [markdown]
# ### Create CNE count files

# %%
for species, threshold_dict in nearby_cne_dict.items():
    print(species)
    output_file_name = species + '_nearby_cne_counts.tsv'
    print("Creating output data frame")
    cne_counts_df = pd.DataFrame()
    for threshold, dist_dict in threshold_dict.items():
        print(threshold)
        column_name = 'cne_count_' + str(int(threshold/1000)) + '_kb'
        print(column_name)
        for gene_id, cne_list in dist_dict.items():
            cne_counts = len(cne_list)
            cne_counts_df.loc[gene_id, column_name] = cne_counts
        if column_name in cne_counts_df.columns:
            cne_counts_df[column_name] = cne_counts_df[column_name].astype(int)
    num_columns = len(cne_counts_df.columns)
    if num_columns > 0:
        cne_counts_df = cne_counts_df.sort_values(by=cne_counts_df.columns[0], ascending=False)
    cne_counts_df.index.name = 'gene_id'
    cne_counts_df.reset_index(inplace=True)
    print("Writing cne count data frame to file")
    cne_counts_df.to_csv(output_file_name, sep="\t")
# Out:
# apis
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file
# aaeg
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file
# aamp
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file
# amel
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file
# alic
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file
# anas
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file
# cscu
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file
# cdip
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file
# csec
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file
# cfel
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file
# dmel
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file
# eaff
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file
# gocc
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file
# hazt
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file
# lpol
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file
# ahyp
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file
# obir
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file
# phum
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file
# pvan
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file
# ptri
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file
# smim
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file
# smar
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file
# tpal
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file
# tcas
# Creating output data frame
# 10000
# cne_count_10_kb
# 25000
# cne_count_25_kb
# 50000
# cne_count_50_kb
# 75000
# cne_count_75_kb
# 100000
# cne_count_100_kb
# 200000
# cne_count_200_kb
# 300000
# cne_count_300_kb
# 400000
# cne_count_400_kb
# 500000
# cne_count_500_kb
# there are  9 columns in data frame
# Writing cne count data frame to file

# %% [markdown]
# ### Run fisher test for all species

# %%
#### Distance thresholds
dist_list = [10, 25, 50, 75, 100, 200, 300 , 400 , 500]

# %% [markdown]
# #### CNE count file

# %%
species = 'apis'
nearby_cne_df = pd.read_csv(species + '_nearby_cne_counts.tsv', sep="\t", index_col=0)
nearby_cne_df
# Out:
#                  gene_id  cne_count_10_kb  cne_count_25_kb  cne_count_50_kb  \
# 0      gene-LOC100570391                4                4                4
# 1      gene-LOC100169440                4                4                4
# 2      gene-LOC100162333                4                4                4
# 3              gene-COX1                3                3                3
# 4      gene-LOC100167988                3                3                3
# ...                  ...              ...              ...              ...
# 18278  gene-LOC100160914                0                0                0
# 18279        gene-Eif1ad                0                0                0
# 18280  gene-LOC103307715                0                0                0
# 18281  gene-LOC100573967                0                0                0
# 18282  gene-LOC100168709                0                0                0
#
#        cne_count_75_kb  cne_count_100_kb  cne_count_200_kb  cne_count_300_kb  \
# 0                    4                 4                 4                 4
# 1                    4                 4                 4                 4
# 2                    4                 4                 4                 4
# 3                    3                 3                 3                 3
# 4                    3                 3                 4                 4
# ...                ...               ...               ...               ...
# 18278                0                 0                 0                 0
# 18279                0                 0                 0                 0
# 18280                0                 0                 0                 0
# 18281                0                 0                 0                 0
# 18282                0                 0                 0                 0
#
#        cne_count_400_kb  cne_count_500_kb
# 0                     5                 5
# 1                     4                 4
# 2                     4                 4
# 3                     3                 3
# 4                     4                 4
# ...                 ...               ...
# 18278                 0                 0
# 18279                 0                 0
# 18280                 0                 0
# 18281                 0                 0
# 18282                 0                 0
#
# [18283 rows x 10 columns]

# %% [markdown]
# ### Function that runs Fisher test

# %%
def fisher_test(merged_data, distance):
    fisher_results = {}
    pvalues = []
    column_name = "cne_count_" + str(distance) + '_kb'
    print(len(sp_df))
    print(len(merged_data))
    mean_cne = statistics.mean(list(sp_df[column_name]))
    stdev_cne =  statistics.stdev(list(sp_df[column_name]))
    cne_threshold = mean_cne # can also be run with avg + stdev or other threshold
    # Count genes with higher than avg CNEs
    with_CNE_df = merged_data[merged_data[column_name] > cne_threshold]
    without_CNE_df = merged_data[merged_data[column_name] <= cne_threshold]
    gene_count_wCNE = len(with_CNE_df['gene_id'].unique())
    gene_count_noCNE = len(without_CNE_df['gene_id'].unique())
    # Only test IPRs present in at least one gene with higher than average CNEs
    test_IPRs = list(with_CNE_df['IPR_id'].unique())
    print("Testing: ", len(test_IPRs), "distinct IPRs")
    print("cne threshold:", cne_threshold)
    for test_IPR in test_IPRs:
        # genes with high CNEs and containing protein domain
        gene_count_wCNE_wIPR = len(with_CNE_df[with_CNE_df['IPR_id'] == test_IPR]['gene_id'].unique())
        # genes with high CNEs not containing protein domain
        gene_count_wCNE_noIPR = gene_count_wCNE - gene_count_wCNE_wIPR
        # genes with low CNEs and containing protein domain
        gene_count_noCNE_wIPR = len(without_CNE_df[without_CNE_df['IPR_id'] == test_IPR]['gene_id'].unique())
        # genes with low CNEs not containing protein domain
        gene_count_noCNE_noIPR = gene_count_noCNE - gene_count_noCNE_wIPR
        # Make contingency table for Fisher test
        cont_matrix = [[gene_count_wCNE_wIPR, gene_count_wCNE_noIPR], [gene_count_noCNE_wIPR, gene_count_noCNE_noIPR]]
        # Run test
        oddsratio, pvalue = stats.fisher_exact(cont_matrix, alternative = 'greater')
        pvalues.append(pvalue)
    # Bonferroni pvalue corrrection
    padj = [pval * len(pvalues) for pval in pvalues]
    table = {'IPR_id':test_IPRs, 'pvalue':pvalues, 'corrected pvalue':padj}
    pval_df = pd.DataFrame(table)
    pval_df = pval_df.sort_values(by = ['corrected pvalue'])
    pval_df = pval_df.reset_index(drop = True)
    # Only keep domains with pvalue <= 0.05
    pval_df = pval_df[pval_df['corrected pvalue'] <= 0.05]
    pval_df = pval_df
    return(pval_df, cne_threshold)

# %%
out_dir = 'avg/'
os.mkdir(out_dir)
for species in species_list:
    nearby_cne_df = pd.read_csv(species + '_nearby_cne_counts.tsv', sep="\t", index_col=0)
    sp_df = nearby_cne_df.groupby('gene_id').sum().reset_index() # no redundant IPRs or CNE counts
    ### Combine nearby CNE info with protein domain info
    merged_data = gene_IPR_df[gene_IPR_df['species'] == species].merge(sp_df, how='left') # one row per IPR
    print("Running Fisher tests")
    for dist in dist_list:
        print("Distance:", dist)
        fisher_results, cne_threshold = fisher_test(merged_data, dist)
        fisher_results = fisher_results.merge(all_IPRS_desc, how='left')
        print("Writing output to file")
        filepath = out_dir + species + '_overrep_domains_' + str(dist) + '_kb.tsv'
        fisher_results.to_csv(filepath, sep = '\t', index = False)
# Out:
# Running Fisher tests
# Distance: 10
# 18283
# 88452
# Testing:  922 distinct IPRs
# cne threshold: 0.04085762730405294
# Writing output to file
# Distance: 25
# 18283
# 88452
# Testing:  1420 distinct IPRs
# cne threshold: 0.0777771700486791
# Writing output to file
# Distance: 50
# 18283
# 88452
# Testing:  2210 distinct IPRs
# cne threshold: 0.14084121861838866
# Writing output to file
# Distance: 75
# 18283
# 88452
# Testing:  2845 distinct IPRs
# cne threshold: 0.20018596510419515
# Writing output to file
# Distance: 100
# 18283
# 88452
# Testing:  3371 distinct IPRs
# cne threshold: 0.26171853634523873
# Writing output to file
# Distance: 200
# 18283
# 88452
# Testing:  4785 distinct IPRs
# cne threshold: 0.5044029973199147
# Writing output to file
# Distance: 300
# 18283
# 88452
# Testing:  5765 distinct IPRs
# cne threshold: 0.7373516381337855
# Writing output to file
# Distance: 400
# 18283
# 88452
# Testing:  6526 distinct IPRs
# cne threshold: 0.9596893288847563
# Writing output to file
# Distance: 500
# 18283
# 88452
# Testing:  4427 distinct IPRs
# cne threshold: 1.1800032817371329
# Writing output to file
# Running Fisher tests
# Distance: 10
# 14626
# 102780
# Testing:  787 distinct IPRs
# cne threshold: 0.045808833584028444
# Writing output to file
# Distance: 25
# 14626
# 102780
# Testing:  1022 distinct IPRs
# cne threshold: 0.07411459045535349
# Writing output to file
# Distance: 50
# 14626
# 102780
# Testing:  1412 distinct IPRs
# cne threshold: 0.11493231232052509
# Writing output to file
# Distance: 75
# 14626
# 102780
# Testing:  1698 distinct IPRs
# cne threshold: 0.15513469164501573
# Writing output to file
# Distance: 100
# 14626
# 102780
# Testing:  1996 distinct IPRs
# cne threshold: 0.19567892793655134
# Writing output to file
# Distance: 200
# 14626
# 102780
# Testing:  3070 distinct IPRs
# cne threshold: 0.36599206891836455
# Writing output to file
# Distance: 300
# 14626
# 102780
# Testing:  3971 distinct IPRs
# cne threshold: 0.5394502939969916
# Writing output to file
# Distance: 400
# 14626
# 102780
# Testing:  4737 distinct IPRs
# cne threshold: 0.705045808833584
# Writing output to file
# Distance: 500
# 14626
# 102780
# Testing:  5350 distinct IPRs
# cne threshold: 0.8638041843292766
# Writing output to file
# Running Fisher tests
# Distance: 10
# 25581
# 73997
# Testing:  1649 distinct IPRs
# cne threshold: 0.06422735624096008
# Writing output to file
# Distance: 25
# 25581
# 73997
# Testing:  2490 distinct IPRs
# cne threshold: 0.1282592549157578
# Writing output to file
# Distance: 50
# 25581
# 73997
# Testing:  3452 distinct IPRs
# cne threshold: 0.22751260701301748
# Writing output to file
# Distance: 75
# 25581
# 73997
# Testing:  4221 distinct IPRs
# cne threshold: 0.31722762988155273
# Writing output to file
# Distance: 100
# 25581
# 73997
# Testing:  4778 distinct IPRs
# cne threshold: 0.39701340838903876
# Writing output to file
# Distance: 200
# 25581
# 73997
# Testing:  5971 distinct IPRs
# cne threshold: 0.6538446503264141
# Writing output to file
# Distance: 300
# 25581
# 73997
# Testing:  6539 distinct IPRs
# cne threshold: 0.8487549353035456
# Writing output to file
# Distance: 400
# 25581
# 73997
# Testing:  6857 distinct IPRs
# cne threshold: 0.9805324264102263
# Writing output to file
# Distance: 500
# 25581
# 73997
# Testing:  4688 distinct IPRs
# cne threshold: 1.068879246315625
# Writing output to file
# Running Fisher tests
# Distance: 10
# 9935
# 90468
# Testing:  2680 distinct IPRs
# cne threshold: 1.6396577755410167
# Writing output to file
# Distance: 25
# 9935
# 90468
# Testing:  3099 distinct IPRs
# cne threshold: 3.146955208857574
# Writing output to file
# Distance: 50
# 9935
# 90468
# Testing:  3587 distinct IPRs
# cne threshold: 6.193759436336185
# Writing output to file
# Distance: 75
# 9935
# 90468
# Testing:  3905 distinct IPRs
# cne threshold: 9.604328132863614
# Writing output to file
# Distance: 100
# 9935
# 90468
# Testing:  3911 distinct IPRs
# cne threshold: 13.231605435329643
# Writing output to file
# Distance: 200
# 9935
# 90468
# Testing:  4192 distinct IPRs
# cne threshold: 29.29250125817816
# Writing output to file
# Distance: 300
# 9935
# 90468
# Testing:  4513 distinct IPRs
# cne threshold: 46.40805234021138
# Writing output to file
# Distance: 400
# 9935
# 90468
# Testing:  4487 distinct IPRs
# cne threshold: 63.40402617010569
# Writing output to file
# Distance: 500
# 9935
# 90468
# Testing:  4589 distinct IPRs
# cne threshold: 80.94111726220433
# Writing output to file
# Running Fisher tests
# Distance: 10
# 22590
# 55995
# Testing:  1657 distinct IPRs
# cne threshold: 0.07233289065958388
# Writing output to file
# Distance: 25
# 22590
# 55995
# Testing:  2240 distinct IPRs
# cne threshold: 0.1228862328463922
# Writing output to file
# Distance: 50
# 22590
# 55995
# Testing:  3060 distinct IPRs
# cne threshold: 0.21274900398406374
# Writing output to file
# Distance: 75
# 22590
# 55995
# Testing:  3656 distinct IPRs
# cne threshold: 0.30110668437361665
# Writing output to file
# Distance: 100
# 22590
# 55995
# Testing:  4168 distinct IPRs
# cne threshold: 0.3870739265161576
# Writing output to file
# Distance: 200
# 22590
# 55995
# Testing:  5457 distinct IPRs
# cne threshold: 0.7224435590969456
# Writing output to file
# Distance: 300
# 22590
# 55995
# Testing:  3872 distinct IPRs
# cne threshold: 1.0574147853032314
# Writing output to file
# Distance: 400
# 22590
# 55995
# Testing:  4712 distinct IPRs
# cne threshold: 1.3945993802567507
# Writing output to file
# Distance: 500
# 22590
# 55995
# Testing:  5377 distinct IPRs
# cne threshold: 1.7242142540947323
# Writing output to file
# Running Fisher tests
# Distance: 10
# 14636
# 38139
# Testing:  1008 distinct IPRs
# cne threshold: 0.07631866630226838
# Writing output to file
# Distance: 25
# 14636
# 38139
# Testing:  1693 distinct IPRs
# cne threshold: 0.14307187756217546
# Writing output to file
# Distance: 50
# 14636
# 38139
# Testing:  2345 distinct IPRs
# cne threshold: 0.22615468707297076
# Writing output to file
# Distance: 75
# 14636
# 38139
# Testing:  2704 distinct IPRs
# cne threshold: 0.2830008198961465
# Writing output to file
# Distance: 100
# 14636
# 38139
# Testing:  2981 distinct IPRs
# cne threshold: 0.32604536758677233
# Writing output to file
# Distance: 200
# 14636
# 38139
# Testing:  3407 distinct IPRs
# cne threshold: 0.4222465154413774
# Writing output to file
# Distance: 300
# 14636
# 38139
# Testing:  3523 distinct IPRs
# cne threshold: 0.4542224651544138
# Writing output to file
# Distance: 400
# 14636
# 38139
# Testing:  3545 distinct IPRs
# cne threshold: 0.46201147854605085
# Writing output to file
# Distance: 500
# 14636
# 38139
# Testing:  3566 distinct IPRs
# cne threshold: 0.46604263459961737
# Writing output to file
# Running Fisher tests
# Distance: 10
# 24591
# 104946
# Testing:  6115 distinct IPRs
# cne threshold: 0.7427920784026676
# Writing output to file
# Distance: 25
# 24591
# 104946
# Testing:  5657 distinct IPRs
# cne threshold: 1.255865967223781
# Writing output to file
# Distance: 50
# 24591
# 104946
# Testing:  5706 distinct IPRs
# cne threshold: 2.070879590093937
# Writing output to file
# Distance: 75
# 24591
# 104946
# Testing:  6655 distinct IPRs
# cne threshold: 2.8091171566833393
# Writing output to file
# Distance: 100
# 24591
# 104946
# Testing:  6286 distinct IPRs
# cne threshold: 3.4851368386808184
# Writing output to file
# Distance: 200
# 24591
# 104946
# Testing:  6723 distinct IPRs
# cne threshold: 5.6749623846122565
# Writing output to file
# Distance: 300
# 24591
# 104946
# Testing:  6539 distinct IPRs
# cne threshold: 7.28974014883494
# Writing output to file
# Distance: 400
# 24591
# 104946
# Testing:  6644 distinct IPRs
# cne threshold: 8.481232971412306
# Writing output to file
# Distance: 500
# 24591
# 104946
# Testing:  6598 distinct IPRs
# cne threshold: 9.361880362734334
# Writing output to file
# Running Fisher tests
# Distance: 10
# 16287
# 97935
# Testing:  295 distinct IPRs
# cne threshold: 0.007613434027138208
# Writing output to file
# Distance: 25
# 16287
# 97935
# Testing:  563 distinct IPRs
# cne threshold: 0.017928409160680298
# Writing output to file
# Distance: 50
# 16287
# 97935
# Testing:  1028 distinct IPRs
# cne threshold: 0.034444649106649475
# Writing output to file
# Distance: 75
# 16287
# 97935
# Testing:  1333 distinct IPRs
# cne threshold: 0.05089949039110948
# Writing output to file
# Distance: 100
# 16287
# 97935
# Testing:  1614 distinct IPRs
# cne threshold: 0.06385460796954627
# Writing output to file
# Distance: 200
# 16287
# 97935
# Testing:  2364 distinct IPRs
# cne threshold: 0.11678025419045865
# Writing output to file
# Distance: 300
# 16287
# 97935
# Testing:  2752 distinct IPRs
# cne threshold: 0.1539878430650212
# Writing output to file
# Distance: 400
# 16287
# 97935
# Testing:  3006 distinct IPRs
# cne threshold: 0.18020507152944065
# Writing output to file
# Distance: 500
# 16287
# 97935
# Testing:  3323 distinct IPRs
# cne threshold: 0.20304537361085528
# Writing output to file
# Running Fisher tests
# Distance: 10
# 13170
# 101339
# Testing:  2372 distinct IPRs
# cne threshold: 0.15056947608200455
# Writing output to file
# Distance: 25
# 13170
# 101339
# Testing:  3037 distinct IPRs
# cne threshold: 0.22399392558845863
# Writing output to file
# Distance: 50
# 13170
# 101339
# Testing:  3902 distinct IPRs
# cne threshold: 0.34001518602885344
# Writing output to file
# Distance: 75
# 13170
# 101339
# Testing:  4610 distinct IPRs
# cne threshold: 0.4463933181473045
# Writing output to file
# Distance: 100
# 13170
# 101339
# Testing:  5083 distinct IPRs
# cne threshold: 0.5405466970387244
# Writing output to file
# Distance: 200
# 13170
# 101339
# Testing:  6344 distinct IPRs
# cne threshold: 0.8706909643128322
# Writing output to file
# Distance: 300
# 13170
# 101339
# Testing:  4607 distinct IPRs
# cne threshold: 1.1363705391040242
# Writing output to file
# Distance: 400
# 13170
# 101339
# Testing:  5183 distinct IPRs
# cne threshold: 1.3504935459377372
# Writing output to file
# Distance: 500
# 13170
# 101339
# Testing:  5603 distinct IPRs
# cne threshold: 1.5280182232346242
# Writing output to file
# Running Fisher tests
# Distance: 10
# 18878
# 70619
# Testing:  2661 distinct IPRs
# cne threshold: 0.1923402902849878
# Writing output to file
# Distance: 25
# 18878
# 70619
# Testing:  3885 distinct IPRs
# cne threshold: 0.34956033478122683
# Writing output to file
# Distance: 50
# 18878
# 70619
# Testing:  5037 distinct IPRs
# cne threshold: 0.5884097891725818
# Writing output to file
# Distance: 75
# 18878
# 70619
# Testing:  5716 distinct IPRs
# cne threshold: 0.8198432037292086
# Writing output to file
# Distance: 100
# 18878
# 70619
# Testing:  4084 distinct IPRs
# cne threshold: 1.0440194935904228
# Writing output to file
# Distance: 200
# 18878
# 70619
# Testing:  5986 distinct IPRs
# cne threshold: 1.950895221951478
# Writing output to file
# Distance: 300
# 18878
# 70619
# Testing:  5773 distinct IPRs
# cne threshold: 2.821326411696154
# Writing output to file
# Distance: 400
# 18878
# 70619
# Testing:  5678 distinct IPRs
# cne threshold: 3.688738213793834
# Writing output to file
# Distance: 500
# 18878
# 70619
# Testing:  5457 distinct IPRs
# cne threshold: 4.542271427057951
# Writing output to file
# Running Fisher tests
# Distance: 10
# 13947
# 132989
# Testing:  455 distinct IPRs
# cne threshold: 0.014340001434000143
# Writing output to file
# Distance: 25
# 13947
# 132989
# Testing:  951 distinct IPRs
# cne threshold: 0.03448770344877034
# Writing output to file
# Distance: 50
# 13947
# 132989
# Testing:  1457 distinct IPRs
# cne threshold: 0.06596400659640066
# Writing output to file
# Distance: 75
# 13947
# 132989
# Testing:  1984 distinct IPRs
# cne threshold: 0.099949809994981
# Writing output to file
# Distance: 100
# 13947
# 132989
# Testing:  2540 distinct IPRs
# cne threshold: 0.13737721373772138
# Writing output to file
# Distance: 200
# 13947
# 132989
# Testing:  4015 distinct IPRs
# cne threshold: 0.28565282856528285
# Writing output to file
# Distance: 300
# 13947
# 132989
# Testing:  5208 distinct IPRs
# cne threshold: 0.44253244425324445
# Writing output to file
# Distance: 400
# 13947
# 132989
# Testing:  6156 distinct IPRs
# cne threshold: 0.6029253602925361
# Writing output to file
# Distance: 500
# 13947
# 132989
# Testing:  6795 distinct IPRs
# cne threshold: 0.7481178748117875
# Writing output to file
# Running Fisher tests
# Distance: 10
# 20716
# 81676
# Testing:  2092 distinct IPRs
# cne threshold: 0.0912338289245028
# Writing output to file
# Distance: 25
# 20716
# 81676
# Testing:  3118 distinct IPRs
# cne threshold: 0.17628885885306045
# Writing output to file
# Distance: 50
# 20716
# 81676
# Testing:  4177 distinct IPRs
# cne threshold: 0.30445066615176675
# Writing output to file
# Distance: 75
# 20716
# 81676
# Testing:  4848 distinct IPRs
# cne threshold: 0.4127244641822746
# Writing output to file
# Distance: 100
# 20716
# 81676
# Testing:  5298 distinct IPRs
# cne threshold: 0.5025101370921027
# Writing output to file
# Distance: 200
# 20716
# 81676
# Testing:  6219 distinct IPRs
# cne threshold: 0.7469106005020274
# Writing output to file
# Distance: 300
# 20716
# 81676
# Testing:  6502 distinct IPRs
# cne threshold: 0.8763274763467851
# Writing output to file
# Distance: 400
# 20716
# 81676
# Testing:  6662 distinct IPRs
# cne threshold: 0.9508592392353736
# Writing output to file
# Distance: 500
# 20716
# 81676
# Testing:  6699 distinct IPRs
# cne threshold: 0.9854701679860977
# Writing output to file
# Running Fisher tests
# Distance: 10
# 11637
# 39121
# Testing:  359 distinct IPRs
# cne threshold: 0.014952307295694767
# Writing output to file
# Distance: 25
# 11637
# 39121
# Testing:  716 distinct IPRs
# cne threshold: 0.03523244822548767
# Writing output to file
# Distance: 50
# 11637
# 39121
# Testing:  1122 distinct IPRs
# cne threshold: 0.060582624387728795
# Writing output to file
# Distance: 75
# 11637
# 39121
# Testing:  1390 distinct IPRs
# cne threshold: 0.08275328692962104
# Writing output to file
# Distance: 100
# 11637
# 39121
# Testing:  1688 distinct IPRs
# cne threshold: 0.1039786886654636
# Writing output to file
# Distance: 200
# 11637
# 39121
# Testing:  2491 distinct IPRs
# cne threshold: 0.17152186989773996
# Writing output to file
# Distance: 300
# 11637
# 39121
# Testing:  3018 distinct IPRs
# cne threshold: 0.2345965455014179
# Writing output to file
# Distance: 400
# 11637
# 39121
# Testing:  3379 distinct IPRs
# cne threshold: 0.2852968978259001
# Writing output to file
# Distance: 500
# 11637
# 39121
# Testing:  3688 distinct IPRs
# cne threshold: 0.33023975251353443
# Writing output to file
# Running Fisher tests
# Distance: 10
# 9003
# 25256
# Testing:  686 distinct IPRs
# cne threshold: 0.060313228923692105
# Writing output to file
# Distance: 25
# 9003
# 25256
# Testing:  1198 distinct IPRs
# cne threshold: 0.12951238476063534
# Writing output to file
# Distance: 50
# 9003
# 25256
# Testing:  1784 distinct IPRs
# cne threshold: 0.24336332333666555
# Writing output to file
# Distance: 75
# 9003
# 25256
# Testing:  2180 distinct IPRs
# cne threshold: 0.34133066755525937
# Writing output to file
# Distance: 100
# 9003
# 25256
# Testing:  2482 distinct IPRs
# cne threshold: 0.42352549150283236
# Writing output to file
# Distance: 200
# 9003
# 25256
# Testing:  3059 distinct IPRs
# cne threshold: 0.643785404865045
# Writing output to file
# Distance: 300
# 9003
# 25256
# Testing:  3341 distinct IPRs
# cne threshold: 0.7715206042430302
# Writing output to file
# Distance: 400
# 9003
# 25256
# Testing:  3492 distinct IPRs
# cne threshold: 0.8529379095856937
# Writing output to file
# Distance: 500
# 9003
# 25256
# Testing:  3547 distinct IPRs
# cne threshold: 0.8995890258802621
# Writing output to file
# Running Fisher tests
# Distance: 10
# 22879
# 131878
# Testing:  1004 distinct IPRs
# cne threshold: 0.023602430176144062
# Writing output to file
# Distance: 25
# 22879
# 131878
# Testing:  1349 distinct IPRs
# cne threshold: 0.03627780934481402
# Writing output to file
# Distance: 50
# 22879
# 131878
# Testing:  1737 distinct IPRs
# cne threshold: 0.053848507364832376
# Writing output to file
# Distance: 75
# 22879
# 131878
# Testing:  2041 distinct IPRs
# cne threshold: 0.0683159228987281
# Writing output to file
# Distance: 100
# 22879
# 131878
# Testing:  2289 distinct IPRs
# cne threshold: 0.08120984308754753
# Writing output to file
# Distance: 200
# 22879
# 131878
# Testing:  2899 distinct IPRs
# cne threshold: 0.11871148214519865
# Writing output to file
# Distance: 300
# 22879
# 131878
# Testing:  3172 distinct IPRs
# cne threshold: 0.14187683028104375
# Writing output to file
# Distance: 400
# 22879
# 131878
# Testing:  3325 distinct IPRs
# cne threshold: 0.15581974736658072
# Writing output to file
# Distance: 500
# 22879
# 131878
# Testing:  3489 distinct IPRs
# cne threshold: 0.16766467065868262
# Writing output to file
# Running Fisher tests
# Distance: 10
# 13005
# 61349
# Testing:  1498 distinct IPRs
# cne threshold: 0.08473663975394079
# Writing output to file
# Distance: 25
# 13005
# 61349
# Testing:  2222 distinct IPRs
# cne threshold: 0.16339869281045752
# Writing output to file
# Distance: 50
# 13005
# 61349
# Testing:  3266 distinct IPRs
# cne threshold: 0.2944252210688197
# Writing output to file
# Distance: 75
# 13005
# 61349
# Testing:  3924 distinct IPRs
# cne threshold: 0.4164552095347943
# Writing output to file
# Distance: 100
# 13005
# 61349
# Testing:  4449 distinct IPRs
# cne threshold: 0.5370242214532872
# Writing output to file
# Distance: 200
# 13005
# 61349
# Testing:  6142 distinct IPRs
# cne threshold: 0.9874663590926567
# Writing output to file
# Distance: 300
# 13005
# 61349
# Testing:  4618 distinct IPRs
# cne threshold: 1.4249903883121877
# Writing output to file
# Distance: 400
# 13005
# 61349
# Testing:  5437 distinct IPRs
# cne threshold: 1.8515955401768551
# Writing output to file
# Distance: 500
# 13005
# 61349
# Testing:  4332 distinct IPRs
# cne threshold: 2.2661284121491736
# Writing output to file
# Running Fisher tests
# Distance: 10
# 11927
# 85012
# Testing:  2520 distinct IPRs
# cne threshold: 1.2672926972415528
# Writing output to file
# Distance: 25
# 11927
# 85012
# Testing:  3635 distinct IPRs
# cne threshold: 2.580196193510522
# Writing output to file
# Distance: 50
# 11927
# 85012
# Testing:  3907 distinct IPRs
# cne threshold: 5.228053995137084
# Writing output to file
# Distance: 75
# 11927
# 85012
# Testing:  4137 distinct IPRs
# cne threshold: 8.282049132221012
# Writing output to file
# Distance: 100
# 11927
# 85012
# Testing:  4483 distinct IPRs
# cne threshold: 11.597384086526368
# Writing output to file
# Distance: 200
# 11927
# 85012
# Testing:  4620 distinct IPRs
# cne threshold: 26.577597048713002
# Writing output to file
# Distance: 300
# 11927
# 85012
# Testing:  4892 distinct IPRs
# cne threshold: 42.275928565439756
# Writing output to file
# Distance: 400
# 11927
# 85012
# Testing:  5091 distinct IPRs
# cne threshold: 58.69908610715184
# Writing output to file
# Distance: 500
# 11927
# 85012
# Testing:  5095 distinct IPRs
# cne threshold: 75.44026159134737
# Writing output to file
# Running Fisher tests
# Distance: 10
# 10773
# 34529
# Testing:  658 distinct IPRs
# cne threshold: 0.03406664810173582
# Writing output to file
# Distance: 25
# 10773
# 34529
# Testing:  1267 distinct IPRs
# cne threshold: 0.0782511835143414
# Writing output to file
# Distance: 50
# 10773
# 34529
# Testing:  1968 distinct IPRs
# cne threshold: 0.13784461152882205
# Writing output to file
# Distance: 75
# 10773
# 34529
# Testing:  2521 distinct IPRs
# cne threshold: 0.19456047526222964
# Writing output to file
# Distance: 100
# 10773
# 34529
# Testing:  2931 distinct IPRs
# cne threshold: 0.2440360159658405
# Writing output to file
# Distance: 200
# 10773
# 34529
# Testing:  3987 distinct IPRs
# cne threshold: 0.3988675392184164
# Writing output to file
# Distance: 300
# 10773
# 34529
# Testing:  4505 distinct IPRs
# cne threshold: 0.5225099786503296
# Writing output to file
# Distance: 400
# 10773
# 34529
# Testing:  4932 distinct IPRs
# cne threshold: 0.6179337231968811
# Writing output to file
# Distance: 500
# 10773
# 34529
# Testing:  5188 distinct IPRs
# cne threshold: 0.6921934465794115
# Writing output to file
# Running Fisher tests
# Distance: 10
# 24987
# 92658
# Testing:  2446 distinct IPRs
# cne threshold: 0.15047824868931844
# Writing output to file
# Distance: 25
# 24987
# 92658
# Testing:  3486 distinct IPRs
# cne threshold: 0.27854484331852564
# Writing output to file
# Distance: 50
# 24987
# 92658
# Testing:  4602 distinct IPRs
# cne threshold: 0.47420658742546123
# Writing output to file
# Distance: 75
# 24987
# 92658
# Testing:  5404 distinct IPRs
# cne threshold: 0.6587025253131629
# Writing output to file
# Distance: 100
# 24987
# 92658
# Testing:  5942 distinct IPRs
# cne threshold: 0.8278304718453596
# Writing output to file
# Distance: 200
# 24987
# 92658
# Testing:  5046 distinct IPRs
# cne threshold: 1.4096129987593549
# Writing output to file
# Distance: 300
# 24987
# 92658
# Testing:  5889 distinct IPRs
# cne threshold: 1.8723736342898307
# Writing output to file
# Distance: 400
# 24987
# 92658
# Testing:  4960 distinct IPRs
# cne threshold: 2.235242326009525
# Writing output to file
# Distance: 500
# 24987
# 92658
# Testing:  5268 distinct IPRs
# cne threshold: 2.4992596149998
# Writing output to file
# Running Fisher tests
# Distance: 10
# 99454
# 119354
# Testing:  1386 distinct IPRs
# cne threshold: 0.11079494037444447
# Writing output to file
# Distance: 25
# 99454
# 119354
# Testing:  1870 distinct IPRs
# cne threshold: 0.17361795402899832
# Writing output to file
# Distance: 50
# 99454
# 119354
# Testing:  2179 distinct IPRs
# cne threshold: 0.2220322963380055
# Writing output to file
# Distance: 75
# 99454
# 119354
# Testing:  2284 distinct IPRs
# cne threshold: 0.24435417378888732
# Writing output to file
# Distance: 100
# 99454
# 119354
# Testing:  2334 distinct IPRs
# cne threshold: 0.25425825004524705
# Writing output to file
# Distance: 200
# 99454
# 119354
# Testing:  2362 distinct IPRs
# cne threshold: 0.26322722062461035
# Writing output to file
# Distance: 300
# 99454
# 119354
# Testing:  2362 distinct IPRs
# cne threshold: 0.26377018521125345
# Writing output to file
# Distance: 400
# 99454
# 119354
# Testing:  2362 distinct IPRs
# cne threshold: 0.26377018521125345
# Writing output to file
# Distance: 500
# 99454
# 119354
# Testing:  2362 distinct IPRs
# cne threshold: 0.26377018521125345
# Writing output to file
# Running Fisher tests
# Distance: 10
# 27135
# 62642
# Testing:  5304 distinct IPRs
# cne threshold: 0.48041275105951725
# Writing output to file
# Distance: 25
# 27135
# 62642
# Testing:  6362 distinct IPRs
# cne threshold: 0.7917081260364842
# Writing output to file
# Distance: 50
# 27135
# 62642
# Testing:  5370 distinct IPRs
# cne threshold: 1.2420121614151465
# Writing output to file
# Distance: 75
# 27135
# 62642
# Testing:  6090 distinct IPRs
# cne threshold: 1.6431914501566243
# Writing output to file
# Distance: 100
# 27135
# 62642
# Testing:  5273 distinct IPRs
# cne threshold: 2.001621522019532
# Writing output to file
# Distance: 200
# 27135
# 62642
# Testing:  5444 distinct IPRs
# cne threshold: 3.091579141330385
# Writing output to file
# Distance: 300
# 27135
# 62642
# Testing:  6188 distinct IPRs
# cne threshold: 3.8384005896443707
# Writing output to file
# Distance: 400
# 27135
# 62642
# Testing:  5744 distinct IPRs
# cne threshold: 4.331896075179658
# Writing output to file
# Distance: 500
# 27135
# 62642
# Testing:  6004 distinct IPRs
# cne threshold: 4.677575087525336
# Writing output to file
# Running Fisher tests
# Distance: 10
# 14992
# 57366
# Testing:  2731 distinct IPRs
# cne threshold: 0.184431696905016
# Writing output to file
# Distance: 25
# 14992
# 57366
# Testing:  4329 distinct IPRs
# cne threshold: 0.3911419423692636
# Writing output to file
# Distance: 50
# 14992
# 57366
# Testing:  5806 distinct IPRs
# cne threshold: 0.669090181430096
# Writing output to file
# Distance: 75
# 14992
# 57366
# Testing:  6687 distinct IPRs
# cne threshold: 0.9186232657417289
# Writing output to file
# Distance: 100
# 14992
# 57366
# Testing:  4705 distinct IPRs
# cne threshold: 1.1301360725720384
# Writing output to file
# Distance: 200
# 14992
# 57366
# Testing:  6096 distinct IPRs
# cne threshold: 1.7137806830309499
# Writing output to file
# Distance: 300
# 14992
# 57366
# Testing:  5286 distinct IPRs
# cne threshold: 2.072838847385272
# Writing output to file
# Distance: 400
# 14992
# 57366
# Testing:  5784 distinct IPRs
# cne threshold: 2.3255736392742796
# Writing output to file
# Distance: 500
# 14992
# 57366
# Testing:  6069 distinct IPRs
# cne threshold: 2.4860592315901813
# Writing output to file
# Running Fisher tests
# Distance: 10
# 14332
# 89096
# Testing:  976 distinct IPRs
# cne threshold: 0.04067820262349986
# Writing output to file
# Distance: 25
# 14332
# 89096
# Testing:  1843 distinct IPRs
# cne threshold: 0.09482277421155456
# Writing output to file
# Distance: 50
# 14332
# 89096
# Testing:  2880 distinct IPRs
# cne threshold: 0.17924923248674296
# Writing output to file
# Distance: 75
# 14332
# 89096
# Testing:  3640 distinct IPRs
# cne threshold: 0.26290817750488416
# Writing output to file
# Distance: 100
# 14332
# 89096
# Testing:  4265 distinct IPRs
# cne threshold: 0.3442645827518839
# Writing output to file
# Distance: 200
# 14332
# 89096
# Testing:  6021 distinct IPRs
# cne threshold: 0.6803656154060843
# Writing output to file
# Distance: 300
# 14332
# 89096
# Testing:  4060 distinct IPRs
# cne threshold: 1.006279653921295
# Writing output to file
# Distance: 400
# 14332
# 89096
# Testing:  5183 distinct IPRs
# cne threshold: 1.351311749930226
# Writing output to file
# Distance: 500
# 14332
# 89096
# Testing:  6132 distinct IPRs
# cne threshold: 1.6712950041864358
# Writing output to file
# Running Fisher tests
# Distance: 10
# 12876
# 82375
# Testing:  1496 distinct IPRs
# cne threshold: 0.0738583410997204
# Writing output to file
# Distance: 25
# 12876
# 82375
# Testing:  2446 distinct IPRs
# cne threshold: 0.15128922025473748
# Writing output to file
# Distance: 50
# 12876
# 82375
# Testing:  3726 distinct IPRs
# cne threshold: 0.28277415346380863
# Writing output to file
# Distance: 75
# 12876
# 82375
# Testing:  4586 distinct IPRs
# cne threshold: 0.4207828518173346
# Writing output to file
# Distance: 100
# 12876
# 82375
# Testing:  5301 distinct IPRs
# cne threshold: 0.5549083566324946
# Writing output to file
# Distance: 200
# 12876
# 82375
# Testing:  4480 distinct IPRs
# cne threshold: 1.1238738738738738
# Writing output to file
# Distance: 300
# 12876
# 82375
# Testing:  6067 distinct IPRs
# cne threshold: 1.6867816091954022
# Writing output to file
# Distance: 400
# 12876
# 82375
# Testing:  5361 distinct IPRs
# cne threshold: 2.252174588381485
# Writing output to file
# Distance: 500
# 12876
# 82375
# Testing:  6274 distinct IPRs
# cne threshold: 2.8329450139794967
# Writing output to file

# %% [markdown]
# ### Combine results

# %%
out_dir = 'avg/'
for dist in dist_list:
    thresh = str(dist) + '_kb'
    print(thresh)
    overrep_domain_files = glob.glob(out_dir + "*_overrep_domains_" + thresh + ".tsv")
    all_species_df = pd.DataFrame()
    for file in overrep_domain_files:
        species = file.split("_")[0]
        species_df = pd.read_csv(file, sep="\t")
        species_df['species'] = species
        all_species_df = all_species_df.append(species_df)
    counter=collections.Counter(list(all_species_df['IPR_id']))
    combined_results = pd.DataFrame(counter.most_common(), columns=['IPR_id', 'number_of_species'])
    combined_results = combined_results.merge(all_species_df[['description', 'IPR_id']], how='left', on='IPR_id').\
        drop_duplicates()
    cols = ['IPR_id', 'description', 'number_of_species']
    combined_results = combined_results[cols]
    combined_results.to_csv("all_species_overrep_domains_" + thresh + ".tsv", sep="\t", index=False)
# Out:
# 10_kb
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# 25_kb
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# 50_kb
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# 75_kb
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# 100_kb
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# 200_kb
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# 300_kb
# 400_kb
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# 500_kb
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)
# /var/folders/7d/1vz75qmd7kn8tg41dhcpk_6cxm7gww/T/ipykernel_63818/338614580.py:11: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   all_species_df = all_species_df.append(species_df)

# %%
combined_results
# Out:
#        IPR_id                                        description  \
# 0   IPR017970                           Homeobox, conserved site
# 5   IPR001356                                    Homeobox domain
# 10  IPR009072                                       Histone-fold
# 14  IPR007125                                 Histone H2A/H2B/H3
# 18  IPR012464                Protein of unknown function DUF1676
# 22  IPR009057                   Homeobox-like domain superfamily
# 26  IPR000558                                        Histone H2B
# 29  IPR002119                                        Histone H2A
# 32  IPR032454                     Histone H2A, C-terminal domain
# 35  IPR032458                         Histone H2A conserved site
# 38  IPR000164                                  Histone H3/CENP-A
# 41  IPR013087                              Zinc finger C2H2-type
# 44  IPR036236                       Zinc finger C2H2 superfamily
# 47  IPR000618                             Insect cuticle protein
# 49  IPR001951                                         Histone H4
# 51  IPR019809                         Histone H4, conserved site
# 53  IPR004823   TATA box binding protein associated factor (TAF)
# 55  IPR035425                    CENP-T/Histone H4, histone fold
# 57  IPR005818                   Linker histone H1/H5, domain H15
# 59  IPR005819                                         Histone H5
# 61  IPR006026                        Peptidase, metallopeptidase
# 62  IPR001506                                     Peptidase M12A
# 63  IPR020479                           Homeobox domain, metazoa
# 64  IPR036388   Winged helix-like DNA-binding domain superfamily
# 65  IPR036390        Winged helix DNA-binding domain superfamily
# 66  IPR036927  Cytochrome c oxidase-like, subunit I  superfamily
# 67  IPR023616        Cytochrome c oxidase-like, subunit I domain
# 68  IPR023796                                      Serpin domain
# 69  IPR036186                                 Serpin superfamily
# 70  IPR035701                                         Caspase-10
# 71  IPR000215                                      Serpin family
# 72  IPR005123            Oxoglutarate/iron-dependent dioxygenase
# 73  IPR045054                               Prolyl 4-hydroxylase
# 74  IPR013547     Prolyl 4-hydroxylase alpha-subunit, N-terminal
# 75  IPR031311                  Chitin-binding type R&R consensus
# 76  IPR029485        Cationic amino acid transporter, C-terminal
# 77  IPR038765         Papain-like cysteine peptidase superfamily
# 78  IPR011598     Myc-type, basic helix-loop-helix (bHLH) domain
# 79  IPR020849                 Small GTPase superfamily, Ras-type
# 80  IPR004117                         Olfactory receptor, insect
# 81  IPR017996           Major royal jelly protein/protein yellow
# 82  IPR002635                                    Chorion protein
# 83  IPR026055                           Fatty acyl-CoA reductase
# 84  IPR013120                        Male sterility, NAD-binding
# 85  IPR005821                               Ion transport domain
# 86  IPR043197                                             Plakin
# 87  IPR012677  Nucleotide-binding alpha-beta plait domain sup...
# 88  IPR033228                                       Protein SZT2
#
#     number_of_species
# 0                   5
# 5                   5
# 10                  4
# 14                  4
# 18                  4
# 22                  4
# 26                  3
# 29                  3
# 32                  3
# 35                  3
# 38                  3
# 41                  3
# 44                  3
# 47                  2
# 49                  2
# 51                  2
# 53                  2
# 55                  2
# 57                  2
# 59                  2
# 61                  1
# 62                  1
# 63                  1
# 64                  1
# 65                  1
# 66                  1
# 67                  1
# 68                  1
# 69                  1
# 70                  1
# 71                  1
# 72                  1
# 73                  1
# 74                  1
# 75                  1
# 76                  1
# 77                  1
# 78                  1
# 79                  1
# 80                  1
# 81                  1
# 82                  1
# 83                  1
# 84                  1
# 85                  1
# 86                  1
# 87                  1
# 88                  1

# %% [markdown]
# ### Identify protein domains most commonly overrepresented (over multiple distance thresholds and number of species)

# %%
from collections import defaultdict
IPR_count_dict = defaultdict(lambda:0)
all_sp_overrep_files = glob.glob("all_species_overrep_domains_*.tsv")
print(all_sp_overrep_files)
for file in all_sp_overrep_files:
    sp_count_df = pd.read_csv(file, sep="\t")
    for index, row in sp_count_df.iterrows():
        IPR_id = row['IPR_id']
        num_sp = row['number_of_species']
        IPR_count_dict[IPR_id] += num_sp
all_thresh_counts = pd.DataFrame(IPR_count_dict.items(), columns=['IPR_id', 'cumulative_score'])
all_thresh_counts = all_thresh_counts.merge(all_IPRS_desc, how='left')
all_thresh_counts = all_thresh_counts.sort_values('cumulative_score', ascending=False)
all_thresh_counts.to_csv(out_dir + "multi_threshold_score.tsv", sep="\t")
all_thresh_counts
# Out:
# ['all_species_overrep_domains_400_kb.tsv', 'all_species_overrep_domains_500_kb.tsv', 'all_species_overrep_domains_25_kb.tsv', 'all_species_overrep_domains_300_kb.tsv', 'all_species_overrep_domains_200_kb.tsv', 'all_species_overrep_domains_50_kb.tsv', 'all_species_overrep_domains_10_kb.tsv', 'all_species_overrep_domains_75_kb.tsv', 'all_species_overrep_domains_100_kb.tsv']
#         IPR_id  cumulative_score                          description
# 1    IPR001356                40                      Homeobox domain
# 0    IPR017970                39             Homeobox, conserved site
# 2    IPR009057                38     Homeobox-like domain superfamily
# 3    IPR009072                28                         Histone-fold
# 4    IPR007125                27                   Histone H2A/H2B/H3
# ..         ...               ...                                  ...
# 139  IPR014753                 1                 Arrestin, N-terminal
# 138  IPR000698                 1                             Arrestin
# 15   IPR001163                 1  LSM domain, eukaryotic/archaea-type
# 136  IPR015897                 1                      CHK kinase-like
# 216  IPR026791                 1             Dedicator of cytokinesis
#
# [217 rows x 3 columns]

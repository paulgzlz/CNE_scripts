# %%
import pandas as pd
import glob
import seaborn as sns
# %matplotlib inline
from collections import defaultdict

# %% [markdown]
# #### BLASTn results

# %%
blastn_dir = "../../blast_metazoa/blastn_output_files/"

# %%
blastn_files = glob.glob(blastn_dir + "*blastn")
blastn_files
# Out:
# ['../../blast_metazoa/blastn_output_files/mollusca_vs_nematoda.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_priapulida.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_arthropoda.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_annelida.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_mollusca.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_nemertea.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_hemichordata.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_rotifera.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_orthonectida.blastn',
#  '../../blast_metazoa/blastn_output_files/mollusca_vs_platyhelminthes.blastn',
#  '../../blast_metazoa/blastn_output_files/mollusca_vs_chordata.blastn',
#  '../../blast_metazoa/blastn_output_files/mollusca_vs_tardigrada.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_onychophora.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_onychophora.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_nematoda.blastn',
#  '../../blast_metazoa/blastn_output_files/mollusca_vs_ctenophora.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_bryozoa.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_xenacoelomorpha.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_porifera.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_echinodermata.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_phoronida.blastn',
#  '../../blast_metazoa/blastn_output_files/mollusca_vs_annelida.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_cnidaria.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_arthropoda.blastn',
#  '../../blast_metazoa/blastn_output_files/mollusca_vs_nemertea.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_xenacoelomorpha.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_dicyemida.blastn',
#  '../../blast_metazoa/blastn_output_files/mollusca_vs_rotifera.blastn',
#  '../../blast_metazoa/blastn_output_files/mollusca_vs_hemichordata.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_priapulida.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_chordata.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_placozoa.blastn',
#  '../../blast_metazoa/blastn_output_files/mollusca_vs_orthonectida.blastn',
#  '../../blast_metazoa/blastn_output_files/mollusca_vs_onychophora.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_platyhelminthes.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_hemichordata.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_echinodermata.blastn',
#  '../../blast_metazoa/blastn_output_files/mollusca_vs_brachiopoda.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_orthonectida.blastn',
#  '../../blast_metazoa/blastn_output_files/mollusca_vs_phoronida.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_dicyemida.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_ctenophora.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_tardigrada.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_placozoa.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_chordata.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_bryozoa.blastn',
#  '../../blast_metazoa/blastn_output_files/mollusca_vs_priapulida.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_nematoda.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_phoronida.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_brachiopoda.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_brachiopoda.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_cnidaria.blastn',
#  '../../blast_metazoa/blastn_output_files/mollusca_vs_mollusca.blastn',
#  '../../blast_metazoa/blastn_output_files/mollusca_vs_dicyemida.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_acanthocephala.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_platyhelminthes.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_porifera.blastn',
#  '../../blast_metazoa/blastn_output_files/mollusca_vs_arthropoda.blastn',
#  '../../blast_metazoa/blastn_output_files/mollusca_vs_bryozoa.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_rotifera.blastn',
#  '../../blast_metazoa/blastn_output_files/mollusca_vs_xenacoelomorpha.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_nemertea.blastn',
#  '../../blast_metazoa/blastn_output_files/mollusca_vs_acanthocephala.blastn',
#  '../../blast_metazoa/blastn_output_files/mollusca_vs_placozoa.blastn',
#  '../../blast_metazoa/blastn_output_files/mollusca_vs_echinodermata.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_tardigrada.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_ctenophora.blastn',
#  '../../blast_metazoa/blastn_output_files/arthropoda_vs_mollusca.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_annelida.blastn',
#  '../../blast_metazoa/blastn_output_files/mollusca_vs_cnidaria.blastn',
#  '../../blast_metazoa/blastn_output_files/mollusca_vs_porifera.blastn',
#  '../../blast_metazoa/blastn_output_files/cnidaria_vs_acanthocephala.blastn']

# %%
coord_dirs = ['../retrieve_original_coords/filtered_coords/',
              '../../arthropoda_06_22/retrieve_original_coords/filtered_coords/',
              '../../mollusca_06_22/retrieve_original_coords/filtered_coords/']

# %%
phyla = ['cnidaria', 'arthropoda', 'mollusca']
cne_count_df = pd.DataFrame(columns=['phylum', 'species', 'cne_count'])
for i in range(3):
    sp_count_dict = {}
    phylum = phyla[i]
    print(phylum)
    coord_dir = coord_dirs[i]
    coord_files = glob.glob(coord_dir + '*orig_coords.tsv')
    #print(coord_files)
    for coord_file in coord_files:
        species = coord_file.split("/")[-1].split("_")[0]
        #print(species)
        coord_df = pd.read_csv(coord_file, sep="\t")
        num_cne = len(coord_df)
        sp_count_dict[species] = num_cne
    sp_count_df = pd.DataFrame(sp_count_dict.items(), columns=['species', 'cne_count'])
    sp_count_df['phylum'] = phylum
    cne_count_df = pd.concat([cne_count_df, sp_count_df], axis=0)
# Out:
# cnidaria
# arthropoda
# mollusca

# %%
cne_count_df
# Out:
#         phylum species cne_count
# 0     cnidaria    spis    110941
# 1     cnidaria    hsym      6532
# 2     cnidaria    aaur      2049
# 3     cnidaria    dgig      3644
# 4     cnidaria    chem      2352
# 5     cnidaria    ofav     43953
# 6     cnidaria    aten      5576
# 7     cnidaria    mvir      2730
# 8     cnidaria    hvul      2540
# 9     cnidaria    adig     50811
# 10    cnidaria    epal      5313
# 11    cnidaria    pdam     85198
# 12    cnidaria    nvec      3824
# 0   arthropoda    phum       194
# 1   arthropoda    lpol      1173
# 2   arthropoda    ptri      8881
# 3   arthropoda    amel     19700
# 4   arthropoda    eaff      1289
# 5   arthropoda    apis       806
# 6   arthropoda    aaeg       877
# 7   arthropoda    aamp      1371
# 8   arthropoda    cfel      4575
# 9   arthropoda    dmel       101
# 10  arthropoda    anas      4661
# 11  arthropoda    tcas       534
# 12  arthropoda    ahyp      1078
# 13  arthropoda    pvan      7275
# 14  arthropoda    cdip        93
# 15  arthropoda    hazt      1497
# 16  arthropoda    gocc       106
# 17  arthropoda    tpal       421
# 18  arthropoda    smar      1557
# 19  arthropoda    smim     25687
# 20  arthropoda    obir     19911
# 21  arthropoda    csec      2383
# 22  arthropoda    alic      1999
# 23  arthropoda    cscu     18140
# 0     mollusca    cgig     24676
# 1     mollusca    obim     40836
# 2     mollusca    pcan      1164
# 3     mollusca    pmax     91747
# 4     mollusca    hruf      3468
# 5     mollusca    spha     66624
# 6     mollusca    mgal      2951
# 7     mollusca    cvir     32653
# 8     mollusca    echl      3559
# 9     mollusca    acal      4553
# 10    mollusca    agra      1633
# 11    mollusca    myes     96983
# 12    mollusca    bgla      3217
# 13    mollusca    lgig      1387

# %%
sp_count_dict
# Out:
# {'aaeg': 877,
#  'aamp': 1371,
#  'aaur': 2049,
#  'acal': 4553,
#  'adig': 50811,
#  'agra': 1633,
#  'ahyp': 1078,
#  'alic': 1999,
#  'amel': 19700,
#  'anas': 4661,
#  'apis': 806,
#  'aten': 5576,
#  'bgla': 3217,
#  'cdip': 93,
#  'cfel': 4575,
#  'cgig': 24676,
#  'chem': 2352,
#  'cscu': 18140,
#  'csec': 2383,
#  'cvir': 32653,
#  'dgig': 3644,
#  'dmel': 101,
#  'eaff': 1289,
#  'echl': 3559,
#  'epal': 5313,
#  'gocc': 106,
#  'hazt': 1497,
#  'hruf': 3468,
#  'hsym': 6532,
#  'hvul': 2540,
#  'lgig': 1387,
#  'lpol': 1173,
#  'mgal': 2951,
#  'mvir': 2730,
#  'myes': 96983,
#  'nvec': 3824,
#  'obim': 40836,
#  'obir': 19911,
#  'ofav': 43953,
#  'pcan': 1164,
#  'pdam': 85198,
#  'phum': 194,
#  'pmax': 91747,
#  'ptri': 8881,
#  'pvan': 7275,
#  'smar': 1557,
#  'smim': 25687,
#  'spha': 66624,
#  'spis': 110941,
#  'tcas': 534,
#  'tpal': 421}

# %% [markdown]
# #### How many CNEs are annotated as non-coding RNAs?

# %%
def annotate_rnas(blastn_file):
    file_df = pd.DataFrame()
    blastn_df = pd.read_csv(blastn_file, sep="\t",
                       names = ['cne_id', 'description', 'sseqid', 'pident', 'length', 'mismatch', 'gapopen',
                        'qstart', 'qend', 'sstart', 'send', 'evalue', 'bitscore'])
    all_cne_ids = list(set(blastn_df['cne_id']))
    print(len(all_cne_ids))
    all_rna_cnes = list(set(blastn_df[blastn_df['description'].str.contains('RNA')]['cne_id']))
    snRNA_cnes = list(set(blastn_df[blastn_df['description'].str.contains('snRNA')]['cne_id']))
    ncRNA_cnes = list(set(blastn_df[blastn_df['description'].str.contains('ncRNA')]['cne_id']))
    #non_RNA_cnes = list(set(blastn_df[~blastn_df['description'].str.contains('RNA')]['cne_id']))
    all_cne_df = pd.DataFrame({'cne_id': all_cne_ids})
    all_rna_cne_df = pd.DataFrame({'cne_id': all_rna_cnes, 'RNA':'yes'})
    snRNA_cne_df = pd.DataFrame({'cne_id': snRNA_cnes, 'snRNA':'yes'})
    ncRNA_cne_df = pd.DataFrame({'cne_id': ncRNA_cnes, 'ncRNA':'yes'})
    file_df = all_cne_df.merge(all_rna_cne_df, how='left', ).merge(snRNA_cne_df, how='left')\
                .merge(ncRNA_cne_df, how='left').fillna('no')
    return(file_df)

# %%
moll_chord = annotate_rnas( '../../blast_metazoa/blastn_output_files/mollusca_vs_chordata.blastn')
# Out:
# 13270

# %%
moll_chord
# Out:
#                cne_id  RNA snRNA ncRNA
# 0      spha_cne_33204  yes    no    no
# 1      spha_cne_80016   no    no    no
# 2      pmax_cne_89217  yes    no    no
# 3      spha_cne_51652  yes    no    no
# 4      pmax_cne_17241   no    no    no
# ...               ...  ...   ...   ...
# 13265   acal_cne_6903   no    no    no
# 13266  spha_cne_84942   no    no    no
# 13267  spha_cne_54755   no    no    no
# 13268   pcan_cne_4150  yes    no    no
# 13269  obim_cne_36272   no    no    no
#
# [13270 rows x 4 columns]

# %%
moll_chord[moll_chord['RNA'] == 'yes']
# Out:
#                cne_id  RNA snRNA ncRNA
# 0      spha_cne_33204  yes    no    no
# 2      pmax_cne_89217  yes    no    no
# 3      spha_cne_51652  yes    no    no
# 6      spha_cne_66343  yes    no   yes
# 9       obim_cne_6821  yes    no   yes
# ...               ...  ...   ...   ...
# 13257  spha_cne_26123  yes    no   yes
# 13259  obim_cne_17029  yes    no   yes
# 13261  obim_cne_52837  yes    no   yes
# 13264  spha_cne_46828  yes    no    no
# 13268   pcan_cne_4150  yes    no    no
#
# [6683 rows x 4 columns]

# %%
moll_chord[moll_chord['ncRNA'] == 'yes']
# Out:
#                cne_id  RNA snRNA ncRNA
# 6      spha_cne_66343  yes    no   yes
# 9       obim_cne_6821  yes    no   yes
# 10       agra_cne_974  yes    no   yes
# 13     spha_cne_41768  yes    no   yes
# 15     spha_cne_68670  yes    no   yes
# ...               ...  ...   ...   ...
# 13251   lgig_cne_1756  yes   yes   yes
# 13254  pmax_cne_18466  yes    no   yes
# 13257  spha_cne_26123  yes    no   yes
# 13259  obim_cne_17029  yes    no   yes
# 13261  obim_cne_52837  yes    no   yes
#
# [3582 rows x 4 columns]

# %%
moll_chord[moll_chord['snRNA'] == 'yes']
# Out:
#                cne_id  RNA snRNA ncRNA
# 121      pcan_cne_320  yes   yes   yes
# 219    obim_cne_16134  yes   yes   yes
# 611    bgla_cne_10474  yes   yes   yes
# 990     echl_cne_6602  yes   yes   yes
# 1218   obim_cne_18903  yes   yes   yes
# ...               ...  ...   ...   ...
# 12682   bgla_cne_7846  yes   yes   yes
# 12825   lgig_cne_3517  yes   yes   yes
# 13143   acal_cne_5564  yes   yes   yes
# 13165   obim_cne_9326  yes   yes   yes
# 13251   lgig_cne_1756  yes   yes   yes
#
# [122 rows x 4 columns]

# %% [markdown]
# #### Organize BLAST results

# %%
blastn_file = blastn_files[0]
file_df = pd.DataFrame()
blastn_df = pd.read_csv(blastn_file, sep="\t",
                   names = ['cne_id', 'description', 'sseqid', 'pident', 'length', 'mismatch', 'gapopen',
                    'qstart', 'qend', 'sstart', 'send', 'evalue', 'bitscore'])
blastn_df
# Out:
#                 cne_id                                        description  \
# 0        acal_cne_1263   Trichinella spiralis isolate ISS534 chromosome 2
# 1        acal_cne_1263      Trichinella spiralis isolate TY2 chromosome 2
# 2        acal_cne_1263  Trichinella spiralis isolate Shisler1 chromoso...
# 3        acal_cne_1263  Caenorhabditis briggsae isolate VX34 chromosome I
# 4        acal_cne_1263  Caenorhabditis briggsae isolate VX34 chromosome I
# ...                ...                                                ...
# 294074  spha_cne_93162  Rhabditophanes sp. KR3021 genome assembly Rhab...
# 294075  spha_cne_93162  Rhabditophanes sp. KR3021 genome assembly Rhab...
# 294076  spha_cne_93162  Oscheius dolichura genome assembly, chromosome: V
# 294077  spha_cne_93162  Oscheius onirici genome assembly, chromosome: III
# 294078  spha_cne_93162  Oscheius onirici genome assembly, chromosome: III
#
#                                sseqid  pident  length  mismatch  gapopen  \
# 0        gi|1755770147|gb|CP032377.1|  82.857     105        14        4
# 1        gi|1755770144|gb|CP032374.1|  82.857     105        14        4
# 2        gi|1755770141|gb|CP032371.1|  82.857     105        14        4
# 3        gi|2202840552|gb|CP092620.1|  94.340      53         2        1
# 4        gi|2202840552|gb|CP092620.1|  92.453      53         3        1
# ...                               ...     ...     ...       ...      ...
# 294074   gi|687916023|emb|LK995555.1|  95.000      40         2        0
# 294075   gi|687915983|emb|LK995699.1|  95.000      40         2        0
# 294076  gi|2211271299|emb|OW051496.1|  97.222      36         1        0
# 294077  gi|2211271102|emb|OW051470.1|  97.222      36         1        0
# 294078  gi|2211271102|emb|OW051470.1|  97.222      36         1        0
#
#         qstart  qend    sstart      send        evalue  bitscore
# 0           57   159  10501195  10501093  1.390000e-16      91.6
# 1           57   159  10503647  10503545  1.390000e-16      91.6
# 2           57   159  10481868  10481766  1.390000e-16      91.6
# 3           72   124   3830875   3830926  3.020000e-13      80.5
# 4           72   124   3824164   3824113  1.400000e-11      75.0
# ...        ...   ...       ...       ...           ...       ...
# 294074      67   106    496068    496107  2.140000e-08      63.9
# 294075      67   106     32255     32294  2.140000e-08      63.9
# 294076      76   111   8896691   8896726  7.690000e-08      62.1
# 294077      78   113   9054206   9054171  7.690000e-08      62.1
# 294078      78   113   9075095   9075130  7.690000e-08      62.1
#
# [294079 rows x 13 columns]

# %%
summary_df = pd.DataFrame()
for file in blastn_files:
    query_phylum = file.split('/')[-1].split("_vs_")[0]
    target_phylum = file.split('/')[-1].split("_vs_")[1].split(".")[0]
    print("Query phylum:", query_phylum, "Target phylum:", target_phylum)
    file_df = pd.DataFrame()
    blastn_df = pd.read_csv(file, sep="\t",
                   names = ['cne_id', 'description', 'sseqid', 'pident', 'length', 'mismatch', 'gapopen',
                    'qstart', 'qend', 'sstart', 'send', 'evalue', 'bitscore'])
    #ll_cne_ids = list(set(blastn_df['cne_id']))
    all_cne_df = blastn_df[['cne_id', 'description', 'pident', 'length', 'evalue']]
    all_cne_df['query_phylum'] = query_phylum
    all_cne_df['target_phylum'] = target_phylum
    #cluster_df = cluster_dfs[query_phylum]
    #rna_df = rna_df.merge(cluster_df, how='left')
    #rna_df['cluster_id'] = query_phylum + "_" + rna_df['cluster_id'] 
    summary_df = pd.concat([summary_df, all_cne_df], axis=0)
summary_df
# Out:
# Query phylum: mollusca Target phylum: nematoda
# /Users/gonzalezp2/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /Users/gonzalezp2/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Query phylum: cnidaria Target phylum: priapulida
# Query phylum: cnidaria Target phylum: arthropoda
# Query phylum: arthropoda Target phylum: annelida
# Query phylum: cnidaria Target phylum: mollusca
# Query phylum: arthropoda Target phylum: nemertea
# Query phylum: arthropoda Target phylum: hemichordata
# Query phylum: arthropoda Target phylum: rotifera
# Query phylum: arthropoda Target phylum: orthonectida
# Query phylum: mollusca Target phylum: platyhelminthes
# Query phylum: mollusca Target phylum: chordata
# Query phylum: mollusca Target phylum: tardigrada
# Query phylum: cnidaria Target phylum: onychophora
# Query phylum: arthropoda Target phylum: onychophora
# Query phylum: arthropoda Target phylum: nematoda
# Query phylum: mollusca Target phylum: ctenophora
# Query phylum: cnidaria Target phylum: bryozoa
# Query phylum: arthropoda Target phylum: xenacoelomorpha
# Query phylum: cnidaria Target phylum: porifera
# Query phylum: cnidaria Target phylum: echinodermata
# Query phylum: arthropoda Target phylum: phoronida
# Query phylum: mollusca Target phylum: annelida
# Query phylum: cnidaria Target phylum: cnidaria
# Query phylum: arthropoda Target phylum: arthropoda
# Query phylum: mollusca Target phylum: nemertea
# Query phylum: cnidaria Target phylum: xenacoelomorpha
# Query phylum: arthropoda Target phylum: dicyemida
# Query phylum: mollusca Target phylum: rotifera
# Query phylum: mollusca Target phylum: hemichordata
# Query phylum: arthropoda Target phylum: priapulida
# Query phylum: arthropoda Target phylum: chordata
# Query phylum: cnidaria Target phylum: placozoa
# Query phylum: mollusca Target phylum: orthonectida
# Query phylum: mollusca Target phylum: onychophora
# Query phylum: cnidaria Target phylum: platyhelminthes
# Query phylum: cnidaria Target phylum: hemichordata
# Query phylum: arthropoda Target phylum: echinodermata
# Query phylum: mollusca Target phylum: brachiopoda
# Query phylum: cnidaria Target phylum: orthonectida
# Query phylum: mollusca Target phylum: phoronida
# Query phylum: cnidaria Target phylum: dicyemida
# Query phylum: arthropoda Target phylum: ctenophora
# Query phylum: cnidaria Target phylum: tardigrada
# Query phylum: arthropoda Target phylum: placozoa
# Query phylum: cnidaria Target phylum: chordata
# Query phylum: arthropoda Target phylum: bryozoa
# Query phylum: mollusca Target phylum: priapulida
# Query phylum: cnidaria Target phylum: nematoda
# Query phylum: cnidaria Target phylum: phoronida
# Query phylum: cnidaria Target phylum: brachiopoda
# Query phylum: arthropoda Target phylum: brachiopoda
# Query phylum: arthropoda Target phylum: cnidaria
# Query phylum: mollusca Target phylum: mollusca
# Query phylum: mollusca Target phylum: dicyemida
# Query phylum: arthropoda Target phylum: acanthocephala
# Query phylum: arthropoda Target phylum: platyhelminthes
# Query phylum: arthropoda Target phylum: porifera
# Query phylum: mollusca Target phylum: arthropoda
# Query phylum: mollusca Target phylum: bryozoa
# Query phylum: cnidaria Target phylum: rotifera
# Query phylum: mollusca Target phylum: xenacoelomorpha
# Query phylum: cnidaria Target phylum: nemertea
# Query phylum: mollusca Target phylum: acanthocephala
# Query phylum: mollusca Target phylum: placozoa
# Query phylum: mollusca Target phylum: echinodermata
# Query phylum: arthropoda Target phylum: tardigrada
# Query phylum: cnidaria Target phylum: ctenophora
# Query phylum: arthropoda Target phylum: mollusca
# Query phylum: cnidaria Target phylum: annelida
# Query phylum: mollusca Target phylum: cnidaria
# Query phylum: mollusca Target phylum: porifera
# Query phylum: cnidaria Target phylum: acanthocephala
#             cne_id                                        description  pident  \
# 0    acal_cne_1263   Trichinella spiralis isolate ISS534 chromosome 2  82.857
# 1    acal_cne_1263      Trichinella spiralis isolate TY2 chromosome 2  82.857
# 2    acal_cne_1263  Trichinella spiralis isolate Shisler1 chromoso...  82.857
# 3    acal_cne_1263  Caenorhabditis briggsae isolate VX34 chromosome I  94.340
# 4    acal_cne_1263  Caenorhabditis briggsae isolate VX34 chromosome I  92.453
# ..             ...                                                ...     ...
# 0   hsym_cne_10568  Southwellina hispida mitochondrion, complete g...  72.606
# 1   hsym_cne_10568  Leptorhynchoides thecatus isolate Withbass2 cy...  73.294
# 2   hsym_cne_10568  Pomphorhynchus tereticollis isolate Ouche mito...  81.295
# 3   hsym_cne_10568  Pomphorhynchus tereticollis isolate Straslund ...  80.576
# 4   hsym_cne_10568  Pomphorhynchus tereticollis isolate Ida mitoch...  79.286
#
#    length        evalue query_phylum   target_phylum
# 0     105  1.390000e-16     mollusca        nematoda
# 1     105  1.390000e-16     mollusca        nematoda
# 2     105  1.390000e-16     mollusca        nematoda
# 3      53  3.020000e-13     mollusca        nematoda
# 4      53  1.400000e-11     mollusca        nematoda
# ..    ...           ...          ...             ...
# 0     449  2.510000e-32     cnidaria  acanthocephala
# 1     337  3.270000e-26     cnidaria  acanthocephala
# 2     139  4.230000e-25     cnidaria  acanthocephala
# 3     139  1.970000e-23     cnidaria  acanthocephala
# 4     140  4.260000e-20     cnidaria  acanthocephala
#
# [41668015 rows x 7 columns]

# %%
summary_df
# Out:
#             cne_id                                        description  pident  \
# 0    acal_cne_1263   Trichinella spiralis isolate ISS534 chromosome 2  82.857
# 1    acal_cne_1263      Trichinella spiralis isolate TY2 chromosome 2  82.857
# 2    acal_cne_1263  Trichinella spiralis isolate Shisler1 chromoso...  82.857
# 3    acal_cne_1263  Caenorhabditis briggsae isolate VX34 chromosome I  94.340
# 4    acal_cne_1263  Caenorhabditis briggsae isolate VX34 chromosome I  92.453
# ..             ...                                                ...     ...
# 0   hsym_cne_10568  Southwellina hispida mitochondrion, complete g...  72.606
# 1   hsym_cne_10568  Leptorhynchoides thecatus isolate Withbass2 cy...  73.294
# 2   hsym_cne_10568  Pomphorhynchus tereticollis isolate Ouche mito...  81.295
# 3   hsym_cne_10568  Pomphorhynchus tereticollis isolate Straslund ...  80.576
# 4   hsym_cne_10568  Pomphorhynchus tereticollis isolate Ida mitoch...  79.286
#
#    length        evalue query_phylum   target_phylum
# 0     105  1.390000e-16     mollusca        nematoda
# 1     105  1.390000e-16     mollusca        nematoda
# 2     105  1.390000e-16     mollusca        nematoda
# 3      53  3.020000e-13     mollusca        nematoda
# 4      53  1.400000e-11     mollusca        nematoda
# ..    ...           ...          ...             ...
# 0     449  2.510000e-32     cnidaria  acanthocephala
# 1     337  3.270000e-26     cnidaria  acanthocephala
# 2     139  4.230000e-25     cnidaria  acanthocephala
# 3     139  1.970000e-23     cnidaria  acanthocephala
# 4     140  4.260000e-20     cnidaria  acanthocephala
#
# [41668015 rows x 7 columns]

# %% [markdown]
# #### Only keep BLAST hits with >75% similarity over >50 bp

# %%
filtered_df = summary_df.query('pident>75' and 'length> 50')
filtered_df
# Out:
#             cne_id                                        description  pident  \
# 0    acal_cne_1263   Trichinella spiralis isolate ISS534 chromosome 2  82.857
# 1    acal_cne_1263      Trichinella spiralis isolate TY2 chromosome 2  82.857
# 2    acal_cne_1263  Trichinella spiralis isolate Shisler1 chromoso...  82.857
# 3    acal_cne_1263  Caenorhabditis briggsae isolate VX34 chromosome I  94.340
# 4    acal_cne_1263  Caenorhabditis briggsae isolate VX34 chromosome I  92.453
# ..             ...                                                ...     ...
# 0   hsym_cne_10568  Southwellina hispida mitochondrion, complete g...  72.606
# 1   hsym_cne_10568  Leptorhynchoides thecatus isolate Withbass2 cy...  73.294
# 2   hsym_cne_10568  Pomphorhynchus tereticollis isolate Ouche mito...  81.295
# 3   hsym_cne_10568  Pomphorhynchus tereticollis isolate Straslund ...  80.576
# 4   hsym_cne_10568  Pomphorhynchus tereticollis isolate Ida mitoch...  79.286
#
#    length        evalue query_phylum   target_phylum
# 0     105  1.390000e-16     mollusca        nematoda
# 1     105  1.390000e-16     mollusca        nematoda
# 2     105  1.390000e-16     mollusca        nematoda
# 3      53  3.020000e-13     mollusca        nematoda
# 4      53  1.400000e-11     mollusca        nematoda
# ..    ...           ...          ...             ...
# 0     449  2.510000e-32     cnidaria  acanthocephala
# 1     337  3.270000e-26     cnidaria  acanthocephala
# 2     139  4.230000e-25     cnidaria  acanthocephala
# 3     139  1.970000e-23     cnidaria  acanthocephala
# 4     140  4.260000e-20     cnidaria  acanthocephala
#
# [25262566 rows x 7 columns]

# %% [markdown]
# ### Count how many unique CNEs have a match to each phylum

# %%
no_dup_df = filtered_df.drop_duplicates(['cne_id', 'query_phylum', 'target_phylum'])

# %%
phylum_count_df = cne_count_df[['phylum', 'cne_count']].groupby('phylum').sum().reset_index().\
    rename({'phylum':'query_phylum', 'cne_count':'phylum_cne_count'}, axis=1)
phylum_count_df
# Out:
#   query_phylum  phylum_cne_count
# 0   arthropoda            124309
# 1     cnidaria            325463
# 2     mollusca            375451

# %%
blast_hit_count_df = no_dup_df[['cne_id', 'query_phylum', 'target_phylum']].groupby(['query_phylum', 'target_phylum' ]).count().\
    reset_index().rename({'cne_id': 'cne_count'}, axis=1)
blast_hit_count_df = blast_hit_count_df.merge(phylum_count_df)
blast_hit_count_df['pct_cnes'] = 100 *blast_hit_count_df['cne_count'] / blast_hit_count_df['phylum_cne_count']

# %%
blast_hit_count_df
# Out:
#    query_phylum    target_phylum  cne_count  phylum_cne_count   pct_cnes
# 0    arthropoda   acanthocephala         19            124309   0.015284
# 1    arthropoda         annelida       2910            124309   2.340941
# 2    arthropoda       arthropoda      75380            124309  60.639214
# 3    arthropoda      brachiopoda        422            124309   0.339477
# 4    arthropoda          bryozoa       1902            124309   1.530058
# ..          ...              ...        ...               ...        ...
# 63     mollusca         porifera         37            375451   0.009855
# 64     mollusca       priapulida        101            375451   0.026901
# 65     mollusca         rotifera        492            375451   0.131042
# 66     mollusca       tardigrada          6            375451   0.001598
# 67     mollusca  xenacoelomorpha         14            375451   0.003729
#
# [68 rows x 5 columns]

# %% [markdown]
# ### Sort data frame to arrange heatmap according to phylogeny

# %%
sorter = ['ctenophora', 'placozoa', 'porifera', 'cnidaria', 'xenacoelomorpha', 'priapulida', 'nematoda', 
          'arthropoda', 'tardigrada', 'onychophora', 'rotifera', 'acanthocephala', 'mollusca', 'annelida', 'nemertea',
          'dicyemida', 'orthonectida','platyhelminthes', 'phoronida', 'brachiopoda', 'bryozoa', 'echinodermata', 
          'hemichordata', 'chordata']

# %%
blast_hit_count_df.target_phylum = blast_hit_count_df.target_phylum.astype("category")
blast_hit_count_df.target_phylum.cat.set_categories(sorter, inplace=True)
blast_hit_count_df = blast_hit_count_df.sort_values(["target_phylum"])
blast_hit_count_df
# Out:
#    query_phylum target_phylum  cne_count  phylum_cne_count  pct_cnes
# 31     cnidaria    ctenophora          8            325463  0.002458
# 7    arthropoda    ctenophora          7            124309  0.005631
# 53     mollusca    ctenophora          8            375451  0.002131
# 39     cnidaria      placozoa         11            325463  0.003380
# 61     mollusca      placozoa          6            375451  0.001598
# ..          ...           ...        ...               ...       ...
# 10   arthropoda  hemichordata         70            124309  0.056311
# 34     cnidaria  hemichordata         25            325463  0.007681
# 5    arthropoda      chordata       8564            124309  6.889284
# 29     cnidaria      chordata       1146            325463  0.352114
# 51     mollusca      chordata       8529            375451  2.271668
#
# [68 rows x 5 columns]

# %% [markdown]
# #### Write to file for plotting in R

# %%
blast_hit_count_df.to_csv('blast_hit_counts.tsv', sep="\t", index=False)

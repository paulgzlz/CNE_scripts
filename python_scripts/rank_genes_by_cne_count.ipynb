# %% [markdown]
# ### Goal
#
# Rank genes according to number of associated CNEs and annotate. CNEs were associated with their closest gene in the genome with find_closest_gene.py
#
# ### Input
#
# - closest_gene_counts_by_node.tsv: number of closest CNEs for each gene, generated with find_closest_gene.py
# - GFF annotations (converted to gffutils databases)
# - directories of proteome annotations (diamond blastp, pannzer, interproscan)
# - gene_IPR_dict.pickle: dictionary of protein domains for each gene, generated with find_closest_gene.py
# - gene_protein_dict.pickle : dictionary of gene-protein IDs, generated with find_closest_gene.py
# - all_IPR_desc.tsv: Interpro protein domain descriptions (retrieve with overrep_domains_closest_gene.py)
# - summary_by_sp.tsv: output of overrep_domains_closest_gene.py
#
# ### Output
#
# - species + "_ranked_genes.tsv": annotated list of all genes with more CNEs than average, ranked by number of associated CNEs
# - species + "_immuno_ranked.tsv: idem, with immunoglobulin-containing genes only
# - species + "_homeo_ranked.tsv: idem, with homeodomain-containing genes only
# - species + "_TF_ranked.tsv: idem, with other transcription factor domainss only

# %%
import pandas as pd
import glob
import pickle
import os
import gffutils

# %%
cne_counts_file = "../find_closest_gene/new_parse_gff/closest_gene_counts_by_node.tsv" 
cne_counts = pd.read_csv(cne_counts_file, sep="\t")
cne_counts
# Out:
#        species               gene  closest_cne_count      cne_node
# 0         spis  gene-LOC111326177                  2  hexacorallia
# 1         spis  gene-LOC111327133                  1  hexacorallia
# 2         spis  gene-LOC111328643                  1  hexacorallia
# 3         spis  gene-LOC111331958                  1  hexacorallia
# 4         spis  gene-LOC111325339                  1  hexacorallia
# ...        ...                ...                ...           ...
# 138947    nvec    gene-LOC5521942                  1     ambiguous
# 138948    nvec    gene-LOC5521953                  1     ambiguous
# 138949    nvec    gene-LOC5522147                  2     ambiguous
# 138950    nvec  gene-LOC116604813                  1     ambiguous
# 138951    nvec    gene-LOC5522361                  1     ambiguous
#
# [138952 rows x 4 columns]

# %%
orig_annot_dir = "../gff_db_files/"

# %%
annotations_dir = "../proteome_annotations/"
interpro_dir ="../proteome_annotations/interpro_files/"

# %%
gene_IPR_file = "../find_closest_gene/new_parse_gff/gene_IPR_dict.pickle"

# %%
with open(gene_IPR_file, 'rb') as handle:
    gene_IPR_dict = pickle.load(handle)

# %%
gene_IPR_dict
# Out:
# {'aaur': {'scaffold1.g1': [],
#   'scaffold1.g2': [],
#   'scaffold1.g3': ['IPR023179', 'IPR027417', 'IPR006073'],
#   'scaffold1.g4': [],
#   'scaffold1.g5': ['IPR011992',
#    'IPR015153',
#    'IPR015154',
#    'IPR015154',
#    'IPR000433',
#    'IPR015153',
#    'IPR011992',
#    'IPR043145',
#    'IPR015154',
#    'IPR015153',
#    'IPR011992'],
#   'scaffold1.g6': ['IPR036020', 'IPR001202'],
#   'scaffold1.g7': [],
#   'scaffold1.g8': [],
#   'scaffold1.g9': [],
#   'scaffold1.g10': ['IPR001680',
#    'IPR019775',
#    'IPR036322',
#    'IPR036322',
#    'IPR001680',
#    'IPR019775'],
#   'scaffold1.g11': ['IPR036322'],
#   'scaffold1.g12': [],
#   'scaffold1.g13': ['IPR011598', 'IPR036638', 'IPR011598', 'IPR036638'],
#   'scaffold1.g14': [],
#   'scaffold1.g15': ['IPR007808', 'IPR038567'],
#   'scaffold1.g16': [],
#   'scaffold1.g17': [],
#   'scaffold1.g18': [],
#   'scaffold1.g19': [],
#   'scaffold1.g20': ['IPR038187', 'IPR039370', 'IPR002715'],
#   'scaffold1.g21': ['IPR018247', 'IPR011992'],
#   'scaffold1.g22': [],
#   'scaffold1.g23': [],
#   'scaffold1.g24': [],
#   'scaffold1.g25': ['IPR018247',
#    'IPR005123',
#    'IPR002048',
#    'IPR011992',
#    'IPR006620'],
#   'scaffold1.g26': [],
#   'scaffold1.g27': ['IPR004878'],
#   'scaffold1.g28': [],
#   'scaffold1.g29': ['IPR000477'],
#   'scaffold1.g30': ['IPR041677',
#    'IPR027417',
#    'IPR027417',
#    'IPR041677',
#    'IPR041679',
#    'IPR041679'],
#   'scaffold1.g31': ['IPR002172', 'IPR023415', 'IPR036055'],
#   'scaffold1.g32': [],
#   'scaffold1.g33': [],
#   'scaffold1.g34': [],
#   'scaffold1.g35': ['IPR040040', 'IPR019460', 'IPR019460', 'IPR040040'],
#   'scaffold1.g36': [],
#   'scaffold1.g37': [],
#   'scaffold1.g38': [],
#   'scaffold1.g39': ['IPR040040'],
#   'scaffold1.g40': [],
#   'scaffold1.g41': ['IPR027359', 'IPR005821', 'IPR028823'],
#   'scaffold1.g42': ['IPR013176'],
#   'scaffold1.g43': [],
#   'scaffold1.g44': [],
#   'scaffold1.g45': ['IPR000203',
#    'IPR001879',
#    'IPR013783',
#    'IPR003961',
#    'IPR032471',
#    'IPR000832',
#    'IPR001881',
#    'IPR000152',
#    'IPR018097',
#    'IPR036445',
#    'IPR017981',
#    'IPR036116',
#    'IPR031240',
#    'IPR013032',
#    'IPR013320',
#    'IPR000742',
#    'IPR013783',
#    'IPR000832',
#    'IPR013320',
#    'IPR003961',
#    'IPR000152',
#    'IPR036116',
#    'IPR017981',
#    'IPR000203',
#    'IPR001881',
#    'IPR001879',
#    'IPR000742',
#    'IPR032471',
#    'IPR036445',
#    'IPR013032',
#    'IPR031240',
#    'IPR018097'],
#   'scaffold1.g46': [],
#   'scaffold1.g47': ['IPR038558', 'IPR032396', 'IPR041513'],
#   'scaffold1.g48': ['IPR036179',
#    'IPR003599',
#    'IPR002181',
#    'IPR007110',
#    'IPR013783',
#    'IPR013098',
#    'IPR036056',
#    'IPR008160',
#    'IPR003598'],
#   'scaffold1.g49': ['IPR003582',
#    'IPR007671',
#    'IPR037941',
#    'IPR003582',
#    'IPR037941',
#    'IPR007671'],
#   'scaffold1.g50': ['IPR036249', 'IPR007671', 'IPR037941'],
#   'scaffold1.g51': ['IPR003582', 'IPR007671', 'IPR037941'],
#   'scaffold1.g52': ['IPR020793'],
#   'scaffold1.g53': ['IPR010345', 'IPR029034'],
#   'scaffold1.g54': ['IPR010345', 'IPR029034'],
#   'scaffold1.g55': ['IPR003959',
#    'IPR015163',
#    'IPR020793',
#    'IPR003593',
#    'IPR041083',
#    'IPR027417',
#    'IPR003959',
#    'IPR020793',
#    'IPR041083',
#    'IPR003593',
#    'IPR027417'],
#   'scaffold1.g56': [],
#   'scaffold1.g57': ['IPR004853', 'IPR004853'],
#   'scaffold1.g58': [],
#   'scaffold1.g59': ['IPR007829', 'IPR007829'],
#   'scaffold1.g60': ['IPR000686'],
#   'scaffold1.g61': ['IPR006759'],
#   'scaffold1.g62': ['IPR008979', 'IPR006759'],
#   'scaffold1.g63': ['IPR037941', 'IPR007671'],
#   'scaffold1.g64': [],
#   'scaffold1.g65': ['IPR041698', 'IPR029063'],
#   'scaffold1.g66': [],
#   'scaffold1.g67': [],
#   'scaffold1.g68': ['IPR007262'],
#   'scaffold1.g69': [],
#   'scaffold1.g70': ['IPR000719', 'IPR034368', 'IPR011009', 'IPR008271'],
#   'scaffold1.g71': [],
#   'scaffold1.g72': [],
#   'scaffold1.g73': [],
#   'scaffold1.g74': ['IPR001810', 'IPR036047', 'IPR006689', 'IPR039588'],
#   'scaffold1.g75': ['IPR019734', 'IPR011990', 'IPR039856', 'IPR013026'],
#   'scaffold1.g76': ['IPR036259', 'IPR020846', 'IPR011701'],
#   'scaffold1.g77': [],
#   'scaffold1.g78': [],
#   'scaffold1.g79': ['IPR033031',
#    'IPR016024',
#    'IPR026003',
#    'IPR033031',
#    'IPR016024',
#    'IPR026003',
#    'IPR033031',
#    'IPR016024',
#    'IPR026003'],
#   'scaffold1.g80': ['IPR024986', 'IPR016024', 'IPR033031'],
#   'scaffold1.g81': [],
#   'scaffold1.g82': [],
#   'scaffold1.g83': ['IPR036187',
#    'IPR011184',
#    'IPR007696',
#    'IPR000432',
#    'IPR027417',
#    'IPR017261',
#    'IPR007696',
#    'IPR000432',
#    'IPR036187',
#    'IPR027417'],
#   'scaffold1.g84': [],
#   'scaffold1.g85': ['IPR000432'],
#   'scaffold1.g86': [],
#   'scaffold1.g87': [],
#   'scaffold1.g88': [],
#   'scaffold1.g89': ['IPR001810', 'IPR036047'],
#   'scaffold1.g90': [],
#   'scaffold1.g91': [],
#   'scaffold1.g92': [],
#   'scaffold1.g93': ['IPR039261',
#    'IPR001709',
#    'IPR001433',
#    'IPR001834',
#    'IPR008333',
#    'IPR017927',
#    'IPR017938',
#    'IPR019180'],
#   'scaffold1.g94': ['IPR016024', 'IPR024372'],
#   'scaffold1.g95': ['IPR001878',
#    'IPR016024',
#    'IPR005312',
#    'IPR008737',
#    'IPR024372',
#    'IPR011989'],
#   'scaffold1.g96': [],
#   'scaffold1.g97': ['IPR011989', 'IPR024372', 'IPR016024'],
#   'scaffold1.g98': ['IPR000210',
#    'IPR015915',
#    'IPR011333',
#    'IPR011705',
#    'IPR011043',
#    'IPR006652',
#    'IPR017096'],
#   'scaffold1.g99': ['IPR019775',
#    'IPR001680',
#    'IPR036322',
#    'IPR015943',
#    'IPR017986',
#    'IPR033010',
#    'IPR024977'],
#   'scaffold1.g100': ['IPR036390', 'IPR000418', 'IPR033077', 'IPR036388'],
#   'scaffold1.g101': ['IPR039477', 'IPR029044', 'IPR004139'],
#   'scaffold1.g102': ['IPR006020',
#    'IPR011993',
#    'IPR028761',
#    'IPR028761',
#    'IPR006020',
#    'IPR011993'],
#   'scaffold1.g103': ['IPR000198',
#    'IPR036034',
#    'IPR001478',
#    'IPR008936',
#    'IPR035892'],
#   'scaffold1.g104': [],
#   'scaffold1.g105': [],
#   'scaffold1.g106': [],
#   'scaffold1.g107': [],
#   'scaffold1.g108': [],
#   'scaffold1.g109': ['IPR018379'],
#   'scaffold2.g1': [],
#   'scaffold2.g2': ['IPR035967',
#    'IPR000061',
#    'IPR022030',
#    'IPR029071',
#    'IPR000626',
#    'IPR000061',
#    'IPR029071',
#    'IPR035967',
#    'IPR000626',
#    'IPR022030',
#    'IPR000061',
#    'IPR000626',
#    'IPR029071',
#    'IPR035967',
#    'IPR022030',
#    'IPR000061',
#    'IPR000626',
#    'IPR029071',
#    'IPR035967',
#    'IPR022030'],
#   'scaffold2.g3': ['IPR036597', 'IPR040198', 'IPR011990', 'IPR003812'],
#   'scaffold2.g4': ['IPR003100',
#    'IPR036397',
#    'IPR003165',
#    'IPR012337',
#    'IPR036085',
#    'IPR003100',
#    'IPR036397',
#    'IPR003165',
#    'IPR012337',
#    'IPR036085'],
#   'scaffold2.g5': ['IPR008160'],
#   'scaffold2.g6': ['IPR008160', 'IPR008160'],
#   'scaffold2.g7': ['IPR015495',
#    'IPR001005',
#    'IPR017930',
#    'IPR009057',
#    'IPR015395',
#    'IPR015495',
#    'IPR001005',
#    'IPR017930',
#    'IPR009057',
#    'IPR015395'],
#   'scaffold2.g8': [],
#   'scaffold2.g9': ['IPR009836'],
#   'scaffold2.g10': [],
#   'scaffold2.g11': ['IPR000998',
#    'IPR002172',
#    'IPR023415',
#    'IPR036055',
#    'IPR013320',
#    'IPR013320',
#    'IPR036055',
#    'IPR002172',
#    'IPR000998',
#    'IPR023415'],
#   'scaffold2.g12': ['IPR007940'],
#   'scaffold2.g13': [],
#   'scaffold2.g14': ['IPR000859', 'IPR035914'],
#   'scaffold2.g15': [],
#   'scaffold2.g16': [],
#   'scaffold2.g17': [],
#   'scaffold2.g18': [],
#   'scaffold2.g19': ['IPR013320'],
#   'scaffold2.g20': ['IPR013087', 'IPR036236'],
#   'scaffold2.g21': [],
#   'scaffold2.g22': ['IPR011993',
#    'IPR004182',
#    'IPR000195',
#    'IPR036014',
#    'IPR002048',
#    'IPR018247',
#    'IPR036017',
#    'IPR011992',
#    'IPR035969',
#    'IPR002048',
#    'IPR018247',
#    'IPR036014',
#    'IPR036017',
#    'IPR035969',
#    'IPR004182',
#    'IPR011992',
#    'IPR011993',
#    'IPR000195'],
#   'scaffold2.g23': ['IPR020683',
#    'IPR036770',
#    'IPR002110',
#    'IPR000719',
#    'IPR008271',
#    'IPR011009'],
#   'scaffold2.g24': ['IPR000109'],
#   'scaffold2.g25': ['IPR026003',
#    'IPR016024',
#    'IPR032682',
#    'IPR011989',
#    'IPR021133',
#    'IPR026971',
#    'IPR026003',
#    'IPR011989',
#    'IPR026971',
#    'IPR016024',
#    'IPR021133',
#    'IPR032682'],
#   'scaffold2.g26': ['IPR023409', 'IPR023410', 'IPR000308', 'IPR036815'],
#   'scaffold2.g27': [],
#   'scaffold2.g28': ['IPR019497', 'IPR027267'],
#   'scaffold2.g29': ['IPR036871', 'IPR019497', 'IPR027267', 'IPR001683'],
#   'scaffold2.g30': ['IPR001452', 'IPR036028', 'IPR036871'],
#   'scaffold2.g31': ['IPR036397',
#    'IPR013520',
#    'IPR034920',
#    'IPR012337',
#    'IPR037431'],
#   'scaffold2.g32': ['IPR012445', 'IPR012445', 'IPR012445'],
#   'scaffold2.g33': ['IPR017452', 'IPR000276'],
#   'scaffold2.g34': ['IPR041973',
#    'IPR039659',
#    'IPR005100',
#    'IPR014722',
#    'IPR008991',
#    'IPR036735',
#    'IPR041976',
#    'IPR041977',
#    'IPR039385',
#    'IPR041978',
#    'IPR005824',
#    'IPR022581',
#    'IPR041975'],
#   'scaffold2.g35': [],
#   'scaffold2.g36': [],
#   'scaffold2.g37': ['IPR013087', 'IPR036236'],
#   'scaffold2.g38': [],
#   'scaffold2.g39': ['IPR001806',
#    'IPR027417',
#    'IPR005225',
#    'IPR001806',
#    'IPR027417',
#    'IPR005225'],
#   'scaffold2.g40': ['IPR005225',
#    'IPR002048',
#    'IPR018247',
#    'IPR027417',
#    'IPR011992',
#    'IPR001806',
#    'IPR005225',
#    'IPR002048',
#    'IPR018247',
#    'IPR027417',
#    'IPR011992',
#    'IPR001806',
#    'IPR027417',
#    'IPR001806',
#    'IPR002048',
#    'IPR005225',
#    'IPR018247',
#    'IPR011992',
#    'IPR001806',
#    'IPR027417'],
#   'scaffold2.g41': ['IPR006578'],
#   'scaffold2.g42': ['IPR036910', 'IPR009071'],
#   'scaffold2.g43': ['IPR027640',
#    'IPR001752',
#    'IPR027417',
#    'IPR019821',
#    'IPR015943',
#    'IPR001680',
#    'IPR036961',
#    'IPR036322',
#    'IPR019775',
#    'IPR017986',
#    'IPR015943',
#    'IPR027640',
#    'IPR001680',
#    'IPR017986',
#    'IPR020472',
#    'IPR036322',
#    'IPR019775',
#    'IPR019775',
#    'IPR001680',
#    'IPR020472',
#    'IPR011047',
#    'IPR015943',
#    'IPR027640',
#    'IPR017986',
#    'IPR017986',
#    'IPR001680',
#    'IPR020472',
#    'IPR027640',
#    'IPR015943',
#    'IPR019775',
#    'IPR011047',
#    'IPR001680',
#    'IPR027640',
#    'IPR019775',
#    'IPR020472',
#    'IPR011047',
#    'IPR017986',
#    'IPR015943',
#    'IPR027417',
#    'IPR001752',
#    'IPR027640',
#    'IPR019821',
#    'IPR036961'],
#   'scaffold2.g44': ['IPR001752', 'IPR027640', 'IPR036961', 'IPR027417'],
#   'scaffold2.g45': ['IPR003347', 'IPR003347'],
#   'scaffold2.g46': ['IPR031481', 'IPR038577', 'IPR001503'],
#   'scaffold2.g47': [],
#   'scaffold2.g48': [],
#   'scaffold2.g49': ['IPR041667', 'IPR003347'],
#   'scaffold2.g50': [],
#   'scaffold2.g51': ['IPR020683', 'IPR002110', 'IPR036770'],
#   'scaffold2.g52': ['IPR032443', 'IPR013083', 'IPR001841', 'IPR017907'],
#   'scaffold2.g53': [],
#   'scaffold2.g54': ['IPR000719', 'IPR011009'],
#   'scaffold2.g55': ['IPR000719', 'IPR011009'],
#   'scaffold2.g56': ['IPR029672', 'IPR029672', 'IPR029672'],
#   'scaffold2.g57': ['IPR000439', 'IPR020925', 'IPR024794', 'IPR012678'],
#   'scaffold2.g58': ['IPR005822', 'IPR036899', 'IPR005823'],
#   'scaffold2.g59': ['IPR023235', 'IPR023235'],
#   'scaffold2.g60': ['IPR004790',
#    'IPR024084',
#    'IPR019818',
#    'IPR004790',
#    'IPR024084',
#    'IPR019818',
#    'IPR024084',
#    'IPR004790',
#    'IPR019818',
#    'IPR024084',
#    'IPR004790'],
#   'scaffold2.g61': [],
#   'scaffold2.g62': ['IPR000058', 'IPR035896'],
#   'scaffold2.g63': [],
#   'scaffold2.g64': [],
#   'scaffold2.g65': [],
#   'scaffold2.g66': [],
#   'scaffold2.g67': [],
#   'scaffold2.g68': [],
#   'scaffold2.g69': [],
#   'scaffold2.g70': ['IPR008979', 'IPR000421', 'IPR006585'],
#   'scaffold2.g71': [],
#   'scaffold2.g72': [],
#   'scaffold2.g73': [],
#   'scaffold2.g74': [],
#   'scaffold2.g75': [],
#   'scaffold2.g76': [],
#   'scaffold2.g77': [],
#   'scaffold2.g78': [],
#   'scaffold2.g79': [],
#   'scaffold2.g80': [],
#   'scaffold2.g81': [],
#   'scaffold2.g82': [],
#   'scaffold2.g83': [],
#   'scaffold2.g84': [],
#   'scaffold2.g85': [],
#   'scaffold2.g86': [],
#   'scaffold2.g87': [],
#   'scaffold2.g88': [],
#   'scaffold2.g89': [],
#   'scaffold2.g90': [],
#   'scaffold2.g91': [],
#   'scaffold2.g92': [],
#   'scaffold3.g1': ['IPR036770',
#    'IPR001164',
#    'IPR002110',
#    'IPR020683',
#    'IPR013724',
#    'IPR037278',
#    'IPR032352',
#    'IPR038508',
#    'IPR032352',
#    'IPR001164',
#    'IPR020683',
#    'IPR002110',
#    'IPR038508',
#    'IPR013724',
#    'IPR036770',
#    'IPR037278'],
#   'scaffold3.g2': ['IPR035445', 'IPR039905', 'IPR003169'],
#   'scaffold3.g3': ['IPR026686'],
#   'scaffold3.g4': [],
#   'scaffold3.g5': [],
#   'scaffold3.g6': ['IPR034751', 'IPR039058', 'IPR004910'],
#   'scaffold3.g7': ['IPR001650',
#    'IPR002464',
#    'IPR011545',
#    'IPR007502',
#    'IPR014001',
#    'IPR011709',
#    'IPR027417',
#    'IPR003593',
#    'IPR001650',
#    'IPR002464',
#    'IPR014001',
#    'IPR011709',
#    'IPR007502',
#    'IPR003593',
#    'IPR011545',
#    'IPR027417'],
#   'scaffold3.g8': ['IPR001611', 'IPR032675'],
#   'scaffold3.g9': [],
#   'scaffold3.g10': [],
#   'scaffold3.g11': [],
#   'scaffold3.g12': [],
#   'scaffold3.g13': [],
#   'scaffold3.g14': [],
#   'scaffold3.g15': ['IPR029681', 'IPR029681'],
#   'scaffold3.g16': [],
#   'scaffold3.g17': ['IPR040185', 'IPR012486', 'IPR021819'],
#   'scaffold3.g18': [],
#   'scaffold3.g19': [],
#   'scaffold3.g20': ['IPR011598', 'IPR036638'],
#   'scaffold3.g21': ['IPR002110',
#    'IPR020683',
#    'IPR036770',
#    'IPR025874',
#    'IPR036280'],
#   'scaffold3.g22': ['IPR002877', 'IPR000467', 'IPR025816', 'IPR030376'],
#   'scaffold3.g23': ['IPR030376', 'IPR001202'],
#   'scaffold3.g24': [],
#   'scaffold3.g25': ['IPR001873'],
#   'scaffold3.g26': [],
#   'scaffold3.g27': [],
#   'scaffold3.g28': [],
#   'scaffold3.g29': [],
#   'scaffold3.g30': ['IPR013761', 'IPR006020', 'IPR011993', 'IPR001660'],
#   'scaffold3.g31': ['IPR020683', 'IPR002110', 'IPR036770', 'IPR033636'],
#   'scaffold3.g32': ['IPR041643', 'IPR041643', 'IPR036236', 'IPR013087'],
#   'scaffold3.g33': ['IPR038968', 'IPR038968'],
#   'scaffold3.g34': [],
#   'scaffold3.g35': ['IPR036259'],
#   'scaffold3.g36': ['IPR036259', 'IPR011701'],
#   'scaffold3.g37': ['IPR011356', 'IPR000819'],
#   'scaffold3.g38': ['IPR008283', 'IPR011356', 'IPR008283', 'IPR011356'],
#   'scaffold3.g39': [],
#   'scaffold3.g40': [],
#   'scaffold3.g41': ['IPR026682'],
#   'scaffold3.g42': [],
#   'scaffold3.g43': [],
#   'scaffold3.g44': [],
#   'scaffold3.g45': ['IPR008974',
#    'IPR017907',
#    'IPR003613',
#    'IPR013083',
#    'IPR001841',
#    'IPR002083',
#    'IPR012227',
#    'IPR043211',
#    'IPR001293'],
#   'scaffold3.g46': [],
#   'scaffold3.g47': ['IPR027359', 'IPR003968', 'IPR028325', 'IPR005821'],
#   'scaffold3.g48': ['IPR003131',
#    'IPR000210',
#    'IPR028325',
#    'IPR003974',
#    'IPR011333',
#    'IPR000210',
#    'IPR003974',
#    'IPR011333',
#    'IPR003131',
#    'IPR028325',
#    'IPR028325',
#    'IPR003974',
#    'IPR000210',
#    'IPR003131',
#    'IPR011333'],
#   'scaffold3.g49': [],
#   'scaffold3.g50': [],
#   'scaffold3.g51': ['IPR019787',
#    'IPR019786',
#    'IPR036427',
#    'IPR011011',
#    'IPR001965',
#    'IPR001841',
#    'IPR019787',
#    'IPR019786',
#    'IPR036427',
#    'IPR011011',
#    'IPR001965',
#    'IPR001841',
#    'IPR019787',
#    'IPR036427',
#    'IPR001965',
#    'IPR001841',
#    'IPR011011',
#    'IPR019786'],
#   'scaffold3.g52': [],
#   'scaffold3.g53': [],
#   'scaffold3.g54': [],
#   'scaffold3.g55': ['IPR017365',
#    'IPR001478',
#    'IPR036034',
#    'IPR014775',
#    'IPR004172',
#    'IPR036892',
#    'IPR017365',
#    'IPR001478',
#    'IPR014775',
#    'IPR036034',
#    'IPR004172',
#    'IPR036892'],
#   'scaffold3.g56': ['IPR000301', 'IPR008952', 'IPR018499', 'IPR018503'],
#   'scaffold3.g57': ['IPR008952', 'IPR018499', 'IPR018503', 'IPR000301'],
#   'scaffold3.g58': [],
#   'scaffold3.g59': ['IPR000301',
#    'IPR018499',
#    'IPR008952',
#    'IPR008952',
#    'IPR000301',
#    'IPR018499'],
#   'scaffold3.g60': [],
#   'scaffold3.g61': [],
#   'scaffold3.g62': ['IPR004254'],
#   'scaffold3.g63': ['IPR004254', 'IPR004254', 'IPR004254'],
#   'scaffold3.g64': [],
#   'scaffold3.g65': [],
#   'scaffold3.g66': [],
#   'scaffold3.g67': ['IPR006202',
#    'IPR006201',
#    'IPR036734',
#    'IPR002394',
#    'IPR006029',
#    'IPR018000',
#    'IPR036719'],
#   'scaffold3.g68': ['IPR002394',
#    'IPR006201',
#    'IPR006029',
#    'IPR036734',
#    'IPR006202',
#    'IPR018000',
#    'IPR036719'],
#   'scaffold3.g69': [],
#   'scaffold3.g70': [],
#   'scaffold3.g71': [],
#   'scaffold3.g72': [],
#   'scaffold3.g73': [],
#   'scaffold3.g74': [],
#   'scaffold3.g75': [],
#   'scaffold3.g76': ['IPR016024', 'IPR011989'],
#   'scaffold3.g77': [],
#   'scaffold3.g78': [],
#   'scaffold3.g79': ['IPR013087', 'IPR036236'],
#   'scaffold3.g80': [],
#   'scaffold3.g81': ['IPR036465', 'IPR005161'],
#   'scaffold3.g82': [],
#   'scaffold3.g83': ['IPR020635',
#    'IPR001245',
#    'IPR008266',
#    'IPR011009',
#    'IPR017441',
#    'IPR000719'],
#   'scaffold3.g84': ['IPR027417', 'IPR001806'],
#   'scaffold4.g1': ['IPR001006', 'IPR005123', 'IPR029044', 'IPR006620'],
#   'scaffold4.g2': [],
#   'scaffold4.g3': [],
#   'scaffold4.g4': ['IPR017452', 'IPR000276'],
#   'scaffold4.g5': ['IPR000276', 'IPR017452'],
#   'scaffold4.g6': [],
#   'scaffold4.g7': ['IPR002130',
#    'IPR029000',
#    'IPR020892',
#    'IPR024936',
#    'IPR029000',
#    'IPR002130',
#    'IPR024936',
#    'IPR020892'],
#   'scaffold4.g8': [],
#   'scaffold4.g9': ['IPR013083',
#    'IPR000953',
#    'IPR019786',
#    'IPR011011',
#    'IPR001965',
#    'IPR019787',
#    'IPR016197',
#    'IPR023780'],
#   'scaffold4.g10': [],
#   'scaffold4.g11': ['IPR028725', 'IPR009462', 'IPR009462', 'IPR028725'],
#   'scaffold4.g12': [],
#   'scaffold4.g13': [],
#   'scaffold4.g14': ['IPR035246',
#    'IPR030668',
#    'IPR037163',
#    'IPR030374',
#    'IPR029063',
#    'IPR001045',
#    'IPR030373'],
#   'scaffold4.g15': ['IPR030381', 'IPR027094', 'IPR027088'],
#   'scaffold4.g16': [],
#   'scaffold4.g17': ['IPR042421', 'IPR035437', 'IPR042421', 'IPR035437'],
#   'scaffold4.g18': [],
#   'scaffold4.g19': [],
#   'scaffold4.g20': ['IPR036915', 'IPR013763', 'IPR043198'],
#   'scaffold4.g21': [],
#   'scaffold4.g22': ['IPR031476', 'IPR031476'],
#   'scaffold4.g23': ['IPR019775',
#    'IPR001680',
#    'IPR016346',
#    'IPR017986',
#    'IPR036322',
#    'IPR001632',
#    'IPR020472',
#    'IPR015943'],
#   'scaffold4.g24': ['IPR005225', 'IPR019009', 'IPR027417'],
#   'scaffold4.g25': ['IPR019009', 'IPR027417'],
#   'scaffold4.g26': [],
#   'scaffold4.g27': ['IPR001611', 'IPR032675'],
#   'scaffold4.g28': [],
#   'scaffold4.g29': ['IPR002293', 'IPR029485', 'IPR029485', 'IPR002293'],
#   'scaffold4.g30': ['IPR041667', 'IPR003347'],
#   'scaffold4.g31': ['IPR008365', 'IPR017452', 'IPR000276'],
#   'scaffold4.g32': [],
#   'scaffold4.g33': ['IPR000718',
#    'IPR018497',
#    'IPR008753',
#    'IPR024079',
#    'IPR042089',
#    'IPR024079',
#    'IPR000718',
#    'IPR018497',
#    'IPR042089',
#    'IPR008753'],
#   'scaffold4.g34': [],
#   'scaffold4.g35': [],
#   'scaffold4.g36': ['IPR001841',
#    'IPR017066',
#    'IPR013083',
#    'IPR013083',
#    'IPR001841'],
#   'scaffold4.g37': [],
#   'scaffold4.g38': ['IPR035992',
#    'IPR000421',
#    'IPR008979',
#    'IPR039477',
#    'IPR000772'],
#   'scaffold4.g39': ['IPR036249',
#    'IPR041269',
#    'IPR039798',
#    'IPR036249',
#    'IPR039798',
#    'IPR041269',
#    'IPR040986',
#    'IPR042568'],
#   'scaffold4.g40': [],
#   'scaffold4.g41': ['IPR001680',
#    'IPR017986',
#    'IPR019775',
#    'IPR015943',
#    'IPR020472',
#    'IPR036322',
#    'IPR037866'],
#   'scaffold4.g42': [],
#   'scaffold4.g43': [],
#   'scaffold4.g44': [],
#   'scaffold4.g45': [],
#   'scaffold4.g46': ['IPR036383',
#    'IPR000884',
#    'IPR035914',
#    'IPR041645',
#    'IPR000859',
#    'IPR013273',
#    'IPR024079',
#    'IPR001590'],
#   'scaffold4.g47': ['IPR002870', 'IPR002870', 'IPR002870'],
#   'scaffold4.g48': ['IPR000048', 'IPR042506'],
#   'scaffold4.g49': [],
#   'scaffold4.g50': ['IPR027005',
#    'IPR003342',
#    'IPR032421',
#    'IPR027005',
#    'IPR016093',
#    'IPR036300',
#    'IPR003342',
#    'IPR003342',
#    'IPR027005',
#    'IPR003342',
#    'IPR016093',
#    'IPR036300',
#    'IPR032421',
#    'IPR027005'],
#   'scaffold4.g51': [],
#   'scaffold4.g52': ['IPR036691'],
#   'scaffold4.g53': [],
#   'scaffold4.g54': [],
#   'scaffold4.g55': [],
#   'scaffold4.g56': ['IPR007603', 'IPR007603'],
#   'scaffold4.g57': ['IPR007603', 'IPR007603'],
#   'scaffold4.g58': ['IPR015422',
#    'IPR015421',
#    'IPR004839',
#    'IPR015424',
#    'IPR015424',
#    'IPR004839',
#    'IPR015422',
#    'IPR015421',
#    'IPR015422',
#    'IPR015424',
#    'IPR015421',
#    'IPR034614',
#    'IPR015422',
#    'IPR015421',
#    'IPR004839',
#    'IPR015424',
#    'IPR015422',
#    'IPR034612',
#    'IPR004839',
#    'IPR015421',
#    'IPR015424'],
#   'scaffold4.g59': ['IPR002398',
#    'IPR001309',
#    'IPR001875',
#    'IPR011029',
#    'IPR029030',
#    'IPR002138',
#    'IPR015917',
#    'IPR033139'],
#   'scaffold4.g60': ['IPR036683',
#    'IPR036884',
#    'IPR002346',
#    'IPR005107',
#    'IPR016166',
#    'IPR036318',
#    'IPR002888'],
#   'scaffold4.g61': ['IPR008274',
#    'IPR037165',
#    'IPR000674',
#    'IPR036856',
#    'IPR008274',
#    'IPR037165',
#    'IPR000674',
#    'IPR036856',
#    'IPR008274',
#    'IPR037165',
#    'IPR000674',
#    'IPR036856',
#    'IPR000674',
#    'IPR037165',
#    'IPR036856',
#    'IPR008274'],
#   'scaffold4.g62': ['IPR002110',
#    'IPR020683',
#    'IPR024862',
#    'IPR036770',
#    'IPR005821',
#    'IPR002110',
#    'IPR036770',
#    'IPR020683'],
#   'scaffold4.g63': ['IPR027417',
#    'IPR026983',
#    'IPR024317',
#    'IPR042228',
#    'IPR013602',
#    'IPR042222',
#    'IPR041589',
#    'IPR043157',
#    'IPR041466',
#    'IPR035699'],
#   'scaffold4.g64': ['IPR026983', 'IPR024743'],
#   'scaffold4.g65': [],
#   'scaffold4.g66': [],
#   'scaffold4.g67': [],
#   'scaffold4.g68': ['IPR005824', 'IPR014722', 'IPR008991'],
#   'scaffold4.g69': ['IPR038586', 'IPR005334'],
#   'scaffold4.g70': [],
#   'scaffold4.g71': [],
#   'scaffold4.g72': [],
#   'scaffold4.g73': [],
#   'scaffold4.g74': ['IPR035979', 'IPR000504', 'IPR012677'],
#   'scaffold4.g75': [],
#   'scaffold4.g76': [],
#   'scaffold4.g77': ['IPR000504', 'IPR012677', 'IPR035979'],
#   'scaffold4.g78': [],
#   'scaffold4.g79': ['IPR000477'],
#   'scaffold4.g80': ['IPR042497', 'IPR004244'],
#   'scaffold4.g81': ['IPR000477'],
#   'scaffold4.g82': [],
#   'scaffold4.g83': [],
#   'scaffold4.g84': [],
#   'scaffold4.g85': [],
#   'scaffold4.g86': [],
#   'scaffold5.g1': ['IPR011545', 'IPR014014', 'IPR027417'],
#   'scaffold5.g2': ['IPR011701', 'IPR020846', 'IPR036259'],
#   'scaffold5.g3': [],
#   'scaffold5.g4': ['IPR007271'],
#   'scaffold5.g5': [],
#   'scaffold5.g6': [],
#   'scaffold5.g7': [],
#   'scaffold5.g8': ['IPR012677', 'IPR005546', 'IPR000504', 'IPR035979'],
#   'scaffold5.g9': ['IPR000082',
#    'IPR000742',
#    'IPR000082',
#    'IPR000742',
#    'IPR000742',
#    'IPR000082'],
#   'scaffold5.g10': ['IPR033116',
#    'IPR036179',
#    'IPR000033',
#    'IPR001254',
#    'IPR000436',
#    'IPR003599',
#    'IPR003598',
#    'IPR011042',
#    'IPR007110',
#    'IPR018114',
#    'IPR009003',
#    'IPR035976',
#    'IPR013098',
#    'IPR013783',
#    'IPR018114',
#    'IPR003598',
#    'IPR001254',
#    'IPR000436',
#    'IPR000033',
#    'IPR035976',
#    'IPR000742',
#    'IPR009003',
#    'IPR009030',
#    'IPR033116',
#    'IPR036179',
#    'IPR003599',
#    'IPR011042',
#    'IPR013783',
#    'IPR013098',
#    'IPR007110',
#    'IPR033116',
#    'IPR036179',
#    'IPR000033',
#    'IPR001254',
#    'IPR000436',
#    'IPR003599',
#    'IPR003598',
#    'IPR011042',
#    'IPR007110',
#    'IPR018114',
#    'IPR009003',
#    'IPR035976',
#    'IPR013098',
#    'IPR013783'],
#   'scaffold5.g11': [],
#   'scaffold5.g12': [],
#   'scaffold5.g13': ['IPR010918',
#    'IPR004733',
#    'IPR036676',
#    'IPR004607',
#    'IPR002376',
#    'IPR036477',
#    'IPR001555'],
#   'scaffold5.g14': ['IPR036921',
#    'IPR020562',
#    'IPR011054',
#    'IPR000115',
#    'IPR016185',
#    'IPR020561',
#    'IPR037123',
#    'IPR020560',
#    'IPR013815',
#    'IPR020559',
#    'IPR011761'],
#   'scaffold5.g15': [],
#   'scaffold5.g16': ['IPR032675'],
#   'scaffold5.g17': ['IPR032675'],
#   'scaffold5.g18': ['IPR005607', 'IPR035925'],
#   'scaffold5.g19': [],
#   'scaffold5.g20': ['IPR036770',
#    'IPR002110',
#    'IPR020683',
#    'IPR036770',
#    'IPR002110',
#    'IPR020683'],
#   'scaffold5.g21': [],
#   'scaffold5.g22': [],
#   'scaffold5.g23': ['IPR001699',
#    'IPR008967',
#    'IPR036960',
#    'IPR002070',
#    'IPR018186',
#    'IPR001699',
#    'IPR008967',
#    'IPR036960',
#    'IPR001699',
#    'IPR018186',
#    'IPR036960',
#    'IPR008967',
#    'IPR001699',
#    'IPR008967',
#    'IPR018186',
#    'IPR036960'],
#   'scaffold5.g24': [],
#   'scaffold5.g25': [],
#   'scaffold5.g26': ['IPR003114', 'IPR003114', 'IPR003114'],
#   'scaffold5.g27': ['IPR011992',
#    'IPR035704',
#    'IPR001683',
#    'IPR000261',
#    'IPR028662',
#    'IPR036871'],
#   'scaffold5.g28': [],
#   'scaffold5.g29': [],
#   'scaffold5.g30': [],
#   'scaffold5.g31': ['IPR026120'],
#   'scaffold5.g32': ['IPR037663', 'IPR019372'],
#   'scaffold5.g33': [],
#   'scaffold5.g34': ['IPR038253', 'IPR034652', 'IPR026258', 'IPR011990'],
#   'scaffold5.g35': ['IPR007175'],
#   'scaffold5.g36': ['IPR036736', 'IPR009081', 'IPR003231', 'IPR006162'],
#   'scaffold5.g37': ['IPR013766', 'IPR036249'],
#   'scaffold5.g38': ['IPR036249', 'IPR013766'],
#   'scaffold5.g39': [],
#   'scaffold5.g40': [],
#   'scaffold5.g41': [],
#   'scaffold5.g42': [],
#   'scaffold5.g43': [],
#   'scaffold5.g44': ['IPR005024'],
#   'scaffold5.g45': [],
#   'scaffold5.g46': [],
#   'scaffold5.g47': ['IPR019135'],
#   'scaffold5.g48': [],
#   'scaffold5.g49': [],
#   'scaffold5.g50': ['IPR004092'],
#   'scaffold5.g51': [],
#   'scaffold5.g52': [],
#   'scaffold5.g53': ['IPR041198',
#    'IPR004152',
#    'IPR002014',
#    'IPR008942',
#    'IPR038425',
#    'IPR004152',
#    'IPR002014',
#    'IPR008942',
#    'IPR041198',
#    'IPR038425'],
#   'scaffold5.g54': ['IPR000276', 'IPR017452'],
#   'scaffold5.g55': ['IPR000276', 'IPR017452'],
#   'scaffold5.g56': [],
#   'scaffold5.g57': ['IPR001206',
#    'IPR016064',
#    'IPR002219',
#    'IPR017438',
#    'IPR037607',
#    'IPR000756'],
#   'scaffold5.g58': ['IPR005818', 'IPR036388', 'IPR005819', 'IPR036390'],
#   'scaffold5.g59': [],
#   'scaffold5.g60': ['IPR019775',
#    'IPR017986',
#    'IPR042626',
#    'IPR036322',
#    'IPR001680',
#    'IPR015943',
#    'IPR019775',
#    'IPR001680',
#    'IPR036322',
#    'IPR042626',
#    'IPR017986',
#    'IPR015943',
#    'IPR015943',
#    'IPR019775',
#    'IPR017986',
#    'IPR042626',
#    'IPR036322',
#    'IPR001680'],
#   'scaffold5.g61': [],
#   'scaffold5.g62': [],
#   'scaffold5.g63': [],
#   'scaffold5.g64': [],
#   'scaffold5.g65': ['IPR011993', 'IPR001849', 'IPR011993', 'IPR001849'],
#   'scaffold5.g66': ['IPR026705'],
#   'scaffold5.g67': ['IPR013122'],
#   'scaffold5.g68': ['IPR026705'],
#   'scaffold5.g69': ['IPR002004', 'IPR036053'],
#   'scaffold5.g70': [],
#   'scaffold5.g71': [],
#   'scaffold5.g72': [],
#   'scaffold5.g73': [],
#   'scaffold5.g74': [],
#   'scaffold5.g75': [],
#   'scaffold5.g76': [],
#   'scaffold5.g77': ['IPR000571', 'IPR036855'],
#   'scaffold5.g78': [],
#   'scaffold5.g79': ['IPR036770', 'IPR002110'],
#   'scaffold5.g80': ['IPR036770',
#    'IPR002110',
#    'IPR020683',
#    'IPR002110',
#    'IPR020683',
#    'IPR036770'],
#   'scaffold6.g1': [],
#   'scaffold6.g2': [],
#   'scaffold6.g3': [],
#   'scaffold6.g4': [],
#   'scaffold6.g5': [],
#   'scaffold6.g6': [],
#   'scaffold6.g7': ['IPR024084', 'IPR019818', 'IPR024084', 'IPR019818'],
#   'scaffold6.g8': ['IPR028222'],
#   'scaffold6.g9': ['IPR028222'],
#   'scaffold6.g10': ['IPR027469', 'IPR002524'],
#   'scaffold6.g11': ['IPR039158'],
#   'scaffold6.g12': [],
#   'scaffold6.g13': [],
#   'scaffold6.g14': [],
#   'scaffold6.g15': [],
#   'scaffold6.g16': [],
#   'scaffold6.g17': ['IPR039031', 'IPR013122'],
#   'scaffold6.g18': ['IPR018556'],
#   'scaffold6.g19': [],
#   'scaffold6.g20': ['IPR012317', 'IPR041400', 'IPR012317', 'IPR041400'],
#   'scaffold6.g21': ['IPR000789', 'IPR036858'],
#   'scaffold6.g22': ['IPR001965',
#    'IPR019787',
#    'IPR019786',
#    'IPR013083',
#    'IPR011011',
#    'IPR019787',
#    'IPR019786',
#    'IPR013083',
#    'IPR001965',
#    'IPR011011',
#    'IPR019787',
#    'IPR013083',
#    'IPR019786',
#    'IPR011011',
#    'IPR001965',
#    'IPR019786',
#    'IPR013083',
#    'IPR019787',
#    'IPR011011',
#    'IPR001965'],
#   'scaffold6.g23': ['IPR022542',
#    'IPR016024',
#    'IPR016024',
#    'IPR022542',
#    'IPR016024',
#    'IPR022542'],
#   'scaffold6.g24': [],
#   'scaffold6.g25': [],
#   'scaffold6.g26': [],
#   'scaffold6.g27': [],
#   'scaffold6.g28': [],
#   'scaffold6.g29': [],
#   'scaffold6.g30': ['IPR000477'],
#   'scaffold6.g31': ['IPR021392'],
#   'scaffold6.g32': ['IPR000008',
#    'IPR035892',
#    'IPR010482',
#    'IPR035892',
#    'IPR000008',
#    'IPR010482'],
#   'scaffold6.g33': [],
#   'scaffold6.g34': [],
#   'scaffold6.g35': [],
#   'scaffold6.g36': [],
#   'scaffold6.g37': ['IPR036872', 'IPR001715'],
#   'scaffold6.g38': ['IPR036734',
#    'IPR002394',
#    'IPR006029',
#    'IPR006202',
#    'IPR036719',
#    'IPR006201'],
#   'scaffold6.g39': [],
#   'scaffold6.g40': [],
#   'scaffold6.g41': ['IPR022742', 'IPR029058', 'IPR022742', 'IPR029058'],
#   'scaffold6.g42': ['IPR016193', 'IPR002125'],
#   'scaffold6.g43': ['IPR036514',
#    'IPR036514',
#    'IPR017868',
#    'IPR013783',
#    'IPR014756',
#    'IPR017868',
#    'IPR014756',
#    'IPR013783'],
#   'scaffold6.g44': ['IPR037523', 'IPR017515', 'IPR029068'],
#   'scaffold6.g45': [],
#   'scaffold6.g46': [],
#   'scaffold6.g47': ['IPR002070',
#    'IPR018186',
#    'IPR001699',
#    'IPR008967',
#    'IPR036960'],
#   'scaffold6.g48': ['IPR036388', 'IPR036390', 'IPR005818', 'IPR005819'],
#   'scaffold6.g49': [],
#   'scaffold6.g50': [],
#   'scaffold6.g51': [],
#   'scaffold6.g52': ['IPR037770', 'IPR011009'],
#   'scaffold6.g53': ['IPR033575', 'IPR018276'],
#   'scaffold6.g54': ['IPR039672',
#    'IPR036259',
#    'IPR039672',
#    'IPR036259',
#    'IPR036259',
#    'IPR039672'],
#   'scaffold6.g55': ['IPR040357'],
#   'scaffold6.g56': ['IPR006029',
#    'IPR006201',
#    'IPR036734',
#    'IPR006202',
#    'IPR018000',
#    'IPR036719'],
#   'scaffold6.g57': ['IPR018163',
#    'IPR002320',
#    'IPR002314',
#    'IPR033728',
#    'IPR006195',
#    'IPR012947',
#    'IPR004154',
#    'IPR036621',
#    'IPR004095',
#    'IPR012675',
#    'IPR012676',
#    'IPR036621',
#    'IPR002320',
#    'IPR004154',
#    'IPR006195',
#    'IPR033728',
#    'IPR012675',
#    'IPR018163',
#    'IPR012947',
#    'IPR002314',
#    'IPR012676',
#    'IPR004095'],
#   'scaffold6.g58': [],
#   'scaffold6.g59': ['IPR008942', 'IPR006569', 'IPR006903'],
#   'scaffold6.g60': [],
#   'scaffold6.g61': [],
#   'scaffold6.g62': [],
#   'scaffold6.g63': ['IPR013783', 'IPR003961', 'IPR036116'],
#   'scaffold6.g64': ['IPR041667', 'IPR003347'],
#   'scaffold6.g65': [],
#   'scaffold6.g66': ['IPR011990'],
#   'scaffold7.g1': [],
#   'scaffold7.g2': ['IPR039844',
#    'IPR021714',
#    'IPR039844',
#    'IPR021714',
#    'IPR039844',
#    'IPR021714',
#    'IPR039844',
#    'IPR021714'],
#   'scaffold7.g3': [],
#   'scaffold7.g4': ['IPR039844',
#    'IPR032436',
#    'IPR039844',
#    'IPR032436',
#    'IPR016024'],
#   'scaffold7.g5': [],
#   'scaffold7.g6': ['IPR013783'],
#   'scaffold7.g7': [],
#   'scaffold7.g8': ['IPR013783'],
#   'scaffold7.g9': [],
#   'scaffold7.g10': [],
#   'scaffold7.g11': [],
#   'scaffold7.g12': ['IPR000477'],
#   'scaffold7.g13': [],
#   'scaffold7.g14': [],
#   'scaffold7.g15': ['IPR006594'],
#   'scaffold7.g16': [],
#   'scaffold7.g17': [],
#   'scaffold7.g18': [],
#   'scaffold7.g19': [],
#   'scaffold7.g20': [],
#   'scaffold7.g21': ['IPR036388', 'IPR001766', 'IPR030456', 'IPR036390'],
#   'scaffold7.g22': [],
#   'scaffold7.g23': [],
#   'scaffold7.g24': ['IPR036259', 'IPR011701', 'IPR020846', 'IPR001958'],
#   'scaffold7.g25': ['IPR008942', 'IPR014712', 'IPR011417', 'IPR013809'],
#   'scaffold7.g26': [],
#   'scaffold7.g27': [],
#   'scaffold7.g28': ['IPR000209', 'IPR036852'],
#   'scaffold7.g29': ['IPR038466', 'IPR036852', 'IPR032815', 'IPR023827'],
#   'scaffold7.g30': [],
#   'scaffold7.g31': [],
#   'scaffold7.g32': [],
#   'scaffold7.g33': [],
#   'scaffold7.g34': [],
#   'scaffold7.g35': ['IPR036249', 'IPR006993', 'IPR002109'],
#   'scaffold7.g36': ['IPR039804',
#    'IPR039795',
#    'IPR011016',
#    'IPR026850',
#    'IPR013083',
#    'IPR039795',
#    'IPR039804',
#    'IPR011016',
#    'IPR026850',
#    'IPR016024',
#    'IPR013083',
#    'IPR039795',
#    'IPR011016',
#    'IPR039804',
#    'IPR013083',
#    'IPR039795',
#    'IPR016024',
#    'IPR026850',
#    'IPR011016',
#    'IPR016024',
#    'IPR039804',
#    'IPR039795',
#    'IPR026850',
#    'IPR013083'],
#   'scaffold7.g37': ['IPR009262'],
#   'scaffold7.g38': ['IPR007109',
#    'IPR039770',
#    'IPR039770',
#    'IPR007109',
#    'IPR039770',
#    'IPR007109',
#    'IPR007109',
#    'IPR039770'],
#   'scaffold7.g39': [],
#   'scaffold7.g40': ['IPR030231', 'IPR004130', 'IPR027417'],
#   'scaffold7.g41': [],
#   'scaffold7.g42': [],
#   'scaffold7.g43': ['IPR000198',
#    'IPR001849',
#    'IPR000159',
#    'IPR008936',
#    'IPR011993',
#    'IPR029071',
#    'IPR001849',
#    'IPR029071',
#    'IPR000159',
#    'IPR011993',
#    'IPR001849',
#    'IPR029071',
#    'IPR000159',
#    'IPR011993',
#    'IPR011993',
#    'IPR001849',
#    'IPR029071',
#    'IPR000159',
#    'IPR029071',
#    'IPR001849',
#    'IPR011993',
#    'IPR000159',
#    'IPR001849',
#    'IPR000159',
#    'IPR029071',
#    'IPR011993'],
#   'scaffold7.g44': [],
#   'scaffold7.g45': [],
#   'scaffold7.g46': ['IPR011722', 'IPR036623'],
#   'scaffold7.g47': ['IPR011990',
#    'IPR019734',
#    'IPR013940',
#    'IPR042861',
#    'IPR011990',
#    'IPR019734',
#    'IPR013940',
#    'IPR042861',
#    'IPR042861'],
#   'scaffold7.g48': ['IPR000276', 'IPR017452'],
#   'scaffold7.g49': ['IPR000477'],
#   'scaffold7.g50': [],
#   'scaffold7.g51': ['IPR038729', 'IPR027417'],
#   'scaffold7.g52': [],
#   'scaffold7.g53': ['IPR042277', 'IPR005024'],
#   'scaffold7.g54': [],
#   'scaffold7.g55': ['IPR020810', 'IPR000941', 'IPR036849'],
#   'scaffold7.g56': ['IPR001594'],
#   'scaffold7.g57': [],
#   'scaffold7.g58': [],
#   'scaffold7.g59': [],
#   'scaffold7.g60': ['IPR002048', 'IPR011992', 'IPR000261', 'IPR018247'],
#   'scaffold7.g61': [],
#   'scaffold7.g62': [],
#   'scaffold7.g63': ['IPR035899', 'IPR000219', 'IPR001331'],
#   'scaffold7.g64': [],
#   'scaffold7.g65': [],
#   'scaffold7.g66': [],
#   'scaffold7.g67': ['IPR020846', 'IPR005829', 'IPR036259', 'IPR005828'],
#   'scaffold7.g68': [],
#   'scaffold7.g69': ['IPR027417', 'IPR005654', 'IPR027417', 'IPR005654'],
#   'scaffold7.g70': [],
#   'scaffold7.g71': ['IPR013783', 'IPR035986'],
#   'scaffold7.g72': [],
#   'scaffold7.g73': ['IPR000276', 'IPR017452'],
#   'scaffold7.g74': ['IPR003583',
#    'IPR002008',
#    'IPR027421',
#    'IPR019843',
#    'IPR002054',
#    'IPR029398',
#    'IPR010996',
#    'IPR028207',
#    'IPR022312',
#    'IPR037160',
#    'IPR018944'],
#   'scaffold7.g75': ['IPR036259', 'IPR011701'],
#   'scaffold8.g1': ['IPR036291',
#    'IPR001753',
#    'IPR018376',
#    'IPR006176',
#    'IPR029045'],
#   'scaffold8.g2': [],
#   'scaffold8.g3': ['IPR035897', 'IPR013761', 'IPR001660', 'IPR000157'],
#   'scaffold8.g4': ['IPR003618',
#    'IPR036575',
#    'IPR001222',
#    'IPR006289',
#    'IPR003617',
#    'IPR001222',
#    'IPR003618',
#    'IPR017923',
#    'IPR035100',
#    'IPR035441',
#    'IPR036575',
#    'IPR001222',
#    'IPR036575',
#    'IPR006289',
#    'IPR035441',
#    'IPR003618',
#    'IPR017923',
#    'IPR003617',
#    'IPR035100'],
#   'scaffold8.g5': ['IPR016137', 'IPR036305'],
#   'scaffold8.g6': [],
#   'scaffold8.g7': ['IPR001353',
#    'IPR016050',
#    'IPR029055',
#    'IPR035206',
#    'IPR023333'],
#   'scaffold8.g8': ['IPR007130'],
#   'scaffold8.g9': [],
#   'scaffold8.g10': [],
#   'scaffold8.g11': [],
#   'scaffold8.g12': [],
#   'scaffold8.g13': [],
#   'scaffold8.g14': ['IPR041442', 'IPR012981'],
#   'scaffold8.g15': ['IPR017978',
#    'IPR028082',
#    'IPR001828',
#    'IPR038550',
#    'IPR011500',
#    'IPR000337'],
#   'scaffold8.g16': [],
#   'scaffold8.g17': ['IPR028082',
#    'IPR001828',
#    'IPR000337',
#    'IPR017978',
#    'IPR011500',
#    'IPR038550',
#    'IPR001828',
#    'IPR028082',
#    'IPR038550',
#    'IPR017978',
#    'IPR000337',
#    'IPR011500'],
#   'scaffold8.g18': [],
#   'scaffold8.g19': ['IPR012349'],
#   'scaffold8.g20': ['IPR001680',
#    'IPR027525',
#    'IPR017986',
#    'IPR015943',
#    'IPR036322'],
#   'scaffold8.g21': ['IPR028009', 'IPR028009', 'IPR028005'],
#   'scaffold8.g22': [],
#   'scaffold8.g23': [],
#   'scaffold8.g24': [],
#   'scaffold8.g25': ['IPR001356', 'IPR017970', 'IPR009057'],
#   'scaffold8.g26': ['IPR032794'],
#   'scaffold8.g27': ['IPR002401', 'IPR001128', 'IPR036396'],
#   'scaffold8.g28': [],
#   'scaffold8.g29': ['IPR001611',
#    'IPR007110',
#    'IPR003599',
#    'IPR013783',
#    'IPR000483',
#    'IPR032675',
#    'IPR036179',
#    'IPR003591',
#    'IPR003598',
#    'IPR013098',
#    'IPR013032',
#    'IPR001611',
#    'IPR007110',
#    'IPR003599',
#    'IPR013783',
#    'IPR000483',
#    'IPR032675',
#    'IPR036179',
#    'IPR003591',
#    'IPR003598',
#    'IPR013098',
#    'IPR013032'],
#   'scaffold8.g30': ['IPR001849',
#    'IPR008937',
#    'IPR035899',
#    'IPR000048',
#    'IPR000219',
#    'IPR000651',
#    'IPR011993',
#    'IPR023578',
#    'IPR001849',
#    'IPR000651',
#    'IPR011993',
#    'IPR035899',
#    'IPR000048',
#    'IPR000219',
#    'IPR023578',
#    'IPR008937'],
#   'scaffold8.g31': [],
#   'scaffold8.g32': ['IPR023578',
#    'IPR001895',
#    'IPR036964',
#    'IPR030745',
#    'IPR008937',
#    'IPR019804',
#    'IPR023578',
#    'IPR001895',
#    'IPR036964',
#    'IPR030745',
#    'IPR008937',
#    'IPR019804'],
#   'scaffold8.g33': [],
#   'scaffold8.g34': ['IPR019440',
#    'IPR019440',
#    'IPR011990',
#    'IPR019440',
#    'IPR011990'],
#   'scaffold8.g35': [],
#   'scaffold8.g36': [],
#   'scaffold8.g37': [],
#   'scaffold8.g38': [],
#   'scaffold8.g39': ['IPR036738',
#    'IPR000403',
#    'IPR026683',
#    'IPR009076',
#    'IPR014009',
#    'IPR003151',
#    'IPR011009',
#    'IPR018936',
#    'IPR009076',
#    'IPR000403',
#    'IPR026683',
#    'IPR036738',
#    'IPR011009',
#    'IPR014009',
#    'IPR003151',
#    'IPR018936'],
#   'scaffold8.g40': ['IPR024585',
#    'IPR026683',
#    'IPR026683',
#    'IPR016024',
#    'IPR024585'],
#   'scaffold8.g41': ['IPR010281'],
#   'scaffold8.g42': ['IPR041093',
#    'IPR012340',
#    'IPR001900',
#    'IPR041505',
#    'IPR028591',
#    'IPR022966',
#    'IPR033771'],
#   'scaffold8.g43': ['IPR035983',
#    'IPR042469',
#    'IPR029063',
#    'IPR000569',
#    'IPR042469',
#    'IPR029063',
#    'IPR000569',
#    'IPR035983',
#    'IPR042469',
#    'IPR029063',
#    'IPR000569',
#    'IPR035983',
#    'IPR035983',
#    'IPR042469',
#    'IPR000569',
#    'IPR029063',
#    'IPR035983',
#    'IPR042469',
#    'IPR000569',
#    'IPR029063',
#    'IPR000569',
#    'IPR035983',
#    'IPR029063',
#    'IPR042469'],
#   'scaffold8.g44': ['IPR002035', 'IPR036465'],
#   'scaffold8.g45': ['IPR038765', 'IPR001394', 'IPR018200', 'IPR028889'],
#   'scaffold8.g46': ['IPR000626', 'IPR029071'],
#   'scaffold8.g47': ['IPR005225',
#    'IPR003165',
#    'IPR001806',
#    'IPR012337',
#    'IPR027417',
#    'IPR036397'],
#   'scaffold8.g48': ['IPR036638', 'IPR011598', 'IPR002418', 'IPR012682'],
#   'scaffold8.g49': ['IPR002110',
#    'IPR020683',
#    'IPR036770',
#    'IPR020683',
#    'IPR002110',
#    'IPR036770',
#    'IPR036770',
#    'IPR002110',
#    'IPR020683',
#    'IPR020683',
#    'IPR036770'],
#   'scaffold8.g50': ['IPR036047', 'IPR040394', 'IPR001810'],
#   'scaffold8.g51': [],
#   'scaffold8.g52': ['IPR037189',
#    'IPR000795',
#    'IPR027417',
#    'IPR009000',
#    'IPR009001',
#    'IPR004160',
#    'IPR015033',
#    'IPR037189',
#    'IPR000795',
#    'IPR027417',
#    'IPR009000',
#    'IPR009001',
#    'IPR004160',
#    'IPR015033',
#    'IPR037189',
#    'IPR000795',
#    'IPR027417',
#    'IPR009000',
#    'IPR009001',
#    'IPR004160',
#    'IPR015033',
#    'IPR037189',
#    'IPR000795',
#    'IPR027417',
#    'IPR009000',
#    'IPR009001',
#    'IPR004160',
#    'IPR015033'],
#   'scaffold8.g53': [],
#   'scaffold8.g54': [],
#   'scaffold8.g55': [],
#   'scaffold8.g56': [],
#   'scaffold8.g57': [],
#   'scaffold8.g58': ['IPR022644',
#    'IPR029066',
#    'IPR009006',
#    'IPR022643',
#    'IPR002433',
#    'IPR000183',
#    'IPR022653'],
#   'scaffold8.g59': ['IPR001506',
#    'IPR008979',
#    'IPR034035',
#    'IPR000884',
#    'IPR000421',
#    'IPR024079',
#    'IPR013320',
#    'IPR006026',
#    'IPR000998',
#    'IPR036383'],
#   'scaffold8.g60': ['IPR000668',
#    'IPR013201',
#    'IPR038765',
#    'IPR025661',
#    'IPR000169',
#    'IPR039417',
#    'IPR000668',
#    'IPR013201',
#    'IPR038765',
#    'IPR025661',
#    'IPR000169',
#    'IPR039417'],
#   'scaffold8.g61': ['IPR000668',
#    'IPR013201',
#    'IPR025660',
#    'IPR039417',
#    'IPR038765',
#    'IPR025661',
#    'IPR000169'],
#   'scaffold8.g62': ['IPR011009', 'IPR000719'],
#   'scaffold8.g63': [],
#   'scaffold8.g64': [],
#   'scaffold8.g65': [],
#   'scaffold9.g1': [],
#   'scaffold9.g2': [],
#   'scaffold9.g3': ['IPR011992',
#    'IPR001589',
#    'IPR001715',
#    'IPR036872',
#    'IPR039959'],
#   'scaffold9.g4': ['IPR013766', 'IPR017937', 'IPR036249', 'IPR005788'],
#   'scaffold9.g5': [],
#   'scaffold9.g6': ['IPR003005',
#    'IPR036028',
#    'IPR027267',
#    'IPR001452',
#    'IPR004148',
#    'IPR001452',
#    'IPR004148',
#    'IPR027267',
#    'IPR003005',
#    'IPR036028'],
#   'scaffold9.g7': ['IPR027417', 'IPR001609', 'IPR036961'],
#   'scaffold9.g8': [],
#   'scaffold9.g9': ['IPR001609', 'IPR027417', 'IPR036961'],
#   'scaffold9.g10': [],
#   'scaffold9.g11': ['IPR027267'],
#   'scaffold9.g12': ['IPR013255', 'IPR013255'],
#   'scaffold9.g13': [],
#   'scaffold9.g14': ['IPR009057',
#    'IPR006634',
#    'IPR001356',
#    'IPR016439',
#    'IPR016439',
#    'IPR006634',
#    'IPR006634',
#    'IPR001356',
#    'IPR016439',
#    'IPR009057'],
#   'scaffold9.g15': [],
#   'scaffold9.g16': [],
#   'scaffold9.g17': ['IPR000159',
#    'IPR011993',
#    'IPR001849',
#    'IPR029071',
#    'IPR039665',
#    'IPR039664',
#    'IPR000159',
#    'IPR011993',
#    'IPR001849',
#    'IPR029071',
#    'IPR039665',
#    'IPR039664',
#    'IPR039664',
#    'IPR039665',
#    'IPR001849',
#    'IPR029071',
#    'IPR011993',
#    'IPR000159',
#    'IPR000159',
#    'IPR001849',
#    'IPR039664',
#    'IPR029071',
#    'IPR039665',
#    'IPR011993'],
#   'scaffold9.g18': ['IPR032465', 'IPR006680', 'IPR032466'],
#   'scaffold9.g19': [],
#   'scaffold9.g20': ['IPR000276', 'IPR017452'],
#   'scaffold9.g21': ['IPR029071', 'IPR019954', 'IPR000626', 'IPR019956'],
#   'scaffold9.g22': ['IPR000626', 'IPR029071'],
#   'scaffold9.g23': ['IPR009045',
#    'IPR001767',
#    'IPR000320',
#    'IPR001657',
#    'IPR036844',
#    'IPR003587',
#    'IPR003586',
#    'IPR009045',
#    'IPR003587',
#    'IPR003586',
#    'IPR001657',
#    'IPR000320',
#    'IPR001767',
#    'IPR036844'],
#   'scaffold9.g24': ['IPR036322',
#    'IPR017986',
#    'IPR001680',
#    'IPR019775',
#    'IPR015943',
#    'IPR020472',
#    'IPR019775',
#    'IPR001680',
#    'IPR036322',
#    'IPR015943',
#    'IPR017986',
#    'IPR012972',
#    'IPR019775',
#    'IPR001680',
#    'IPR028599',
#    'IPR015943',
#    'IPR020472',
#    'IPR012972',
#    'IPR017986',
#    'IPR036322'],
#   'scaffold9.g25': [],
#   'scaffold9.g26': ['IPR010617'],
#   'scaffold9.g27': ['IPR036465',
#    'IPR002369',
#    'IPR036349',
#    'IPR032695',
#    'IPR012896',
#    'IPR015812',
#    'IPR014836',
#    'IPR012896',
#    'IPR014836',
#    'IPR032695',
#    'IPR015812',
#    'IPR036349',
#    'IPR002369',
#    'IPR036465',
#    'IPR015812',
#    'IPR033760',
#    'IPR002369',
#    'IPR036465',
#    'IPR015812',
#    'IPR033760'],
#   'scaffold9.g28': ['IPR015812',
#    'IPR033760',
#    'IPR002369',
#    'IPR013111',
#    'IPR016201',
#    'IPR012896',
#    'IPR036465',
#    'IPR014836',
#    'IPR032695',
#    'IPR036349',
#    'IPR015812',
#    'IPR032695',
#    'IPR036465',
#    'IPR016201',
#    'IPR002369',
#    'IPR015812',
#    'IPR036465',
#    'IPR032695',
#    'IPR002369',
#    'IPR016201',
#    'IPR033760'],
#   'scaffold9.g29': [],
#   'scaffold9.g30': ['IPR017868', 'IPR014756', 'IPR013783', 'IPR001298'],
#   'scaffold9.g31': ['IPR016039',
#    'IPR014030',
#    'IPR000794',
#    'IPR014031',
#    'IPR020841',
#    'IPR018201',
#    'IPR017568'],
#   'scaffold9.g32': ['IPR000276', 'IPR017452'],
#   'scaffold9.g33': ['IPR001487',
#    'IPR019787',
#    'IPR036427',
#    'IPR013083',
#    'IPR011011',
#    'IPR001965',
#    'IPR018359',
#    'IPR011011',
#    'IPR001965',
#    'IPR018359',
#    'IPR019787',
#    'IPR013083',
#    'IPR036427',
#    'IPR001487'],
#   'scaffold9.g34': ['IPR001739', 'IPR016177'],
#   'scaffold9.g35': [],
#   'scaffold9.g36': ['IPR003000', 'IPR026590', 'IPR029035'],
#   'scaffold9.g37': ['IPR010326',
#    'IPR010326',
#    'IPR042532',
#    'IPR010326',
#    'IPR010326'],
#   'scaffold9.g38': [],
#   'scaffold9.g39': ['IPR013783',
#    'IPR009030',
#    'IPR001881',
#    'IPR000152',
#    'IPR000742',
#    'IPR013032',
#    'IPR007110',
#    'IPR018097',
#    'IPR008983',
#    'IPR024731',
#    'IPR036179',
#    'IPR013783',
#    'IPR009030',
#    'IPR001881',
#    'IPR000152',
#    'IPR000742',
#    'IPR013032',
#    'IPR007110',
#    'IPR018097',
#    'IPR008983',
#    'IPR024731',
#    'IPR036179',
#    'IPR013783',
#    'IPR013032',
#    'IPR008983',
#    'IPR000742',
#    'IPR036179',
#    'IPR000152',
#    'IPR007110',
#    'IPR024731',
#    'IPR001881',
#    'IPR018097',
#    'IPR009030'],
#   'scaffold9.g40': [],
#   'scaffold9.g41': [],
#   'scaffold9.g42': [],
#   'scaffold9.g43': ['IPR013032',
#    'IPR001881',
#    'IPR024731',
#    'IPR000742',
#    'IPR000152',
#    'IPR009030',
#    'IPR018097',
#    'IPR013099',
#    'IPR001638',
#    'IPR001320'],
#   'scaffold9.g44': [],
#   'scaffold9.g45': ['IPR035897', 'IPR000157'],
#   'scaffold9.g46': [],
#   'scaffold9.g47': ['IPR028325', 'IPR013099'],
#   'scaffold9.g48': ['IPR003891', 'IPR016021', 'IPR016024', 'IPR003890'],
#   'scaffold9.g49': [],
#   'scaffold9.g50': [],
#   'scaffold9.g51': ['IPR004255', 'IPR009721'],
#   'scaffold9.g52': [],
#   'scaffold9.g53': [],
#   'scaffold9.g54': [],
#   'scaffold9.g55': [],
#   'scaffold9.g56': [],
#   'scaffold9.g57': [],
#   'scaffold9.g58': [],
#   'scaffold9.g59': [],
#   'scaffold9.g60': [],
#   'scaffold9.g61': [],
#   'scaffold9.g62': [],
#   'scaffold10.g1': ['IPR039356', 'IPR006674'],
#   'scaffold10.g2': ['IPR003593',
#    'IPR006507',
#    'IPR002078',
#    'IPR025662',
#    'IPR013767',
#    'IPR021147',
#    'IPR025943',
#    'IPR035965',
#    'IPR009057',
#    'IPR030828',
#    'IPR027417',
#    'IPR000014',
#    'IPR025944',
#    'IPR007413'],
#   'scaffold10.g3': ['IPR036660', 'IPR004647', 'IPR004646'],
#   'scaffold10.g4': ['IPR005801',
#    'IPR019999',
#    'IPR015890',
#    'IPR006805',
#    'IPR005802'],
#   'scaffold10.g5': ['IPR003661',
#    'IPR036890',
#    'IPR003594',
#    'IPR036097',
#    'IPR004358',
#    'IPR005467'],
#   'scaffold10.g6': [],
#   'scaffold10.g7': ['IPR004644', 'IPR005130', 'IPR029009', 'IPR005131'],
#   'scaffold10.g8': ['IPR015421',
#    'IPR003660',
#    'IPR004838',
#    'IPR004364',
#    'IPR006195',
#    'IPR004089',
#    'IPR004839',
#    'IPR018821',
#    'IPR015422',
#    'IPR015424',
#    'IPR004522',
#    'IPR005105',
#    'IPR000796'],
#   'scaffold10.g9': ['IPR003660', 'IPR004089', 'IPR029151', 'IPR033479'],
#   'scaffold10.g10': ['IPR036890',
#    'IPR004681',
#    'IPR005467',
#    'IPR011712',
#    'IPR033480',
#    'IPR010656',
#    'IPR003594'],
#   'scaffold10.g11': ['IPR001279',
#    'IPR036866',
#    'IPR034984',
#    'IPR002477',
#    'IPR018976',
#    'IPR005490',
#    'IPR023346',
#    'IPR038063',
#    'IPR038352',
#    'IPR008311'],
#   'scaffold10.g12': ['IPR018976',
#    'IPR011031',
#    'IPR002541',
#    'IPR017900',
#    'IPR017896',
#    'IPR036144',
#    'IPR036280',
#    'IPR000926',
#    'IPR032523',
#    'IPR038352',
#    'IPR032677',
#    'IPR003567'],
#   'scaffold10.g13': ['IPR003321', 'IPR017570', 'IPR011031', 'IPR036280'],
#   'scaffold10.g14': ['IPR002205',
#    'IPR011990',
#    'IPR013026',
#    'IPR019734',
#    'IPR035516',
#    'IPR013758',
#    'IPR006691',
#    'IPR013760',
#    'IPR013757',
#    'IPR005743'],
#   'scaffold10.g15': ['IPR010233', 'IPR029063'],
#   'scaffold10.g16': ['IPR030475',
#    'IPR025079',
#    'IPR005144',
#    'IPR000788',
#    'IPR000358',
#    'IPR012348',
#    'IPR009078',
#    'IPR008926',
#    'IPR033909'],
#   'scaffold10.g17': ['IPR029066', 'IPR005730', 'IPR009006'],
#   'scaffold10.g18': ['IPR036291',
#    'IPR015422',
#    'IPR032095',
#    'IPR004637',
#    'IPR005814',
#    'IPR005097',
#    'IPR002129',
#    'IPR015421',
#    'IPR015424'],
#   'scaffold10.g19': ['IPR000305',
#    'IPR004791',
#    'IPR010994',
#    'IPR035901',
#    'IPR038476',
#    'IPR001943',
#    'IPR003583',
#    'IPR036876',
#    'IPR001162'],
#   'scaffold10.g20': ['IPR006133',
#    'IPR006172',
#    'IPR023211',
#    'IPR036397',
#    'IPR012337',
#    'IPR042087',
#    'IPR006134',
#    'IPR017964'],
#   'scaffold10.g21': ['IPR012340',
#    'IPR001059',
#    'IPR015365',
#    'IPR013852',
#    'IPR020599',
#    'IPR014722',
#    'IPR011897',
#    'IPR008991',
#    'IPR013185'],
#   'scaffold10.g22': ['IPR018496',
#    'IPR002942',
#    'IPR042092',
#    'IPR000748',
#    'IPR036986',
#    'IPR020103',
#    'IPR006145'],
#   'scaffold10.g23': ['IPR006070', 'IPR017945'],
#   'scaffold10.g24': ['IPR004013', 'IPR003141', 'IPR016195'],
#   'scaffold10.g25': ['IPR036052',
#    'IPR029062',
#    'IPR001926',
#    'IPR005801',
#    'IPR006654',
#    'IPR015890',
#    'IPR023026',
#    'IPR006653',
#    'IPR006805',
#    'IPR017926'],
#   'scaffold10.g26': ['IPR012318',
#    'IPR036388',
#    'IPR036390',
#    'IPR000595',
#    'IPR014710',
#    'IPR018490'],
#   'scaffold10.g27': ['IPR042099', 'IPR025110', 'IPR000873', 'IPR020845'],
#   'scaffold10.g28': ['IPR036458', 'IPR001991'],
#   'scaffold10.g29': ['IPR011008', 'IPR011006', 'IPR001789', 'IPR005545'],
#   'scaffold10.g30': ['IPR013215', 'IPR038071', 'IPR002629'],
#   'scaffold10.g31': ['IPR000644',
#    'IPR001633',
#    'IPR035965',
#    'IPR000014',
#    'IPR035919',
#    'IPR013767'],
#   'scaffold10.g32': ['IPR013704', 'IPR024560', 'IPR022946'],
#   'scaffold10.g33': ['IPR001867',
#    'IPR001789',
#    'IPR003661',
#    'IPR036388',
#    'IPR036890',
#    'IPR016032',
# ...
#   'gene-LOC111326309': ['IPR006875', 'IPR039972', 'IPR006875', 'IPR039972'],
#   'gene-LOC111327563': ['IPR007111',
#    'IPR011047',
#    'IPR015943',
#    'IPR017986',
#    'IPR001680',
#    'IPR003593',
#    'IPR019775',
#    'IPR027417',
#    'IPR025139'],
#   'gene-LOC111327412': ['IPR015943',
#    'IPR017986',
#    'IPR027417',
#    'IPR007111',
#    'IPR025139',
#    'IPR036322',
#    'IPR003593',
#    'IPR001680',
#    'IPR011047'],
#   'gene-LOC111328251': ['IPR025139',
#    'IPR027417',
#    'IPR007111',
#    'IPR015943',
#    'IPR011044'],
#   'gene-LOC111328261': ['IPR011044', 'IPR015943'],
#   'gene-LOC111326877': ['IPR042201',
#    'IPR015425',
#    'IPR010473',
#    'IPR011989',
#    'IPR027644',
#    'IPR016024',
#    'IPR014768',
#    'IPR010472',
#    'IPR014767'],
#   'gene-LOC111326887': ['IPR023395', 'IPR002113', 'IPR018108', 'IPR002067'],
#   'gene-LOC111327104': ['IPR002067', 'IPR023395', 'IPR018108'],
#   'gene-LOC111327113': ['IPR016135', 'IPR000608', 'IPR023313'],
#   'gene-LOC111327437': ['IPR024810'],
#   'gene-LOC111327429': ['IPR013026',
#    'IPR019734',
#    'IPR011990',
#    'IPR003593',
#    'IPR027417'],
#   'gene-LOC111328029': [],
#   'gene-LOC111328035': ['IPR027417'],
#   'gene-LOC111326680': ['IPR024810'],
#   'gene-LOC111326665': ['IPR012462'],
#   'gene-LOC111326672': ['IPR009097', 'IPR019510'],
#   'gene-LOC111327776': ['IPR019510', 'IPR009097'],
#   'gene-LOC111326384': ['IPR035874',
#    'IPR017850',
#    'IPR000917',
#    'IPR024607',
#    'IPR017850',
#    'IPR035874',
#    'IPR000917'],
#   'gene-LOC111326402': ['IPR002110',
#    'IPR020683',
#    'IPR036770',
#    'IPR002110',
#    'IPR036770',
#    'IPR020683',
#    'IPR002110',
#    'IPR036770',
#    'IPR020683'],
#   'gene-LOC111326418': ['IPR033335'],
#   'gene-LOC111328053': ['IPR039034',
#    'IPR001849',
#    'IPR035892',
#    'IPR011993',
#    'IPR000008'],
#   'gene-LOC111328231': ['IPR001841',
#    'IPR002867',
#    'IPR006575',
#    'IPR031127',
#    'IPR016135',
#    'IPR013083',
#    'IPR017907'],
#   'gene-LOC111327173': ['IPR004993'],
#   'gene-LOC111326325': ['IPR036921',
#    'IPR036676',
#    'IPR029062',
#    'IPR041609',
#    'IPR040707',
#    'IPR010918',
#    'IPR017926',
#    'IPR010073',
#    'IPR036604'],
#   'gene-LOC111326335': ['IPR033333', 'IPR033333'],
#   'gene-LOC111328059': ['IPR000315'],
#   'gene-LOC111328108': ['IPR000337',
#    'IPR011500',
#    'IPR028082',
#    'IPR038550',
#    'IPR017978',
#    'IPR001828',
#    'IPR009030'],
#   'gene-LOC111328116': ['IPR000337',
#    'IPR028082',
#    'IPR009030',
#    'IPR001828',
#    'IPR017978',
#    'IPR011500',
#    'IPR038550'],
#   'gene-LOC111328272': ['IPR038736', 'IPR038736'],
#   'gene-LOC111328130': ['IPR013783',
#    'IPR003961',
#    'IPR001245',
#    'IPR017441',
#    'IPR003598',
#    'IPR008266',
#    'IPR036116',
#    'IPR011009',
#    'IPR020635',
#    'IPR003599',
#    'IPR000719',
#    'IPR036179',
#    'IPR007110'],
#   'gene-LOC111327597': ['IPR000276', 'IPR017452'],
#   'gene-LOC111328140': [],
#   'gene-LOC111326351': [],
#   'gene-LOC111328150': ['IPR017452', 'IPR000276'],
#   'gene-LOC111329714': [],
#   'gene-LOC111329100': ['IPR020846',
#    'IPR011701',
#    'IPR036259',
#    'IPR036259',
#    'IPR011701',
#    'IPR020846'],
#   'gene-LOC111329111': ['IPR001680',
#    'IPR013083',
#    'IPR001841',
#    'IPR037381',
#    'IPR036322'],
#   'gene-LOC111329777': ['IPR000849', 'IPR036259', 'IPR011701', 'IPR020846'],
#   'gene-LOC111329766': ['IPR035901', 'IPR000305', 'IPR000477', 'IPR013087'],
#   'gene-LOC111328770': ['IPR008365', 'IPR017452', 'IPR000276'],
#   'gene-LOC111329350': ['IPR019734',
#    'IPR011990',
#    'IPR013026',
#    'IPR024983',
#    'IPR011990',
#    'IPR019734',
#    'IPR024983',
#    'IPR013026',
#    'IPR011990',
#    'IPR019734',
#    'IPR024983',
#    'IPR013026',
#    'IPR011990',
#    'IPR019734',
#    'IPR024983',
#    'IPR013026',
#    'IPR011990',
#    'IPR019734',
#    'IPR013026',
#    'IPR024983'],
#   'gene-LOC111328781': ['IPR027806'],
#   'gene-LOC111328790': ['IPR000832', 'IPR017981', 'IPR002172'],
#   'gene-LOC111329634': ['IPR011990',
#    'IPR019734',
#    'IPR024983',
#    'IPR013026',
#    'IPR011990',
#    'IPR019734',
#    'IPR024983',
#    'IPR013026'],
#   'gene-LOC111329788': ['IPR008160'],
#   'gene-LOC111328341': ['IPR011598', 'IPR026052', 'IPR036638'],
#   'gene-LOC111328797': ['IPR001012',
#    'IPR036241',
#    'IPR029071',
#    'IPR009060',
#    'IPR012989'],
#   'gene-LOC111328511': ['IPR001452', 'IPR000980', 'IPR036860', 'IPR036028'],
#   'gene-LOC111329119': ['IPR012677',
#    'IPR000504',
#    'IPR001841',
#    'IPR003954',
#    'IPR035979',
#    'IPR034261',
#    'IPR039780',
#    'IPR039515',
#    'IPR013083',
#    'IPR035979',
#    'IPR000504',
#    'IPR012677',
#    'IPR039780',
#    'IPR013083',
#    'IPR001841',
#    'IPR003954',
#    'IPR034261',
#    'IPR039515',
#    'IPR012677',
#    'IPR000504',
#    'IPR013083',
#    'IPR039780',
#    'IPR001841',
#    'IPR003954',
#    'IPR034261',
#    'IPR039515',
#    'IPR035979'],
#   'gene-LOC111329325': ['IPR003150',
#    'IPR036390',
#    'IPR039779',
#    'IPR036388',
#    'IPR003150',
#    'IPR036390',
#    'IPR039779',
#    'IPR036388',
#    'IPR036390',
#    'IPR003150',
#    'IPR039779',
#    'IPR036388',
#    'IPR036390',
#    'IPR003150',
#    'IPR039779',
#    'IPR036388'],
#   'gene-LOC111329423': ['IPR029752',
#    'IPR006140',
#    'IPR036291',
#    'IPR006139',
#    'IPR029753',
#    'IPR029752',
#    'IPR029753',
#    'IPR006139',
#    'IPR006140',
#    'IPR036291'],
#   'gene-LOC111328722': ['IPR017978', 'IPR001828', 'IPR002455', 'IPR028082'],
#   'gene-LOC111329182': ['IPR007111',
#    'IPR025139',
#    'IPR011990',
#    'IPR027417',
#    'IPR007111',
#    'IPR025139',
#    'IPR011990',
#    'IPR027417',
#    'IPR007111',
#    'IPR025139',
#    'IPR011990',
#    'IPR027417'],
#   'gene-LOC111329314': ['IPR035979', 'IPR000504', 'IPR012677'],
#   'gene-LOC111328713': ['IPR020785',
#    'IPR000911',
#    'IPR020784',
#    'IPR036769',
#    'IPR036796',
#    'IPR020783'],
#   'gene-LOC111328691': ['IPR008908',
#    'IPR015919',
#    'IPR008908',
#    'IPR015919',
#    'IPR008908',
#    'IPR015919'],
#   'gene-LOC111328332': ['IPR029063', 'IPR007757'],
#   'gene-LOC111329817': ['IPR007724'],
#   'gene-LOC111329396': ['IPR015421', 'IPR005814', 'IPR015422', 'IPR015424'],
#   'gene-LOC111329569': ['IPR000863', 'IPR027417'],
#   'gene-LOC111329829': ['IPR009069'],
#   'gene-LOC111328316': ['IPR016662',
#    'IPR042490',
#    'IPR029058',
#    'IPR006862',
#    'IPR014940',
#    'IPR016662',
#    'IPR042490',
#    'IPR029058',
#    'IPR006862',
#    'IPR014940'],
#   'gene-LOC111329196': ['IPR042490',
#    'IPR006862',
#    'IPR029058',
#    'IPR016662',
#    'IPR014940'],
#   'gene-LOC111329273': ['IPR001976', 'IPR012678', 'IPR018098'],
#   'gene-LOC111329263': ['IPR021867', 'IPR029063'],
#   'gene-LOC111328350': ['IPR035892', 'IPR000008'],
#   'gene-LOC111329440': ['IPR032675',
#    'IPR013783',
#    'IPR001611',
#    'IPR035914',
#    'IPR003591',
#    'IPR000859',
#    'IPR009030',
#    'IPR011641',
#    'IPR036179',
#    'IPR001611',
#    'IPR035914',
#    'IPR000859',
#    'IPR036179',
#    'IPR011641',
#    'IPR009030',
#    'IPR013783',
#    'IPR003591',
#    'IPR032675',
#    'IPR001611',
#    'IPR000859',
#    'IPR032675',
#    'IPR035914',
#    'IPR003591',
#    'IPR011641',
#    'IPR036179',
#    'IPR009030',
#    'IPR013783',
#    'IPR035914',
#    'IPR001611',
#    'IPR000859',
#    'IPR009030',
#    'IPR003591',
#    'IPR032675',
#    'IPR036179',
#    'IPR011641',
#    'IPR013783',
#    'IPR035914',
#    'IPR001611',
#    'IPR000859',
#    'IPR009030',
#    'IPR003591',
#    'IPR032675',
#    'IPR036179',
#    'IPR011641',
#    'IPR013783'],
#   'gene-LOC111328824': ['IPR000859', 'IPR036179', 'IPR035914'],
#   'gene-LOC111329798': ['IPR001828',
#    'IPR018297',
#    'IPR029787',
#    'IPR001054',
#    'IPR011645',
#    'IPR008266',
#    'IPR011009',
#    'IPR000719',
#    'IPR001170',
#    'IPR028082',
#    'IPR001245'],
#   'gene-LOC111329524': ['IPR017978', 'IPR002455', 'IPR001828', 'IPR028082'],
#   'gene-LOC111329678': ['IPR009730', 'IPR033194'],
#   'gene-LOC111329306': ['IPR027806'],
#   'gene-LOC111328839': ['IPR007249', 'IPR040314'],
#   'gene-LOC111329612': ['IPR001060', 'IPR027267', 'IPR031160'],
#   'gene-LOC111329617': ['IPR000719',
#    'IPR011009',
#    'IPR017441',
#    'IPR008271',
#    'IPR000719',
#    'IPR011009',
#    'IPR017441',
#    'IPR008271'],
#   'gene-LOC111329514': ['IPR015943', 'IPR001680', 'IPR036322', 'IPR017986'],
#   'gene-LOC111328849': ['IPR000884',
#    'IPR000421',
#    'IPR036465',
#    'IPR008979',
#    'IPR002035',
#    'IPR036383'],
#   'gene-LOC111329959': ['IPR000562',
#    'IPR008979',
#    'IPR036943',
#    'IPR000421',
#    'IPR013806'],
#   'gene-LOC111329950': ['IPR036943',
#    'IPR008979',
#    'IPR000421',
#    'IPR000562',
#    'IPR013806'],
#   'gene-LOC111329940': ['IPR035972',
#    'IPR000294',
#    'IPR000421',
#    'IPR008979',
#    'IPR013806',
#    'IPR017857',
#    'IPR000562',
#    'IPR036943'],
#   'gene-LOC111329930': ['IPR009011', 'IPR000479'],
#   'gene-LOC111329920': ['IPR009011', 'IPR000479'],
#   'gene-LOC111329542': ['IPR001715',
#    'IPR036872',
#    'IPR003096',
#    'IPR001715',
#    'IPR036872',
#    'IPR003096'],
#   'gene-LOC111328859': ['IPR036872', 'IPR001715', 'IPR000557', 'IPR003096'],
#   'gene-LOC111329533': ['IPR036872', 'IPR003096', 'IPR000557', 'IPR001715'],
#   'gene-LOC111329685': ['IPR000048'],
#   'gene-LOC111328869': ['IPR016024', 'IPR000225', 'IPR011989', 'IPR038905'],
#   'gene-LOC111328361': ['IPR024977',
#    'IPR015943',
#    'IPR001680',
#    'IPR024789',
#    'IPR024790',
#    'IPR036322',
#    'IPR017986'],
#   'gene-LOC111328518': ['IPR013154',
#    'IPR036291',
#    'IPR002328',
#    'IPR011032',
#    'IPR013149',
#    'IPR020843'],
#   'gene-LOC111328525': ['IPR016565', 'IPR038389'],
#   'gene-LOC111328534': [],
#   'gene-LOC111329601': [],
#   'gene-LOC111329413': ['IPR026687'],
#   'gene-LOC111329891': [],
#   'gene-LOC111328410': ['IPR000504',
#    'IPR035979',
#    'IPR012975',
#    'IPR012677',
#    'IPR012975',
#    'IPR012677',
#    'IPR000504',
#    'IPR035979',
#    'IPR012975',
#    'IPR012677',
#    'IPR000504',
#    'IPR035979',
#    'IPR012975',
#    'IPR000504',
#    'IPR035979',
#    'IPR012677'],
#   'gene-LOC111329027': ['IPR006709'],
#   'gene-LOC111329032': ['IPR002123',
#    'IPR032098',
#    'IPR002123',
#    'IPR032098',
#    'IPR002123',
#    'IPR032098',
#    'IPR002123',
#    'IPR032098'],
#   'gene-LOC111328999': ['IPR036236',
#    'IPR013087',
#    'IPR036236',
#    'IPR013087',
#    'IPR036236',
#    'IPR013087',
#    'IPR036236',
#    'IPR013087',
#    'IPR036236',
#    'IPR013087',
#    'IPR036236',
#    'IPR013087'],
#   'gene-LOC111329298': ['IPR012292', 'IPR000971', 'IPR009050'],
#   'gene-LOC111329292': ['IPR019332'],
#   'gene-LOC111328667': ['IPR036397',
#    'IPR017964',
#    'IPR006134',
#    'IPR030559',
#    'IPR023211',
#    'IPR012337',
#    'IPR025687',
#    'IPR006172',
#    'IPR042087',
#    'IPR006133',
#    'IPR006134',
#    'IPR036397',
#    'IPR006172',
#    'IPR030559',
#    'IPR006133',
#    'IPR023211',
#    'IPR012337'],
#   'gene-LOC111328683': ['IPR012337', 'IPR030559', 'IPR006133'],
#   'gene-LOC111329204': ['IPR036390',
#    'IPR032067',
#    'IPR001766',
#    'IPR030456',
#    'IPR036388'],
#   'gene-LOC111329214': ['IPR006594'],
#   'gene-LOC111328644': ['IPR001660',
#    'IPR013761',
#    'IPR004092',
#    'IPR038348',
#    'IPR021987',
#    'IPR004092',
#    'IPR001660',
#    'IPR013761',
#    'IPR021987',
#    'IPR038348',
#    'IPR004092',
#    'IPR001660',
#    'IPR013761',
#    'IPR021987',
#    'IPR038348'],
#   'gene-LOC111328924': ['IPR006730', 'IPR029032'],
#   'gene-LOC111329144': ['IPR020556', 'IPR036928', 'IPR023631'],
#   'gene-LOC111328625': ['IPR027417',
#    'IPR036114',
#    'IPR032412',
#    'IPR004009',
#    'IPR001609',
#    'IPR008989',
#    'IPR036961'],
#   'gene-LOC111328633': ['IPR000301', 'IPR008952', 'IPR018499'],
#   'gene-LOC111328878': ['IPR036770', 'IPR020683', 'IPR002110'],
#   'gene-LOC111329757': ['IPR002227', 'IPR008922'],
#   'gene-LOC111329749': ['IPR000832', 'IPR000848', 'IPR022343', 'IPR017981'],
#   'gene-LOC111329243': ['IPR000832', 'IPR017981'],
#   'gene-LOC111329228': ['IPR039421',
#    'IPR036640',
#    'IPR003593',
#    'IPR027417',
#    'IPR011527',
#    'IPR017871',
#    'IPR003439',
#    'IPR039421',
#    'IPR036640',
#    'IPR003593',
#    'IPR027417',
#    'IPR011527',
#    'IPR017871',
#    'IPR003439'],
#   'gene-LOC111328448': ['IPR036424',
#    'IPR001441',
#    'IPR038887',
#    'IPR036424',
#    'IPR038887',
#    'IPR001441'],
#   'gene-LOC111328439': ['IPR013216', 'IPR010233', 'IPR029063'],
#   'gene-LOC111328464': ['IPR003599',
#    'IPR003112',
#    'IPR013783',
#    'IPR007110',
#    'IPR003598',
#    'IPR036179',
#    'IPR008160',
#    'IPR013098'],
#   'gene-LOC111328473': ['IPR014717', 'IPR000529', 'IPR035980'],
#   'gene-LOC111328889': ['IPR002347', 'IPR036291', 'IPR020904'],
#   'gene-LOC111328901': [],
#   'gene-LOC111328495': ['IPR023267', 'IPR001678', 'IPR029063'],
#   'gene-LOC111328483': ['IPR000270', 'IPR033512', 'IPR034857'],
#   'gene-LOC111328502': ['IPR002307',
#    'IPR002547',
#    'IPR014729',
#    'IPR012340',
#    'IPR002305'],
#   'gene-LOC111329739': ['IPR000533'],
#   'gene-LOC111329806': ['IPR017441', 'IPR000719', 'IPR011009'],
#   'gene-LOC111329483': ['IPR000719',
#    'IPR011009',
#    'IPR008266',
#    'IPR017441',
#    'IPR000719',
#    'IPR011009',
#    'IPR008266',
#    'IPR017441',
#    'IPR000719',
#    'IPR011009',
#    'IPR008266',
#    'IPR017441',
#    'IPR000719',
#    'IPR011009',
#    'IPR008266',
#    'IPR017441',
#    'IPR017441',
#    'IPR000719',
#    'IPR008266',
#    'IPR011009'],
#   'gene-LOC111329155': ['IPR003653', 'IPR038765', 'IPR003653', 'IPR038765'],
#   'gene-LOC111329705': [],
#   'gene-LOC111329695': ['IPR017978',
#    'IPR001828',
#    'IPR028082',
#    'IPR000068',
#    'IPR038550',
#    'IPR000337',
#    'IPR011500'],
#   'gene-LOC111328379': ['IPR028082',
#    'IPR017978',
#    'IPR038550',
#    'IPR011500',
#    'IPR001828',
#    'IPR000337'],
#   'gene-LOC111329280': ['IPR017956',
#    'IPR023779',
#    'IPR036770',
#    'IPR020683',
#    'IPR000953',
#    'IPR002110',
#    'IPR023780',
#    'IPR016197',
#    'IPR017956',
#    'IPR023779',
#    'IPR036770',
#    'IPR020683',
#    'IPR000953',
#    'IPR002110',
#    'IPR023780',
#    'IPR016197'],
#   'gene-LOC111329057': ['IPR036249', 'IPR001853'],
#   'gene-LOC111329067': ['IPR005225', 'IPR006689', 'IPR027417'],
#   'gene-LOC111328606': ['IPR004733',
#    'IPR016185',
#    'IPR001555',
#    'IPR013815',
#    'IPR002376',
#    'IPR004607',
#    'IPR036477',
#    'IPR011761',
#    'IPR020559',
#    'IPR036676',
#    'IPR016188',
#    'IPR020560',
#    'IPR011054',
#    'IPR000115',
#    'IPR036921',
#    'IPR037123',
#    'IPR010918',
#    'IPR020561',
#    'IPR020562'],
#   'gene-LOC111328615': ['IPR013154',
#    'IPR037397',
#    'IPR036291',
#    'IPR020843',
#    'IPR011032'],
#   'gene-LOC111328394': ['IPR019786',
#    'IPR000313',
#    'IPR001487',
#    'IPR002893',
#    'IPR001965',
#    'IPR036427',
#    'IPR019787',
#    'IPR013083',
#    'IPR011011'],
#   'gene-LOC111328401': ['IPR024132'],
#   'gene-LOC111328910': ['IPR038726'],
#   'gene-LOC111329172': ['IPR001806', 'IPR005225', 'IPR027417'],
#   'gene-LOC111328571': ['IPR001985', 'IPR016067', 'IPR001985', 'IPR016067'],
#   'gene-LOC111328595': ['IPR036397', 'IPR002562', 'IPR012337'],
#   'gene-LOC111328586': ['IPR017452', 'IPR000276', 'IPR008365'],
#   'gene-LOC111328389': ['IPR020846', 'IPR036259', 'IPR011701'],
#   'gene-LOC111329580': ['IPR013919'],
#   'gene-LOC111328370': ['IPR011043',
#    'IPR000210',
#    'IPR006652',
#    'IPR017096',
#    'IPR011705',
#    'IPR011333',
#    'IPR015915'],
#   'gene-LOC111329851': ['IPR026060'],
#   'gene-LOC111329839': ['IPR008554', 'IPR036249'],
#   'gene-LOC111329860': ['IPR001424',
#    'IPR024134',
#    'IPR036423',
#    'IPR001424',
#    'IPR036423',
#    'IPR024134',
#    'IPR036423',
#    'IPR024134',
#    'IPR001424'],
#   'gene-LOC111329882': ['IPR018152', 'IPR001424', 'IPR024134', 'IPR036423'],
#   'gene-LOC111329374': ['IPR019130', 'IPR019130'],
#   'gene-LOC111328304': ['IPR000731', 'IPR003392'],
#   'gene-LOC111329388': ['IPR003392', 'IPR000731'],
#   'gene-LOC111328932': ['IPR013968',
#    'IPR018201',
#    'IPR014031',
#    'IPR036291',
#    'IPR016035',
#    'IPR020841',
#    'IPR042104',
#    'IPR032821',
#    'IPR029058',
#    'IPR016036',
#    'IPR014030',
#    'IPR020843',
#    'IPR001031',
#    'IPR001227',
#    'IPR003392',
#    'IPR020801',
#    'IPR020807',
#    'IPR016039',
#    'IPR014043',
#    'IPR036736',
#    'IPR009081'],
#   'gene-LOC111328543': ['IPR020807',
#    'IPR020801',
#    'IPR014031',
#    'IPR016035',
#    'IPR001227',
#    'IPR009081',
#    'IPR036291',
#    'IPR036736',
#    'IPR011032',
#    'IPR029058',
#    'IPR003392',
#    'IPR018201',
#    'IPR042104',
#    'IPR014043',
#    'IPR020841',
#    'IPR013968',
#    'IPR016036',
#    'IPR016039',
#    'IPR032821',
#    'IPR001031',
#    'IPR014030',
#    'IPR020843'],
#   ...}}

# %%
gene_protein_file = "../find_closest_gene/new_parse_gff/gene_protein_dict.pickle"

# %%
with open(gene_protein_file, 'rb') as handle:
    gene_protein_dict = pickle.load(handle)

# %%
gene_protein_dict['pdam']
# Out:
# defaultdict(set,
#             {'gene-LOC113673859': {'XP_027049641.1'},
#              'gene-LOC113668373': {'XP_027040096.1'},
#              'gene-LOC113667069': {'XP_027038702.1'},
#              'gene-LOC113670418': {'XP_027042395.1'},
#              'gene-LOC113666499': {'XP_027038121.1'},
#              'gene-LOC113666399': {'XP_027038016.1'},
#              'gene-LOC113670712': {'XP_027042728.1'},
#              'gene-LOC113670806': {'XP_027042830.1'},
#              'gene-LOC113668840': {'XP_027040630.1'},
#              'gene-LOC113670613': {'XP_027042619.1'},
#              'gene-LOC113665099': {'XP_027036909.1'},
#              'gene-LOC113668074': {'XP_027039789.1'},
#              'gene-LOC113666803': {'XP_027038432.1', 'XP_027038505.1'},
#              'gene-LOC113666701': {'XP_027038326.1'},
#              'gene-LOC113668672': {'XP_027040457.1'},
#              'gene-LOC113686527': {'XP_027059994.1',
#               'XP_027060065.1',
#               'XP_027060134.1',
#               'XP_027060212.1',
#               'XP_027060284.1'},
#              'gene-LOC113665166': {'XP_027036664.1'},
#              'gene-LOC113665260': {'XP_027036768.1'},
#              'gene-LOC113669509': {'XP_027041397.1'},
#              'gene-LOC113666967': {'XP_027038595.1'},
#              'gene-LOC113666070': {'XP_027037979.1'},
#              'gene-LOC113667174': {'XP_027038803.1', 'XP_027038880.1'},
#              'gene-LOC113685178': {'XP_027058816.1', 'XP_027059533.1'},
#              'gene-LOC113667068': {'XP_027039016.1'},
#              'gene-LOC113684240': {'XP_027057746.1'},
#              'gene-LOC113686876': {'XP_027060393.1',
#               'XP_027060462.1',
#               'XP_027060537.1'},
#              'gene-LOC113687102': {'XP_027035543.1',
#               'XP_027035609.1',
#               'XP_027035682.1',
#               'XP_027060644.1'},
#              'gene-LOC113668270': {'XP_027039992.1'},
#              'gene-LOC113669256': {'XP_027041093.1'},
#              'gene-LOC113667332': {'XP_027038980.1'},
#              'gene-LOC113667687': {'XP_027039378.1',
#               'XP_027039445.1',
#               'XP_027039513.1',
#               'XP_027039578.1'},
#              'gene-LOC113682315': {'XP_027055617.1'},
#              'gene-LOC113681330': {'XP_027054571.1'},
#              'gene-LOC113680347': {'XP_027053515.1'},
#              'gene-LOC113665515': {'XP_027037061.1'},
#              'gene-LOC113665613': {'XP_027037163.1'},
#              'gene-LOC113668037': {'XP_027040061.1'},
#              'gene-LOC113665425': {'XP_027036945.1'},
#              'gene-LOC113666599': {'XP_027038226.1'},
#              'gene-LOC113668992': {'XP_027041135.1'},
#              'gene-LOC113683294': {'XP_027056671.1'},
#              'gene-LOC113667433': {'XP_027039087.1', 'XP_027039166.1'},
#              'gene-LOC113667593': {'XP_027039277.1'},
#              'gene-LOC113666102': {'XP_027037698.1'},
#              'gene-LOC113666204': {'XP_027037799.1'},
#              'gene-LOC113679366': {'XP_027052467.1'},
#              'gene-LOC113669606': {'XP_027041507.1'},
#              'gene-LOC113664112': {'XP_027035853.1'},
#              'gene-LOC113669026': {'XP_027040849.1', 'XP_027040922.1'},
#              'gene-LOC113665707': {'XP_027037263.1'},
#              'gene-LOC113665808': {'XP_027037365.1',
#               'XP_027037437.1',
#               'XP_027037513.1',
#               'XP_027037589.1'},
#              'gene-LOC113669703': {'XP_027041613.1'},
#              'gene-LOC113666303': {'XP_027037909.1'},
#              'gene-LOC113674852': {'XP_027047512.1',
#               'XP_027048210.1',
#               'XP_027048920.1',
#               'XP_027049642.1'},
#              'gene-LOC113677736': {'XP_027050727.1', 'XP_027051413.1'},
#              'gene-LOC113669966': {'XP_027042212.1'},
#              'gene-LOC113670514': {'XP_027042506.1'},
#              'gene-LOC113668175': {'XP_027039888.1'},
#              'gene-LOC113670264': {'XP_027042213.1'},
#              'gene-LOC113670005': {'XP_027041923.1', 'XP_027041994.1'},
#              'gene-LOC113669897': {'XP_027041818.1'},
#              'gene-LOC113669806': {'XP_027041716.1'},
#              'gene-LOC113670928': {'XP_027043272.1'},
#              'gene-LOC113664815': {'XP_027036267.1',
#               'XP_027036337.1',
#               'XP_027036414.1',
#               'XP_027036486.1',
#               'XP_027036553.1'},
#              'gene-LOC113664458': {'XP_027035891.1', 'XP_027035965.1'},
#              'gene-LOC113664353': {'XP_027035783.1'},
#              'gene-LOC113664611': {'XP_027036075.1'},
#              'gene-LOC113664711': {'XP_027036173.1'},
#              'gene-LOC113671922': {'XP_027044333.1'},
#              'gene-LOC113668928': {'XP_027040741.1'},
#              'gene-LOC113668471': {'XP_027040206.1',
#               'XP_027040279.1',
#               'XP_027040354.1'},
#              'gene-LOC113673860': {'XP_027046457.1'},
#              'gene-LOC113669353': {'XP_027041203.1', 'XP_027041279.1'},
#              'gene-LOC113671064': {'XP_027043111.1'},
#              'gene-LOC113671164': {'XP_027043214.1'},
#              'gene-LOC113672050': {'XP_027044160.1'},
#              'gene-LOC113671373': {'XP_027043393.1'},
#              'gene-LOC113671268': {'XP_027043310.1'},
#              'gene-LOC113671649': {'XP_027043732.1'},
#              'gene-LOC113672147': {'XP_027044259.1'},
#              'gene-LOC113671751': {'XP_027043841.1'},
#              'gene-LOC113671853': {'XP_027043948.1'},
#              'gene-LOC113673669': {'XP_027045922.1'},
#              'gene-LOC113677024': {'XP_027049606.1'},
#              'gene-LOC113677124': {'XP_027049715.1'},
#              'gene-LOC113675812': {'XP_027048246.1'},
#              'gene-LOC113676013': {'XP_027048461.1'},
#              'gene-LOC113675912': {'XP_027048353.1'},
#              'gene-LOC113673375': {'XP_027045609.1'},
#              'gene-LOC113673188': {'XP_027045397.1'},
#              'gene-LOC113673467': {'XP_027045721.1'},
#              'gene-LOC113673281': {'XP_027045505.1'},
#              'gene-LOC113672995': {'XP_027045179.1'},
#              'gene-LOC113672898': {'XP_027045078.1'},
#              'gene-LOC113673763': {'XP_027046037.1'},
#              'gene-LOC113672347': {'XP_027044463.1'},
#              'gene-LOC113673861': {'XP_027046152.1'},
#              'gene-LOC113673950': {'XP_027046263.1'},
#              'gene-LOC113676204': {'XP_027048670.1'},
#              'gene-LOC113674050': {'XP_027046353.1'},
#              'gene-LOC113676297': {'XP_027048784.1'},
#              'gene-LOC113675615': {'XP_027048042.1'},
#              'gene-LOC113676107': {'XP_027048557.1'},
#              'gene-LOC113672542': {'XP_027044676.1'},
#              'gene-LOC113674151': {'XP_027046458.1'},
#              'gene-LOC113675363': {'XP_027047762.1'},
#              'gene-LOC113675268': {'XP_027047658.1'},
#              'gene-LOC113674255': {'XP_027046567.1'},
#              'gene-LOC113677310': {'XP_027049948.1'},
#              'gene-LOC113677220': {'XP_027049831.1'},
#              'gene-LOC113672641': {'XP_027044789.1', 'XP_027044863.1'},
#              'gene-LOC113672791': {'XP_027044975.1'},
#              'gene-LOC113676776': {'XP_027049316.1', 'XP_027049394.1'},
#              'gene-LOC113674853': {'XP_027047188.1',
#               'XP_027047256.1',
#               'XP_027047331.1'},
#              'gene-LOC113675077': {'XP_027047447.1'},
#              'gene-LOC113675173': {'XP_027047548.1'},
#              'gene-LOC113674354': {'XP_027046673.1'},
#              'gene-LOC113674461': {'XP_027046772.1'},
#              'gene-LOC113676589': {'XP_027049102.1'},
#              'gene-LOC113676493': {'XP_027048993.1'},
#              'gene-LOC113675517': {'XP_027047949.1'},
#              'gene-LOC113676926': {'XP_027049500.1'},
#              'gene-LOC113673576': {'XP_027045812.1'},
#              'gene-LOC113674653': {'XP_027046974.1'},
#              'gene-LOC113674753': {'XP_027047084.1'},
#              'gene-LOC113676398': {'XP_027048888.1'},
#              'gene-LOC113672246': {'XP_027044360.1'},
#              'gene-LOC113676686': {'XP_027049210.1'},
#              'gene-LOC113675716': {'XP_027048147.1'},
#              'gene-LOC113677470': {'XP_027050121.1'},
#              'gene-LOC113677571': {'XP_027050229.1'},
#              'gene-LOC113678351': {'XP_027051071.1'},
#              'gene-LOC113678255': {'XP_027050967.1'},
#              'gene-LOC113679834': {'XP_027052644.1'},
#              'gene-LOC113680124': {'XP_027052958.1'},
#              'gene-LOC113678544': {'XP_027051276.1'},
#              'gene-LOC113678645': {'XP_027051378.1', 'XP_027051450.1'},
#              'gene-LOC113678807': {'XP_027051552.1'},
#              'gene-LOC113679531': {'XP_027052335.1'},
#              'gene-LOC113679128': {'XP_027051912.1'},
#              'gene-LOC113678909': {'XP_027051664.1',
#               'XP_027051734.1',
#               'XP_027051812.1'},
#              'gene-LOC113679737': {'XP_027052539.1'},
#              'gene-LOC113681011': {'XP_027053903.1'},
#              'gene-LOC113679631': {'XP_027052430.1'},
#              'gene-LOC113677764': {'XP_027050440.1'},
#              'gene-LOC113680612': {'XP_027053481.1'},
#              'gene-LOC113680711': {'XP_027053585.1'},
#              'gene-LOC113679227': {'XP_027052013.1'},
#              'gene-LOC113680514': {'XP_027053382.1'},
#              'gene-LOC113680024': {'XP_027052858.1'},
#              'gene-LOC113680810': {'XP_027053695.1'},
#              'gene-LOC113680909': {'XP_027053796.1'},
#              'gene-LOC113680410': {'XP_027053282.1'},
#              'gene-LOC113677868': {'XP_027050550.1'},
#              'gene-LOC113680319': {'XP_027053173.1'},
#              'gene-LOC113680218': {'XP_027053070.1'},
#              'gene-LOC113679930': {'XP_027052747.1'},
#              'gene-LOC113677662': {'XP_027050335.1'},
#              'gene-LOC113681105': {'XP_027054009.1',
#               'XP_027054080.1',
#               'XP_027054151.1'},
#              'gene-LOC113678159': {'XP_027050864.1'},
#              'gene-LOC113677962': {'XP_027050661.1'},
#              'gene-LOC113679329': {'XP_027052119.1'},
#              'gene-LOC113679434': {'XP_027052227.1'},
#              'gene-LOC113678057': {'XP_027050761.1'},
#              'gene-LOC113681465': {'XP_027054391.1'},
#              'gene-LOC113682447': {'XP_027055452.1',
#               'XP_027055514.1',
#               'XP_027055579.1',
#               'XP_027055651.1'},
#              'gene-LOC113681755': {'XP_027054710.1'},
#              'gene-LOC113682843': {'XP_027055854.1'},
#              'gene-LOC113681854': {'XP_027054820.1'},
#              'gene-LOC113683323': {'XP_027056391.1'},
#              'gene-LOC113683129': {'XP_027056176.1'},
#              'gene-LOC113683230': {'XP_027056282.1'},
#              'gene-LOC113682351': {'XP_027055349.1'},
#              'gene-LOC113682250': {'XP_027055239.1'},
#              'gene-LOC113681563': {'XP_027054498.1'},
#              'gene-LOC113683517': {'XP_027056600.1'},
#              'gene-LOC113681665': {'XP_027054609.1'},
#              'gene-LOC113682941': {'XP_027055969.1'},
#              'gene-LOC113681950': {'XP_027054929.1'},
#              'gene-LOC113683040': {'XP_027056072.1'},
#              'gene-LOC113682745': {'XP_027055759.1'},
#              'gene-LOC113683708': {'XP_027056814.1'},
#              'gene-LOC113682051': {'XP_027055036.1'},
#              'gene-LOC113683614': {'XP_027056703.1'},
#              'gene-LOC113682147': {'XP_027055136.1'},
#              'gene-LOC113683418': {'XP_027056492.1'},
#              'gene-LOC113685273': {'XP_027058597.1'},
#              'gene-LOC113685366': {'XP_027058711.1'},
#              'gene-LOC113685469': {'XP_027058817.1'},
#              'gene-LOC113685088': {'XP_027058388.1'},
#              'gene-LOC113684397': {'XP_027057603.1',
#               'XP_027057671.1',
#               'XP_027057747.1',
#               'XP_027057812.1',
#               'XP_027057877.1',
#               'XP_027057945.1'},
#              'gene-LOC113684206': {'XP_027057377.1'},
#              'gene-LOC113684303': {'XP_027057489.1'},
#              'gene-LOC113684909': {'XP_027058164.1'},
#              'gene-LOC113684021': {'XP_027057157.1'},
#              'gene-LOC113684110': {'XP_027057277.1'},
#              'gene-LOC113683932': {'XP_027057053.1'},
#              'gene-LOC113684816': {'XP_027058054.1'},
#              'gene-LOC113685001': {'XP_027058276.1'},
#              'gene-LOC113685662': {'XP_027059031.1'},
#              'gene-LOC113686565': {'XP_027060006.1'},
#              'gene-LOC113685758': {'XP_027059139.1', 'XP_027059217.1'},
#              'gene-LOC113686001': {'XP_027059427.1',
#               'XP_027059498.1',
#               'XP_027059564.1',
#               'XP_027059630.1'},
#              'gene-LOC113686400': {'XP_027059852.1', 'XP_027059926.1'},
#              'gene-LOC113686300': {'XP_027059742.1'},
#              'gene-LOC113685908': {'XP_027059328.1'},
#              'gene-LOC113686541': {'XP_027059981.1'},
#              'gene-LOC113686533': {'XP_027059970.1'},
#              'gene-LOC113686523': {'XP_027059958.1'},
#              'gene-LOC113686514': {'XP_027059948.1'},
#              'gene-LOC113686591': {'XP_027060032.1', 'XP_027060039.1'},
#              'gene-LOC113686608': {'XP_027060048.1'},
#              'gene-LOC113686575': {'XP_027060016.1', 'XP_027060023.1'},
#              'gene-LOC113686668': {'XP_027060118.1'},
#              'gene-LOC113686650': {'XP_027060101.1', 'XP_027060108.1'},
#              'gene-LOC113686626': {'XP_027060074.1'},
#              'gene-LOC113686617': {'XP_027060061.1'},
#              'gene-LOC113664386': {'XP_027035787.1'},
#              'gene-LOC113686921': {'XP_027060408.1'},
#              'gene-LOC113664237': {'XP_027035638.1', 'XP_027035646.1'},
#              'gene-LOC113664255': {'XP_027035657.1', 'XP_027035663.1'},
#              'gene-LOC113664273': {'XP_027035673.1'},
#              'gene-LOC113664282': {'XP_027035685.1'},
#              'gene-LOC113686704': {'XP_027060158.1', 'XP_027060166.1'},
#              'gene-LOC113686689': {'XP_027060139.1', 'XP_027060146.1'},
#              'gene-LOC113664535': {'XP_027035951.1',
#               'XP_027035958.1',
#               'XP_027035966.1',
#               'XP_027035971.1'},
#              'gene-LOC113664563': {'XP_027035985.1'},
#              'gene-LOC113664974': {'XP_027036423.1'},
#              'gene-LOC113664965': {'XP_027036400.1', 'XP_027036408.1'},
#              'gene-LOC113664981': {'XP_027036435.1'},
#              'gene-LOC113664990': {'XP_027036443.1', 'XP_027036451.1'},
#              'gene-LOC113665015': {'XP_027036473.1', 'XP_027036479.1'},
#              'gene-LOC113665007': {'XP_027036461.1'},
#              'gene-LOC113665032': {'XP_027036489.1', 'XP_027036494.1'},
#              'gene-LOC113664500': {'XP_027035910.1'},
#              'gene-LOC113664469': {'XP_027035866.1'},
#              'gene-LOC113686679': {'XP_027060127.1'},
#              'gene-LOC113664697': {'XP_027036128.1', 'XP_027036136.1'},
#              'gene-LOC113665243': {'XP_027036721.1'},
#              'gene-LOC113665050': {'XP_027036503.1'},
#              'gene-LOC113664189': {'XP_027035586.1'},
#              'gene-LOC113664199': {'XP_027035595.1'},
#              'gene-LOC113665261': {'XP_027036739.1'},
#              'gene-LOC113665196': {'XP_027036668.1', 'XP_027036676.1'},
#              'gene-LOC113665234': {'XP_027036712.1'},
#              'gene-LOC113665217': {'XP_027036688.1'},
#              'gene-LOC113665226': {'XP_027036700.1'},
#              'gene-LOC113687103': {'XP_027060611.1'},
#              'gene-LOC113686851': {'XP_027060329.1'},
#              'gene-LOC113686868': {'XP_027060350.1',
#               'XP_027060357.1',
#               'XP_027060366.1'},
#              'gene-LOC113686891': {'XP_027060377.1'},
#              'gene-LOC113686859': {'XP_027060342.1'},
#              'gene-LOC113686901': {'XP_027060389.1'},
#              'gene-LOC113686910': {'XP_027060398.1'},
#              'gene-LOC113687066': {'XP_027060572.1'},
#              'gene-LOC113686778': {'XP_027060253.1'},
#              'gene-LOC113686764': {'XP_027060233.1', 'XP_027060241.1'},
#              'gene-LOC113687113': {'XP_027060621.1'},
#              'gene-LOC113687124': {'XP_027060631.1'},
#              'gene-LOC113686799': {'XP_027060274.1'},
#              'gene-LOC113686788': {'XP_027060264.1'},
#              'gene-LOC113686810': {'XP_027060285.1',
#               'XP_027060294.1',
#               'XP_027060301.1'},
#              'gene-LOC113686753': {'XP_027060223.1'},
#              'gene-LOC113664687': {'XP_027036117.1'},
#              'gene-LOC113665107': {'XP_027036562.1', 'XP_027036568.1'},
#              'gene-LOC113664639': {'XP_027036070.1',
#               'XP_027036081.1',
#               'XP_027036088.1',
#               'XP_027036095.1'},
#              'gene-LOC113664879': {'XP_027036301.1', 'XP_027036308.1'},
#              'gene-LOC113664896': {'XP_027036319.1'},
#              'gene-LOC113664907': {'XP_027036329.1', 'XP_027036338.1'},
#              'gene-LOC113664862': {'XP_027036285.1', 'XP_027036293.1'},
#              'gene-LOC113664434': {'XP_027035838.1'},
#              'gene-LOC113664447': {'XP_027035846.1'},
#              'gene-LOC113664219': {'XP_027035616.1'},
#              'gene-LOC113664209': {'XP_027035604.1'},
#              'gene-LOC113664228': {'XP_027035628.1'},
#              'gene-LOC113664629': {'XP_027036059.1'},
#              'gene-LOC113687135': {'XP_027060645.1'},
#              'gene-LOC113664459': {'XP_027035858.1'},
#              'gene-LOC113687055': {'XP_027060561.1'},
#              'gene-LOC113664826': {'XP_027036253.1'},
#              'gene-LOC113664770': {'XP_027036201.1', 'XP_027036207.1'},
#              'gene-LOC113664787': {'XP_027036218.1'},
#              'gene-LOC113665096': {'XP_027036554.1'},
#              'gene-LOC113665061': {'XP_027036513.1', 'XP_027036522.1'},
#              'gene-LOC113665087': {'XP_027036543.1'},
#              'gene-LOC113665076': {'XP_027036533.1'},
#              'gene-LOC113664612': {'XP_027036040.1', 'XP_027036048.1'},
#              'gene-LOC113664956': {'XP_027036389.1'},
#              'gene-LOC113664945': {'XP_027036378.1'},
#              'gene-LOC113664931': {'XP_027036358.1', 'XP_027036367.1'},
#              'gene-LOC113664511': {'XP_027035920.1'},
#              'gene-LOC113687153': {'XP_027060665.1'},
#              'gene-LOC113686743': {'XP_027060213.1'},
#              'gene-LOC113665167': {'XP_027036628.1'},
#              'gene-LOC113665156': {'XP_027036617.1'},
#              'gene-LOC113665140': {'XP_027036598.1', 'XP_027036606.1'},
#              'gene-LOC113665125': {'XP_027036578.1', 'XP_027036586.1'},
#              'gene-LOC113664806': {'XP_027036232.1'},
#              'gene-LOC113664423': {'XP_027035828.1'},
#              'gene-LOC113687164': {'XP_027060675.1'},
#              'gene-LOC113664520': {'XP_027035932.1'},
#              'gene-LOC113664115': {'XP_027035518.1'},
#              'gene-LOC113664316': {'XP_027035717.1'},
#              'gene-LOC113664921': {'XP_027036347.1'},
#              'gene-LOC113664491': {'XP_027035899.1'},
#              'gene-LOC113664124': {'XP_027035528.1'},
#              'gene-LOC113664816': {'XP_027036242.1'},
#              'gene-LOC113664835': {'XP_027036260.1'},
#              'gene-LOC113664479': {'XP_027035878.1', 'XP_027035887.1'},
#              'gene-LOC113664135': {'XP_027035536.1'},
#              'gene-LOC113664396': {'XP_027035798.1', 'XP_027035806.1'},
#              'gene-LOC113664157': {'XP_027035554.1'},
#              'gene-LOC113664570': {'XP_027035997.1'},
#              'gene-LOC113664578': {'XP_027036008.1',
#               'XP_027036013.1',
#               'XP_027036019.1'},
#              'gene-LOC113664413': {'XP_027035817.1'},
#              'gene-LOC113664349': {'XP_027035749.1',
#               'XP_027035757.1',
#               'XP_027035763.1',
#               'XP_027035770.1',
#               'XP_027035777.1'},
#              'gene-LOC113664602': {'XP_027036030.1'},
#              'gene-LOC113687030': {'XP_027060532.1', 'XP_027060542.1'},
#              'gene-LOC113687046': {'XP_027060552.1'},
#              'gene-LOC113687018': {'XP_027060522.1'},
#              'gene-LOC113664167': {'XP_027035565.1'},
#              'gene-LOC113665176': {'XP_027036642.1',
#               'XP_027036648.1',
#               'XP_027036656.1'},
#              'gene-LOC113664665': {'XP_027036101.1'},
#              'gene-LOC113686964': {'XP_027060455.1'},
#              'gene-LOC113686953': {'XP_027060445.1'},
#              'gene-LOC113686932': {'XP_027060418.1',
#               'XP_027060426.1',
#               'XP_027060434.1'},
#              'gene-LOC113687009': {'XP_027060511.1'},
#              'gene-LOC113686973': {'XP_027060468.1'},
#              'gene-LOC113687000': {'XP_027060499.1'},
#              'gene-LOC113686980': {'XP_027060478.1', 'XP_027060485.1'},
#              'gene-LOC113664721': {'XP_027036153.1', 'XP_027036158.1'},
#              'gene-LOC113664760': {'XP_027036191.1'},
#              'gene-LOC113664739': {'XP_027036168.1'},
#              'gene-LOC113686830': {'XP_027060309.1'},
#              'gene-LOC113686841': {'XP_027060318.1'},
#              'gene-LOC113686719': {'XP_027060178.1'},
#              'gene-LOC113686735': {'XP_027060201.1'},
#              'gene-LOC113686726': {'XP_027060189.1'},
#              'gene-LOC113664338': {'XP_027035738.1'},
#              'gene-LOC113664327': {'XP_027035727.1'},
#              'gene-LOC113687075': {'XP_027060583.1'},
#              'gene-LOC113664177': {'XP_027035575.1'},
#              'gene-LOC113687083': {'XP_027060595.1'},
#              'gene-LOC113665282': {'XP_027036759.1'},
#              'gene-LOC113665293': {'XP_027036769.1'},
#              'gene-LOC113665271': {'XP_027036750.1'},
#              'gene-LOC113665312': {'XP_027036791.1'},
#              'gene-LOC113665319': {'XP_027036802.1'},
#              'gene-LOC113665362': {'XP_027036838.1'},
#              'gene-LOC113665329': {'XP_027036812.1'},
#              'gene-LOC113665373': {'XP_027036848.1'},
#              'gene-LOC113665395': {'XP_027036869.1'},
#              'gene-LOC113665384': {'XP_027036859.1'},
#              'gene-LOC113665405': {'XP_027036879.1'},
#              'gene-LOC113665421': {'XP_027036905.1'},
#              'gene-LOC113665429': {'XP_027036917.1'},
#              'gene-LOC113665439': {'XP_027036926.1'},
#              'gene-LOC113665454': {'XP_027036950.1', 'XP_027036959.1'},
#              'gene-LOC113665447': {'XP_027036939.1'},
#              'gene-LOC113665467': {'XP_027036969.1'},
#              'gene-LOC113665478': {'XP_027036980.1'},
#              'gene-LOC113665488': {'XP_027036992.1'},
#              'gene-LOC113665506': {'XP_027037013.1'},
#              'gene-LOC113665496': {'XP_027037003.1'},
#              'gene-LOC113665547': {'XP_027037065.1'},
#              'gene-LOC113665525': {'XP_027037038.1',
#               'XP_027037045.1',
#               'XP_027037054.1'},
#              'gene-LOC113665516': {'XP_027037026.1'},
#              'gene-LOC113665713': {'XP_027037244.1'},
#              'gene-LOC113665774': {'XP_027037301.1'},
#              'gene-LOC113665724': {'XP_027037251.1',
#               'XP_027037256.1',
#               'XP_027037264.1'},
#              'gene-LOC113665564': {'XP_027037083.1',
#               'XP_027037090.1',
#               'XP_027037098.1',
#               'XP_027037105.1'},
#              'gene-LOC113665592': {'XP_027037115.1'},
#              'gene-LOC113665634': {'XP_027037158.1'},
#              'gene-LOC113665641': {'XP_027037164.1',
#               'XP_027037172.1',
#               'XP_027037180.1'},
#              'gene-LOC113665624': {'XP_027037146.1'},
#              'gene-LOC113665614': {'XP_027037135.1'},
#              'gene-LOC113665602': {'XP_027037126.1'},
#              'gene-LOC113665837': {'XP_027037366.1',
#               'XP_027037376.1',
#               'XP_027037384.1',
#               'XP_027037389.1'},
#              'gene-LOC113665804': {'XP_027037331.1',
#               'XP_027037337.1',
#               'XP_027037343.1',
#               'XP_027037354.1'},
#              'gene-LOC113665764': {'XP_027037291.1'},
#              'gene-LOC113666011': {'XP_027037560.1'},
#              'gene-LOC113665874': {'XP_027037407.1'},
#              'gene-LOC113665943': {'XP_027037488.1', 'XP_027037496.1'},
#              'gene-LOC113665960': {'XP_027037506.1'},
#              'gene-LOC113665747': {'XP_027037274.1', 'XP_027037281.1'},
#              'gene-LOC113666022': {'XP_027037572.1'},
#              'gene-LOC113665783': {'XP_027037312.1'},
#              'gene-LOC113665970': {'XP_027037518.1'},
#              'gene-LOC113665980': {'XP_027037528.1'},
#              'gene-LOC113665864': {'XP_027037397.1'},
#              'gene-LOC113665682': {'XP_027037214.1'},
#              'gene-LOC113665794': {'XP_027037321.1'},
#              'gene-LOC113665664': {'XP_027037187.1',
#               'XP_027037192.1',
#               'XP_027037201.1'},
#              'gene-LOC113665935': {'XP_027037476.1'},
#              'gene-LOC113665885': {'XP_027037419.1', 'XP_027037427.1'},
#              'gene-LOC113665913': {'XP_027037448.1',
#               'XP_027037456.1',
#               'XP_027037464.1'},
#              'gene-LOC113665902': {'XP_027037438.1'},
#              'gene-LOC113666032': {'XP_027037584.1'},
#              'gene-LOC113666000': {'XP_027037549.1'},
#              'gene-LOC113665991': {'XP_027037538.1'},
#              'gene-LOC113665693': {'XP_027037225.1'},
#              'gene-LOC113665703': {'XP_027037234.1'},
#              'gene-LOC113666049': {'XP_027037607.1', 'XP_027037614.1'},
#              'gene-LOC113666074': {'XP_027037638.1'},
#              'gene-LOC113666066': {'XP_027037626.1'},
#              'gene-LOC113666084': {'XP_027037649.1'},
#              'gene-LOC113666188': {'XP_027037755.1'},
#              'gene-LOC113666244': {'XP_027037807.1'},
#              'gene-LOC113666253': {'XP_027037818.1'},
#              'gene-LOC113666260': {'XP_027037826.1'},
#              'gene-LOC113666147': {'XP_027037712.1'},
#              'gene-LOC113666158': {'XP_027037722.1'},
#              'gene-LOC113666169': {'XP_027037732.1'},
#              'gene-LOC113666128': {'XP_027037689.1'},
#              'gene-LOC113666137': {'XP_027037702.1'},
#              'gene-LOC113666117': {'XP_027037679.1'},
#              'gene-LOC113666235': {'XP_027037793.1'},
#              'gene-LOC113666179': {'XP_027037744.1'},
#              'gene-LOC113666213': {'XP_027037773.1'},
#              'gene-LOC113666225': {'XP_027037782.1'},
#              'gene-LOC113666271': {'XP_027037837.1'},
#              'gene-LOC113666281': {'XP_027037849.1'},
#              'gene-LOC113666299': {'XP_027037870.1'},
#              'gene-LOC113666289': {'XP_027037859.1'},
#              'gene-LOC113666383': {'XP_027037964.1', 'XP_027037972.1'},
#              'gene-LOC113666352': {'XP_027037933.1'},
#              'gene-LOC113666373': {'XP_027037954.1'},
#              'gene-LOC113666363': {'XP_027037944.1'},
#              'gene-LOC113666332': {'XP_027037912.1'},
#              'gene-LOC113666313': {'XP_027037889.1'},
#              'gene-LOC113666324': {'XP_027037901.1'},
#              'gene-LOC113666494': {'XP_027038089.1'},
#              'gene-LOC113666485': {'XP_027038078.1'},
#              'gene-LOC113666467': {'XP_027038062.1', 'XP_027038070.1'},
#              'gene-LOC113666778': {'XP_027038371.1'},
#              'gene-LOC113666767': {'XP_027038361.1'},
#              'gene-LOC113666658': {'XP_027038255.1'},
#              'gene-LOC113666795': {'XP_027038392.1'},
#              'gene-LOC113666788': {'XP_027038382.1'},
#              'gene-LOC113666737': {'XP_027038330.1'},
#              'gene-LOC113666836': {'XP_027038433.1'},
#              'gene-LOC113666825': {'XP_027038422.1'},
#              'gene-LOC113666847': {'XP_027038441.1'},
#              'gene-LOC113666437': {'XP_027038029.1'},
#              'gene-LOC113666456': {'XP_027038051.1'},
#              'gene-LOC113666446': {'XP_027038041.1'},
#              'gene-LOC113666685': {'XP_027038283.1'},
#              'gene-LOC113666626': {'XP_027038222.1'},
#              'gene-LOC113666637': {'XP_027038234.1'},
#              'gene-LOC113666807': {'XP_027038403.1', 'XP_027038410.1'},
#              'gene-LOC113666757': {'XP_027038349.1'},
#              'gene-LOC113666607': {'XP_027038198.1'},
#              'gene-LOC113666669': {'XP_027038264.1', 'XP_027038272.1'},
#              'gene-LOC113666535': {'XP_027038130.1'},
#              'gene-LOC113666647': {'XP_027038245.1'},
#              'gene-LOC113666543': {'XP_027038142.1'},
#              'gene-LOC113666553': {'XP_027038153.1'},
#              'gene-LOC113666563': {'XP_027038162.1'},
#              'gene-LOC113666715': {'XP_027038310.1'},
#              'gene-LOC113666726': {'XP_027038319.1'},
#              'gene-LOC113666573': {'XP_027038171.1'},
#              'gene-LOC113666595': {'XP_027038189.1'},
#              'gene-LOC113666584': {'XP_027038181.1'},
#              'gene-LOC113666880': {'XP_027038482.1', 'XP_027038490.1'},
#              'gene-LOC113666870': {'XP_027038473.1'},
#              'gene-LOC113666895': {'XP_027038501.1'},
#              'gene-LOC113666853': {'XP_027038454.1', 'XP_027038461.1'},
#              'gene-LOC113666421': {'XP_027038004.1'},
#              'gene-LOC113666428': {'XP_027038017.1'},
#              'gene-LOC113666516': {'XP_027038107.1'},
#              'gene-LOC113666747': {'XP_027038338.1'},
#              'gene-LOC113666527': {'XP_027038116.1'},
#              'gene-LOC113666506': {'XP_027038098.1'},
#              'gene-LOC113666694': {'XP_027038294.1'},
#              'gene-LOC113666705': {'XP_027038303.1'},
#              'gene-LOC113666618': {'XP_027038210.1'},
#              'gene-LOC113666904': {'XP_027038513.1',
#               'XP_027038518.1',
#               'XP_027038523.1'},
#              'gene-LOC113666982': {'XP_027038579.1'},
#              'gene-LOC113666972': {'XP_027038570.1'},
#              'gene-LOC113666949': {'XP_027038548.1'},
#              'gene-LOC113666960': {'XP_027038559.1'},
#              'gene-LOC113667009': {'XP_027038606.1'},
#              'gene-LOC113667082': {'XP_027038689.1'},
#              'gene-LOC113667039': {'XP_027038636.1'},
#              'gene-LOC113667049': {'XP_027038648.1'},
#              'gene-LOC113667070': {'XP_027038669.1'},
#              'gene-LOC113667287': {'XP_027038906.1'},
#              'gene-LOC113667100': {'XP_027038706.1'},
#              'gene-LOC113667137': {'XP_027038727.1'},
#              'gene-LOC113667257': {'XP_027038872.1'},
#              'gene-LOC113667277': {'XP_027038895.1'},
#              'gene-LOC113667268': {'XP_027038884.1'},
#              'gene-LOC113667297': {'XP_027038912.1'},
#              'gene-LOC113667187': {'XP_027038784.1'},
#              'gene-LOC113667204': {'XP_027038808.1'},
#              'gene-LOC113667196': {'XP_027038796.1'},
#              'gene-LOC113667147': {'XP_027038738.1'},
#              'gene-LOC113667157': {'XP_027038749.1'},
#              'gene-LOC113667247': {'XP_027038861.1'},
#              'gene-LOC113667215': {'XP_027038818.1',
#               'XP_027038826.1',
#               'XP_027038834.1',
#               'XP_027038842.1',
#               'XP_027038850.1'},
#              'gene-LOC113667166': {'XP_027038761.1'},
#              'gene-LOC113667178': {'XP_027038772.1'},
#              'gene-LOC113667307': {'XP_027038921.1'},
#              'gene-LOC113667337': {'XP_027038956.1', 'XP_027038963.1'},
#              'gene-LOC113667360': {'XP_027038981.1'},
#              'gene-LOC113667371': {'XP_027038991.1'},
#              'gene-LOC113667410': {'XP_027039030.1'},
#              'gene-LOC113667429': {'XP_027039054.1'},
#              'gene-LOC113667441': {'XP_027039063.1'},
#              'gene-LOC113667452': {'XP_027039073.1'},
#              'gene-LOC113667392': {'XP_027039011.1', 'XP_027039020.1'},
#              'gene-LOC113667419': {'XP_027039042.1'},
#              'gene-LOC113667484': {'XP_027039106.1'},
#              'gene-LOC113667527': {'XP_027039167.1', 'XP_027039175.1'},
#              'gene-LOC113667511': {'XP_027039141.1'},
#              'gene-LOC113667539': {'XP_027039185.1'},
#              'gene-LOC113667518': {'XP_027039154.1'},
#              'gene-LOC113667642': {'XP_027039305.1'},
#              'gene-LOC113667549': {'XP_027039197.1'},
#              'gene-LOC113667493': {'XP_027039118.1'},
#              'gene-LOC113667653': {'XP_027039313.1'},
#              'gene-LOC113667597': {'XP_027039246.1',
#               'XP_027039254.1',
#               'XP_027039262.1'},
#              'gene-LOC113667709': {'XP_027039367.1'},
#              'gene-LOC113667662': {'XP_027039325.1'},
#              'gene-LOC113667635': {'XP_027039293.1'},
#              'gene-LOC113667673': {'XP_027039336.1'},
#              'gene-LOC113667683': {'XP_027039348.1'},
#              'gene-LOC113667618': {'XP_027039273.1'},
#              'gene-LOC113667503': {'XP_027039128.1'},
#              'gene-LOC113667559': {'XP_027039208.1', 'XP_027039215.1'},
#              'gene-LOC113667585': {'XP_027039237.1'},
#              'gene-LOC113667574': {'XP_027039226.1'},
#              'gene-LOC113667718': {'XP_027039379.1'},
#              'gene-LOC113667789': {'XP_027039448.1'},
#              'gene-LOC113667782': {'XP_027039436.1'},
#              'gene-LOC113667728': {'XP_027039389.1'},
#              'gene-LOC113667748': {'XP_027039409.1'},
#              'gene-LOC113667739': {'XP_027039400.1'},
#              'gene-LOC113667771': {'XP_027039429.1'},
#              'gene-LOC113667795': {'XP_027039460.1'},
#              'gene-LOC113667813': {'XP_027039475.1'},
#              'gene-LOC113667852': {'XP_027039518.1', 'XP_027039525.1'},
#              'gene-LOC113667867': {'XP_027039536.1'},
#              'gene-LOC113667843': {'XP_027039505.1'},
#              'gene-LOC113667923': {'XP_027039591.1'},
#              'gene-LOC113667931': {'XP_027039603.1',
#               'XP_027039613.1',
#               'XP_027039619.1'},
#              'gene-LOC113667893': {'XP_027039556.1'},
#              'gene-LOC113667914': {'XP_027039579.1'},
#              'gene-LOC113667950': {'XP_027039628.1'},
#              'gene-LOC113667902': {'XP_027039568.1'},
#              'gene-LOC113668038': {'XP_027039725.1'},
#              'gene-LOC113668015': {'XP_027039702.1'},
#              'gene-LOC113667975': {'XP_027039657.1', 'XP_027039665.1'},
#              'gene-LOC113667992': {'XP_027039675.1', 'XP_027039682.1'},
#              'gene-LOC113668049': {'XP_027039736.1'},
#              'gene-LOC113668058': {'XP_027039747.1'},
#              'gene-LOC113668109': {'XP_027039794.1'},
#              'gene-LOC113668093': {'XP_027039773.1', 'XP_027039781.1'},
#              'gene-LOC113668082': {'XP_027039765.1'},
#              'gene-LOC113668154': {'XP_027039836.1'},
#              'gene-LOC113668166': {'XP_027039845.1'},
#              'gene-LOC113668437': {'XP_027040142.1'},
#              'gene-LOC113668349': {'XP_027040040.1'},
#              'gene-LOC113668359': {'XP_027040049.1'},
#              'gene-LOC113668423': {'XP_027040123.1'},
#              'gene-LOC113668415': {'XP_027040110.1'},
#              'gene-LOC113668448': {'XP_027040152.1'},
#              'gene-LOC113668368': {'XP_027040062.1'},
#              'gene-LOC113668394': {'XP_027040088.1'},
#              'gene-LOC113668405': {'XP_027040100.1'},
#              'gene-LOC113668245': {'XP_027039932.1'},
#              'gene-LOC113668236': {'XP_027039921.1'},
#              'gene-LOC113668256': {'XP_027039942.1', 'XP_027039947.1'},
#              'gene-LOC113668271': {'XP_027039960.1'},
#              'gene-LOC113668282': {'XP_027039971.1'},
#              'gene-LOC113668378': {'XP_027040072.1', 'XP_027040080.1'},
#              'gene-LOC113668293': {'XP_027039981.1'},
#              'gene-LOC113668302': {'XP_027039993.1',
#               'XP_027040000.1',
#               'XP_027040008.1'},
#              'gene-LOC113668326': {'XP_027040016.1'},
#              'gene-LOC113668207': {'XP_027039893.1'},
#              'gene-LOC113668215': {'XP_027039903.1'},
#              'gene-LOC113668226': {'XP_027039911.1'},
#              'gene-LOC113668339': {'XP_027040032.1'},
#              'gene-LOC113668176': {'XP_027039856.1',
#               'XP_027039861.1',
#               'XP_027039869.1',
#               'XP_027039876.1'},
#              'gene-LOC113668551': {'XP_027040274.1'},
#              'gene-LOC113668559': {'XP_027040287.1'},
#              'gene-LOC113668569': {'XP_027040299.1', 'XP_027040307.1'},
#              'gene-LOC113668509': {'XP_027040224.1'},
#              'gene-LOC113668490': {'XP_027040196.1'},
#              'gene-LOC113668484': {'XP_027040183.1'},
#              'gene-LOC113668527': {'XP_027040244.1', 'XP_027040251.1'},
#              'gene-LOC113668587': {'XP_027040324.1'},
#              'gene-LOC113668610': {'XP_027040355.1', 'XP_027040362.1'},
#              'gene-LOC113668972': {'XP_027040762.1'},
#              'gene-LOC113668654': {'XP_027040399.1'},
#              'gene-LOC113669127': {'XP_027040931.1'},
#              'gene-LOC113669135': {'XP_027040941.1', 'XP_027040948.1'},
#              'gene-LOC113668804': {'XP_027040565.1'},
#              'gene-LOC113668625': {'XP_027040370.1'},
#              'gene-LOC113668940': {'XP_027040722.1'},
#              'gene-LOC113668815': {'XP_027040574.1'},
#              'gene-LOC113668826': {'XP_027040586.1'},
#              'gene-LOC113668748': {'XP_027040503.1'},
#              'gene-LOC113668781': {'XP_027040533.1'},
#              'gene-LOC113668668': {'XP_027040424.1'},
#              'gene-LOC113668662': {'XP_027040411.1'},
#              'gene-LOC113668679': {'XP_027040435.1'},
#              'gene-LOC113669087': {'XP_027040888.1'},
#              'gene-LOC113669052': {'XP_027040845.1'},
#              'gene-LOC113669066': {'XP_027040861.1',
#               'XP_027040870.1',
#               'XP_027040878.1'},
#              'gene-LOC113668881': {'XP_027040654.1'},
#              'gene-LOC113668878': {'XP_027040640.1'},
#              'gene-LOC113668894': {'XP_027040672.1'},
#              'gene-LOC113668759': {'XP_027040511.1'},
#              'gene-LOC113668835': {'XP_027040597.1'},
#              'gene-LOC113668993': {'XP_027040784.1'},
#              'gene-LOC113668950': {'XP_027040731.1'},
#              'gene-LOC113668848': {'XP_027040605.1'},
#              'gene-LOC113668911': {'XP_027040690.1',
#               'XP_027040697.1',
#               'XP_027040704.1',
#               'XP_027040712.1'},
#              'gene-LOC113669149': {'XP_027040957.1', 'XP_027040962.1'},
#              'gene-LOC113668769': {'XP_027040523.1'},
#              'gene-LOC113668697': {'XP_027040450.1',
#               'XP_027040458.1',
#               'XP_027040466.1'},
#              'gene-LOC113668636': {'XP_027040379.1'},
#              'gene-LOC113668718': {'XP_027040477.1'},
#              'gene-LOC113668728': {'XP_027040484.1'},
#              'gene-LOC113668859': {'XP_027040615.1'},
#              'gene-LOC113668982': {'XP_027040771.1'},
#              'gene-LOC113668790': {'XP_027040545.1', 'XP_027040554.1'},
#              'gene-LOC113669023': {'XP_027040816.1'},
#              'gene-LOC113669013': {'XP_027040804.1'},
#              'gene-LOC113668646': {'XP_027040387.1'},
#              'gene-LOC113669108': {'XP_027040908.1'},
#              'gene-LOC113669097': {'XP_027040898.1'},
#              'gene-LOC113668869': {'XP_027040626.1'},
#              'gene-LOC113669032': {'XP_027040828.1'},
#              'gene-LOC113669041': {'XP_027040837.1'},
#              'gene-LOC113669167': {'XP_027040972.1'},
#              'gene-LOC113669176': {'XP_027040984.1'},
#              'gene-LOC113669187': {'XP_027040993.1'},
#              'gene-LOC113668960': {'XP_027040742.1', 'XP_027040750.1'},
#              'gene-LOC113669117': {'XP_027040917.1'},
#              'gene-LOC113669252': {'XP_027041056.1'},
#              'gene-LOC113669263': {'XP_027041067.1'},
#              'gene-LOC113669274': {'XP_027041078.1'},
#              'gene-LOC113669283': {'XP_027041089.1'},
#              'gene-LOC113669294': {'XP_027041101.1'},
#              'gene-LOC113669434': {'XP_027041268.1'},
#              'gene-LOC113669498': {'XP_027041348.1'},
#              'gene-LOC113669323': {'XP_027041145.1'},
#              'gene-LOC113669372': {'XP_027041192.1'},
#              'gene-LOC113669456': {'XP_027041292.1',
#               'XP_027041300.1',
#               'XP_027041306.1',
#               'XP_027041314.1',
#               'XP_027041321.1'},
#              'gene-LOC113669445': {'XP_027041280.1'},
#              'gene-LOC113669312': {'XP_027041136.1'},
#              'gene-LOC113669301': {'XP_027041115.1', 'XP_027041124.1'},
#              'gene-LOC113669399': {'XP_027041222.1', 'XP_027041230.1'},
#              'gene-LOC113669415': {'XP_027041240.1', 'XP_027041248.1'},
#              'gene-LOC113669491': {'XP_027041333.1'},
#              'gene-LOC113669345': {'XP_027041165.1'},
#              'gene-LOC113669356': {'XP_027041172.1', 'XP_027041181.1'},
#              'gene-LOC113669334': {'XP_027041154.1'},
#              'gene-LOC113669383': {'XP_027041204.1', 'XP_027041211.1'},
#              'gene-LOC113669527': {'XP_027041381.1'},
#              'gene-LOC113669505': {'XP_027041359.1'},
#              'gene-LOC113669557': {'XP_027041416.1', 'XP_027041423.1'},
#              'gene-LOC113669546': {'XP_027041405.1'},
#              'gene-LOC113669535': {'XP_027041392.1'},
#              'gene-LOC113669516': {'XP_027041369.1'},
#              'gene-LOC113669608': {'XP_027041482.1'},
#              'gene-LOC113669579': {'XP_027041448.1'},
#              'gene-LOC113669617': {'XP_027041492.1'},
#              'gene-LOC113669574': {'XP_027041434.1'},
#              'gene-LOC113669588': {'XP_027041458.1'},
#              'gene-LOC113669599': {'XP_027041469.1'},
#              'gene-LOC113669704': {'XP_027041583.1'},
#              'gene-LOC113669744': {'XP_027041625.1'},
#              'gene-LOC113669733': {'XP_027041614.1'},
#              'gene-LOC113669722': {'XP_027041603.1'},
#              'gene-LOC113669887': {'XP_027041775.1'},
#              'gene-LOC113669892': {'XP_027041786.1'},
#              'gene-LOC113669904': {'XP_027041796.1'},
#              'gene-LOC113670134': {'XP_027042027.1'},
#              'gene-LOC113670112': {'XP_027042009.1'},
#              'gene-LOC113669916': {'XP_027041804.1'},
#              'gene-LOC113669927': {'XP_027041814.1'},
#              'gene-LOC113669935': {'XP_027041823.1'},
#              'gene-LOC113669868': {'XP_027041754.1'},
#              'gene-LOC113669946': {'XP_027041831.1'},
#              'gene-LOC113669956': {'XP_027041843.1'},
#              'gene-LOC113669647': {'XP_027041522.1'},
#              'gene-LOC113669967': {'XP_027041854.1'},
#              'gene-LOC113669978': {'XP_027041865.1'},
#              'gene-LOC113669989': {'XP_027041875.1'},
#              'gene-LOC113670000': {'XP_027041885.1'},
#              'gene-LOC113669683': {'XP_027041562.1'},
#              'gene-LOC113669692': {'XP_027041574.1'},
#              'gene-LOC113669713': {'XP_027041592.1'},
#              'gene-LOC113670012': {'XP_027041895.1'},
#              'gene-LOC113669638': {'XP_027041512.1'},
#              'gene-LOC113670021': {'XP_027041906.1'},
#              'gene-LOC113670062': {'XP_027041951.1', 'XP_027041957.1'},
#              'gene-LOC113670079': {'XP_027041968.1'},
#              'gene-LOC113670123': {'XP_027042018.1'},
#              'gene-LOC113670032': {'XP_027041918.1'},
#              'gene-LOC113670041': {'XP_027041931.1'},
#              'gene-LOC113669859': {'XP_027041744.1'},
#              'gene-LOC113670153': {'XP_027042047.1'},
#              'gene-LOC113669844': {'XP_027041729.1'},
#              'gene-LOC113669837': {'XP_027041717.1'},
#              'gene-LOC113669811': {'XP_027041689.1', 'XP_027041697.1'},
#              'gene-LOC113670160': {'XP_027042059.1',
#               'XP_027042067.1',
#               'XP_027042075.1'},
#              'gene-LOC113669826': {'XP_027041707.1'},
#              'gene-LOC113669668': {'XP_027041544.1', 'XP_027041551.1'},
#              'gene-LOC113670052': {'XP_027041940.1'},
#              'gene-LOC113669755': {'XP_027041636.1'},
#              'gene-LOC113669657': {'XP_027041532.1'},
#              'gene-LOC113669784': {'XP_027041666.1',
#               'XP_027041673.1',
#               'XP_027041678.1'},
#              'gene-LOC113670143': {'XP_027042036.1'},
#              'gene-LOC113670087': {'XP_027041978.1'},
#              'gene-LOC113670103': {'XP_027041998.1'},
#              'gene-LOC113670194': {'XP_027042095.1', 'XP_027042102.1'},
#              'gene-LOC113670182': {'XP_027042086.1'},
#              'gene-LOC113670244': {'XP_027042153.1'},
#              'gene-LOC113670218': {'XP_027042125.1'},
#              'gene-LOC113670210': {'XP_027042112.1'},
#              'gene-LOC113670386': {'XP_027042332.1'},
#              'gene-LOC113670265': {'XP_027042176.1'},
#              'gene-LOC113670354': {'XP_027042293.1',
#               'XP_027042302.1',
#               'XP_027042310.1'},
#              'gene-LOC113670344': {'XP_027042281.1'},
#              'gene-LOC113670375': {'XP_027042321.1'},
#              'gene-LOC113670331': {'XP_027042256.1'},
#              'gene-LOC113670309': {'XP_027042236.1'},
#              'gene-LOC113670298': {'XP_027042224.1'},
#              'gene-LOC113670336': {'XP_027042269.1'},
#              'gene-LOC113670404': {'XP_027042348.1', 'XP_027042355.1'},
#              'gene-LOC113670422': {'XP_027042366.1'},
#              'gene-LOC113670284': {'XP_027042208.1'},
#              'gene-LOC113670273': {'XP_027042189.1', 'XP_027042198.1'},
#              'gene-LOC113670432': {'XP_027042377.1'},
#              'gene-LOC113670443': {'XP_027042387.1'},
#              'gene-LOC113670597': {'XP_027042563.1'},
#              'gene-LOC113670453': {'XP_027042399.1'},
#              'gene-LOC113670734': {'XP_027042719.1'},
#              'gene-LOC113670742': {'XP_027042733.1'},
#              'gene-LOC113670750': {'XP_027042745.1'},
#              'gene-LOC113670760': {'XP_027042753.1'},
#              'gene-LOC113670868': {'XP_027042871.1'},
#              'gene-LOC113670788': {'XP_027042788.1'},
#              'gene-LOC113670871': {'XP_027042884.1'},
#              'gene-LOC113670821': {'XP_027042814.1'},
#              'gene-LOC113670499': {'XP_027042457.1', 'XP_027042464.1'},
#              'gene-LOC113670484': {'XP_027042432.1'},
#              'gene-LOC113670492': {'XP_027042443.1'},
#              'gene-LOC113670608': {'XP_027042575.1'},
#              'gene-LOC113670617': {'XP_027042587.1'},
#              'gene-LOC113670473': {'XP_027042420.1'},
#              'gene-LOC113670832': {'XP_027042822.1'},
#              'gene-LOC113670843': {'XP_027042834.1'},
#              'gene-LOC113670698': {'XP_027042679.1'},
#              'gene-LOC113670644': {'XP_027042621.1', 'XP_027042628.1'},
#              'gene-LOC113670553': {'XP_027042514.1',
#               'XP_027042526.1',
#               'XP_027042534.1',
#               'XP_027042541.1',
#               'XP_027042549.1',
#               'XP_027042555.1'},
#              'gene-LOC113670769': {'XP_027042766.1'},
#              'gene-LOC113670779': {'XP_027042777.1'},
#              'gene-LOC113670853': {'XP_027042846.1'},
#              'gene-LOC113670687': {'XP_027042667.1'},
#              'gene-LOC113670659': {'XP_027042639.1', 'XP_027042646.1'},
#              'gene-LOC113670676': {'XP_027042657.1'},
#              'gene-LOC113670635': {'XP_027042611.1'},
#              'gene-LOC113670626': {'XP_027042599.1'},
#              'gene-LOC113670525': {'XP_027042484.1'},
#              'gene-LOC113670515': {'XP_027042476.1'},
#              'gene-LOC113670536': {'XP_027042496.1', 'XP_027042502.1'},
#              'gene-LOC113670716': {'XP_027042695.1'},
#              'gene-LOC113671071': {'XP_027043087.1'},
#              'gene-LOC113670959': {'XP_027042978.1'},
#              'gene-LOC113670983': {'XP_027042997.1',
#               'XP_027043002.1',
#               'XP_027043009.1',
#               'XP_027043012.1'},
#              'gene-LOC113671023': {'XP_027043031.1'},
#              'gene-LOC113671041': {'XP_027043054.1'},
#              'gene-LOC113670899': {'XP_027042916.1'},
#              'gene-LOC113670971': {'XP_027042989.1'},
#              'gene-LOC113671011': {'XP_027043023.1'},
#              'gene-LOC113670909': {'XP_027042925.1'},
#              'gene-LOC113671060': {'XP_027043075.1'},
#              'gene-LOC113670940': {'XP_027042957.1'},
#              'gene-LOC113670949': {'XP_027042968.1'},
#              'gene-LOC113670919': {'XP_027042936.1'},
#              'gene-LOC113670929': {'XP_027042947.1'},
#              'gene-LOC113670882': {'XP_027042893.1'},
#              'gene-LOC113670892': {'XP_027042906.1'},
#              'gene-LOC113671052': {'XP_027043065.1'},
#              'gene-LOC113671034': {'XP_027043042.1'},
#              'gene-LOC113671077': {'XP_027043098.1'},
#              'gene-LOC113671113': {'XP_027043136.1'},
#              'gene-LOC113671123': {'XP_027043147.1'},
#              'gene-LOC113671097': {'XP_027043120.1', 'XP_027043125.1'},
#              'gene-LOC113671390': {'XP_027043369.1'},
#              'gene-LOC113671301': {'XP_027043316.1'},
#              'gene-LOC113671221': {'XP_027043231.1'},
#              'gene-LOC113671232': {'XP_027043239.1'},
#              'gene-LOC113671243': {'XP_027043251.1'},
#              'gene-LOC113671148': {'XP_027043166.1'},
#              'gene-LOC113671171': {'XP_027043187.1'},
#              'gene-LOC113671159': {'XP_027043175.1'},
#              'gene-LOC113671210': {'XP_027043228.1'},
#              'gene-LOC113671199': {'XP_027043220.1'},
#              'gene-LOC113671189': {'XP_027043210.1'},
#              'gene-LOC113671180': {'XP_027043198.1'},
#              'gene-LOC113671264': {'XP_027043273.1'},
#              'gene-LOC113671273': {'XP_027043285.1'},
#              'gene-LOC113671348': {'XP_027043365.1'},
#              'gene-LOC113671362': {'XP_027043366.1'},
#              'gene-LOC113671312': {'XP_027043328.1', 'XP_027043334.1'},
#              'gene-LOC113671337': {'XP_027043357.1'},
#              'gene-LOC113671327': {'XP_027043347.1'},
#              'gene-LOC113671422': {'XP_027043411.1'},
#              'gene-LOC113671454': {'XP_027043460.1',
#               'XP_027043468.1',
#               'XP_027043477.1'},
#              'gene-LOC113671431': {'XP_027043423.1'},
#              'gene-LOC113671445': {'XP_027043448.1'},
#              'gene-LOC113671475': {'XP_027043488.1'},
#              'gene-LOC113671890': {'XP_027043953.1'},
#              'gene-LOC113671934': {'XP_027044004.1'},
#              'gene-LOC113671896': {'XP_027043964.1'},
#              'gene-LOC113671919': {'XP_027043985.1', 'XP_027043993.1'},
#              'gene-LOC113671908': {'XP_027043975.1'},
#              'gene-LOC113671869': {'XP_027043930.1'},
#              'gene-LOC113671846': {'XP_027043910.1'},
#              'gene-LOC113671588': {'XP_027043636.1', 'XP_027043644.1'},
#              'gene-LOC113671721': {'XP_027043774.1',
#               'XP_027043781.1',
#               'XP_027043789.1'},
#              'gene-LOC113671605': {'XP_027043655.1'},
#              'gene-LOC113671626': {'XP_027043675.1', 'XP_027043682.1'},
#              'gene-LOC113671642': {'XP_027043692.1'},
#              'gene-LOC113671615': {'XP_027043666.1'},
#              'gene-LOC113671653': {'XP_027043701.1'},
#              'gene-LOC113671661': {'XP_027043713.1'},
#              'gene-LOC113671688': {'XP_027043744.1'},
#              'gene-LOC113671699': {'XP_027043755.1'},
#              'gene-LOC113671672': {'XP_027043724.1', 'XP_027043733.1'},
#              'gene-LOC113671744': {'XP_027043801.1'},
#              'gene-LOC113671755': {'XP_027043812.1'},
#              'gene-LOC113671858': {'XP_027043919.1'},
#              'gene-LOC113671570': {'XP_027043616.1'},
#              'gene-LOC113671577': {'XP_027043627.1'},
#              'gene-LOC113671516': {'XP_027043535.1'},
#              'gene-LOC113671540': {'XP_027043565.1'},
#              'gene-LOC113671530': {'XP_027043554.1'},
#              'gene-LOC113671497': {'XP_027043514.1'},
#              'gene-LOC113671564': {'XP_027043601.1'},
#              'gene-LOC113671546': {'XP_027043578.1'},
#              'gene-LOC113671556': {'XP_027043589.1'},
#              'gene-LOC113671766': {'XP_027043822.1'},
#              'gene-LOC113671879': {'XP_027043940.1'},
#              'gene-LOC113671776': {'XP_027043833.1'},
#              'gene-LOC113671797': {'XP_027043855.1'},
#              'gene-LOC113671808': {'XP_027043867.1'},
#              'gene-LOC113671815': {'XP_027043877.1'},
#              'gene-LOC113671508': {'XP_027043525.1'},
#              'gene-LOC113671826': {'XP_027043889.1'},
#              'gene-LOC113671836': {'XP_027043899.1'},
#              'gene-LOC113671953': {'XP_027044026.1'},
#              'gene-LOC113671984': {'XP_027044053.1'},
#              'gene-LOC113672003': {'XP_027044077.1'},
#              'gene-LOC113672219': {'XP_027044307.1',
#               'XP_027044316.1',
#               'XP_027044324.1'},
#              'gene-LOC113672198': {'XP_027044280.1',
#               'XP_027044289.1',
#               'XP_027044297.1'},
#              'gene-LOC113671994': {'XP_027044065.1'},
#              'gene-LOC113672068': {'XP_027044144.1',
#               'XP_027044153.1',
#               'XP_027044161.1',
#               'XP_027044168.1'},
#              'gene-LOC113672264': {'XP_027044351.1'},
#              'gene-LOC113672331': {'XP_027044412.1'},
#              'gene-LOC113672297': {'XP_027044374.1'},
#              'gene-LOC113672275': {'XP_027044357.1'},
#              'gene-LOC113672342': {'XP_027044424.1'},
#              'gene-LOC113672254': {'XP_027044343.1'},
#              'gene-LOC113672285': {'XP_027044365.1'},
#              'gene-LOC113672322': {'XP_027044401.1'},
#              'gene-LOC113672012': {'XP_027044087.1'},
#              'gene-LOC113672042': {'XP_027044118.1', 'XP_027044126.1'},
#              'gene-LOC113672096': {'XP_027044176.1', 'XP_027044183.1'},
#              'gene-LOC113672110': {'XP_027044193.1', 'XP_027044200.1'},
#              'gene-LOC113672156': {'XP_027044239.1'},
#              'gene-LOC113672148': {'XP_027044229.1'},
#              'gene-LOC113672135': {'XP_027044219.1'},
#              'gene-LOC113672177': {'XP_027044260.1'},
#              'gene-LOC113672125': {'XP_027044209.1'},
#              'gene-LOC113672167': {'XP_027044248.1'},
#              'gene-LOC113672057': {'XP_027044135.1'},
#              'gene-LOC113672023': {'XP_027044096.1'},
#              'gene-LOC113672033': {'XP_027044108.1'},
#              'gene-LOC113672242': {'XP_027044334.1'},
#              'gene-LOC113672188': {'XP_027044270.1'},
#              'gene-LOC113672498': {'XP_027044589.1'},
#              'gene-LOC113672451': {'XP_027044536.1'},
#              'gene-LOC113672538': {'XP_027044634.1', 'XP_027044642.1'},
#              'gene-LOC113672528': {'XP_027044621.1'},
#              'gene-LOC113672458': {'XP_027044548.1'},
#              'gene-LOC113672440': {'XP_027044523.1'},
#              'gene-LOC113672390': {'XP_027044478.1'},
#              'gene-LOC113672380': {'XP_027044468.1'},
#              'gene-LOC113672411': {'XP_027044496.1'},
#              'gene-LOC113672519': {'XP_027044611.1'},
#              'gene-LOC113672508': {'XP_027044600.1'},
#              'gene-LOC113672430': {'XP_027044513.1'},
#              'gene-LOC113672400': {'XP_027044486.1'},
#              'gene-LOC113672360': {'XP_027044445.1'},
#              'gene-LOC113672371': {'XP_027044455.1'},
#              'gene-LOC113672352': {'XP_027044435.1'},
#              'gene-LOC113672549': {'XP_027044654.1'},
#              'gene-LOC113672560': {'XP_027044665.1'},
#              'gene-LOC113672664': {'XP_027044790.1'},
#              'gene-LOC113672615': {'XP_027044727.1'},
#              'gene-LOC113672658': {'XP_027044777.1'},
#              'gene-LOC113672637': {'XP_027044749.1',
#               'XP_027044757.1',
#               'XP_027044765.1'},
#              'gene-LOC113672626': {'XP_027044738.1'},
#              'gene-LOC113672590': {'XP_027044697.1'},
#              'gene-LOC113672601': {'XP_027044713.1'},
#              'gene-LOC113672570': {'XP_027044677.1'},
#              'gene-LOC113672680': {'XP_027044808.1', 'XP_027044816.1'},
#              'gene-LOC113672701': {'XP_027044833.1'},
#              'gene-LOC113672720': {'XP_027044856.1', 'XP_027044864.1'},
#              'gene-LOC113672733': {'XP_027044877.1'},
#              'gene-LOC113672766': {'XP_027044910.1'},
#              'gene-LOC113672771': {'XP_027044921.1'},
#              'gene-LOC113672780': {'XP_027044932.1'},
#              'gene-LOC113672792': {'XP_027044942.1', 'XP_027044949.1'},
#              'gene-LOC113672809': {'XP_027044959.1'},
#              'gene-LOC113672710': {'XP_027044845.1'},
#              'gene-LOC113672754': {'XP_027044898.1'},
#              'gene-LOC113672743': {'XP_027044888.1'},
#              'gene-LOC113672842': {'XP_027044994.1'},
#              'gene-LOC113672831': {'XP_027044983.1'},
#              'gene-LOC113672820': {'XP_027044970.1'},
#              'gene-LOC113672853': {'XP_027045005.1'},
#              'gene-LOC113672874': {'XP_027045024.1'},
#              'gene-LOC113673077': {'XP_027045235.1'},
#              'gene-LOC113672929': {'XP_027045079.1'},
#              'gene-LOC113672884': {'XP_027045034.1', 'XP_027045041.1'},
#              'gene-LOC113672903': {'XP_027045050.1', 'XP_027045057.1'},
#              'gene-LOC113673056': {'XP_027045215.1'},
#              'gene-LOC113673046': {'XP_027045203.1'},
#              'gene-LOC113673065': {'XP_027045225.1'},
#              'gene-LOC113673162': {'XP_027045336.1'},
#              'gene-LOC113673097': {'XP_027045258.1'},
#              'gene-LOC113673006': {'XP_027045158.1'},
#              'gene-LOC113672996': {'XP_027045147.1'},
#              'gene-LOC113673115': {'XP_027045281.1'},
#              'gene-LOC113673245': {'XP_027045435.1'},
#              'gene-LOC113673169': {'XP_027045348.1'},
#              'gene-LOC113672939': {'XP_027045087.1'},
#              'gene-LOC113672950': {'XP_027045096.1'},
#              'gene-LOC113672959': {'XP_027045107.1'},
#              'gene-LOC113672977': {'XP_027045131.1'},
#              'gene-LOC113673180': {'XP_027045357.1'},
#              'gene-LOC113672968': {'XP_027045119.1'},
#              'gene-LOC113673192': {'XP_027045367.1'},
#              'gene-LOC113673202': {'XP_027045377.1'},
#              'gene-LOC113672987': {'XP_027045135.1'},
#              'gene-LOC113673210': {'XP_027045389.1'},
#              'gene-LOC113673154': {'XP_027045324.1'},
#              'gene-LOC113672864': {'XP_027045014.1'},
#              'gene-LOC113673143': {'XP_027045315.1'},
#              'gene-LOC113673218': {'XP_027045401.1'},
#              'gene-LOC113673230': {'XP_027045412.1'},
#              'gene-LOC113673106': {'XP_027045269.1'},
#              'gene-LOC113673122': {'XP_027045293.1'},
#              'gene-LOC113673133': {'XP_027045304.1'},
#              'gene-LOC113673087': {'XP_027045246.1'},
#              'gene-LOC113673235': {'XP_027045425.1'},
#              'gene-LOC113673266': {'XP_027045457.1'},
#              'gene-LOC113673407': {'XP_027045605.1'},
#              'gene-LOC113673416': {'XP_027045618.1'},
#              'gene-LOC113673395': {'XP_027045593.1'},
#              'gene-LOC113673305': {'XP_027045501.1'},
#              'gene-LOC113673298': {'XP_027045488.1'},
#              'gene-LOC113673657': {'XP_027045877.1', 'XP_027045883.1'},
#              'gene-LOC113673614': {'XP_027045826.1',
#               'XP_027045834.1',
#               'XP_027045841.1'},
#              'gene-LOC113673440': {'XP_027045659.1'},
#              'gene-LOC113673276': {'XP_027045466.1'},
#              'gene-LOC113673474': {'XP_027045698.1'},
#              'gene-LOC113673335': {'XP_027045533.1'},
#              'gene-LOC113673520': {'XP_027045742.1'},
#              'gene-LOC113673533': {'XP_027045746.1'},
#              'gene-LOC113673648': {'XP_027045866.1'},
#              'gene-LOC113673547': {'XP_027045756.1'},
#              'gene-LOC113673511': {'XP_027045731.1'},
#              'gene-LOC113673500': {'XP_027045722.1'},
#              'gene-LOC113673586': {'XP_027045794.1'},
#              'gene-LOC113673711': {'XP_027045943.1'},
#              'gene-LOC113673288': {'XP_027045477.1'},
#              'gene-LOC113673449': {'XP_027045670.1'},
#              'gene-LOC113673383': {'XP_027045588.1'},
#              'gene-LOC113673354': {'XP_027045553.1',
#               'XP_027045562.1',
#               'XP_027045569.1',
#               'XP_027045577.1'},
#              'gene-LOC113673315': {'XP_027045512.1'},
#              'gene-LOC113673343': {'XP_027045544.1'},
#              'gene-LOC113673430': {'XP_027045636.1', 'XP_027045646.1'},
#              'gene-LOC113673325': {'XP_027045523.1'},
#              'gene-LOC113673673': {'XP_027045891.1',
#               'XP_027045898.1',
#               'XP_027045905.1',
#               'XP_027045914.1'},
#              'gene-LOC113673721': {'XP_027045952.1'},
#              'gene-LOC113673732': {'XP_027045963.1'},
#              'gene-LOC113673742': {'XP_027045976.1'},
#              'gene-LOC113673749': {'XP_027045987.1'},
#              'gene-LOC113673863': {'XP_027046120.1'},
#              'gene-LOC113673804': {'XP_027046052.1'},
#              'gene-LOC113673902': {'XP_027046170.1', 'XP_027046180.1'},
#              ...})

# %%
all_IPRS_desc = pd.read_csv("../overrep_domains/avg/with_conv_filt/all_IPR_desc.tsv", sep="\t")
all_IPRS_desc
# Out:
#           IPR_id                                        description
# 0            NaN                                                NaN
# 1      IPR002181  Fibrinogen, alpha/beta/gamma chain, C-terminal...
# 2      IPR036056                        Fibrinogen-like, C-terminal
# 3      IPR000885                     Fibrillar collagen, C-terminal
# 4      IPR002110                                     Ankyrin repeat
# ...          ...                                                ...
# 14329  IPR003566                    T-cell surface glycoprotein CD5
# 14330  IPR037004         Exonuclease VII, small subunit superfamily
# 14331  IPR004124         Glycoside hydrolase, family 33, N-terminal
# 14332  IPR012480                             Heparinase II/III-like
# 14333  IPR022045           Insecticide toxin TcdB middle/N-terminal
#
# [14334 rows x 2 columns]

# %% [markdown]
# ### Retrieve CNE thresholds

# %%
summary_by_sp_file = "../overrep_domains/new_parse_gff/avg/summary_by_sp.tsv"
summary_by_sp_df = pd.read_csv(summary_by_sp_file, sep="\t")
summary_by_sp_df
# Out:
#    species  cne_count  gene_count  cne_threshold  num_IPR_tested  \
# 0     hsym       6463       22022       0.293479            4375
# 1     hvul       2029       20058       0.101157            2064
# 2     pdam      81412       19935       4.083873            4895
# 3     ofav      42827       25929       1.651703            5081
# 4     epal       5026       22509       0.223288            2859
# 5     mvir       2654       24278       0.109317            2480
# 6     spis     106547       24846       4.288296            5348
# 7     chem       2289       45872       0.049900            1505
# 8     dgig       3562       22045       0.161579            1509
# 9     nvec       3471       23845       0.145565            2590
# 10    aaur       2009       30167       0.066596            1601
# 11    adig      49942       26073       1.915468            4224
# 12    aten       5256       19980       0.263063            3539
#
#     num_sig_IPRs  num_homeo
# 0             21          0
# 1              0          0
# 2             76          4
# 3             22          3
# 4             12          1
# 5              6          0
# 6             71          4
# 7              1          0
# 8             21          0
# 9              4          0
# 10             1          0
# 11            56          0
# 12            22          4

# %%
mean_cne_dict = {}
for idx, row in summary_by_sp_df.iterrows():
    species = row['species']
    mean_cne = row['cne_threshold']
    mean_cne_dict[species] = mean_cne
mean_cne_dict
# Out:
# {'aaur': 0.06659594921603076,
#  'adig': 1.9154681087715264,
#  'aten': 0.26306306306306304,
#  'chem': 0.049899720962678765,
#  'dgig': 0.16157858924926288,
#  'epal': 0.22328846239282066,
#  'hsym': 0.2934792480247025,
#  'hvul': 0.10115664572739057,
#  'mvir': 0.1093170771892248,
#  'nvec': 0.14556510798909625,
#  'ofav': 1.6517027266766942,
#  'pdam': 4.083872585904189,
#  'spis': 4.288295902761008}

# %%
def format_interpro_res(interpro_file, cne_count_df):
    interpro_results = pd.read_table(interpro_file, names = ('protein_id', 'identifier', 'length', 'software', 
                                                             'software_id', 'software_prediction', 'start', 'end',
                                                             'score', 'status', 'date', 'IPR_id', 'description'))
    interpro_results = interpro_results.dropna(subset=['IPR_id'])
    #### dmel has dashes insted of NA column IPR_id
    interpro_results = interpro_results[interpro_results['IPR_id'] != '-']
    interpro_results = interpro_results.reset_index(drop = True)
    interpro_results = interpro_results[['protein_id', 'software','IPR_id', 'description']]
    interpro_results = interpro_results.drop_duplicates(subset=['protein_id', 'IPR_id'])
    # Merge with closest_genes_df
    #interpro_results = interpro_results.merge(closest_genes_df, how = 'left', on = 'gene_id')
    annot_df = cne_count_df.merge(interpro_results, how = 'left', on = 'protein_id' )
    #interpro_results = interpro_results.merge(cne_count_df, how = 'outer', on = 'gene_id') # how = 'left',
    #interpro_results.loc[interpro_results['closest_cne_count'].isna(), 'closest_cne_count'] = 0 
    annot_df.loc[annot_df['IPR_id'].isna(), 'IPR_id'] = 'no_IPR' 
    return annot_df

# %% [markdown]
# ### Retrieve one protein per gene to merge Blast annotations

# %%
all_sp_protein_df = pd.DataFrame(columns=['species', 'gene_id', 'protein_id'])
for species, gene_dict in gene_protein_dict.items():
    sp_protein_dict = {}
    for gene_id, protein_set in gene_dict.items():
        sp_protein_dict[gene_id] = list(protein_set)[0] # random protein for annotation
    sp_gene_protein_df = pd.DataFrame(sp_protein_dict.items(), columns=['gene_id', 'protein_id'])
    sp_gene_protein_df['species'] = species
    all_sp_protein_df = pd.concat([all_sp_protein_df, sp_gene_protein_df])
all_sp_protein_df
# Out:
#       species            gene_id      protein_id
# 0        spis  gene-LOC111326177  XP_022785962.1
# 1        spis  gene-LOC111327133  XP_022787155.1
# 2        spis  gene-LOC111327047  XP_022786908.1
# 3        spis  gene-LOC111328643  XP_022788889.1
# 4        spis  gene-LOC111328547  XP_022788781.1
# ...       ...                ...             ...
# 23840    nvec    gene-LOC5522391  XP_032223481.1
# 23841    nvec    gene-LOC5522393  XP_032223620.1
# 23842    nvec    gene-LOC5522254  XP_032223631.1
# 23843    nvec    gene-LOC5522255  XP_001642144.2
# 23844    nvec  gene-LOC116604818  XP_032223632.1
#
# [327559 rows x 3 columns]

# %%
def rank_genes_by_cne_count(cne_counts, species):
    print('Read Blast annotations')
    annotations = annotations_dir + species + "_annotations_combined.tsv"
    annotations_df = pd.read_csv(annotations, sep="\t")
    annotations_df = annotations_df.rename({'gene_id':'protein_id'}, axis=1)
    print('Merge CNE counts with BLAST annotations') 
    cne_counts_sp = cne_counts[cne_counts['species']==species]
    cne_counts_sp = cne_counts_sp.rename({'gene': 'gene_id'}, axis=1)
    cne_counts_sp = cne_counts_sp.groupby('gene_id').sum().reset_index()
    cne_counts_sp = cne_counts_sp.merge(all_sp_protein_df)
    cne_counts_sp = cne_counts_sp.merge(annotations_df, how='left', on='protein_id')
    print("Merge CNE counts with Interpro annotations")
    interpro_file = interpro_dir + species + "_combined.tsv"
    cne_counts_annot = format_interpro_res(interpro_file, cne_counts_sp)
    print("Combine IPR IDs and descriptions for each gene")
    cne_counts_annot = cne_counts_annot.fillna('')
    combined_IPRid = cne_counts_annot.groupby('gene_id')['IPR_id'].apply(lambda x: ','.join(x)).reset_index()\
        .rename({'IPR_id': 'IPR_ids'}, axis=1)
    combined_descs = cne_counts_annot.groupby('gene_id')['description'].apply(lambda x: ','.join(x)).reset_index()\
        .rename({'description': 'descriptions'}, axis=1)
    output_df = cne_counts_annot.drop(['software', 'IPR_id', 'description'], axis=1).drop_duplicates('gene_id').\
        merge(combined_IPRid, how='left').merge(combined_descs, how='left')
    output_df = output_df[output_df['closest_cne_count']!='']
    output_df = output_df.sort_values('closest_cne_count',ascending=False).reset_index(drop=True)
    output_df.closest_cne_count = output_df.closest_cne_count.astype(int)
    output_df['rank'] = output_df.index + 1
    return(output_df)

# %%
for species in set(cne_counts['species']):
    output_df = rank_genes_by_cne_count(cne_counts, species)
    output_df.to_csv(species + "_ranked_genes.tsv", sep="\t", index=False)
# Out:
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Merge CNE counts with Interpro annotations
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Merge CNE counts with Interpro annotations
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Merge CNE counts with Interpro annotations
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Merge CNE counts with Interpro annotations
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Merge CNE counts with Interpro annotations
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Merge CNE counts with Interpro annotations
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Merge CNE counts with Interpro annotations
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Merge CNE counts with Interpro annotations
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Merge CNE counts with Interpro annotations
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Merge CNE counts with Interpro annotations
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Merge CNE counts with Interpro annotations
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Merge CNE counts with Interpro annotations
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Merge CNE counts with Interpro annotations
# Combine IPR IDs and descriptions for each gene

# %% [markdown]
# ### Rank genes with protein domains of interest only

# %%
### Take all overrepresented domains
### Classify by type (already curated IPRs for stacked barplots): homeo, TF, immuno, TE...
### Retrieve all genes with > average CNEs
### Assign gene to each type
### Calculate pct CNEs associated with each type
### Make piechart for all species
### output

# %%
def rank_genes_IPR_list(cne_counts, species, IPR_list):
    mean_cne = mean_cne_dict[species]
    print('Read Blast annotations')
    annotations = annotations_dir + species + "_annotations_combined.tsv"
    annotations_df = pd.read_csv(annotations, sep="\t")
    annotations_df = annotations_df.rename({'gene_id':'protein_id'}, axis=1)
    print('Merge CNE counts with BLAST annotations') 
    cne_counts_sp = cne_counts[cne_counts['species']==species]
    cne_counts_sp = cne_counts_sp.rename({'gene': 'gene_id'}, axis=1)
    cne_counts_sp = cne_counts_sp.groupby('gene_id').sum().reset_index()
    if species not in ['hsym']: # no origin annot available
        print('Read original annotations')
        orig_annot_file = orig_annot_dir + species + "_orig_annot.tsv"
        orig_annot_df = pd.read_csv(orig_annot_file, sep="\t")
        cne_counts_sp = cne_counts_sp.merge(orig_annot_df)
    cne_counts_sp = cne_counts_sp.merge(all_sp_protein_df)
    cne_counts_sp = cne_counts_sp.merge(annotations_df, how='left', on='protein_id')
    print("Merge CNE counts with Interpro annotations")
    interpro_file = interpro_dir + species + "_combined.tsv"
    cne_counts_annot = format_interpro_res(interpro_file, cne_counts_sp)
    print("Filter by IPR_id")
    cne_counts_annot = cne_counts_annot[cne_counts_annot['IPR_id'].isin(IPR_list)]
    print("Combine IPR IDs and descriptions for each gene")
    cne_counts_annot = cne_counts_annot.fillna('')
    combined_IPRid = cne_counts_annot.groupby('gene_id')['IPR_id'].apply(lambda x: ','.join(x)).reset_index()\
        .rename({'IPR_id': 'IPR_ids'}, axis=1)
    combined_descs = cne_counts_annot.groupby('gene_id')['description'].apply(lambda x: ','.join(x)).reset_index()\
        .rename({'description': 'descriptions'}, axis=1)
    output_df = cne_counts_annot.drop(['software', 'IPR_id', 'description'], axis=1).drop_duplicates('gene_id').\
        merge(combined_IPRid, how='left').merge(combined_descs, how='left')
    output_df = output_df[output_df['closest_cne_count']!='']
    output_df = output_df.sort_values('closest_cne_count',ascending=False).reset_index(drop=True)
    output_df.closest_cne_count = output_df.closest_cne_count.astype(int)
    output_df['rank'] = output_df.index + 1
    # remove genes with CNEs < mean
    output_df = output_df[output_df['closest_cne_count'] > mean_cne]
    return(output_df)

# %%
homeo_IPRs = ['IPR009057', 'IPR017970', 'IPR001356', 'IPR020479', 'IPR008422', 'IPR032967',
               'IPR032453', 'IPR000747' ]

# %% [markdown]
# ### Output ranked homeodomain genes

# %%
out_dir = 'homeo_ranked_genes/'
os.mkdir(out_dir)
for species in set(cne_counts['species']):
    output_df = rank_genes_IPR_list(cne_counts, species, homeo_IPRs)
    output_df.to_csv(out_dir + species + "_homeo_ranked.tsv", sep="\t", index=False)
# Out:
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene

# %% [markdown]
# ### Output ranked Immunoglobulin genes

# %%
IPRs_file = "../../cnidaria_06_22/combine_overrep_analyses/all_IPRs_curated.txt"
IPRs_df = pd.read_csv(IPRs_file, sep="\t")
IPRs_df
# Out:
#         IPR_id                                        description  class
# 0    IPR029034                              Cystine-knot cytokine  other
# 1    IPR001303               Class II aldolase/adducin N-terminal  other
# 2    IPR033929             Tensin, phosphotyrosine-binding domain  other
# 3    IPR011641  Tyrosine-protein kinase ephrin type A/B recept...  other
# 4    IPR036300                             Mir domain superfamily  other
# ..         ...                                                ...    ...
# 621  IPR010442                                         PET domain     TF
# 622  IPR038096                        TEA/ATTS domain superfamily     TF
# 623  IPR008967         p53-like transcription factor, DNA-binding     TF
# 624  IPR011598     Myc-type, basic helix-loop-helix (bHLH) domain     TF
# 625  IPR004826              Basic leucine zipper domain, Maf-type     TF
#
# [626 rows x 3 columns]

# %%
IPRs_df[IPRs_df['class']=='immunoglobulin']
# Out:
#         IPR_id                             description           class
# 507  IPR043204                            Basigin-like  immunoglobulin
# 508  IPR036179  Immunoglobulin-like domain superfamily  immunoglobulin
# 509  IPR007110              Immunoglobulin-like domain  immunoglobulin
# 510  IPR013106             Immunoglobulin V-set domain  immunoglobulin
# 511  IPR013783                Immunoglobulin-like fold  immunoglobulin
# 512  IPR013098                    Immunoglobulin I-set  immunoglobulin
# 513  IPR003598                Immunoglobulin subtype 2  immunoglobulin
# 514  IPR003599                  Immunoglobulin subtype  immunoglobulin
# 515  IPR014756                    Immunoglobulin E-set  immunoglobulin
# 516  IPR037448            Zwei Ig domain protein zig-8  immunoglobulin
# 517  IPR013162        CD80-like, immunoglobulin C2-set  immunoglobulin

# %%
immuno_IPRs = list(IPRs_df[IPRs_df['class']=='immunoglobulin']['IPR_id'])
immuno_IPRs
# Out:
# ['IPR043204',
#  'IPR036179',
#  'IPR007110',
#  'IPR013106',
#  'IPR013783',
#  'IPR013098',
#  'IPR003598',
#  'IPR003599',
#  'IPR014756',
#  'IPR037448',
#  'IPR013162']

# %%
out_dir = 'immunoglobulin/'
os.mkdir(out_dir)
for species in set(cne_counts['species']):
    output_df = rank_genes_IPR_list(cne_counts, species, immuno_IPRs)
    output_df.to_csv(out_dir + species + "_immuno_ranked.tsv", sep="\t", index=False)
# Out:
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene

# %% [markdown]
# ### Transcription factors

# %%
IPRs_df[IPRs_df['class']=='TF']
# Out:
#         IPR_id                                        description class
# 475  IPR000664                     Lethal(2) giant larvae protein    TF
# 558  IPR013847                                         POU domain    TF
# 559  IPR008116  Sequence-specific single-strand DNA-binding pr...    TF
# 560  IPR000327                                POU-specific domain    TF
# 561  IPR037987          Four and a half LIM domains protein 2/3/5    TF
# ..         ...                                                ...   ...
# 621  IPR010442                                         PET domain    TF
# 622  IPR038096                        TEA/ATTS domain superfamily    TF
# 623  IPR008967         p53-like transcription factor, DNA-binding    TF
# 624  IPR011598     Myc-type, basic helix-loop-helix (bHLH) domain    TF
# 625  IPR004826              Basic leucine zipper domain, Maf-type    TF
#
# [69 rows x 3 columns]

# %%
TF_IPRs = list(IPRs_df[IPRs_df['class']=='TF']['IPR_id'])

# %%
out_dir = 'TF/'
os.mkdir(out_dir)
for species in set(cne_counts['species']):
    output_df = rank_genes_IPR_list(cne_counts, species, TF_IPRs)
    output_df.to_csv(out_dir + species + "_TF_ranked.tsv", sep="\t", index=False)
# Out:
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene
# Read Blast annotations
# Merge CNE counts with BLAST annotations
# Read original annotations
# Merge CNE counts with Interpro annotations
# Filter by IPR_id
# Combine IPR IDs and descriptions for each gene

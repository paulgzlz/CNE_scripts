# %% [markdown]
# ### Goal
#
# Create cluster file without clusters containing only CNEs from two sister-species (because we assume that these CNEs are not convergent and originate from the commmon ancestor of these two species). Saves a lot of time for ancestral character state reconstruction step because most CNEs are from sister-species.
#
# ### Input
#
# pre_filtering_clusters.csv: cluster CNE composition file, output of assign_cluster_ids.ipynb
#
# ### Output
#
# pre_filtering_clusters_for_parsimony.csv: cluster CNE composition file, ready for parsimony_analysis.py

# %%
import csv
import pandas as pd

# %%
cluster_file_repeats = '../assign_cluster_ids/pre_filtering_clusters.csv' #cluster file
cluster_file_no_repeats = '../cluster_stats/clusters_no_repeats_10.csv' # clusters with > 10 CNEs from same sp. filtered out

# %% [markdown]
# #### Create set list of species pairs to exclude

# %%
#exclude_setlist = [{'cgig', 'cvir'}, {'myes', 'pmax'}, {'obim', 'ovul'}, {'bgla', 'echl'}]
exclude_setlist = [{'pdam', 'spis'}, {'epal', 'aten'}, {'mvir', 'aaur'}, {'hsym', 'chem'}]

# %% [markdown]
# #### Function that retrieves species IDs in cluster

# %%
def retrieve_species_set(cluster_row):
    species_set = set()
    for cne in cluster_row:
        #print(cne)
        # Retrieve species ID and add to set
        species = cne.split("_cne_")[0]
        species_set.add(species)
    return(species_set)

# %% [markdown]
# #### Function that removes clusters

# %%
def remove_clusters(cluster_file):
    output_file_name = cluster_file.split("/")[-1].split(".")[0] + "_for_parsimony.csv"
    # Dict to hold excluded clusters
    # excluded_clusters['cgig_cvir'] = ['cluster_x', 'cluster_y', ...]
    excluded_clusters = {}
    for exclude_set in exclude_setlist:
        exclude_name = "_".join(sorted(exclude_set))
        excluded_clusters[exclude_name] = []
    with open(cluster_file) as input_csv:
        with open(output_file_name, "w") as parsimony_output_csv:
            cne_file = csv.reader(input_csv, delimiter = ',')
            parsimony_writer = csv.writer(parsimony_output_csv, delimiter=',')
            # Each row is a cluster
            for row in cne_file:
                cluster_id = row[0]
                cnes = row[1:]
                species_set = retrieve_species_set(cnes)
                set_id = "_".join(sorted(species_set))
                if species_set not in exclude_setlist:
                    parsimony_writer.writerow(row)
                else:
                    excluded_clusters[set_id].append(row)
        # Print number of clusters at node between species pairs - Important result
        for comp, cluster_list in excluded_clusters.items():
            print(comp)
            print(len(cluster_list))

# %%
remove_clusters(cluster_file_repeats)
# Out:
# pdam_spis
# 49371
# aten_epal
# 906
# aaur_mvir
# 792
# chem_hsym
# 471

# %%
remove_clusters(cluster_file_no_repeats)
# Out:
# pdam_spis
# 49108
# aten_epal
# 873
# aaur_mvir
# 782
# chem_hsym
# 434

# %% [markdown]
# #### Update: also output cluster:node dict for downstream analyses (e.g. transposon cluster analysis)

# %%
def output_excluded_clusters(cluster_file):
    #output_file_name = cluster_file.split("/")[-1].split(".")[0] + "_for_parsimony.csv"
    # Dict to hold excluded clusters
    # excluded_clusters['cgig_cvir'] = ['cluster_x', 'cluster_y', ...]
    excluded_clusters = {}
    for exclude_set in exclude_setlist:
        exclude_name = "_".join(sorted(exclude_set))
        excluded_clusters[exclude_name] = []
    with open(cluster_file) as input_csv:
        cne_file = csv.reader(input_csv, delimiter = ',')
        # Each row is a cluster
        for row in cne_file:
            cluster_id = row[0]
            cnes = row[1:]
            species_set = retrieve_species_set(cnes)
            set_id = "_".join(sorted(species_set))
            if species_set in exclude_setlist:
                excluded_clusters[set_id].append(cluster_id)
    return(excluded_clusters)

# %%
excluded_cluster_dict = output_excluded_clusters(cluster_file_repeats)

# %%
excluded_cluster_dict
# Out:
# {'pdam_spis': ['cluster_30687',
#   'cluster_30688',
#   'cluster_30689',
#   'cluster_30690',
#   'cluster_30691',
#   'cluster_30692',
#   'cluster_30693',
#   'cluster_30694',
#   'cluster_30695',
#   'cluster_30696',
#   'cluster_30697',
#   'cluster_30698',
#   'cluster_30699',
#   'cluster_30700',
#   'cluster_30701',
#   'cluster_30702',
#   'cluster_30703',
#   'cluster_30704',
#   'cluster_30705',
#   'cluster_30706',
#   'cluster_30707',
#   'cluster_30708',
#   'cluster_30709',
#   'cluster_30710',
#   'cluster_30711',
#   'cluster_30712',
#   'cluster_30713',
#   'cluster_30714',
#   'cluster_30715',
#   'cluster_30716',
#   'cluster_30717',
#   'cluster_30718',
#   'cluster_30719',
#   'cluster_30720',
#   'cluster_30721',
#   'cluster_30722',
#   'cluster_30723',
#   'cluster_30724',
#   'cluster_30725',
#   'cluster_30726',
#   'cluster_30727',
#   'cluster_30728',
#   'cluster_30729',
#   'cluster_30730',
#   'cluster_30731',
#   'cluster_30732',
#   'cluster_30733',
#   'cluster_30734',
#   'cluster_30735',
#   'cluster_30736',
#   'cluster_30737',
#   'cluster_30738',
#   'cluster_30739',
#   'cluster_30740',
#   'cluster_30741',
#   'cluster_30742',
#   'cluster_30743',
#   'cluster_30744',
#   'cluster_30745',
#   'cluster_30746',
#   'cluster_30747',
#   'cluster_30748',
#   'cluster_30749',
#   'cluster_30750',
#   'cluster_30751',
#   'cluster_30752',
#   'cluster_30753',
#   'cluster_30754',
#   'cluster_30755',
#   'cluster_30756',
#   'cluster_30757',
#   'cluster_30758',
#   'cluster_30759',
#   'cluster_30760',
#   'cluster_30761',
#   'cluster_30762',
#   'cluster_30763',
#   'cluster_30764',
#   'cluster_30765',
#   'cluster_30766',
#   'cluster_30767',
#   'cluster_30768',
#   'cluster_30769',
#   'cluster_30770',
#   'cluster_30771',
#   'cluster_30772',
#   'cluster_30773',
#   'cluster_30774',
#   'cluster_30775',
#   'cluster_30776',
#   'cluster_30777',
#   'cluster_30778',
#   'cluster_30779',
#   'cluster_30780',
#   'cluster_30781',
#   'cluster_30782',
#   'cluster_30783',
#   'cluster_30784',
#   'cluster_30785',
#   'cluster_30786',
#   'cluster_30787',
#   'cluster_30788',
#   'cluster_30789',
#   'cluster_30790',
#   'cluster_30791',
#   'cluster_30792',
#   'cluster_30793',
#   'cluster_30794',
#   'cluster_30795',
#   'cluster_30796',
#   'cluster_30797',
#   'cluster_30798',
#   'cluster_30799',
#   'cluster_30800',
#   'cluster_30801',
#   'cluster_30802',
#   'cluster_30803',
#   'cluster_30804',
#   'cluster_30805',
#   'cluster_30806',
#   'cluster_30807',
#   'cluster_30808',
#   'cluster_30809',
#   'cluster_30810',
#   'cluster_30811',
#   'cluster_30812',
#   'cluster_30813',
#   'cluster_30814',
#   'cluster_30815',
#   'cluster_30816',
#   'cluster_30817',
#   'cluster_30818',
#   'cluster_30819',
#   'cluster_30820',
#   'cluster_30821',
#   'cluster_30822',
#   'cluster_30823',
#   'cluster_30824',
#   'cluster_30825',
#   'cluster_30826',
#   'cluster_30827',
#   'cluster_30828',
#   'cluster_30829',
#   'cluster_30830',
#   'cluster_30831',
#   'cluster_30832',
#   'cluster_30833',
#   'cluster_30834',
#   'cluster_30835',
#   'cluster_30836',
#   'cluster_30837',
#   'cluster_30838',
#   'cluster_30839',
#   'cluster_30840',
#   'cluster_30841',
#   'cluster_30842',
#   'cluster_30843',
#   'cluster_30844',
#   'cluster_30845',
#   'cluster_30846',
#   'cluster_30847',
#   'cluster_30848',
#   'cluster_30849',
#   'cluster_30850',
#   'cluster_30851',
#   'cluster_30852',
#   'cluster_30853',
#   'cluster_30854',
#   'cluster_30855',
#   'cluster_30856',
#   'cluster_30857',
#   'cluster_30858',
#   'cluster_30859',
#   'cluster_30860',
#   'cluster_30861',
#   'cluster_30862',
#   'cluster_30863',
#   'cluster_30864',
#   'cluster_30865',
#   'cluster_30866',
#   'cluster_30867',
#   'cluster_30868',
#   'cluster_30869',
#   'cluster_30870',
#   'cluster_30871',
#   'cluster_30872',
#   'cluster_30873',
#   'cluster_30874',
#   'cluster_30875',
#   'cluster_30876',
#   'cluster_30877',
#   'cluster_30878',
#   'cluster_30879',
#   'cluster_30880',
#   'cluster_30881',
#   'cluster_30882',
#   'cluster_30883',
#   'cluster_30885',
#   'cluster_30886',
#   'cluster_30887',
#   'cluster_30888',
#   'cluster_30889',
#   'cluster_30890',
#   'cluster_30891',
#   'cluster_30892',
#   'cluster_30893',
#   'cluster_30894',
#   'cluster_30895',
#   'cluster_30896',
#   'cluster_30897',
#   'cluster_30898',
#   'cluster_30899',
#   'cluster_30900',
#   'cluster_30901',
#   'cluster_30902',
#   'cluster_30903',
#   'cluster_30904',
#   'cluster_30905',
#   'cluster_30906',
#   'cluster_30907',
#   'cluster_30908',
#   'cluster_30909',
#   'cluster_30910',
#   'cluster_30911',
#   'cluster_30912',
#   'cluster_30913',
#   'cluster_30914',
#   'cluster_30915',
#   'cluster_30916',
#   'cluster_30917',
#   'cluster_30918',
#   'cluster_30919',
#   'cluster_30920',
#   'cluster_30921',
#   'cluster_30922',
#   'cluster_30923',
#   'cluster_30924',
#   'cluster_30925',
#   'cluster_30926',
#   'cluster_30927',
#   'cluster_30928',
#   'cluster_30929',
#   'cluster_30930',
#   'cluster_30931',
#   'cluster_30932',
#   'cluster_30933',
#   'cluster_30934',
#   'cluster_30935',
#   'cluster_30936',
#   'cluster_30937',
#   'cluster_30938',
#   'cluster_30939',
#   'cluster_30940',
#   'cluster_30941',
#   'cluster_30942',
#   'cluster_30943',
#   'cluster_30944',
#   'cluster_30945',
#   'cluster_30946',
#   'cluster_30947',
#   'cluster_30948',
#   'cluster_30949',
#   'cluster_30950',
#   'cluster_30951',
#   'cluster_30952',
#   'cluster_30953',
#   'cluster_30954',
#   'cluster_30955',
#   'cluster_30956',
#   'cluster_30957',
#   'cluster_30958',
#   'cluster_30959',
#   'cluster_30960',
#   'cluster_30961',
#   'cluster_30962',
#   'cluster_30963',
#   'cluster_30964',
#   'cluster_30965',
#   'cluster_30966',
#   'cluster_30967',
#   'cluster_30968',
#   'cluster_30969',
#   'cluster_30970',
#   'cluster_30971',
#   'cluster_30972',
#   'cluster_30973',
#   'cluster_30974',
#   'cluster_30975',
#   'cluster_30976',
#   'cluster_30977',
#   'cluster_30978',
#   'cluster_30979',
#   'cluster_30980',
#   'cluster_30981',
#   'cluster_30982',
#   'cluster_30983',
#   'cluster_30985',
#   'cluster_30986',
#   'cluster_30987',
#   'cluster_30988',
#   'cluster_30989',
#   'cluster_30990',
#   'cluster_30991',
#   'cluster_30992',
#   'cluster_30993',
#   'cluster_30994',
#   'cluster_30995',
#   'cluster_30996',
#   'cluster_30997',
#   'cluster_30998',
#   'cluster_30999',
#   'cluster_31000',
#   'cluster_31001',
#   'cluster_31002',
#   'cluster_31003',
#   'cluster_31004',
#   'cluster_31005',
#   'cluster_31006',
#   'cluster_31007',
#   'cluster_31008',
#   'cluster_31009',
#   'cluster_31010',
#   'cluster_31011',
#   'cluster_31012',
#   'cluster_31013',
#   'cluster_31014',
#   'cluster_31015',
#   'cluster_31016',
#   'cluster_31017',
#   'cluster_31018',
#   'cluster_31019',
#   'cluster_31020',
#   'cluster_31021',
#   'cluster_31022',
#   'cluster_31023',
#   'cluster_31024',
#   'cluster_31025',
#   'cluster_31026',
#   'cluster_31027',
#   'cluster_31028',
#   'cluster_31029',
#   'cluster_31030',
#   'cluster_31031',
#   'cluster_31032',
#   'cluster_31033',
#   'cluster_31034',
#   'cluster_31035',
#   'cluster_31036',
#   'cluster_31037',
#   'cluster_31038',
#   'cluster_31039',
#   'cluster_31040',
#   'cluster_31041',
#   'cluster_31042',
#   'cluster_31043',
#   'cluster_31044',
#   'cluster_31045',
#   'cluster_31046',
#   'cluster_31047',
#   'cluster_31048',
#   'cluster_31049',
#   'cluster_31050',
#   'cluster_31051',
#   'cluster_31052',
#   'cluster_31053',
#   'cluster_31054',
#   'cluster_31055',
#   'cluster_31056',
#   'cluster_31057',
#   'cluster_31058',
#   'cluster_31059',
#   'cluster_31060',
#   'cluster_31061',
#   'cluster_31062',
#   'cluster_31063',
#   'cluster_31064',
#   'cluster_31065',
#   'cluster_31066',
#   'cluster_31067',
#   'cluster_31068',
#   'cluster_31069',
#   'cluster_31070',
#   'cluster_31071',
#   'cluster_31072',
#   'cluster_31073',
#   'cluster_31074',
#   'cluster_31075',
#   'cluster_31076',
#   'cluster_31077',
#   'cluster_31078',
#   'cluster_31079',
#   'cluster_31080',
#   'cluster_31081',
#   'cluster_31082',
#   'cluster_31083',
#   'cluster_31084',
#   'cluster_31085',
#   'cluster_31086',
#   'cluster_31087',
#   'cluster_31088',
#   'cluster_31089',
#   'cluster_31090',
#   'cluster_31091',
#   'cluster_31092',
#   'cluster_31093',
#   'cluster_31094',
#   'cluster_31095',
#   'cluster_31096',
#   'cluster_31097',
#   'cluster_31098',
#   'cluster_31099',
#   'cluster_31100',
#   'cluster_31101',
#   'cluster_31102',
#   'cluster_31103',
#   'cluster_31104',
#   'cluster_31105',
#   'cluster_31106',
#   'cluster_31107',
#   'cluster_31108',
#   'cluster_31109',
#   'cluster_31110',
#   'cluster_31111',
#   'cluster_31112',
#   'cluster_31113',
#   'cluster_31114',
#   'cluster_31115',
#   'cluster_31116',
#   'cluster_31117',
#   'cluster_31118',
#   'cluster_31119',
#   'cluster_31120',
#   'cluster_31121',
#   'cluster_31122',
#   'cluster_31123',
#   'cluster_31124',
#   'cluster_31125',
#   'cluster_31126',
#   'cluster_31127',
#   'cluster_31128',
#   'cluster_31129',
#   'cluster_31130',
#   'cluster_31131',
#   'cluster_31132',
#   'cluster_31133',
#   'cluster_31134',
#   'cluster_31135',
#   'cluster_31136',
#   'cluster_31137',
#   'cluster_31138',
#   'cluster_31139',
#   'cluster_31140',
#   'cluster_31141',
#   'cluster_31142',
#   'cluster_31143',
#   'cluster_31144',
#   'cluster_31145',
#   'cluster_31146',
#   'cluster_31147',
#   'cluster_31148',
#   'cluster_31149',
#   'cluster_31150',
#   'cluster_31151',
#   'cluster_31152',
#   'cluster_31153',
#   'cluster_31154',
#   'cluster_31155',
#   'cluster_31157',
#   'cluster_31158',
#   'cluster_31159',
#   'cluster_31160',
#   'cluster_31161',
#   'cluster_31162',
#   'cluster_31163',
#   'cluster_31164',
#   'cluster_31165',
#   'cluster_31166',
#   'cluster_31167',
#   'cluster_31168',
#   'cluster_31169',
#   'cluster_31170',
#   'cluster_31171',
#   'cluster_31172',
#   'cluster_31173',
#   'cluster_31174',
#   'cluster_31175',
#   'cluster_31176',
#   'cluster_31177',
#   'cluster_31178',
#   'cluster_31179',
#   'cluster_31180',
#   'cluster_31181',
#   'cluster_31182',
#   'cluster_31183',
#   'cluster_31184',
#   'cluster_31185',
#   'cluster_31186',
#   'cluster_31187',
#   'cluster_31188',
#   'cluster_31189',
#   'cluster_31190',
#   'cluster_31191',
#   'cluster_31192',
#   'cluster_31193',
#   'cluster_31194',
#   'cluster_31195',
#   'cluster_31196',
#   'cluster_31197',
#   'cluster_31198',
#   'cluster_31199',
#   'cluster_31200',
#   'cluster_31201',
#   'cluster_31202',
#   'cluster_31203',
#   'cluster_31204',
#   'cluster_31205',
#   'cluster_31206',
#   'cluster_31207',
#   'cluster_31208',
#   'cluster_31209',
#   'cluster_31210',
#   'cluster_31211',
#   'cluster_31212',
#   'cluster_31213',
#   'cluster_31214',
#   'cluster_31215',
#   'cluster_31216',
#   'cluster_31217',
#   'cluster_31218',
#   'cluster_31219',
#   'cluster_31220',
#   'cluster_31221',
#   'cluster_31222',
#   'cluster_31223',
#   'cluster_31224',
#   'cluster_31225',
#   'cluster_31226',
#   'cluster_31227',
#   'cluster_31228',
#   'cluster_31229',
#   'cluster_31230',
#   'cluster_31231',
#   'cluster_31232',
#   'cluster_31233',
#   'cluster_31234',
#   'cluster_31235',
#   'cluster_31236',
#   'cluster_31237',
#   'cluster_31238',
#   'cluster_31239',
#   'cluster_31240',
#   'cluster_31241',
#   'cluster_31242',
#   'cluster_31243',
#   'cluster_31244',
#   'cluster_31245',
#   'cluster_31246',
#   'cluster_31247',
#   'cluster_31248',
#   'cluster_31249',
#   'cluster_31250',
#   'cluster_31251',
#   'cluster_31252',
#   'cluster_31253',
#   'cluster_31254',
#   'cluster_31255',
#   'cluster_31256',
#   'cluster_31257',
#   'cluster_31258',
#   'cluster_31259',
#   'cluster_31260',
#   'cluster_31261',
#   'cluster_31262',
#   'cluster_31263',
#   'cluster_31264',
#   'cluster_31265',
#   'cluster_31266',
#   'cluster_31267',
#   'cluster_31268',
#   'cluster_31269',
#   'cluster_31270',
#   'cluster_31271',
#   'cluster_31272',
#   'cluster_31273',
#   'cluster_31274',
#   'cluster_31275',
#   'cluster_31276',
#   'cluster_31277',
#   'cluster_31278',
#   'cluster_31279',
#   'cluster_31280',
#   'cluster_31281',
#   'cluster_31282',
#   'cluster_31283',
#   'cluster_31284',
#   'cluster_31285',
#   'cluster_31286',
#   'cluster_31287',
#   'cluster_31288',
#   'cluster_31289',
#   'cluster_31290',
#   'cluster_31291',
#   'cluster_31292',
#   'cluster_31293',
#   'cluster_31294',
#   'cluster_31295',
#   'cluster_31296',
#   'cluster_31297',
#   'cluster_31298',
#   'cluster_31299',
#   'cluster_31300',
#   'cluster_31301',
#   'cluster_31302',
#   'cluster_31303',
#   'cluster_31304',
#   'cluster_31305',
#   'cluster_31306',
#   'cluster_31307',
#   'cluster_31308',
#   'cluster_31309',
#   'cluster_31310',
#   'cluster_31311',
#   'cluster_31312',
#   'cluster_31313',
#   'cluster_31314',
#   'cluster_31315',
#   'cluster_31316',
#   'cluster_31317',
#   'cluster_31318',
#   'cluster_31319',
#   'cluster_31320',
#   'cluster_31321',
#   'cluster_31322',
#   'cluster_31323',
#   'cluster_31324',
#   'cluster_31325',
#   'cluster_31326',
#   'cluster_31327',
#   'cluster_31328',
#   'cluster_31329',
#   'cluster_31330',
#   'cluster_31331',
#   'cluster_31332',
#   'cluster_31333',
#   'cluster_31334',
#   'cluster_31335',
#   'cluster_31336',
#   'cluster_31337',
#   'cluster_31338',
#   'cluster_31339',
#   'cluster_31340',
#   'cluster_31341',
#   'cluster_31342',
#   'cluster_31343',
#   'cluster_31344',
#   'cluster_31345',
#   'cluster_31346',
#   'cluster_31347',
#   'cluster_31348',
#   'cluster_31349',
#   'cluster_31350',
#   'cluster_31351',
#   'cluster_31352',
#   'cluster_31353',
#   'cluster_31354',
#   'cluster_31355',
#   'cluster_31356',
#   'cluster_31357',
#   'cluster_31358',
#   'cluster_31359',
#   'cluster_31360',
#   'cluster_31361',
#   'cluster_31362',
#   'cluster_31363',
#   'cluster_31364',
#   'cluster_31365',
#   'cluster_31366',
#   'cluster_31367',
#   'cluster_31368',
#   'cluster_31369',
#   'cluster_31370',
#   'cluster_31371',
#   'cluster_31372',
#   'cluster_31373',
#   'cluster_31374',
#   'cluster_31375',
#   'cluster_31376',
#   'cluster_31377',
#   'cluster_31378',
#   'cluster_31379',
#   'cluster_31380',
#   'cluster_31381',
#   'cluster_31382',
#   'cluster_31383',
#   'cluster_31384',
#   'cluster_31385',
#   'cluster_31386',
#   'cluster_31387',
#   'cluster_31388',
#   'cluster_31389',
#   'cluster_31390',
#   'cluster_31391',
#   'cluster_31392',
#   'cluster_31393',
#   'cluster_31394',
#   'cluster_31395',
#   'cluster_31396',
#   'cluster_31397',
#   'cluster_31398',
#   'cluster_31399',
#   'cluster_31400',
#   'cluster_31401',
#   'cluster_31402',
#   'cluster_31403',
#   'cluster_31404',
#   'cluster_31405',
#   'cluster_31406',
#   'cluster_31407',
#   'cluster_31408',
#   'cluster_31409',
#   'cluster_31410',
#   'cluster_31411',
#   'cluster_31412',
#   'cluster_31413',
#   'cluster_31414',
#   'cluster_31415',
#   'cluster_31416',
#   'cluster_31417',
#   'cluster_31418',
#   'cluster_31419',
#   'cluster_31420',
#   'cluster_31421',
#   'cluster_31422',
#   'cluster_31423',
#   'cluster_31424',
#   'cluster_31425',
#   'cluster_31426',
#   'cluster_31427',
#   'cluster_31428',
#   'cluster_31429',
#   'cluster_31430',
#   'cluster_31431',
#   'cluster_31432',
#   'cluster_31433',
#   'cluster_31434',
#   'cluster_31435',
#   'cluster_31436',
#   'cluster_31437',
#   'cluster_31438',
#   'cluster_31439',
#   'cluster_31440',
#   'cluster_31441',
#   'cluster_31442',
#   'cluster_31443',
#   'cluster_31444',
#   'cluster_31445',
#   'cluster_31446',
#   'cluster_31447',
#   'cluster_31448',
#   'cluster_31449',
#   'cluster_31450',
#   'cluster_31451',
#   'cluster_31452',
#   'cluster_31453',
#   'cluster_31454',
#   'cluster_31455',
#   'cluster_31456',
#   'cluster_31457',
#   'cluster_31458',
#   'cluster_31459',
#   'cluster_31460',
#   'cluster_31461',
#   'cluster_31462',
#   'cluster_31463',
#   'cluster_31464',
#   'cluster_31465',
#   'cluster_31466',
#   'cluster_31467',
#   'cluster_31468',
#   'cluster_31469',
#   'cluster_31470',
#   'cluster_31471',
#   'cluster_31472',
#   'cluster_31473',
#   'cluster_31474',
#   'cluster_31475',
#   'cluster_31476',
#   'cluster_31477',
#   'cluster_31478',
#   'cluster_31479',
#   'cluster_31480',
#   'cluster_31481',
#   'cluster_31482',
#   'cluster_31483',
#   'cluster_31484',
#   'cluster_31485',
#   'cluster_31486',
#   'cluster_31487',
#   'cluster_31488',
#   'cluster_31489',
#   'cluster_31490',
#   'cluster_31491',
#   'cluster_31492',
#   'cluster_31493',
#   'cluster_31494',
#   'cluster_31495',
#   'cluster_31496',
#   'cluster_31497',
#   'cluster_31498',
#   'cluster_31499',
#   'cluster_31500',
#   'cluster_31501',
#   'cluster_31502',
#   'cluster_31503',
#   'cluster_31504',
#   'cluster_31505',
#   'cluster_31506',
#   'cluster_31507',
#   'cluster_31508',
#   'cluster_31509',
#   'cluster_31510',
#   'cluster_31511',
#   'cluster_31512',
#   'cluster_31513',
#   'cluster_31514',
#   'cluster_31515',
#   'cluster_31516',
#   'cluster_31517',
#   'cluster_31518',
#   'cluster_31519',
#   'cluster_31520',
#   'cluster_31521',
#   'cluster_31522',
#   'cluster_31523',
#   'cluster_31524',
#   'cluster_31525',
#   'cluster_31526',
#   'cluster_31527',
#   'cluster_31528',
#   'cluster_31529',
#   'cluster_31530',
#   'cluster_31531',
#   'cluster_31532',
#   'cluster_31533',
#   'cluster_31534',
#   'cluster_31535',
#   'cluster_31536',
#   'cluster_31537',
#   'cluster_31538',
#   'cluster_31539',
#   'cluster_31540',
#   'cluster_31541',
#   'cluster_31542',
#   'cluster_31543',
#   'cluster_31544',
#   'cluster_31545',
#   'cluster_31546',
#   'cluster_31547',
#   'cluster_31548',
#   'cluster_31549',
#   'cluster_31550',
#   'cluster_31551',
#   'cluster_31552',
#   'cluster_31553',
#   'cluster_31554',
#   'cluster_31555',
#   'cluster_31556',
#   'cluster_31557',
#   'cluster_31558',
#   'cluster_31559',
#   'cluster_31560',
#   'cluster_31561',
#   'cluster_31562',
#   'cluster_31563',
#   'cluster_31564',
#   'cluster_31565',
#   'cluster_31566',
#   'cluster_31567',
#   'cluster_31568',
#   'cluster_31569',
#   'cluster_31570',
#   'cluster_31571',
#   'cluster_31572',
#   'cluster_31573',
#   'cluster_31574',
#   'cluster_31575',
#   'cluster_31576',
#   'cluster_31577',
#   'cluster_31578',
#   'cluster_31579',
#   'cluster_31580',
#   'cluster_31581',
#   'cluster_31582',
#   'cluster_31583',
#   'cluster_31584',
#   'cluster_31585',
#   'cluster_31586',
#   'cluster_31587',
#   'cluster_31588',
#   'cluster_31589',
#   'cluster_31590',
#   'cluster_31591',
#   'cluster_31592',
#   'cluster_31593',
#   'cluster_31594',
#   'cluster_31595',
#   'cluster_31596',
#   'cluster_31597',
#   'cluster_31598',
#   'cluster_31599',
#   'cluster_31600',
#   'cluster_31601',
#   'cluster_31602',
#   'cluster_31603',
#   'cluster_31604',
#   'cluster_31605',
#   'cluster_31606',
#   'cluster_31607',
#   'cluster_31608',
#   'cluster_31609',
#   'cluster_31610',
#   'cluster_31611',
#   'cluster_31612',
#   'cluster_31613',
#   'cluster_31614',
#   'cluster_31615',
#   'cluster_31616',
#   'cluster_31617',
#   'cluster_31618',
#   'cluster_31619',
#   'cluster_31620',
#   'cluster_31621',
#   'cluster_31622',
#   'cluster_31623',
#   'cluster_31624',
#   'cluster_31625',
#   'cluster_31626',
#   'cluster_31627',
#   'cluster_31628',
#   'cluster_31629',
#   'cluster_31630',
#   'cluster_31631',
#   'cluster_31632',
#   'cluster_31633',
#   'cluster_31634',
#   'cluster_31635',
#   'cluster_31636',
#   'cluster_31637',
#   'cluster_31638',
#   'cluster_31639',
#   'cluster_31640',
#   'cluster_31641',
#   'cluster_31642',
#   'cluster_31643',
#   'cluster_31644',
#   'cluster_31646',
#   'cluster_31647',
#   'cluster_31648',
#   'cluster_31649',
#   'cluster_31650',
#   'cluster_31651',
#   'cluster_31652',
#   'cluster_31653',
#   'cluster_31654',
#   'cluster_31655',
#   'cluster_31656',
#   'cluster_31657',
#   'cluster_31658',
#   'cluster_31659',
#   'cluster_31660',
#   'cluster_31661',
#   'cluster_31662',
#   'cluster_31663',
#   'cluster_31664',
#   'cluster_31665',
#   'cluster_31666',
#   'cluster_31667',
#   'cluster_31668',
#   'cluster_31669',
#   'cluster_31670',
#   'cluster_31671',
#   'cluster_31672',
#   'cluster_31673',
#   'cluster_31674',
#   'cluster_31675',
#   'cluster_31676',
#   'cluster_31677',
#   'cluster_31678',
#   'cluster_31679',
#   'cluster_31680',
#   'cluster_31681',
#   'cluster_31682',
#   'cluster_31683',
#   'cluster_31684',
#   'cluster_31685',
#   'cluster_31686',
#   'cluster_31687',
#   'cluster_31688',
#   'cluster_31689',
#   'cluster_31690',
#   ...],
#  'aten_epal': ['cluster_13732',
#   'cluster_13733',
#   'cluster_13737',
#   'cluster_13738',
#   'cluster_13739',
#   'cluster_13740',
#   'cluster_13741',
#   'cluster_13742',
#   'cluster_13743',
#   'cluster_13745',
#   'cluster_13746',
#   'cluster_13747',
#   'cluster_13748',
#   'cluster_13749',
#   'cluster_13751',
#   'cluster_13752',
#   'cluster_13753',
#   'cluster_13754',
#   'cluster_13755',
#   'cluster_13756',
#   'cluster_13757',
#   'cluster_13758',
#   'cluster_13759',
#   'cluster_13760',
#   'cluster_13761',
#   'cluster_13763',
#   'cluster_13765',
#   'cluster_13766',
#   'cluster_13768',
#   'cluster_13771',
#   'cluster_13772',
#   'cluster_13773',
#   'cluster_13774',
#   'cluster_13777',
#   'cluster_13778',
#   'cluster_13779',
#   'cluster_13780',
#   'cluster_13781',
#   'cluster_13783',
#   'cluster_13784',
#   'cluster_13785',
#   'cluster_13786',
#   'cluster_13787',
#   'cluster_13788',
#   'cluster_13793',
#   'cluster_13794',
#   'cluster_13795',
#   'cluster_13796',
#   'cluster_13797',
#   'cluster_13798',
#   'cluster_13799',
#   'cluster_13800',
#   'cluster_13801',
#   'cluster_13802',
#   'cluster_13803',
#   'cluster_13804',
#   'cluster_13805',
#   'cluster_13806',
#   'cluster_13808',
#   'cluster_13809',
#   'cluster_13810',
#   'cluster_13812',
#   'cluster_13813',
#   'cluster_13814',
#   'cluster_13815',
#   'cluster_13816',
#   'cluster_13818',
#   'cluster_13819',
#   'cluster_13820',
#   'cluster_13821',
#   'cluster_13822',
#   'cluster_13823',
#   'cluster_13824',
#   'cluster_13825',
#   'cluster_13826',
#   'cluster_13827',
#   'cluster_13828',
#   'cluster_13829',
#   'cluster_13830',
#   'cluster_13831',
#   'cluster_13832',
#   'cluster_13835',
#   'cluster_13836',
#   'cluster_13837',
#   'cluster_13838',
#   'cluster_13839',
#   'cluster_13841',
#   'cluster_13843',
#   'cluster_13844',
#   'cluster_13846',
#   'cluster_13847',
#   'cluster_13848',
#   'cluster_13849',
#   'cluster_13850',
#   'cluster_13851',
#   'cluster_13852',
#   'cluster_13853',
#   'cluster_13854',
#   'cluster_13856',
#   'cluster_13859',
#   'cluster_13860',
#   'cluster_13861',
#   'cluster_13863',
#   'cluster_13864',
#   'cluster_13865',
#   'cluster_13867',
#   'cluster_13868',
#   'cluster_13869',
#   'cluster_13871',
#   'cluster_13872',
#   'cluster_13873',
#   'cluster_13874',
#   'cluster_13875',
#   'cluster_13877',
#   'cluster_13878',
#   'cluster_13879',
#   'cluster_13880',
#   'cluster_13881',
#   'cluster_13883',
#   'cluster_13884',
#   'cluster_13886',
#   'cluster_13887',
#   'cluster_13888',
#   'cluster_13890',
#   'cluster_13891',
#   'cluster_13892',
#   'cluster_13893',
#   'cluster_13894',
#   'cluster_13895',
#   'cluster_13897',
#   'cluster_13901',
#   'cluster_13903',
#   'cluster_13906',
#   'cluster_13907',
#   'cluster_13908',
#   'cluster_13909',
#   'cluster_13910',
#   'cluster_13911',
#   'cluster_13912',
#   'cluster_13913',
#   'cluster_13914',
#   'cluster_13915',
#   'cluster_13916',
#   'cluster_13917',
#   'cluster_13918',
#   'cluster_13921',
#   'cluster_13922',
#   'cluster_13924',
#   'cluster_13925',
#   'cluster_13926',
#   'cluster_13927',
#   'cluster_13928',
#   'cluster_13929',
#   'cluster_13930',
#   'cluster_13931',
#   'cluster_13932',
#   'cluster_13933',
#   'cluster_13934',
#   'cluster_13935',
#   'cluster_13936',
#   'cluster_13937',
#   'cluster_13938',
#   'cluster_13939',
#   'cluster_13940',
#   'cluster_13941',
#   'cluster_13942',
#   'cluster_13943',
#   'cluster_13944',
#   'cluster_13945',
#   'cluster_13946',
#   'cluster_13947',
#   'cluster_13948',
#   'cluster_13950',
#   'cluster_13951',
#   'cluster_13952',
#   'cluster_13953',
#   'cluster_13954',
#   'cluster_13956',
#   'cluster_13957',
#   'cluster_13958',
#   'cluster_13959',
#   'cluster_13961',
#   'cluster_13962',
#   'cluster_13964',
#   'cluster_13965',
#   'cluster_13966',
#   'cluster_13968',
#   'cluster_13969',
#   'cluster_13970',
#   'cluster_13971',
#   'cluster_13973',
#   'cluster_13974',
#   'cluster_13975',
#   'cluster_13976',
#   'cluster_13977',
#   'cluster_13980',
#   'cluster_13981',
#   'cluster_13982',
#   'cluster_13983',
#   'cluster_13984',
#   'cluster_13985',
#   'cluster_13986',
#   'cluster_13987',
#   'cluster_13989',
#   'cluster_13990',
#   'cluster_13991',
#   'cluster_13993',
#   'cluster_13994',
#   'cluster_13995',
#   'cluster_13996',
#   'cluster_13997',
#   'cluster_13998',
#   'cluster_13999',
#   'cluster_14000',
#   'cluster_14001',
#   'cluster_14003',
#   'cluster_14005',
#   'cluster_14006',
#   'cluster_14007',
#   'cluster_14009',
#   'cluster_14010',
#   'cluster_14011',
#   'cluster_14012',
#   'cluster_14013',
#   'cluster_14014',
#   'cluster_14016',
#   'cluster_14017',
#   'cluster_14018',
#   'cluster_14019',
#   'cluster_14020',
#   'cluster_14021',
#   'cluster_14022',
#   'cluster_14023',
#   'cluster_14024',
#   'cluster_14025',
#   'cluster_14026',
#   'cluster_14027',
#   'cluster_14029',
#   'cluster_14030',
#   'cluster_14031',
#   'cluster_14032',
#   'cluster_14034',
#   'cluster_14035',
#   'cluster_14036',
#   'cluster_14038',
#   'cluster_14039',
#   'cluster_14040',
#   'cluster_14041',
#   'cluster_14042',
#   'cluster_14044',
#   'cluster_14046',
#   'cluster_14047',
#   'cluster_14048',
#   'cluster_14049',
#   'cluster_14050',
#   'cluster_14051',
#   'cluster_14052',
#   'cluster_14053',
#   'cluster_14054',
#   'cluster_14055',
#   'cluster_14056',
#   'cluster_14057',
#   'cluster_14058',
#   'cluster_14060',
#   'cluster_14062',
#   'cluster_14063',
#   'cluster_14064',
#   'cluster_14065',
#   'cluster_14066',
#   'cluster_14067',
#   'cluster_14068',
#   'cluster_14069',
#   'cluster_14070',
#   'cluster_14071',
#   'cluster_14072',
#   'cluster_14073',
#   'cluster_14074',
#   'cluster_14075',
#   'cluster_14076',
#   'cluster_14077',
#   'cluster_14078',
#   'cluster_14080',
#   'cluster_14082',
#   'cluster_14083',
#   'cluster_14084',
#   'cluster_14085',
#   'cluster_14086',
#   'cluster_14087',
#   'cluster_14088',
#   'cluster_14090',
#   'cluster_14091',
#   'cluster_14094',
#   'cluster_14095',
#   'cluster_14096',
#   'cluster_14097',
#   'cluster_14098',
#   'cluster_14099',
#   'cluster_14100',
#   'cluster_14101',
#   'cluster_14103',
#   'cluster_14104',
#   'cluster_14106',
#   'cluster_14107',
#   'cluster_14108',
#   'cluster_14109',
#   'cluster_14112',
#   'cluster_14113',
#   'cluster_14114',
#   'cluster_14115',
#   'cluster_14116',
#   'cluster_14117',
#   'cluster_14119',
#   'cluster_14120',
#   'cluster_14121',
#   'cluster_14122',
#   'cluster_14123',
#   'cluster_14125',
#   'cluster_14126',
#   'cluster_14127',
#   'cluster_14128',
#   'cluster_14129',
#   'cluster_14130',
#   'cluster_14131',
#   'cluster_14132',
#   'cluster_14133',
#   'cluster_14134',
#   'cluster_14135',
#   'cluster_14136',
#   'cluster_14137',
#   'cluster_14138',
#   'cluster_14139',
#   'cluster_14140',
#   'cluster_14141',
#   'cluster_14142',
#   'cluster_14143',
#   'cluster_14144',
#   'cluster_14145',
#   'cluster_14146',
#   'cluster_14147',
#   'cluster_14148',
#   'cluster_14149',
#   'cluster_14150',
#   'cluster_14151',
#   'cluster_14152',
#   'cluster_14153',
#   'cluster_14154',
#   'cluster_14155',
#   'cluster_14156',
#   'cluster_14157',
#   'cluster_14158',
#   'cluster_14159',
#   'cluster_14160',
#   'cluster_14161',
#   'cluster_14162',
#   'cluster_14164',
#   'cluster_14166',
#   'cluster_14167',
#   'cluster_14168',
#   'cluster_14169',
#   'cluster_14170',
#   'cluster_14171',
#   'cluster_14172',
#   'cluster_14173',
#   'cluster_14174',
#   'cluster_14175',
#   'cluster_14176',
#   'cluster_14177',
#   'cluster_14178',
#   'cluster_14179',
#   'cluster_14180',
#   'cluster_14181',
#   'cluster_14182',
#   'cluster_14183',
#   'cluster_14184',
#   'cluster_14185',
#   'cluster_14186',
#   'cluster_14187',
#   'cluster_14188',
#   'cluster_14189',
#   'cluster_14190',
#   'cluster_14191',
#   'cluster_14192',
#   'cluster_14193',
#   'cluster_14194',
#   'cluster_14195',
#   'cluster_14196',
#   'cluster_14197',
#   'cluster_14198',
#   'cluster_14199',
#   'cluster_14200',
#   'cluster_14201',
#   'cluster_14202',
#   'cluster_14203',
#   'cluster_14204',
#   'cluster_14205',
#   'cluster_14206',
#   'cluster_14207',
#   'cluster_14208',
#   'cluster_14209',
#   'cluster_14214',
#   'cluster_14215',
#   'cluster_14217',
#   'cluster_14221',
#   'cluster_14224',
#   'cluster_14226',
#   'cluster_14227',
#   'cluster_14228',
#   'cluster_14229',
#   'cluster_14230',
#   'cluster_14231',
#   'cluster_14232',
#   'cluster_14233',
#   'cluster_14234',
#   'cluster_14235',
#   'cluster_14236',
#   'cluster_14237',
#   'cluster_14238',
#   'cluster_14239',
#   'cluster_14242',
#   'cluster_14243',
#   'cluster_14244',
#   'cluster_14245',
#   'cluster_14246',
#   'cluster_14247',
#   'cluster_14248',
#   'cluster_14249',
#   'cluster_14250',
#   'cluster_14251',
#   'cluster_14252',
#   'cluster_14253',
#   'cluster_14254',
#   'cluster_14255',
#   'cluster_14257',
#   'cluster_14258',
#   'cluster_14259',
#   'cluster_14261',
#   'cluster_14262',
#   'cluster_14263',
#   'cluster_14264',
#   'cluster_14265',
#   'cluster_14266',
#   'cluster_14267',
#   'cluster_14269',
#   'cluster_14270',
#   'cluster_14271',
#   'cluster_14272',
#   'cluster_14273',
#   'cluster_14274',
#   'cluster_14275',
#   'cluster_14276',
#   'cluster_14277',
#   'cluster_14278',
#   'cluster_14279',
#   'cluster_14280',
#   'cluster_14282',
#   'cluster_14284',
#   'cluster_14285',
#   'cluster_14286',
#   'cluster_14287',
#   'cluster_14288',
#   'cluster_14289',
#   'cluster_14290',
#   'cluster_14291',
#   'cluster_14292',
#   'cluster_14293',
#   'cluster_14294',
#   'cluster_14295',
#   'cluster_14296',
#   'cluster_14297',
#   'cluster_14299',
#   'cluster_14300',
#   'cluster_14301',
#   'cluster_14302',
#   'cluster_14303',
#   'cluster_14304',
#   'cluster_14305',
#   'cluster_14306',
#   'cluster_14307',
#   'cluster_14308',
#   'cluster_14309',
#   'cluster_14310',
#   'cluster_14312',
#   'cluster_14313',
#   'cluster_14315',
#   'cluster_14318',
#   'cluster_14319',
#   'cluster_14320',
#   'cluster_14321',
#   'cluster_14322',
#   'cluster_14323',
#   'cluster_14324',
#   'cluster_14325',
#   'cluster_14327',
#   'cluster_14328',
#   'cluster_14329',
#   'cluster_14330',
#   'cluster_14331',
#   'cluster_14332',
#   'cluster_14334',
#   'cluster_14335',
#   'cluster_14336',
#   'cluster_14337',
#   'cluster_14338',
#   'cluster_14339',
#   'cluster_14341',
#   'cluster_14345',
#   'cluster_14346',
#   'cluster_14347',
#   'cluster_14348',
#   'cluster_14349',
#   'cluster_14350',
#   'cluster_14351',
#   'cluster_14352',
#   'cluster_14355',
#   'cluster_14356',
#   'cluster_14357',
#   'cluster_14358',
#   'cluster_14359',
#   'cluster_14360',
#   'cluster_14362',
#   'cluster_14363',
#   'cluster_14364',
#   'cluster_14365',
#   'cluster_14367',
#   'cluster_14368',
#   'cluster_14369',
#   'cluster_14370',
#   'cluster_14371',
#   'cluster_14372',
#   'cluster_14373',
#   'cluster_14375',
#   'cluster_14376',
#   'cluster_14377',
#   'cluster_14378',
#   'cluster_14379',
#   'cluster_14380',
#   'cluster_14382',
#   'cluster_14383',
#   'cluster_14384',
#   'cluster_14385',
#   'cluster_14386',
#   'cluster_14387',
#   'cluster_14388',
#   'cluster_14389',
#   'cluster_14390',
#   'cluster_14391',
#   'cluster_14392',
#   'cluster_14393',
#   'cluster_14394',
#   'cluster_14395',
#   'cluster_14396',
#   'cluster_14397',
#   'cluster_14399',
#   'cluster_14400',
#   'cluster_14401',
#   'cluster_14403',
#   'cluster_14404',
#   'cluster_14405',
#   'cluster_14406',
#   'cluster_14407',
#   'cluster_14409',
#   'cluster_14410',
#   'cluster_14411',
#   'cluster_14412',
#   'cluster_14413',
#   'cluster_14416',
#   'cluster_14418',
#   'cluster_14419',
#   'cluster_14420',
#   'cluster_14421',
#   'cluster_14422',
#   'cluster_14425',
#   'cluster_14426',
#   'cluster_14427',
#   'cluster_14428',
#   'cluster_14429',
#   'cluster_14430',
#   'cluster_14431',
#   'cluster_14432',
#   'cluster_14434',
#   'cluster_14435',
#   'cluster_14436',
#   'cluster_14437',
#   'cluster_14438',
#   'cluster_14439',
#   'cluster_14440',
#   'cluster_14441',
#   'cluster_14442',
#   'cluster_14443',
#   'cluster_14444',
#   'cluster_14445',
#   'cluster_14446',
#   'cluster_14447',
#   'cluster_14448',
#   'cluster_14449',
#   'cluster_14450',
#   'cluster_14451',
#   'cluster_14452',
#   'cluster_14453',
#   'cluster_14454',
#   'cluster_14455',
#   'cluster_14458',
#   'cluster_14459',
#   'cluster_14460',
#   'cluster_14462',
#   'cluster_14463',
#   'cluster_14464',
#   'cluster_14465',
#   'cluster_14466',
#   'cluster_14467',
#   'cluster_14468',
#   'cluster_14470',
#   'cluster_14471',
#   'cluster_14472',
#   'cluster_14473',
#   'cluster_14474',
#   'cluster_14476',
#   'cluster_14477',
#   'cluster_14478',
#   'cluster_14479',
#   'cluster_14480',
#   'cluster_14481',
#   'cluster_14483',
#   'cluster_14484',
#   'cluster_14485',
#   'cluster_14486',
#   'cluster_14487',
#   'cluster_14488',
#   'cluster_14489',
#   'cluster_14490',
#   'cluster_14491',
#   'cluster_14492',
#   'cluster_14493',
#   'cluster_14494',
#   'cluster_14495',
#   'cluster_14497',
#   'cluster_14498',
#   'cluster_14499',
#   'cluster_14500',
#   'cluster_14501',
#   'cluster_14503',
#   'cluster_14504',
#   'cluster_14506',
#   'cluster_14507',
#   'cluster_14508',
#   'cluster_14509',
#   'cluster_14510',
#   'cluster_14511',
#   'cluster_14512',
#   'cluster_14513',
#   'cluster_14514',
#   'cluster_14516',
#   'cluster_14518',
#   'cluster_14520',
#   'cluster_14521',
#   'cluster_14522',
#   'cluster_14523',
#   'cluster_14524',
#   'cluster_14525',
#   'cluster_14526',
#   'cluster_14527',
#   'cluster_14528',
#   'cluster_14529',
#   'cluster_14530',
#   'cluster_14531',
#   'cluster_14532',
#   'cluster_14533',
#   'cluster_14534',
#   'cluster_14535',
#   'cluster_14536',
#   'cluster_14537',
#   'cluster_14538',
#   'cluster_14539',
#   'cluster_14540',
#   'cluster_14541',
#   'cluster_14542',
#   'cluster_14543',
#   'cluster_14544',
#   'cluster_14545',
#   'cluster_14546',
#   'cluster_14547',
#   'cluster_14548',
#   'cluster_14549',
#   'cluster_14550',
#   'cluster_14551',
#   'cluster_14552',
#   'cluster_14553',
#   'cluster_14554',
#   'cluster_14555',
#   'cluster_14556',
#   'cluster_14557',
#   'cluster_14558',
#   'cluster_14561',
#   'cluster_14562',
#   'cluster_14564',
#   'cluster_14565',
#   'cluster_14566',
#   'cluster_14567',
#   'cluster_14568',
#   'cluster_14569',
#   'cluster_14570',
#   'cluster_14571',
#   'cluster_14572',
#   'cluster_14573',
#   'cluster_14574',
#   'cluster_14575',
#   'cluster_14576',
#   'cluster_14577',
#   'cluster_14578',
#   'cluster_14579',
#   'cluster_14580',
#   'cluster_14581',
#   'cluster_14582',
#   'cluster_14583',
#   'cluster_14584',
#   'cluster_14585',
#   'cluster_14586',
#   'cluster_14587',
#   'cluster_14588',
#   'cluster_14589',
#   'cluster_14590',
#   'cluster_14591',
#   'cluster_14592',
#   'cluster_14593',
#   'cluster_14594',
#   'cluster_14598',
#   'cluster_14599',
#   'cluster_14600',
#   'cluster_14601',
#   'cluster_14602',
#   'cluster_14603',
#   'cluster_14604',
#   'cluster_14605',
#   'cluster_14606',
#   'cluster_14607',
#   'cluster_14608',
#   'cluster_14609',
#   'cluster_14610',
#   'cluster_14611',
#   'cluster_14612',
#   'cluster_14613',
#   'cluster_14615',
#   'cluster_14616',
#   'cluster_14617',
#   'cluster_14619',
#   'cluster_14620',
#   'cluster_14621',
#   'cluster_14623',
#   'cluster_14624',
#   'cluster_14625',
#   'cluster_14629',
#   'cluster_14630',
#   'cluster_14631',
#   'cluster_14632',
#   'cluster_14633',
#   'cluster_14634',
#   'cluster_14635',
#   'cluster_14636',
#   'cluster_14637',
#   'cluster_14638',
#   'cluster_14640',
#   'cluster_14641',
#   'cluster_14642',
#   'cluster_14643',
#   'cluster_14644',
#   'cluster_14645',
#   'cluster_14646',
#   'cluster_14647',
#   'cluster_14648',
#   'cluster_14649',
#   'cluster_14650',
#   'cluster_14652',
#   'cluster_14653',
#   'cluster_14654',
#   'cluster_14655',
#   'cluster_14656',
#   'cluster_14657',
#   'cluster_14658',
#   'cluster_14659',
#   'cluster_14660',
#   'cluster_14661',
#   'cluster_14662',
#   'cluster_14663',
#   'cluster_14664',
#   'cluster_14665',
#   'cluster_14666',
#   'cluster_14668',
#   'cluster_14669',
#   'cluster_14670',
#   'cluster_14671',
#   'cluster_14673',
#   'cluster_14674',
#   'cluster_14675',
#   'cluster_14676',
#   'cluster_14677',
#   'cluster_14678',
#   'cluster_14679',
#   'cluster_14680',
#   'cluster_14683',
#   'cluster_14684',
#   'cluster_14685',
#   'cluster_14686',
#   'cluster_14687',
#   'cluster_14688',
#   'cluster_14690',
#   'cluster_14691',
#   'cluster_14692',
#   'cluster_14693',
#   'cluster_14694',
#   'cluster_14695',
#   'cluster_14697',
#   'cluster_14698',
#   'cluster_14699',
#   'cluster_14700',
#   'cluster_14703',
#   'cluster_14704',
#   'cluster_14705',
#   'cluster_14706',
#   'cluster_14707',
#   'cluster_14708',
#   'cluster_14709',
#   'cluster_14710',
#   'cluster_14711',
#   'cluster_14712',
#   'cluster_14713',
#   'cluster_14714',
#   'cluster_14715',
#   'cluster_14716',
#   'cluster_14718',
#   'cluster_14719',
#   'cluster_14720',
#   'cluster_14721',
#   'cluster_14722',
#   'cluster_14723',
#   'cluster_14724',
#   'cluster_14725',
#   'cluster_14728',
#   'cluster_14729',
#   'cluster_14730',
#   'cluster_14732',
#   'cluster_14733',
#   'cluster_14735',
#   'cluster_14736',
#   'cluster_14737',
#   'cluster_14738',
#   'cluster_14739',
#   'cluster_14740',
#   'cluster_14742',
#   'cluster_14744',
#   'cluster_14745',
#   'cluster_14746',
#   'cluster_14748',
#   'cluster_14749',
#   'cluster_14750',
#   'cluster_14752',
#   'cluster_14753',
#   'cluster_14754',
#   'cluster_14755',
#   'cluster_14756',
#   'cluster_14757',
#   'cluster_14758',
#   'cluster_14759',
#   'cluster_14760',
#   'cluster_14761',
#   'cluster_14762',
#   'cluster_14763',
#   'cluster_14764',
#   'cluster_14765',
#   'cluster_14767',
#   'cluster_14768',
#   'cluster_14769',
#   'cluster_14770',
#   'cluster_14771',
#   'cluster_14772',
#   'cluster_14773',
#   'cluster_14774',
#   'cluster_14775',
#   'cluster_14776',
#   'cluster_14777',
#   'cluster_14778',
#   'cluster_14779',
#   'cluster_14780',
#   'cluster_14781',
#   'cluster_14782',
#   'cluster_14783',
#   'cluster_14784',
#   'cluster_14785',
#   'cluster_14786',
#   'cluster_14787',
#   'cluster_14788',
#   'cluster_14790',
#   'cluster_14791',
#   'cluster_14793',
#   'cluster_14794',
#   'cluster_14795',
#   'cluster_14796',
#   'cluster_14797',
#   'cluster_14798',
#   'cluster_14799',
#   'cluster_14800',
#   'cluster_14801',
#   'cluster_14802',
#   'cluster_14804',
#   'cluster_14805',
#   'cluster_14806',
#   'cluster_81508'],
#  'aaur_mvir': ['cluster_80498',
#   'cluster_80499',
#   'cluster_80500',
#   'cluster_80501',
#   'cluster_80502',
#   'cluster_80503',
#   'cluster_80504',
#   'cluster_80505',
#   'cluster_80506',
#   'cluster_80507',
#   'cluster_80508',
#   'cluster_80509',
#   'cluster_80510',
#   'cluster_80511',
#   'cluster_80512',
#   'cluster_80513',
#   'cluster_80514',
#   'cluster_80515',
#   'cluster_80516',
#   'cluster_80517',
#   'cluster_80518',
#   'cluster_80519',
#   'cluster_80520',
#   'cluster_80521',
#   'cluster_80522',
#   'cluster_80523',
#   'cluster_80524',
#   'cluster_80525',
#   'cluster_80526',
#   'cluster_80527',
#   'cluster_80528',
#   'cluster_80529',
#   'cluster_80530',
#   'cluster_80531',
#   'cluster_80532',
#   'cluster_80533',
#   'cluster_80534',
#   'cluster_80535',
#   'cluster_80536',
#   'cluster_80537',
#   'cluster_80538',
#   'cluster_80539',
#   'cluster_80540',
#   'cluster_80541',
#   'cluster_80542',
#   'cluster_80543',
#   'cluster_80544',
#   'cluster_80545',
#   'cluster_80546',
#   'cluster_80547',
#   'cluster_80548',
#   'cluster_80549',
#   'cluster_80550',
#   'cluster_80551',
#   'cluster_80552',
#   'cluster_80553',
#   'cluster_80554',
#   'cluster_80555',
#   'cluster_80556',
#   'cluster_80557',
#   'cluster_80558',
#   'cluster_80559',
#   'cluster_80560',
#   'cluster_80561',
#   'cluster_80562',
#   'cluster_80563',
#   'cluster_80564',
#   'cluster_80565',
#   'cluster_80566',
#   'cluster_80567',
#   'cluster_80568',
#   'cluster_80569',
#   'cluster_80570',
#   'cluster_80571',
#   'cluster_80572',
#   'cluster_80573',
#   'cluster_80574',
#   'cluster_80575',
#   'cluster_80576',
#   'cluster_80577',
#   'cluster_80578',
#   'cluster_80579',
#   'cluster_80580',
#   'cluster_80581',
#   'cluster_80582',
#   'cluster_80583',
#   'cluster_80584',
#   'cluster_80585',
#   'cluster_80586',
#   'cluster_80587',
#   'cluster_80588',
#   'cluster_80589',
#   'cluster_80590',
#   'cluster_80591',
#   'cluster_80592',
#   'cluster_80593',
#   'cluster_80594',
#   'cluster_80595',
#   'cluster_80596',
#   'cluster_80597',
#   'cluster_80598',
#   'cluster_80599',
#   'cluster_80600',
#   'cluster_80601',
#   'cluster_80602',
#   'cluster_80603',
#   'cluster_80604',
#   'cluster_80605',
#   'cluster_80606',
#   'cluster_80607',
#   'cluster_80608',
#   'cluster_80609',
#   'cluster_80610',
#   'cluster_80611',
#   'cluster_80612',
#   'cluster_80613',
#   'cluster_80614',
#   'cluster_80615',
#   'cluster_80616',
#   'cluster_80617',
#   'cluster_80618',
#   'cluster_80619',
#   'cluster_80620',
#   'cluster_80621',
#   'cluster_80622',
#   'cluster_80623',
#   'cluster_80624',
#   'cluster_80625',
#   'cluster_80626',
#   'cluster_80627',
#   'cluster_80628',
#   'cluster_80629',
#   'cluster_80630',
#   'cluster_80631',
#   'cluster_80632',
#   'cluster_80633',
#   'cluster_80634',
#   'cluster_80635',
#   'cluster_80636',
#   'cluster_80637',
#   'cluster_80638',
#   'cluster_80639',
#   'cluster_80640',
#   'cluster_80641',
#   'cluster_80642',
#   'cluster_80643',
#   'cluster_80644',
#   'cluster_80645',
#   'cluster_80646',
#   'cluster_80647',
#   'cluster_80648',
#   'cluster_80649',
#   'cluster_80650',
#   'cluster_80651',
#   'cluster_80652',
#   'cluster_80653',
#   'cluster_80654',
#   'cluster_80655',
#   'cluster_80656',
#   'cluster_80657',
#   'cluster_80658',
#   'cluster_80659',
#   'cluster_80660',
#   'cluster_80661',
#   'cluster_80662',
#   'cluster_80663',
#   'cluster_80664',
#   'cluster_80665',
#   'cluster_80666',
#   'cluster_80667',
#   'cluster_80668',
#   'cluster_80669',
#   'cluster_80670',
#   'cluster_80671',
#   'cluster_80672',
#   'cluster_80673',
#   'cluster_80674',
#   'cluster_80675',
#   'cluster_80676',
#   'cluster_80677',
#   'cluster_80678',
#   'cluster_80679',
#   'cluster_80680',
#   'cluster_80681',
#   'cluster_80682',
#   'cluster_80683',
#   'cluster_80684',
#   'cluster_80685',
#   'cluster_80686',
#   'cluster_80687',
#   'cluster_80688',
#   'cluster_80689',
#   'cluster_80690',
#   'cluster_80691',
#   'cluster_80692',
#   'cluster_80693',
#   'cluster_80694',
#   'cluster_80695',
#   'cluster_80696',
#   'cluster_80697',
#   'cluster_80698',
#   'cluster_80699',
#   'cluster_80700',
#   'cluster_80701',
#   'cluster_80702',
#   'cluster_80703',
#   'cluster_80704',
#   'cluster_80705',
#   'cluster_80706',
#   'cluster_80707',
#   'cluster_80708',
#   'cluster_80709',
#   'cluster_80710',
#   'cluster_80711',
#   'cluster_80712',
#   'cluster_80713',
#   'cluster_80714',
#   'cluster_80715',
#   'cluster_80716',
#   'cluster_80717',
#   'cluster_80718',
#   'cluster_80719',
#   'cluster_80720',
#   'cluster_80721',
#   'cluster_80722',
#   'cluster_80723',
#   'cluster_80724',
#   'cluster_80725',
#   'cluster_80726',
#   'cluster_80727',
#   'cluster_80728',
#   'cluster_80729',
#   'cluster_80730',
#   'cluster_80731',
#   'cluster_80732',
#   'cluster_80733',
#   'cluster_80734',
#   'cluster_80735',
#   'cluster_80736',
#   'cluster_80737',
#   'cluster_80738',
#   'cluster_80739',
#   'cluster_80740',
#   'cluster_80741',
#   'cluster_80742',
#   'cluster_80743',
#   'cluster_80744',
#   'cluster_80745',
#   'cluster_80746',
#   'cluster_80747',
#   'cluster_80748',
#   'cluster_80749',
#   'cluster_80750',
#   'cluster_80751',
#   'cluster_80752',
#   'cluster_80753',
#   'cluster_80754',
#   'cluster_80755',
#   'cluster_80756',
#   'cluster_80757',
#   'cluster_80758',
#   'cluster_80759',
#   'cluster_80760',
#   'cluster_80761',
#   'cluster_80762',
#   'cluster_80763',
#   'cluster_80764',
#   'cluster_80765',
#   'cluster_80766',
#   'cluster_80767',
#   'cluster_80768',
#   'cluster_80769',
#   'cluster_80770',
#   'cluster_80771',
#   'cluster_80772',
#   'cluster_80773',
#   'cluster_80774',
#   'cluster_80775',
#   'cluster_80776',
#   'cluster_80777',
#   'cluster_80778',
#   'cluster_80779',
#   'cluster_80780',
#   'cluster_80781',
#   'cluster_80782',
#   'cluster_80783',
#   'cluster_80784',
#   'cluster_80785',
#   'cluster_80786',
#   'cluster_80787',
#   'cluster_80788',
#   'cluster_80789',
#   'cluster_80790',
#   'cluster_80791',
#   'cluster_80792',
#   'cluster_80793',
#   'cluster_80794',
#   'cluster_80795',
#   'cluster_80796',
#   'cluster_80797',
#   'cluster_80798',
#   'cluster_80799',
#   'cluster_80800',
#   'cluster_80801',
#   'cluster_80802',
#   'cluster_80803',
#   'cluster_80804',
#   'cluster_80805',
#   'cluster_80806',
#   'cluster_80807',
#   'cluster_80808',
#   'cluster_80809',
#   'cluster_80810',
#   'cluster_80811',
#   'cluster_80812',
#   'cluster_80813',
#   'cluster_80814',
#   'cluster_80815',
#   'cluster_80816',
#   'cluster_80817',
#   'cluster_80818',
#   'cluster_80819',
#   'cluster_80820',
#   'cluster_80821',
#   'cluster_80822',
#   'cluster_80823',
#   'cluster_80824',
#   'cluster_80825',
#   'cluster_80826',
#   'cluster_80827',
#   'cluster_80828',
#   'cluster_80829',
#   'cluster_80830',
#   'cluster_80831',
#   'cluster_80832',
#   'cluster_80833',
#   'cluster_80834',
#   'cluster_80835',
#   'cluster_80836',
#   'cluster_80837',
#   'cluster_80838',
#   'cluster_80839',
#   'cluster_80840',
#   'cluster_80841',
#   'cluster_80842',
#   'cluster_80843',
#   'cluster_80844',
#   'cluster_80845',
#   'cluster_80846',
#   'cluster_80847',
#   'cluster_80848',
#   'cluster_80849',
#   'cluster_80850',
#   'cluster_80851',
#   'cluster_80852',
#   'cluster_80853',
#   'cluster_80854',
#   'cluster_80855',
#   'cluster_80856',
#   'cluster_80857',
#   'cluster_80858',
#   'cluster_80859',
#   'cluster_80860',
#   'cluster_80861',
#   'cluster_80862',
#   'cluster_80863',
#   'cluster_80864',
#   'cluster_80865',
#   'cluster_80866',
#   'cluster_80867',
#   'cluster_80868',
#   'cluster_80869',
#   'cluster_80870',
#   'cluster_80871',
#   'cluster_80872',
#   'cluster_80873',
#   'cluster_80874',
#   'cluster_80875',
#   'cluster_80876',
#   'cluster_80877',
#   'cluster_80878',
#   'cluster_80879',
#   'cluster_80880',
#   'cluster_80881',
#   'cluster_80882',
#   'cluster_80883',
#   'cluster_80884',
#   'cluster_80885',
#   'cluster_80886',
#   'cluster_80887',
#   'cluster_80888',
#   'cluster_80889',
#   'cluster_80890',
#   'cluster_80891',
#   'cluster_80892',
#   'cluster_80893',
#   'cluster_80894',
#   'cluster_80895',
#   'cluster_80896',
#   'cluster_80897',
#   'cluster_80898',
#   'cluster_80899',
#   'cluster_80900',
#   'cluster_80901',
#   'cluster_80902',
#   'cluster_80903',
#   'cluster_80904',
#   'cluster_80905',
#   'cluster_80906',
#   'cluster_80907',
#   'cluster_80908',
#   'cluster_80909',
#   'cluster_80910',
#   'cluster_80911',
#   'cluster_80912',
#   'cluster_80913',
#   'cluster_80914',
#   'cluster_80915',
#   'cluster_80916',
#   'cluster_80917',
#   'cluster_80918',
#   'cluster_80919',
#   'cluster_80920',
#   'cluster_80921',
#   'cluster_80922',
#   'cluster_80923',
#   'cluster_80924',
#   'cluster_80925',
#   'cluster_80926',
#   'cluster_80927',
#   'cluster_80928',
#   'cluster_80929',
#   'cluster_80930',
#   'cluster_80931',
#   'cluster_80932',
#   'cluster_80933',
#   'cluster_80934',
#   'cluster_80935',
#   'cluster_80936',
#   'cluster_80937',
#   'cluster_80938',
#   'cluster_80939',
#   'cluster_80940',
#   'cluster_80941',
#   'cluster_80942',
#   'cluster_80943',
#   'cluster_80944',
#   'cluster_80945',
#   'cluster_80946',
#   'cluster_80947',
#   'cluster_80948',
#   'cluster_80949',
#   'cluster_80950',
#   'cluster_80951',
#   'cluster_80952',
#   'cluster_80953',
#   'cluster_80954',
#   'cluster_80955',
#   'cluster_80956',
#   'cluster_80957',
#   'cluster_80958',
#   'cluster_80959',
#   'cluster_80960',
#   'cluster_80961',
#   'cluster_80962',
#   'cluster_80963',
#   'cluster_80964',
#   'cluster_80965',
#   'cluster_80966',
#   'cluster_80967',
#   'cluster_80968',
#   'cluster_80969',
#   'cluster_80970',
#   'cluster_80971',
#   'cluster_80972',
#   'cluster_80973',
#   'cluster_80974',
#   'cluster_80975',
#   'cluster_80976',
#   'cluster_80977',
#   'cluster_80978',
#   'cluster_80979',
#   'cluster_80980',
#   'cluster_80981',
#   'cluster_80982',
#   'cluster_80983',
#   'cluster_80984',
#   'cluster_80985',
#   'cluster_80986',
#   'cluster_80987',
#   'cluster_80988',
#   'cluster_80989',
#   'cluster_80990',
#   'cluster_80991',
#   'cluster_80992',
#   'cluster_80993',
#   'cluster_80994',
#   'cluster_80995',
#   'cluster_80996',
#   'cluster_80997',
#   'cluster_80998',
#   'cluster_80999',
#   'cluster_81000',
#   'cluster_81001',
#   'cluster_81002',
#   'cluster_81003',
#   'cluster_81004',
#   'cluster_81005',
#   'cluster_81006',
#   'cluster_81007',
#   'cluster_81008',
#   'cluster_81009',
#   'cluster_81010',
#   'cluster_81011',
#   'cluster_81012',
#   'cluster_81013',
#   'cluster_81014',
#   'cluster_81015',
#   'cluster_81016',
#   'cluster_81017',
#   'cluster_81018',
#   'cluster_81019',
#   'cluster_81020',
#   'cluster_81021',
#   'cluster_81022',
#   'cluster_81023',
#   'cluster_81024',
#   'cluster_81025',
#   'cluster_81026',
#   'cluster_81027',
#   'cluster_81028',
#   'cluster_81029',
#   'cluster_81030',
#   'cluster_81031',
#   'cluster_81032',
#   'cluster_81033',
#   'cluster_81034',
#   'cluster_81035',
#   'cluster_81036',
#   'cluster_81037',
#   'cluster_81038',
#   'cluster_81039',
#   'cluster_81040',
#   'cluster_81041',
#   'cluster_81042',
#   'cluster_81043',
#   'cluster_81044',
#   'cluster_81045',
#   'cluster_81046',
#   'cluster_81047',
#   'cluster_81048',
#   'cluster_81049',
#   'cluster_81050',
#   'cluster_81051',
#   'cluster_81052',
#   'cluster_81053',
#   'cluster_81054',
#   'cluster_81055',
#   'cluster_81056',
#   'cluster_81057',
#   'cluster_81058',
#   'cluster_81059',
#   'cluster_81060',
#   'cluster_81061',
#   'cluster_81062',
#   'cluster_81063',
#   'cluster_81064',
#   'cluster_81065',
#   'cluster_81066',
#   'cluster_81067',
#   'cluster_81068',
#   'cluster_81069',
#   'cluster_81070',
#   'cluster_81071',
#   'cluster_81072',
#   'cluster_81073',
#   'cluster_81074',
#   'cluster_81075',
#   'cluster_81076',
#   'cluster_81077',
#   'cluster_81078',
#   'cluster_81079',
#   'cluster_81080',
#   'cluster_81081',
#   'cluster_81082',
#   'cluster_81083',
#   'cluster_81084',
#   'cluster_81085',
#   'cluster_81086',
#   'cluster_81087',
#   'cluster_81088',
#   'cluster_81089',
#   'cluster_81090',
#   'cluster_81091',
#   'cluster_81092',
#   'cluster_81093',
#   'cluster_81094',
#   'cluster_81095',
#   'cluster_81096',
#   'cluster_81097',
#   'cluster_81098',
#   'cluster_81099',
#   'cluster_81100',
#   'cluster_81101',
#   'cluster_81102',
#   'cluster_81103',
#   'cluster_81104',
#   'cluster_81105',
#   'cluster_81106',
#   'cluster_81107',
#   'cluster_81108',
#   'cluster_81109',
#   'cluster_81110',
#   'cluster_81111',
#   'cluster_81112',
#   'cluster_81113',
#   'cluster_81114',
#   'cluster_81115',
#   'cluster_81116',
#   'cluster_81117',
#   'cluster_81118',
#   'cluster_81119',
#   'cluster_81120',
#   'cluster_81121',
#   'cluster_81122',
#   'cluster_81123',
#   'cluster_81124',
#   'cluster_81125',
#   'cluster_81126',
#   'cluster_81127',
#   'cluster_81128',
#   'cluster_81129',
#   'cluster_81130',
#   'cluster_81131',
#   'cluster_81132',
#   'cluster_81133',
#   'cluster_81134',
#   'cluster_81135',
#   'cluster_81136',
#   'cluster_81137',
#   'cluster_81138',
#   'cluster_81139',
#   'cluster_81140',
#   'cluster_81141',
#   'cluster_81142',
#   'cluster_81143',
#   'cluster_81144',
#   'cluster_81145',
#   'cluster_81146',
#   'cluster_81147',
#   'cluster_81148',
#   'cluster_81149',
#   'cluster_81150',
#   'cluster_81151',
#   'cluster_81152',
#   'cluster_81153',
#   'cluster_81154',
#   'cluster_81155',
#   'cluster_81156',
#   'cluster_81157',
#   'cluster_81158',
#   'cluster_81159',
#   'cluster_81160',
#   'cluster_81161',
#   'cluster_81162',
#   'cluster_81163',
#   'cluster_81164',
#   'cluster_81165',
#   'cluster_81166',
#   'cluster_81167',
#   'cluster_81168',
#   'cluster_81169',
#   'cluster_81170',
#   'cluster_81171',
#   'cluster_81172',
#   'cluster_81173',
#   'cluster_81174',
#   'cluster_81175',
#   'cluster_81176',
#   'cluster_81177',
#   'cluster_81178',
#   'cluster_81179',
#   'cluster_81180',
#   'cluster_81181',
#   'cluster_81182',
#   'cluster_81183',
#   'cluster_81184',
#   'cluster_81185',
#   'cluster_81186',
#   'cluster_81187',
#   'cluster_81188',
#   'cluster_81189',
#   'cluster_81190',
#   'cluster_81191',
#   'cluster_81192',
#   'cluster_81193',
#   'cluster_81194',
#   'cluster_81195',
#   'cluster_81196',
#   'cluster_81197',
#   'cluster_81198',
#   'cluster_81199',
#   'cluster_81200',
#   'cluster_81201',
#   'cluster_81202',
#   'cluster_81203',
#   'cluster_81204',
#   'cluster_81205',
#   'cluster_81206',
#   'cluster_81207',
#   'cluster_81208',
#   'cluster_81209',
#   'cluster_81210',
#   'cluster_81211',
#   'cluster_81212',
#   'cluster_81213',
#   'cluster_81214',
#   'cluster_81215',
#   'cluster_81216',
#   'cluster_81217',
#   'cluster_81218',
#   'cluster_81219',
#   'cluster_81220',
#   'cluster_81221',
#   'cluster_81222',
#   'cluster_81223',
#   'cluster_81224',
#   'cluster_81225',
#   'cluster_81226',
#   'cluster_81227',
#   'cluster_81228',
#   'cluster_81229',
#   'cluster_81230',
#   'cluster_81231',
#   'cluster_81232',
#   'cluster_81233',
#   'cluster_81234',
#   'cluster_81235',
#   'cluster_81236',
#   'cluster_81237',
#   'cluster_81238',
#   'cluster_81239',
#   'cluster_81240',
#   'cluster_81241',
#   'cluster_81242',
#   'cluster_81243',
#   'cluster_81244',
#   'cluster_81245',
#   'cluster_81246',
#   'cluster_81247',
#   'cluster_81248',
#   'cluster_81249',
#   'cluster_81250',
#   'cluster_81251',
#   'cluster_81252',
#   'cluster_81253',
#   'cluster_81254',
#   'cluster_81255',
#   'cluster_81256',
#   'cluster_81257',
#   'cluster_81258',
#   'cluster_81259',
#   'cluster_81260',
#   'cluster_81261',
#   'cluster_81262',
#   'cluster_81263',
#   'cluster_81264',
#   'cluster_81265',
#   'cluster_81266',
#   'cluster_81267',
#   'cluster_81268',
#   'cluster_81269',
#   'cluster_81270',
#   'cluster_81271',
#   'cluster_81272',
#   'cluster_81273',
#   'cluster_81274',
#   'cluster_81275',
#   'cluster_81276',
#   'cluster_81277',
#   'cluster_81278',
#   'cluster_81279',
#   'cluster_81280',
#   'cluster_81281',
#   'cluster_81282',
#   'cluster_81283',
#   'cluster_81284',
#   'cluster_81285',
#   'cluster_81286',
#   'cluster_81287',
#   'cluster_81288',
#   'cluster_81289'],
#  'chem_hsym': ['cluster_4557',
#   'cluster_4559',
#   'cluster_4560',
#   'cluster_4561',
#   'cluster_4563',
#   'cluster_4564',
#   'cluster_4565',
#   'cluster_4566',
#   'cluster_4567',
#   'cluster_4568',
#   'cluster_4569',
#   'cluster_4570',
#   'cluster_4571',
#   'cluster_4572',
#   'cluster_4573',
#   'cluster_4574',
#   'cluster_4575',
#   'cluster_4578',
#   'cluster_4579',
#   'cluster_4580',
#   'cluster_4581',
#   'cluster_4582',
#   'cluster_4583',
#   'cluster_4584',
#   'cluster_4585',
#   'cluster_4586',
#   'cluster_4587',
#   'cluster_4588',
#   'cluster_4590',
#   'cluster_4592',
#   'cluster_4593',
#   'cluster_4594',
#   'cluster_4595',
#   'cluster_4596',
#   'cluster_4598',
#   'cluster_4599',
#   'cluster_4600',
#   'cluster_4601',
#   'cluster_4602',
#   'cluster_4603',
#   'cluster_4604',
#   'cluster_4605',
#   'cluster_4606',
#   'cluster_4607',
#   'cluster_4608',
#   'cluster_4609',
#   'cluster_4610',
#   'cluster_4611',
#   'cluster_4612',
#   'cluster_4613',
#   'cluster_4614',
#   'cluster_4616',
#   'cluster_4617',
#   'cluster_4618',
#   'cluster_4619',
#   'cluster_4620',
#   'cluster_4621',
#   'cluster_4622',
#   'cluster_4623',
#   'cluster_4624',
#   'cluster_4625',
#   'cluster_4628',
#   'cluster_4629',
#   'cluster_4630',
#   'cluster_4631',
#   'cluster_4632',
#   'cluster_4633',
#   'cluster_4634',
#   'cluster_4635',
#   'cluster_4636',
#   'cluster_4637',
#   'cluster_4638',
#   'cluster_4639',
#   'cluster_4640',
#   'cluster_4641',
#   'cluster_4642',
#   'cluster_4643',
#   'cluster_4644',
#   'cluster_4645',
#   'cluster_4646',
#   'cluster_4648',
#   'cluster_4649',
#   'cluster_4650',
#   'cluster_4651',
#   'cluster_4652',
#   'cluster_4653',
#   'cluster_4654',
#   'cluster_4655',
#   'cluster_4656',
#   'cluster_4657',
#   'cluster_4658',
#   'cluster_4659',
#   'cluster_4660',
#   'cluster_4661',
#   'cluster_4662',
#   'cluster_4663',
#   'cluster_4664',
#   'cluster_4666',
#   'cluster_4667',
#   'cluster_4668',
#   'cluster_4669',
#   'cluster_4670',
#   'cluster_4671',
#   'cluster_4672',
#   'cluster_4673',
#   'cluster_4674',
#   'cluster_4675',
#   'cluster_4676',
#   'cluster_4677',
#   'cluster_4678',
#   'cluster_4679',
#   'cluster_4680',
#   'cluster_4681',
#   'cluster_4682',
#   'cluster_4684',
#   'cluster_4685',
#   'cluster_4686',
#   'cluster_4687',
#   'cluster_4688',
#   'cluster_4689',
#   'cluster_4690',
#   'cluster_4691',
#   'cluster_4693',
#   'cluster_4694',
#   'cluster_4695',
#   'cluster_4696',
#   'cluster_4697',
#   'cluster_4698',
#   'cluster_4699',
#   'cluster_4700',
#   'cluster_4701',
#   'cluster_4702',
#   'cluster_4703',
#   'cluster_4704',
#   'cluster_4705',
#   'cluster_4706',
#   'cluster_4707',
#   'cluster_4708',
#   'cluster_4709',
#   'cluster_4710',
#   'cluster_4711',
#   'cluster_4712',
#   'cluster_4714',
#   'cluster_4717',
#   'cluster_4718',
#   'cluster_4719',
#   'cluster_4721',
#   'cluster_4722',
#   'cluster_4723',
#   'cluster_4724',
#   'cluster_4725',
#   'cluster_4726',
#   'cluster_4727',
#   'cluster_4728',
#   'cluster_4729',
#   'cluster_4731',
#   'cluster_4733',
#   'cluster_4734',
#   'cluster_4735',
#   'cluster_4736',
#   'cluster_4737',
#   'cluster_4738',
#   'cluster_4739',
#   'cluster_4740',
#   'cluster_4741',
#   'cluster_4742',
#   'cluster_4743',
#   'cluster_4744',
#   'cluster_4745',
#   'cluster_4746',
#   'cluster_4747',
#   'cluster_4749',
#   'cluster_4750',
#   'cluster_4751',
#   'cluster_4752',
#   'cluster_4753',
#   'cluster_4754',
#   'cluster_4755',
#   'cluster_4756',
#   'cluster_4757',
#   'cluster_4758',
#   'cluster_4759',
#   'cluster_4760',
#   'cluster_4761',
#   'cluster_4762',
#   'cluster_4763',
#   'cluster_4764',
#   'cluster_4765',
#   'cluster_4766',
#   'cluster_4767',
#   'cluster_4769',
#   'cluster_4770',
#   'cluster_4771',
#   'cluster_4772',
#   'cluster_4773',
#   'cluster_4774',
#   'cluster_4775',
#   'cluster_4776',
#   'cluster_4777',
#   'cluster_4778',
#   'cluster_4779',
#   'cluster_4780',
#   'cluster_4781',
#   'cluster_4782',
#   'cluster_4784',
#   'cluster_4785',
#   'cluster_4786',
#   'cluster_4787',
#   'cluster_4788',
#   'cluster_4789',
#   'cluster_4790',
#   'cluster_4791',
#   'cluster_4792',
#   'cluster_4793',
#   'cluster_4794',
#   'cluster_4795',
#   'cluster_4796',
#   'cluster_4797',
#   'cluster_4798',
#   'cluster_4799',
#   'cluster_4800',
#   'cluster_4801',
#   'cluster_4802',
#   'cluster_4803',
#   'cluster_4804',
#   'cluster_4805',
#   'cluster_4806',
#   'cluster_4807',
#   'cluster_4808',
#   'cluster_4810',
#   'cluster_4811',
#   'cluster_4812',
#   'cluster_4813',
#   'cluster_4814',
#   'cluster_4816',
#   'cluster_4817',
#   'cluster_4820',
#   'cluster_4821',
#   'cluster_4822',
#   'cluster_4823',
#   'cluster_4824',
#   'cluster_4825',
#   'cluster_4826',
#   'cluster_4827',
#   'cluster_4828',
#   'cluster_4829',
#   'cluster_4830',
#   'cluster_4831',
#   'cluster_4832',
#   'cluster_4833',
#   'cluster_4834',
#   'cluster_4835',
#   'cluster_4836',
#   'cluster_4837',
#   'cluster_4838',
#   'cluster_4839',
#   'cluster_4840',
#   'cluster_4841',
#   'cluster_4842',
#   'cluster_4843',
#   'cluster_4844',
#   'cluster_4845',
#   'cluster_4846',
#   'cluster_4847',
#   'cluster_4848',
#   'cluster_4849',
#   'cluster_4850',
#   'cluster_4851',
#   'cluster_4852',
#   'cluster_4853',
#   'cluster_4854',
#   'cluster_4855',
#   'cluster_4856',
#   'cluster_4857',
#   'cluster_4858',
#   'cluster_4860',
#   'cluster_4861',
#   'cluster_4862',
#   'cluster_4863',
#   'cluster_4865',
#   'cluster_4866',
#   'cluster_4867',
#   'cluster_4869',
#   'cluster_4870',
#   'cluster_4871',
#   'cluster_4872',
#   'cluster_4873',
#   'cluster_4874',
#   'cluster_4875',
#   'cluster_4876',
#   'cluster_4877',
#   'cluster_4878',
#   'cluster_4879',
#   'cluster_4880',
#   'cluster_4881',
#   'cluster_4882',
#   'cluster_4883',
#   'cluster_4884',
#   'cluster_4885',
#   'cluster_4886',
#   'cluster_4887',
#   'cluster_4888',
#   'cluster_4889',
#   'cluster_4890',
#   'cluster_4891',
#   'cluster_4892',
#   'cluster_4893',
#   'cluster_4894',
#   'cluster_4895',
#   'cluster_4896',
#   'cluster_4897',
#   'cluster_4898',
#   'cluster_4899',
#   'cluster_4900',
#   'cluster_4901',
#   'cluster_4903',
#   'cluster_4904',
#   'cluster_4905',
#   'cluster_4906',
#   'cluster_4907',
#   'cluster_4908',
#   'cluster_4909',
#   'cluster_4910',
#   'cluster_4911',
#   'cluster_4912',
#   'cluster_4913',
#   'cluster_4914',
#   'cluster_4915',
#   'cluster_4916',
#   'cluster_4917',
#   'cluster_4918',
#   'cluster_4919',
#   'cluster_4920',
#   'cluster_4921',
#   'cluster_4922',
#   'cluster_4923',
#   'cluster_4924',
#   'cluster_4925',
#   'cluster_4926',
#   'cluster_4928',
#   'cluster_4929',
#   'cluster_4930',
#   'cluster_4931',
#   'cluster_4932',
#   'cluster_4933',
#   'cluster_4934',
#   'cluster_4935',
#   'cluster_4936',
#   'cluster_4937',
#   'cluster_4938',
#   'cluster_4939',
#   'cluster_4940',
#   'cluster_4941',
#   'cluster_4942',
#   'cluster_4943',
#   'cluster_4944',
#   'cluster_4945',
#   'cluster_4946',
#   'cluster_4947',
#   'cluster_4948',
#   'cluster_4949',
#   'cluster_4950',
#   'cluster_4951',
#   'cluster_4952',
#   'cluster_4953',
#   'cluster_4954',
#   'cluster_4955',
#   'cluster_4956',
#   'cluster_4957',
#   'cluster_4958',
#   'cluster_4959',
#   'cluster_4961',
#   'cluster_4962',
#   'cluster_4963',
#   'cluster_4964',
#   'cluster_4965',
#   'cluster_4966',
#   'cluster_4968',
#   'cluster_4969',
#   'cluster_4970',
#   'cluster_4971',
#   'cluster_4972',
#   'cluster_4973',
#   'cluster_4974',
#   'cluster_4975',
#   'cluster_4976',
#   'cluster_4978',
#   'cluster_4979',
#   'cluster_4980',
#   'cluster_4981',
#   'cluster_4982',
#   'cluster_4983',
#   'cluster_4985',
#   'cluster_4986',
#   'cluster_4987',
#   'cluster_4988',
#   'cluster_4989',
#   'cluster_4990',
#   'cluster_4991',
#   'cluster_4992',
#   'cluster_4993',
#   'cluster_4994',
#   'cluster_4995',
#   'cluster_4996',
#   'cluster_4997',
#   'cluster_4998',
#   'cluster_4999',
#   'cluster_5000',
#   'cluster_5001',
#   'cluster_5002',
#   'cluster_5003',
#   'cluster_5004',
#   'cluster_5005',
#   'cluster_5006',
#   'cluster_5007',
#   'cluster_5008',
#   'cluster_5009',
#   'cluster_5010',
#   'cluster_5011',
#   'cluster_5012',
#   'cluster_5014',
#   'cluster_5015',
#   'cluster_5016',
#   'cluster_5017',
#   'cluster_5018',
#   'cluster_5019',
#   'cluster_5020',
#   'cluster_5021',
#   'cluster_5022',
#   'cluster_5023',
#   'cluster_5024',
#   'cluster_5025',
#   'cluster_5026',
#   'cluster_5027',
#   'cluster_5028',
#   'cluster_5029',
#   'cluster_5030',
#   'cluster_5031',
#   'cluster_5032',
#   'cluster_5033',
#   'cluster_5034',
#   'cluster_5035',
#   'cluster_5036',
#   'cluster_5037',
#   'cluster_5038',
#   'cluster_5039',
#   'cluster_5040',
#   'cluster_5041',
#   'cluster_5042',
#   'cluster_5043',
#   'cluster_5044',
#   'cluster_5045',
#   'cluster_5046',
#   'cluster_5047',
#   'cluster_5048',
#   'cluster_5049',
#   'cluster_5050',
#   'cluster_5051',
#   'cluster_5052',
#   'cluster_5053',
#   'cluster_5054',
#   'cluster_5055',
#   'cluster_5056',
#   'cluster_5057',
#   'cluster_5058',
#   'cluster_5059',
#   'cluster_5060',
#   'cluster_5061',
#   'cluster_5062',
#   'cluster_5063',
#   'cluster_5064']}

# %%
node_set_id_dict = {'pdam_spis': 'pocilloporidae', 'aten_epal': 'enthemonae', 'aaur_mvir': 'acraspeda',
                    'chem_hsym': 'leptothecata'}
node_set_id_df = pd.DataFrame(node_set_id_dict.items(), columns=['set_id', 'node'])
node_set_id_df
# Out:
#       set_id            node
# 0  pdam_spis  pocilloporidae
# 1  aten_epal      enthemonae
# 2  aaur_mvir       acraspeda
# 3  chem_hsym    leptothecata

# %%
excluded_cluster_nodes = {}
for set_id, cluster_list in excluded_cluster_dict.items():
    node_id = node_set_id_dict[set_id]
    for cluster_id in cluster_list:
        excluded_cluster_nodes[cluster_id]=node_id
excluded_cluster_nodes
# Out:
# {'cluster_30687': 'pocilloporidae',
#  'cluster_30688': 'pocilloporidae',
#  'cluster_30689': 'pocilloporidae',
#  'cluster_30690': 'pocilloporidae',
#  'cluster_30691': 'pocilloporidae',
#  'cluster_30692': 'pocilloporidae',
#  'cluster_30693': 'pocilloporidae',
#  'cluster_30694': 'pocilloporidae',
#  'cluster_30695': 'pocilloporidae',
#  'cluster_30696': 'pocilloporidae',
#  'cluster_30697': 'pocilloporidae',
#  'cluster_30698': 'pocilloporidae',
#  'cluster_30699': 'pocilloporidae',
#  'cluster_30700': 'pocilloporidae',
#  'cluster_30701': 'pocilloporidae',
#  'cluster_30702': 'pocilloporidae',
#  'cluster_30703': 'pocilloporidae',
#  'cluster_30704': 'pocilloporidae',
#  'cluster_30705': 'pocilloporidae',
#  'cluster_30706': 'pocilloporidae',
#  'cluster_30707': 'pocilloporidae',
#  'cluster_30708': 'pocilloporidae',
#  'cluster_30709': 'pocilloporidae',
#  'cluster_30710': 'pocilloporidae',
#  'cluster_30711': 'pocilloporidae',
#  'cluster_30712': 'pocilloporidae',
#  'cluster_30713': 'pocilloporidae',
#  'cluster_30714': 'pocilloporidae',
#  'cluster_30715': 'pocilloporidae',
#  'cluster_30716': 'pocilloporidae',
#  'cluster_30717': 'pocilloporidae',
#  'cluster_30718': 'pocilloporidae',
#  'cluster_30719': 'pocilloporidae',
#  'cluster_30720': 'pocilloporidae',
#  'cluster_30721': 'pocilloporidae',
#  'cluster_30722': 'pocilloporidae',
#  'cluster_30723': 'pocilloporidae',
#  'cluster_30724': 'pocilloporidae',
#  'cluster_30725': 'pocilloporidae',
#  'cluster_30726': 'pocilloporidae',
#  'cluster_30727': 'pocilloporidae',
#  'cluster_30728': 'pocilloporidae',
#  'cluster_30729': 'pocilloporidae',
#  'cluster_30730': 'pocilloporidae',
#  'cluster_30731': 'pocilloporidae',
#  'cluster_30732': 'pocilloporidae',
#  'cluster_30733': 'pocilloporidae',
#  'cluster_30734': 'pocilloporidae',
#  'cluster_30735': 'pocilloporidae',
#  'cluster_30736': 'pocilloporidae',
#  'cluster_30737': 'pocilloporidae',
#  'cluster_30738': 'pocilloporidae',
#  'cluster_30739': 'pocilloporidae',
#  'cluster_30740': 'pocilloporidae',
#  'cluster_30741': 'pocilloporidae',
#  'cluster_30742': 'pocilloporidae',
#  'cluster_30743': 'pocilloporidae',
#  'cluster_30744': 'pocilloporidae',
#  'cluster_30745': 'pocilloporidae',
#  'cluster_30746': 'pocilloporidae',
#  'cluster_30747': 'pocilloporidae',
#  'cluster_30748': 'pocilloporidae',
#  'cluster_30749': 'pocilloporidae',
#  'cluster_30750': 'pocilloporidae',
#  'cluster_30751': 'pocilloporidae',
#  'cluster_30752': 'pocilloporidae',
#  'cluster_30753': 'pocilloporidae',
#  'cluster_30754': 'pocilloporidae',
#  'cluster_30755': 'pocilloporidae',
#  'cluster_30756': 'pocilloporidae',
#  'cluster_30757': 'pocilloporidae',
#  'cluster_30758': 'pocilloporidae',
#  'cluster_30759': 'pocilloporidae',
#  'cluster_30760': 'pocilloporidae',
#  'cluster_30761': 'pocilloporidae',
#  'cluster_30762': 'pocilloporidae',
#  'cluster_30763': 'pocilloporidae',
#  'cluster_30764': 'pocilloporidae',
#  'cluster_30765': 'pocilloporidae',
#  'cluster_30766': 'pocilloporidae',
#  'cluster_30767': 'pocilloporidae',
#  'cluster_30768': 'pocilloporidae',
#  'cluster_30769': 'pocilloporidae',
#  'cluster_30770': 'pocilloporidae',
#  'cluster_30771': 'pocilloporidae',
#  'cluster_30772': 'pocilloporidae',
#  'cluster_30773': 'pocilloporidae',
#  'cluster_30774': 'pocilloporidae',
#  'cluster_30775': 'pocilloporidae',
#  'cluster_30776': 'pocilloporidae',
#  'cluster_30777': 'pocilloporidae',
#  'cluster_30778': 'pocilloporidae',
#  'cluster_30779': 'pocilloporidae',
#  'cluster_30780': 'pocilloporidae',
#  'cluster_30781': 'pocilloporidae',
#  'cluster_30782': 'pocilloporidae',
#  'cluster_30783': 'pocilloporidae',
#  'cluster_30784': 'pocilloporidae',
#  'cluster_30785': 'pocilloporidae',
#  'cluster_30786': 'pocilloporidae',
#  'cluster_30787': 'pocilloporidae',
#  'cluster_30788': 'pocilloporidae',
#  'cluster_30789': 'pocilloporidae',
#  'cluster_30790': 'pocilloporidae',
#  'cluster_30791': 'pocilloporidae',
#  'cluster_30792': 'pocilloporidae',
#  'cluster_30793': 'pocilloporidae',
#  'cluster_30794': 'pocilloporidae',
#  'cluster_30795': 'pocilloporidae',
#  'cluster_30796': 'pocilloporidae',
#  'cluster_30797': 'pocilloporidae',
#  'cluster_30798': 'pocilloporidae',
#  'cluster_30799': 'pocilloporidae',
#  'cluster_30800': 'pocilloporidae',
#  'cluster_30801': 'pocilloporidae',
#  'cluster_30802': 'pocilloporidae',
#  'cluster_30803': 'pocilloporidae',
#  'cluster_30804': 'pocilloporidae',
#  'cluster_30805': 'pocilloporidae',
#  'cluster_30806': 'pocilloporidae',
#  'cluster_30807': 'pocilloporidae',
#  'cluster_30808': 'pocilloporidae',
#  'cluster_30809': 'pocilloporidae',
#  'cluster_30810': 'pocilloporidae',
#  'cluster_30811': 'pocilloporidae',
#  'cluster_30812': 'pocilloporidae',
#  'cluster_30813': 'pocilloporidae',
#  'cluster_30814': 'pocilloporidae',
#  'cluster_30815': 'pocilloporidae',
#  'cluster_30816': 'pocilloporidae',
#  'cluster_30817': 'pocilloporidae',
#  'cluster_30818': 'pocilloporidae',
#  'cluster_30819': 'pocilloporidae',
#  'cluster_30820': 'pocilloporidae',
#  'cluster_30821': 'pocilloporidae',
#  'cluster_30822': 'pocilloporidae',
#  'cluster_30823': 'pocilloporidae',
#  'cluster_30824': 'pocilloporidae',
#  'cluster_30825': 'pocilloporidae',
#  'cluster_30826': 'pocilloporidae',
#  'cluster_30827': 'pocilloporidae',
#  'cluster_30828': 'pocilloporidae',
#  'cluster_30829': 'pocilloporidae',
#  'cluster_30830': 'pocilloporidae',
#  'cluster_30831': 'pocilloporidae',
#  'cluster_30832': 'pocilloporidae',
#  'cluster_30833': 'pocilloporidae',
#  'cluster_30834': 'pocilloporidae',
#  'cluster_30835': 'pocilloporidae',
#  'cluster_30836': 'pocilloporidae',
#  'cluster_30837': 'pocilloporidae',
#  'cluster_30838': 'pocilloporidae',
#  'cluster_30839': 'pocilloporidae',
#  'cluster_30840': 'pocilloporidae',
#  'cluster_30841': 'pocilloporidae',
#  'cluster_30842': 'pocilloporidae',
#  'cluster_30843': 'pocilloporidae',
#  'cluster_30844': 'pocilloporidae',
#  'cluster_30845': 'pocilloporidae',
#  'cluster_30846': 'pocilloporidae',
#  'cluster_30847': 'pocilloporidae',
#  'cluster_30848': 'pocilloporidae',
#  'cluster_30849': 'pocilloporidae',
#  'cluster_30850': 'pocilloporidae',
#  'cluster_30851': 'pocilloporidae',
#  'cluster_30852': 'pocilloporidae',
#  'cluster_30853': 'pocilloporidae',
#  'cluster_30854': 'pocilloporidae',
#  'cluster_30855': 'pocilloporidae',
#  'cluster_30856': 'pocilloporidae',
#  'cluster_30857': 'pocilloporidae',
#  'cluster_30858': 'pocilloporidae',
#  'cluster_30859': 'pocilloporidae',
#  'cluster_30860': 'pocilloporidae',
#  'cluster_30861': 'pocilloporidae',
#  'cluster_30862': 'pocilloporidae',
#  'cluster_30863': 'pocilloporidae',
#  'cluster_30864': 'pocilloporidae',
#  'cluster_30865': 'pocilloporidae',
#  'cluster_30866': 'pocilloporidae',
#  'cluster_30867': 'pocilloporidae',
#  'cluster_30868': 'pocilloporidae',
#  'cluster_30869': 'pocilloporidae',
#  'cluster_30870': 'pocilloporidae',
#  'cluster_30871': 'pocilloporidae',
#  'cluster_30872': 'pocilloporidae',
#  'cluster_30873': 'pocilloporidae',
#  'cluster_30874': 'pocilloporidae',
#  'cluster_30875': 'pocilloporidae',
#  'cluster_30876': 'pocilloporidae',
#  'cluster_30877': 'pocilloporidae',
#  'cluster_30878': 'pocilloporidae',
#  'cluster_30879': 'pocilloporidae',
#  'cluster_30880': 'pocilloporidae',
#  'cluster_30881': 'pocilloporidae',
#  'cluster_30882': 'pocilloporidae',
#  'cluster_30883': 'pocilloporidae',
#  'cluster_30885': 'pocilloporidae',
#  'cluster_30886': 'pocilloporidae',
#  'cluster_30887': 'pocilloporidae',
#  'cluster_30888': 'pocilloporidae',
#  'cluster_30889': 'pocilloporidae',
#  'cluster_30890': 'pocilloporidae',
#  'cluster_30891': 'pocilloporidae',
#  'cluster_30892': 'pocilloporidae',
#  'cluster_30893': 'pocilloporidae',
#  'cluster_30894': 'pocilloporidae',
#  'cluster_30895': 'pocilloporidae',
#  'cluster_30896': 'pocilloporidae',
#  'cluster_30897': 'pocilloporidae',
#  'cluster_30898': 'pocilloporidae',
#  'cluster_30899': 'pocilloporidae',
#  'cluster_30900': 'pocilloporidae',
#  'cluster_30901': 'pocilloporidae',
#  'cluster_30902': 'pocilloporidae',
#  'cluster_30903': 'pocilloporidae',
#  'cluster_30904': 'pocilloporidae',
#  'cluster_30905': 'pocilloporidae',
#  'cluster_30906': 'pocilloporidae',
#  'cluster_30907': 'pocilloporidae',
#  'cluster_30908': 'pocilloporidae',
#  'cluster_30909': 'pocilloporidae',
#  'cluster_30910': 'pocilloporidae',
#  'cluster_30911': 'pocilloporidae',
#  'cluster_30912': 'pocilloporidae',
#  'cluster_30913': 'pocilloporidae',
#  'cluster_30914': 'pocilloporidae',
#  'cluster_30915': 'pocilloporidae',
#  'cluster_30916': 'pocilloporidae',
#  'cluster_30917': 'pocilloporidae',
#  'cluster_30918': 'pocilloporidae',
#  'cluster_30919': 'pocilloporidae',
#  'cluster_30920': 'pocilloporidae',
#  'cluster_30921': 'pocilloporidae',
#  'cluster_30922': 'pocilloporidae',
#  'cluster_30923': 'pocilloporidae',
#  'cluster_30924': 'pocilloporidae',
#  'cluster_30925': 'pocilloporidae',
#  'cluster_30926': 'pocilloporidae',
#  'cluster_30927': 'pocilloporidae',
#  'cluster_30928': 'pocilloporidae',
#  'cluster_30929': 'pocilloporidae',
#  'cluster_30930': 'pocilloporidae',
#  'cluster_30931': 'pocilloporidae',
#  'cluster_30932': 'pocilloporidae',
#  'cluster_30933': 'pocilloporidae',
#  'cluster_30934': 'pocilloporidae',
#  'cluster_30935': 'pocilloporidae',
#  'cluster_30936': 'pocilloporidae',
#  'cluster_30937': 'pocilloporidae',
#  'cluster_30938': 'pocilloporidae',
#  'cluster_30939': 'pocilloporidae',
#  'cluster_30940': 'pocilloporidae',
#  'cluster_30941': 'pocilloporidae',
#  'cluster_30942': 'pocilloporidae',
#  'cluster_30943': 'pocilloporidae',
#  'cluster_30944': 'pocilloporidae',
#  'cluster_30945': 'pocilloporidae',
#  'cluster_30946': 'pocilloporidae',
#  'cluster_30947': 'pocilloporidae',
#  'cluster_30948': 'pocilloporidae',
#  'cluster_30949': 'pocilloporidae',
#  'cluster_30950': 'pocilloporidae',
#  'cluster_30951': 'pocilloporidae',
#  'cluster_30952': 'pocilloporidae',
#  'cluster_30953': 'pocilloporidae',
#  'cluster_30954': 'pocilloporidae',
#  'cluster_30955': 'pocilloporidae',
#  'cluster_30956': 'pocilloporidae',
#  'cluster_30957': 'pocilloporidae',
#  'cluster_30958': 'pocilloporidae',
#  'cluster_30959': 'pocilloporidae',
#  'cluster_30960': 'pocilloporidae',
#  'cluster_30961': 'pocilloporidae',
#  'cluster_30962': 'pocilloporidae',
#  'cluster_30963': 'pocilloporidae',
#  'cluster_30964': 'pocilloporidae',
#  'cluster_30965': 'pocilloporidae',
#  'cluster_30966': 'pocilloporidae',
#  'cluster_30967': 'pocilloporidae',
#  'cluster_30968': 'pocilloporidae',
#  'cluster_30969': 'pocilloporidae',
#  'cluster_30970': 'pocilloporidae',
#  'cluster_30971': 'pocilloporidae',
#  'cluster_30972': 'pocilloporidae',
#  'cluster_30973': 'pocilloporidae',
#  'cluster_30974': 'pocilloporidae',
#  'cluster_30975': 'pocilloporidae',
#  'cluster_30976': 'pocilloporidae',
#  'cluster_30977': 'pocilloporidae',
#  'cluster_30978': 'pocilloporidae',
#  'cluster_30979': 'pocilloporidae',
#  'cluster_30980': 'pocilloporidae',
#  'cluster_30981': 'pocilloporidae',
#  'cluster_30982': 'pocilloporidae',
#  'cluster_30983': 'pocilloporidae',
#  'cluster_30985': 'pocilloporidae',
#  'cluster_30986': 'pocilloporidae',
#  'cluster_30987': 'pocilloporidae',
#  'cluster_30988': 'pocilloporidae',
#  'cluster_30989': 'pocilloporidae',
#  'cluster_30990': 'pocilloporidae',
#  'cluster_30991': 'pocilloporidae',
#  'cluster_30992': 'pocilloporidae',
#  'cluster_30993': 'pocilloporidae',
#  'cluster_30994': 'pocilloporidae',
#  'cluster_30995': 'pocilloporidae',
#  'cluster_30996': 'pocilloporidae',
#  'cluster_30997': 'pocilloporidae',
#  'cluster_30998': 'pocilloporidae',
#  'cluster_30999': 'pocilloporidae',
#  'cluster_31000': 'pocilloporidae',
#  'cluster_31001': 'pocilloporidae',
#  'cluster_31002': 'pocilloporidae',
#  'cluster_31003': 'pocilloporidae',
#  'cluster_31004': 'pocilloporidae',
#  'cluster_31005': 'pocilloporidae',
#  'cluster_31006': 'pocilloporidae',
#  'cluster_31007': 'pocilloporidae',
#  'cluster_31008': 'pocilloporidae',
#  'cluster_31009': 'pocilloporidae',
#  'cluster_31010': 'pocilloporidae',
#  'cluster_31011': 'pocilloporidae',
#  'cluster_31012': 'pocilloporidae',
#  'cluster_31013': 'pocilloporidae',
#  'cluster_31014': 'pocilloporidae',
#  'cluster_31015': 'pocilloporidae',
#  'cluster_31016': 'pocilloporidae',
#  'cluster_31017': 'pocilloporidae',
#  'cluster_31018': 'pocilloporidae',
#  'cluster_31019': 'pocilloporidae',
#  'cluster_31020': 'pocilloporidae',
#  'cluster_31021': 'pocilloporidae',
#  'cluster_31022': 'pocilloporidae',
#  'cluster_31023': 'pocilloporidae',
#  'cluster_31024': 'pocilloporidae',
#  'cluster_31025': 'pocilloporidae',
#  'cluster_31026': 'pocilloporidae',
#  'cluster_31027': 'pocilloporidae',
#  'cluster_31028': 'pocilloporidae',
#  'cluster_31029': 'pocilloporidae',
#  'cluster_31030': 'pocilloporidae',
#  'cluster_31031': 'pocilloporidae',
#  'cluster_31032': 'pocilloporidae',
#  'cluster_31033': 'pocilloporidae',
#  'cluster_31034': 'pocilloporidae',
#  'cluster_31035': 'pocilloporidae',
#  'cluster_31036': 'pocilloporidae',
#  'cluster_31037': 'pocilloporidae',
#  'cluster_31038': 'pocilloporidae',
#  'cluster_31039': 'pocilloporidae',
#  'cluster_31040': 'pocilloporidae',
#  'cluster_31041': 'pocilloporidae',
#  'cluster_31042': 'pocilloporidae',
#  'cluster_31043': 'pocilloporidae',
#  'cluster_31044': 'pocilloporidae',
#  'cluster_31045': 'pocilloporidae',
#  'cluster_31046': 'pocilloporidae',
#  'cluster_31047': 'pocilloporidae',
#  'cluster_31048': 'pocilloporidae',
#  'cluster_31049': 'pocilloporidae',
#  'cluster_31050': 'pocilloporidae',
#  'cluster_31051': 'pocilloporidae',
#  'cluster_31052': 'pocilloporidae',
#  'cluster_31053': 'pocilloporidae',
#  'cluster_31054': 'pocilloporidae',
#  'cluster_31055': 'pocilloporidae',
#  'cluster_31056': 'pocilloporidae',
#  'cluster_31057': 'pocilloporidae',
#  'cluster_31058': 'pocilloporidae',
#  'cluster_31059': 'pocilloporidae',
#  'cluster_31060': 'pocilloporidae',
#  'cluster_31061': 'pocilloporidae',
#  'cluster_31062': 'pocilloporidae',
#  'cluster_31063': 'pocilloporidae',
#  'cluster_31064': 'pocilloporidae',
#  'cluster_31065': 'pocilloporidae',
#  'cluster_31066': 'pocilloporidae',
#  'cluster_31067': 'pocilloporidae',
#  'cluster_31068': 'pocilloporidae',
#  'cluster_31069': 'pocilloporidae',
#  'cluster_31070': 'pocilloporidae',
#  'cluster_31071': 'pocilloporidae',
#  'cluster_31072': 'pocilloporidae',
#  'cluster_31073': 'pocilloporidae',
#  'cluster_31074': 'pocilloporidae',
#  'cluster_31075': 'pocilloporidae',
#  'cluster_31076': 'pocilloporidae',
#  'cluster_31077': 'pocilloporidae',
#  'cluster_31078': 'pocilloporidae',
#  'cluster_31079': 'pocilloporidae',
#  'cluster_31080': 'pocilloporidae',
#  'cluster_31081': 'pocilloporidae',
#  'cluster_31082': 'pocilloporidae',
#  'cluster_31083': 'pocilloporidae',
#  'cluster_31084': 'pocilloporidae',
#  'cluster_31085': 'pocilloporidae',
#  'cluster_31086': 'pocilloporidae',
#  'cluster_31087': 'pocilloporidae',
#  'cluster_31088': 'pocilloporidae',
#  'cluster_31089': 'pocilloporidae',
#  'cluster_31090': 'pocilloporidae',
#  'cluster_31091': 'pocilloporidae',
#  'cluster_31092': 'pocilloporidae',
#  'cluster_31093': 'pocilloporidae',
#  'cluster_31094': 'pocilloporidae',
#  'cluster_31095': 'pocilloporidae',
#  'cluster_31096': 'pocilloporidae',
#  'cluster_31097': 'pocilloporidae',
#  'cluster_31098': 'pocilloporidae',
#  'cluster_31099': 'pocilloporidae',
#  'cluster_31100': 'pocilloporidae',
#  'cluster_31101': 'pocilloporidae',
#  'cluster_31102': 'pocilloporidae',
#  'cluster_31103': 'pocilloporidae',
#  'cluster_31104': 'pocilloporidae',
#  'cluster_31105': 'pocilloporidae',
#  'cluster_31106': 'pocilloporidae',
#  'cluster_31107': 'pocilloporidae',
#  'cluster_31108': 'pocilloporidae',
#  'cluster_31109': 'pocilloporidae',
#  'cluster_31110': 'pocilloporidae',
#  'cluster_31111': 'pocilloporidae',
#  'cluster_31112': 'pocilloporidae',
#  'cluster_31113': 'pocilloporidae',
#  'cluster_31114': 'pocilloporidae',
#  'cluster_31115': 'pocilloporidae',
#  'cluster_31116': 'pocilloporidae',
#  'cluster_31117': 'pocilloporidae',
#  'cluster_31118': 'pocilloporidae',
#  'cluster_31119': 'pocilloporidae',
#  'cluster_31120': 'pocilloporidae',
#  'cluster_31121': 'pocilloporidae',
#  'cluster_31122': 'pocilloporidae',
#  'cluster_31123': 'pocilloporidae',
#  'cluster_31124': 'pocilloporidae',
#  'cluster_31125': 'pocilloporidae',
#  'cluster_31126': 'pocilloporidae',
#  'cluster_31127': 'pocilloporidae',
#  'cluster_31128': 'pocilloporidae',
#  'cluster_31129': 'pocilloporidae',
#  'cluster_31130': 'pocilloporidae',
#  'cluster_31131': 'pocilloporidae',
#  'cluster_31132': 'pocilloporidae',
#  'cluster_31133': 'pocilloporidae',
#  'cluster_31134': 'pocilloporidae',
#  'cluster_31135': 'pocilloporidae',
#  'cluster_31136': 'pocilloporidae',
#  'cluster_31137': 'pocilloporidae',
#  'cluster_31138': 'pocilloporidae',
#  'cluster_31139': 'pocilloporidae',
#  'cluster_31140': 'pocilloporidae',
#  'cluster_31141': 'pocilloporidae',
#  'cluster_31142': 'pocilloporidae',
#  'cluster_31143': 'pocilloporidae',
#  'cluster_31144': 'pocilloporidae',
#  'cluster_31145': 'pocilloporidae',
#  'cluster_31146': 'pocilloporidae',
#  'cluster_31147': 'pocilloporidae',
#  'cluster_31148': 'pocilloporidae',
#  'cluster_31149': 'pocilloporidae',
#  'cluster_31150': 'pocilloporidae',
#  'cluster_31151': 'pocilloporidae',
#  'cluster_31152': 'pocilloporidae',
#  'cluster_31153': 'pocilloporidae',
#  'cluster_31154': 'pocilloporidae',
#  'cluster_31155': 'pocilloporidae',
#  'cluster_31157': 'pocilloporidae',
#  'cluster_31158': 'pocilloporidae',
#  'cluster_31159': 'pocilloporidae',
#  'cluster_31160': 'pocilloporidae',
#  'cluster_31161': 'pocilloporidae',
#  'cluster_31162': 'pocilloporidae',
#  'cluster_31163': 'pocilloporidae',
#  'cluster_31164': 'pocilloporidae',
#  'cluster_31165': 'pocilloporidae',
#  'cluster_31166': 'pocilloporidae',
#  'cluster_31167': 'pocilloporidae',
#  'cluster_31168': 'pocilloporidae',
#  'cluster_31169': 'pocilloporidae',
#  'cluster_31170': 'pocilloporidae',
#  'cluster_31171': 'pocilloporidae',
#  'cluster_31172': 'pocilloporidae',
#  'cluster_31173': 'pocilloporidae',
#  'cluster_31174': 'pocilloporidae',
#  'cluster_31175': 'pocilloporidae',
#  'cluster_31176': 'pocilloporidae',
#  'cluster_31177': 'pocilloporidae',
#  'cluster_31178': 'pocilloporidae',
#  'cluster_31179': 'pocilloporidae',
#  'cluster_31180': 'pocilloporidae',
#  'cluster_31181': 'pocilloporidae',
#  'cluster_31182': 'pocilloporidae',
#  'cluster_31183': 'pocilloporidae',
#  'cluster_31184': 'pocilloporidae',
#  'cluster_31185': 'pocilloporidae',
#  'cluster_31186': 'pocilloporidae',
#  'cluster_31187': 'pocilloporidae',
#  'cluster_31188': 'pocilloporidae',
#  'cluster_31189': 'pocilloporidae',
#  'cluster_31190': 'pocilloporidae',
#  'cluster_31191': 'pocilloporidae',
#  'cluster_31192': 'pocilloporidae',
#  'cluster_31193': 'pocilloporidae',
#  'cluster_31194': 'pocilloporidae',
#  'cluster_31195': 'pocilloporidae',
#  'cluster_31196': 'pocilloporidae',
#  'cluster_31197': 'pocilloporidae',
#  'cluster_31198': 'pocilloporidae',
#  'cluster_31199': 'pocilloporidae',
#  'cluster_31200': 'pocilloporidae',
#  'cluster_31201': 'pocilloporidae',
#  'cluster_31202': 'pocilloporidae',
#  'cluster_31203': 'pocilloporidae',
#  'cluster_31204': 'pocilloporidae',
#  'cluster_31205': 'pocilloporidae',
#  'cluster_31206': 'pocilloporidae',
#  'cluster_31207': 'pocilloporidae',
#  'cluster_31208': 'pocilloporidae',
#  'cluster_31209': 'pocilloporidae',
#  'cluster_31210': 'pocilloporidae',
#  'cluster_31211': 'pocilloporidae',
#  'cluster_31212': 'pocilloporidae',
#  'cluster_31213': 'pocilloporidae',
#  'cluster_31214': 'pocilloporidae',
#  'cluster_31215': 'pocilloporidae',
#  'cluster_31216': 'pocilloporidae',
#  'cluster_31217': 'pocilloporidae',
#  'cluster_31218': 'pocilloporidae',
#  'cluster_31219': 'pocilloporidae',
#  'cluster_31220': 'pocilloporidae',
#  'cluster_31221': 'pocilloporidae',
#  'cluster_31222': 'pocilloporidae',
#  'cluster_31223': 'pocilloporidae',
#  'cluster_31224': 'pocilloporidae',
#  'cluster_31225': 'pocilloporidae',
#  'cluster_31226': 'pocilloporidae',
#  'cluster_31227': 'pocilloporidae',
#  'cluster_31228': 'pocilloporidae',
#  'cluster_31229': 'pocilloporidae',
#  'cluster_31230': 'pocilloporidae',
#  'cluster_31231': 'pocilloporidae',
#  'cluster_31232': 'pocilloporidae',
#  'cluster_31233': 'pocilloporidae',
#  'cluster_31234': 'pocilloporidae',
#  'cluster_31235': 'pocilloporidae',
#  'cluster_31236': 'pocilloporidae',
#  'cluster_31237': 'pocilloporidae',
#  'cluster_31238': 'pocilloporidae',
#  'cluster_31239': 'pocilloporidae',
#  'cluster_31240': 'pocilloporidae',
#  'cluster_31241': 'pocilloporidae',
#  'cluster_31242': 'pocilloporidae',
#  'cluster_31243': 'pocilloporidae',
#  'cluster_31244': 'pocilloporidae',
#  'cluster_31245': 'pocilloporidae',
#  'cluster_31246': 'pocilloporidae',
#  'cluster_31247': 'pocilloporidae',
#  'cluster_31248': 'pocilloporidae',
#  'cluster_31249': 'pocilloporidae',
#  'cluster_31250': 'pocilloporidae',
#  'cluster_31251': 'pocilloporidae',
#  'cluster_31252': 'pocilloporidae',
#  'cluster_31253': 'pocilloporidae',
#  'cluster_31254': 'pocilloporidae',
#  'cluster_31255': 'pocilloporidae',
#  'cluster_31256': 'pocilloporidae',
#  'cluster_31257': 'pocilloporidae',
#  'cluster_31258': 'pocilloporidae',
#  'cluster_31259': 'pocilloporidae',
#  'cluster_31260': 'pocilloporidae',
#  'cluster_31261': 'pocilloporidae',
#  'cluster_31262': 'pocilloporidae',
#  'cluster_31263': 'pocilloporidae',
#  'cluster_31264': 'pocilloporidae',
#  'cluster_31265': 'pocilloporidae',
#  'cluster_31266': 'pocilloporidae',
#  'cluster_31267': 'pocilloporidae',
#  'cluster_31268': 'pocilloporidae',
#  'cluster_31269': 'pocilloporidae',
#  'cluster_31270': 'pocilloporidae',
#  'cluster_31271': 'pocilloporidae',
#  'cluster_31272': 'pocilloporidae',
#  'cluster_31273': 'pocilloporidae',
#  'cluster_31274': 'pocilloporidae',
#  'cluster_31275': 'pocilloporidae',
#  'cluster_31276': 'pocilloporidae',
#  'cluster_31277': 'pocilloporidae',
#  'cluster_31278': 'pocilloporidae',
#  'cluster_31279': 'pocilloporidae',
#  'cluster_31280': 'pocilloporidae',
#  'cluster_31281': 'pocilloporidae',
#  'cluster_31282': 'pocilloporidae',
#  'cluster_31283': 'pocilloporidae',
#  'cluster_31284': 'pocilloporidae',
#  'cluster_31285': 'pocilloporidae',
#  'cluster_31286': 'pocilloporidae',
#  'cluster_31287': 'pocilloporidae',
#  'cluster_31288': 'pocilloporidae',
#  'cluster_31289': 'pocilloporidae',
#  'cluster_31290': 'pocilloporidae',
#  'cluster_31291': 'pocilloporidae',
#  'cluster_31292': 'pocilloporidae',
#  'cluster_31293': 'pocilloporidae',
#  'cluster_31294': 'pocilloporidae',
#  'cluster_31295': 'pocilloporidae',
#  'cluster_31296': 'pocilloporidae',
#  'cluster_31297': 'pocilloporidae',
#  'cluster_31298': 'pocilloporidae',
#  'cluster_31299': 'pocilloporidae',
#  'cluster_31300': 'pocilloporidae',
#  'cluster_31301': 'pocilloporidae',
#  'cluster_31302': 'pocilloporidae',
#  'cluster_31303': 'pocilloporidae',
#  'cluster_31304': 'pocilloporidae',
#  'cluster_31305': 'pocilloporidae',
#  'cluster_31306': 'pocilloporidae',
#  'cluster_31307': 'pocilloporidae',
#  'cluster_31308': 'pocilloporidae',
#  'cluster_31309': 'pocilloporidae',
#  'cluster_31310': 'pocilloporidae',
#  'cluster_31311': 'pocilloporidae',
#  'cluster_31312': 'pocilloporidae',
#  'cluster_31313': 'pocilloporidae',
#  'cluster_31314': 'pocilloporidae',
#  'cluster_31315': 'pocilloporidae',
#  'cluster_31316': 'pocilloporidae',
#  'cluster_31317': 'pocilloporidae',
#  'cluster_31318': 'pocilloporidae',
#  'cluster_31319': 'pocilloporidae',
#  'cluster_31320': 'pocilloporidae',
#  'cluster_31321': 'pocilloporidae',
#  'cluster_31322': 'pocilloporidae',
#  'cluster_31323': 'pocilloporidae',
#  'cluster_31324': 'pocilloporidae',
#  'cluster_31325': 'pocilloporidae',
#  'cluster_31326': 'pocilloporidae',
#  'cluster_31327': 'pocilloporidae',
#  'cluster_31328': 'pocilloporidae',
#  'cluster_31329': 'pocilloporidae',
#  'cluster_31330': 'pocilloporidae',
#  'cluster_31331': 'pocilloporidae',
#  'cluster_31332': 'pocilloporidae',
#  'cluster_31333': 'pocilloporidae',
#  'cluster_31334': 'pocilloporidae',
#  'cluster_31335': 'pocilloporidae',
#  'cluster_31336': 'pocilloporidae',
#  'cluster_31337': 'pocilloporidae',
#  'cluster_31338': 'pocilloporidae',
#  'cluster_31339': 'pocilloporidae',
#  'cluster_31340': 'pocilloporidae',
#  'cluster_31341': 'pocilloporidae',
#  'cluster_31342': 'pocilloporidae',
#  'cluster_31343': 'pocilloporidae',
#  'cluster_31344': 'pocilloporidae',
#  'cluster_31345': 'pocilloporidae',
#  'cluster_31346': 'pocilloporidae',
#  'cluster_31347': 'pocilloporidae',
#  'cluster_31348': 'pocilloporidae',
#  'cluster_31349': 'pocilloporidae',
#  'cluster_31350': 'pocilloporidae',
#  'cluster_31351': 'pocilloporidae',
#  'cluster_31352': 'pocilloporidae',
#  'cluster_31353': 'pocilloporidae',
#  'cluster_31354': 'pocilloporidae',
#  'cluster_31355': 'pocilloporidae',
#  'cluster_31356': 'pocilloporidae',
#  'cluster_31357': 'pocilloporidae',
#  'cluster_31358': 'pocilloporidae',
#  'cluster_31359': 'pocilloporidae',
#  'cluster_31360': 'pocilloporidae',
#  'cluster_31361': 'pocilloporidae',
#  'cluster_31362': 'pocilloporidae',
#  'cluster_31363': 'pocilloporidae',
#  'cluster_31364': 'pocilloporidae',
#  'cluster_31365': 'pocilloporidae',
#  'cluster_31366': 'pocilloporidae',
#  'cluster_31367': 'pocilloporidae',
#  'cluster_31368': 'pocilloporidae',
#  'cluster_31369': 'pocilloporidae',
#  'cluster_31370': 'pocilloporidae',
#  'cluster_31371': 'pocilloporidae',
#  'cluster_31372': 'pocilloporidae',
#  'cluster_31373': 'pocilloporidae',
#  'cluster_31374': 'pocilloporidae',
#  'cluster_31375': 'pocilloporidae',
#  'cluster_31376': 'pocilloporidae',
#  'cluster_31377': 'pocilloporidae',
#  'cluster_31378': 'pocilloporidae',
#  'cluster_31379': 'pocilloporidae',
#  'cluster_31380': 'pocilloporidae',
#  'cluster_31381': 'pocilloporidae',
#  'cluster_31382': 'pocilloporidae',
#  'cluster_31383': 'pocilloporidae',
#  'cluster_31384': 'pocilloporidae',
#  'cluster_31385': 'pocilloporidae',
#  'cluster_31386': 'pocilloporidae',
#  'cluster_31387': 'pocilloporidae',
#  'cluster_31388': 'pocilloporidae',
#  'cluster_31389': 'pocilloporidae',
#  'cluster_31390': 'pocilloporidae',
#  'cluster_31391': 'pocilloporidae',
#  'cluster_31392': 'pocilloporidae',
#  'cluster_31393': 'pocilloporidae',
#  'cluster_31394': 'pocilloporidae',
#  'cluster_31395': 'pocilloporidae',
#  'cluster_31396': 'pocilloporidae',
#  'cluster_31397': 'pocilloporidae',
#  'cluster_31398': 'pocilloporidae',
#  'cluster_31399': 'pocilloporidae',
#  'cluster_31400': 'pocilloporidae',
#  'cluster_31401': 'pocilloporidae',
#  'cluster_31402': 'pocilloporidae',
#  'cluster_31403': 'pocilloporidae',
#  'cluster_31404': 'pocilloporidae',
#  'cluster_31405': 'pocilloporidae',
#  'cluster_31406': 'pocilloporidae',
#  'cluster_31407': 'pocilloporidae',
#  'cluster_31408': 'pocilloporidae',
#  'cluster_31409': 'pocilloporidae',
#  'cluster_31410': 'pocilloporidae',
#  'cluster_31411': 'pocilloporidae',
#  'cluster_31412': 'pocilloporidae',
#  'cluster_31413': 'pocilloporidae',
#  'cluster_31414': 'pocilloporidae',
#  'cluster_31415': 'pocilloporidae',
#  'cluster_31416': 'pocilloporidae',
#  'cluster_31417': 'pocilloporidae',
#  'cluster_31418': 'pocilloporidae',
#  'cluster_31419': 'pocilloporidae',
#  'cluster_31420': 'pocilloporidae',
#  'cluster_31421': 'pocilloporidae',
#  'cluster_31422': 'pocilloporidae',
#  'cluster_31423': 'pocilloporidae',
#  'cluster_31424': 'pocilloporidae',
#  'cluster_31425': 'pocilloporidae',
#  'cluster_31426': 'pocilloporidae',
#  'cluster_31427': 'pocilloporidae',
#  'cluster_31428': 'pocilloporidae',
#  'cluster_31429': 'pocilloporidae',
#  'cluster_31430': 'pocilloporidae',
#  'cluster_31431': 'pocilloporidae',
#  'cluster_31432': 'pocilloporidae',
#  'cluster_31433': 'pocilloporidae',
#  'cluster_31434': 'pocilloporidae',
#  'cluster_31435': 'pocilloporidae',
#  'cluster_31436': 'pocilloporidae',
#  'cluster_31437': 'pocilloporidae',
#  'cluster_31438': 'pocilloporidae',
#  'cluster_31439': 'pocilloporidae',
#  'cluster_31440': 'pocilloporidae',
#  'cluster_31441': 'pocilloporidae',
#  'cluster_31442': 'pocilloporidae',
#  'cluster_31443': 'pocilloporidae',
#  'cluster_31444': 'pocilloporidae',
#  'cluster_31445': 'pocilloporidae',
#  'cluster_31446': 'pocilloporidae',
#  'cluster_31447': 'pocilloporidae',
#  'cluster_31448': 'pocilloporidae',
#  'cluster_31449': 'pocilloporidae',
#  'cluster_31450': 'pocilloporidae',
#  'cluster_31451': 'pocilloporidae',
#  'cluster_31452': 'pocilloporidae',
#  'cluster_31453': 'pocilloporidae',
#  'cluster_31454': 'pocilloporidae',
#  'cluster_31455': 'pocilloporidae',
#  'cluster_31456': 'pocilloporidae',
#  'cluster_31457': 'pocilloporidae',
#  'cluster_31458': 'pocilloporidae',
#  'cluster_31459': 'pocilloporidae',
#  'cluster_31460': 'pocilloporidae',
#  'cluster_31461': 'pocilloporidae',
#  'cluster_31462': 'pocilloporidae',
#  'cluster_31463': 'pocilloporidae',
#  'cluster_31464': 'pocilloporidae',
#  'cluster_31465': 'pocilloporidae',
#  'cluster_31466': 'pocilloporidae',
#  'cluster_31467': 'pocilloporidae',
#  'cluster_31468': 'pocilloporidae',
#  'cluster_31469': 'pocilloporidae',
#  'cluster_31470': 'pocilloporidae',
#  'cluster_31471': 'pocilloporidae',
#  'cluster_31472': 'pocilloporidae',
#  'cluster_31473': 'pocilloporidae',
#  'cluster_31474': 'pocilloporidae',
#  'cluster_31475': 'pocilloporidae',
#  'cluster_31476': 'pocilloporidae',
#  'cluster_31477': 'pocilloporidae',
#  'cluster_31478': 'pocilloporidae',
#  'cluster_31479': 'pocilloporidae',
#  'cluster_31480': 'pocilloporidae',
#  'cluster_31481': 'pocilloporidae',
#  'cluster_31482': 'pocilloporidae',
#  'cluster_31483': 'pocilloporidae',
#  'cluster_31484': 'pocilloporidae',
#  'cluster_31485': 'pocilloporidae',
#  'cluster_31486': 'pocilloporidae',
#  'cluster_31487': 'pocilloporidae',
#  'cluster_31488': 'pocilloporidae',
#  'cluster_31489': 'pocilloporidae',
#  'cluster_31490': 'pocilloporidae',
#  'cluster_31491': 'pocilloporidae',
#  'cluster_31492': 'pocilloporidae',
#  'cluster_31493': 'pocilloporidae',
#  'cluster_31494': 'pocilloporidae',
#  'cluster_31495': 'pocilloporidae',
#  'cluster_31496': 'pocilloporidae',
#  'cluster_31497': 'pocilloporidae',
#  'cluster_31498': 'pocilloporidae',
#  'cluster_31499': 'pocilloporidae',
#  'cluster_31500': 'pocilloporidae',
#  'cluster_31501': 'pocilloporidae',
#  'cluster_31502': 'pocilloporidae',
#  'cluster_31503': 'pocilloporidae',
#  'cluster_31504': 'pocilloporidae',
#  'cluster_31505': 'pocilloporidae',
#  'cluster_31506': 'pocilloporidae',
#  'cluster_31507': 'pocilloporidae',
#  'cluster_31508': 'pocilloporidae',
#  'cluster_31509': 'pocilloporidae',
#  'cluster_31510': 'pocilloporidae',
#  'cluster_31511': 'pocilloporidae',
#  'cluster_31512': 'pocilloporidae',
#  'cluster_31513': 'pocilloporidae',
#  'cluster_31514': 'pocilloporidae',
#  'cluster_31515': 'pocilloporidae',
#  'cluster_31516': 'pocilloporidae',
#  'cluster_31517': 'pocilloporidae',
#  'cluster_31518': 'pocilloporidae',
#  'cluster_31519': 'pocilloporidae',
#  'cluster_31520': 'pocilloporidae',
#  'cluster_31521': 'pocilloporidae',
#  'cluster_31522': 'pocilloporidae',
#  'cluster_31523': 'pocilloporidae',
#  'cluster_31524': 'pocilloporidae',
#  'cluster_31525': 'pocilloporidae',
#  'cluster_31526': 'pocilloporidae',
#  'cluster_31527': 'pocilloporidae',
#  'cluster_31528': 'pocilloporidae',
#  'cluster_31529': 'pocilloporidae',
#  'cluster_31530': 'pocilloporidae',
#  'cluster_31531': 'pocilloporidae',
#  'cluster_31532': 'pocilloporidae',
#  'cluster_31533': 'pocilloporidae',
#  'cluster_31534': 'pocilloporidae',
#  'cluster_31535': 'pocilloporidae',
#  'cluster_31536': 'pocilloporidae',
#  'cluster_31537': 'pocilloporidae',
#  'cluster_31538': 'pocilloporidae',
#  'cluster_31539': 'pocilloporidae',
#  'cluster_31540': 'pocilloporidae',
#  'cluster_31541': 'pocilloporidae',
#  'cluster_31542': 'pocilloporidae',
#  'cluster_31543': 'pocilloporidae',
#  'cluster_31544': 'pocilloporidae',
#  'cluster_31545': 'pocilloporidae',
#  'cluster_31546': 'pocilloporidae',
#  'cluster_31547': 'pocilloporidae',
#  'cluster_31548': 'pocilloporidae',
#  'cluster_31549': 'pocilloporidae',
#  'cluster_31550': 'pocilloporidae',
#  'cluster_31551': 'pocilloporidae',
#  'cluster_31552': 'pocilloporidae',
#  'cluster_31553': 'pocilloporidae',
#  'cluster_31554': 'pocilloporidae',
#  'cluster_31555': 'pocilloporidae',
#  'cluster_31556': 'pocilloporidae',
#  'cluster_31557': 'pocilloporidae',
#  'cluster_31558': 'pocilloporidae',
#  'cluster_31559': 'pocilloporidae',
#  'cluster_31560': 'pocilloporidae',
#  'cluster_31561': 'pocilloporidae',
#  'cluster_31562': 'pocilloporidae',
#  'cluster_31563': 'pocilloporidae',
#  'cluster_31564': 'pocilloporidae',
#  'cluster_31565': 'pocilloporidae',
#  'cluster_31566': 'pocilloporidae',
#  'cluster_31567': 'pocilloporidae',
#  'cluster_31568': 'pocilloporidae',
#  'cluster_31569': 'pocilloporidae',
#  'cluster_31570': 'pocilloporidae',
#  'cluster_31571': 'pocilloporidae',
#  'cluster_31572': 'pocilloporidae',
#  'cluster_31573': 'pocilloporidae',
#  'cluster_31574': 'pocilloporidae',
#  'cluster_31575': 'pocilloporidae',
#  'cluster_31576': 'pocilloporidae',
#  'cluster_31577': 'pocilloporidae',
#  'cluster_31578': 'pocilloporidae',
#  'cluster_31579': 'pocilloporidae',
#  'cluster_31580': 'pocilloporidae',
#  'cluster_31581': 'pocilloporidae',
#  'cluster_31582': 'pocilloporidae',
#  'cluster_31583': 'pocilloporidae',
#  'cluster_31584': 'pocilloporidae',
#  'cluster_31585': 'pocilloporidae',
#  'cluster_31586': 'pocilloporidae',
#  'cluster_31587': 'pocilloporidae',
#  'cluster_31588': 'pocilloporidae',
#  'cluster_31589': 'pocilloporidae',
#  'cluster_31590': 'pocilloporidae',
#  'cluster_31591': 'pocilloporidae',
#  'cluster_31592': 'pocilloporidae',
#  'cluster_31593': 'pocilloporidae',
#  'cluster_31594': 'pocilloporidae',
#  'cluster_31595': 'pocilloporidae',
#  'cluster_31596': 'pocilloporidae',
#  'cluster_31597': 'pocilloporidae',
#  'cluster_31598': 'pocilloporidae',
#  'cluster_31599': 'pocilloporidae',
#  'cluster_31600': 'pocilloporidae',
#  'cluster_31601': 'pocilloporidae',
#  'cluster_31602': 'pocilloporidae',
#  'cluster_31603': 'pocilloporidae',
#  'cluster_31604': 'pocilloporidae',
#  'cluster_31605': 'pocilloporidae',
#  'cluster_31606': 'pocilloporidae',
#  'cluster_31607': 'pocilloporidae',
#  'cluster_31608': 'pocilloporidae',
#  'cluster_31609': 'pocilloporidae',
#  'cluster_31610': 'pocilloporidae',
#  'cluster_31611': 'pocilloporidae',
#  'cluster_31612': 'pocilloporidae',
#  'cluster_31613': 'pocilloporidae',
#  'cluster_31614': 'pocilloporidae',
#  'cluster_31615': 'pocilloporidae',
#  'cluster_31616': 'pocilloporidae',
#  'cluster_31617': 'pocilloporidae',
#  'cluster_31618': 'pocilloporidae',
#  'cluster_31619': 'pocilloporidae',
#  'cluster_31620': 'pocilloporidae',
#  'cluster_31621': 'pocilloporidae',
#  'cluster_31622': 'pocilloporidae',
#  'cluster_31623': 'pocilloporidae',
#  'cluster_31624': 'pocilloporidae',
#  'cluster_31625': 'pocilloporidae',
#  'cluster_31626': 'pocilloporidae',
#  'cluster_31627': 'pocilloporidae',
#  'cluster_31628': 'pocilloporidae',
#  'cluster_31629': 'pocilloporidae',
#  'cluster_31630': 'pocilloporidae',
#  'cluster_31631': 'pocilloporidae',
#  'cluster_31632': 'pocilloporidae',
#  'cluster_31633': 'pocilloporidae',
#  'cluster_31634': 'pocilloporidae',
#  'cluster_31635': 'pocilloporidae',
#  'cluster_31636': 'pocilloporidae',
#  'cluster_31637': 'pocilloporidae',
#  'cluster_31638': 'pocilloporidae',
#  'cluster_31639': 'pocilloporidae',
#  'cluster_31640': 'pocilloporidae',
#  'cluster_31641': 'pocilloporidae',
#  'cluster_31642': 'pocilloporidae',
#  'cluster_31643': 'pocilloporidae',
#  'cluster_31644': 'pocilloporidae',
#  'cluster_31646': 'pocilloporidae',
#  'cluster_31647': 'pocilloporidae',
#  'cluster_31648': 'pocilloporidae',
#  'cluster_31649': 'pocilloporidae',
#  'cluster_31650': 'pocilloporidae',
#  'cluster_31651': 'pocilloporidae',
#  'cluster_31652': 'pocilloporidae',
#  'cluster_31653': 'pocilloporidae',
#  'cluster_31654': 'pocilloporidae',
#  'cluster_31655': 'pocilloporidae',
#  'cluster_31656': 'pocilloporidae',
#  'cluster_31657': 'pocilloporidae',
#  'cluster_31658': 'pocilloporidae',
#  'cluster_31659': 'pocilloporidae',
#  'cluster_31660': 'pocilloporidae',
#  'cluster_31661': 'pocilloporidae',
#  'cluster_31662': 'pocilloporidae',
#  'cluster_31663': 'pocilloporidae',
#  'cluster_31664': 'pocilloporidae',
#  'cluster_31665': 'pocilloporidae',
#  'cluster_31666': 'pocilloporidae',
#  'cluster_31667': 'pocilloporidae',
#  'cluster_31668': 'pocilloporidae',
#  'cluster_31669': 'pocilloporidae',
#  'cluster_31670': 'pocilloporidae',
#  'cluster_31671': 'pocilloporidae',
#  'cluster_31672': 'pocilloporidae',
#  'cluster_31673': 'pocilloporidae',
#  'cluster_31674': 'pocilloporidae',
#  'cluster_31675': 'pocilloporidae',
#  'cluster_31676': 'pocilloporidae',
#  'cluster_31677': 'pocilloporidae',
#  'cluster_31678': 'pocilloporidae',
#  'cluster_31679': 'pocilloporidae',
#  'cluster_31680': 'pocilloporidae',
#  'cluster_31681': 'pocilloporidae',
#  'cluster_31682': 'pocilloporidae',
#  'cluster_31683': 'pocilloporidae',
#  'cluster_31684': 'pocilloporidae',
#  'cluster_31685': 'pocilloporidae',
#  'cluster_31686': 'pocilloporidae',
#  'cluster_31687': 'pocilloporidae',
#  'cluster_31688': 'pocilloporidae',
#  'cluster_31689': 'pocilloporidae',
#  'cluster_31690': 'pocilloporidae',
#  ...}

# %%
excluded_cluster_nodes_df = pd.DataFrame(excluded_cluster_nodes.items(), columns=['cluster_id', 'node'])
excluded_cluster_nodes_df
# Out:
#           cluster_id            node
# 0      cluster_30687  pocilloporidae
# 1      cluster_30688  pocilloporidae
# 2      cluster_30689  pocilloporidae
# 3      cluster_30690  pocilloporidae
# 4      cluster_30691  pocilloporidae
# ...              ...             ...
# 51535   cluster_5060    leptothecata
# 51536   cluster_5061    leptothecata
# 51537   cluster_5062    leptothecata
# 51538   cluster_5063    leptothecata
# 51539   cluster_5064    leptothecata
#
# [51540 rows x 2 columns]

# %%
excluded_cluster_nodes_df.to_csv('excluded_cluster_nodes.tsv', sep="\t", index=False)

# %% [markdown]
# ### Goal
#
# - For each gene in the genome, count the number of nearby CNEs within distance window (adjustable distance).
#
# ### Input
#
# - CNE coordinates
# - GFF genome annotations converted to gffutils database
#
# ### Output
#
# - all_sp_nearby_cnes.tsv: Data frame with basic stats for each species and distance threshold.
# - all_sp_nearby_cnes.pickle Dictionary of nearby CNEs to be processed with overrep_domains_nearby_cnes.ipynb

# %%
import pandas as pd
import glob
import json
import sys
import gffutils
from statistics import mean 
from os import listdir
from os.path import isfile, join
from collections import namedtuple
import pickle

# %% [markdown]
# #### Input data

# %%
coord_dir = "../../retrieve_original_coords/filtered_coords/"
gff_dir = "../../gff_dbs/"

# %% [markdown]
# #### Species list

# %%
species_list = ['apis',
                'aaeg',
                'aamp',
                'amel',
                'alic',
                'anas',
                'cscu',
                'cdip',
                'csec',
                'cfel',
                'dmel',
                'eaff',
                'gocc',
                'hazt',
                'lpol',
                'ahyp',
                'obir',
                'phum',
                'pvan',
                'ptri',
                'smim',
                'smar',
                'tpal',
                'tcas']

# %% [markdown]
# #### Distance threshold list

# %%
dist_threshold_list = [10000, 25000, 50000, 75000, 100000, 200000, 300000, 400000, 500000]

# %% [markdown]
# #### Function that calculates distance between two sequences

# %%
def seq_dist(start_1,end_1,start_2,end_2):
    return(abs(min(end_1,end_2) - max(start_1,start_2)))

# %% [markdown]
# ###  Function to retrieve coordinates of each gene

# %%
def parse_cds(species):
    gff_file = gff_dir + species + "_gff.db"
    gene_db = gffutils.FeatureDB(gff_file,keep_order=True)
    cds_coords = {}
    gene_scaff_dict = {}
    for gene in gene_db.features_of_type(featuretype="gene"):
        if 'gene_biotype' not in gene.attributes or 'gene_biotype' in gene.attributes and \
            gene.attributes['gene_biotype'][0] == 'protein_coding' :
            scaff = gene.chrom
            gene_id = str(gene.id)
            gene_scaff_dict[gene_id] = scaff
            for CDS in gene_db.children(gene.id,featuretype='CDS'): 
                if species in ['spha', 'echl']:
                    CDS_id = CDS.id.split("-")[-1].split("_")[0]
                elif species in ['hruf']:
                    CDS_id = CDS.id.split(":")[0]
                elif species in ['agra']:
                    CDS_id = CDS.id.split("model.")[-1].split("_")[0]
                else:
                    CDS_id = "_".join(CDS.id.split("-")[-1].split("_")[:2])
                CDS_start = CDS.start
                CDS_end = CDS.end
                if gene_id not in cds_coords:
                    cds_coords[gene_id] = [CDS_start, CDS_end]
                else:
                    cds_coords[gene_id] = [min(CDS_start,cds_coords[gene_id][0]) , max(CDS_end,cds_coords[gene_id][1]) ]
    return(cds_coords, gene_scaff_dict)

# %%
cds_coords, gene_scaff_dict = parse_cds('lpol')

# %%
cds_coords
# Out:
# {'gene-LOC106456832': [2798, 21366],
#  'gene-LOC106466742': [147538, 148950],
#  'gene-LOC106477029': [351899, 360775],
#  'gene-LOC106456833': [437378, 608322],
#  'gene-LOC111085464': [608733, 619667],
#  'gene-LOC106457832': [792808, 925197],
#  'gene-LOC106457563': [956304, 998504],
#  'gene-LOC106457663': [1046831, 1132952],
#  'gene-LOC106457765': [1151353, 1177206],
#  'gene-LOC106458816': [1195078, 1197294],
#  'gene-LOC106459800': [1303279, 1306712],
#  'gene-LOC106460795': [1486322, 1493673],
#  'gene-LOC106478102': [1501969, 1604399],
#  'gene-LOC111087465': [1623300, 1705067],
#  'gene-LOC106461769': [1842501, 1896076],
#  'gene-LOC106462746': [1985589, 2003262],
#  'gene-LOC106478203': [2163205, 2201845],
#  'gene-LOC111089463': [2219189, 2246770],
#  'gene-LOC106458041': [2296038, 2359342],
#  'gene-LOC106463729': [2428699, 2461553],
#  'gene-LOC106458387': [2472424, 2602122],
#  'gene-LOC106464713': [2613381, 2667802],
#  'gene-LOC106478309': [2721156, 2740348],
#  'gene-LOC106478541': [2751655, 2790344],
#  'gene-LOC106465725': [2830345, 2831982],
#  'gene-LOC106466743': [3099065, 3159153],
#  'gene-LOC106467741': [3171061, 3337672],
#  'gene-LOC106478641': [3338250, 3351997],
#  'gene-LOC106458621': [3413953, 3416102],
#  'gene-LOC106478743': [3432614, 3444834],
#  'gene-LOC106468760': [3445561, 3498246],
#  'gene-LOC106469774': [3608010, 3624244],
#  'gene-LOC106470777': [3656879, 3675705],
#  'gene-LOC106471801': [3734570, 3796901],
#  'gene-LOC106472817': [3838536, 3844521],
#  'gene-LOC106473861': [3857103, 3887532],
#  'gene-LOC106478843': [3898448, 3927736],
#  'gene-LOC106456866': [3937761, 3938815],
#  'gene-LOC106458717': [3956221, 3971024],
#  'gene-LOC106457032': [3985162, 4014762],
#  'gene-LOC106474893': [4156506, 4435623],
#  'gene-LOC106458879': [4452774, 4516250],
#  'gene-LOC106457270': [4846954, 4888506],
#  'gene-LOC106477030': [4888971, 4890761],
#  'gene-LOC106457365': [5052965, 5081120],
#  'gene-LOC106477983': [5097629, 5126074],
#  'gene-LOC106457465': [5143600, 5153433],
#  'gene-LOC111085736': [5157376, 5187618],
#  'gene-LOC106459044': [35342, 90852],
#  'gene-LOC106462096': [151167, 157860],
#  'gene-LOC106464376': [165374, 184645],
#  'gene-LOC106464206': [185349, 209376],
#  'gene-LOC106464474': [231608, 269053],
#  'gene-LOC106459239': [303422, 361231],
#  'gene-LOC106459331': [509523, 571954],
#  'gene-LOC106464783': [589675, 608397],
#  'gene-LOC106462193': [626813, 643290],
#  'gene-LOC106459436': [647471, 916879],
#  'gene-LOC106459536': [963782, 1092023],
#  'gene-LOC111087181': [1136177, 1158357],
#  'gene-LOC106462483': [1195834, 1196496],
#  'gene-LOC106459639': [1212291, 1212740],
#  'gene-LOC106459732': [1306687, 1347216],
#  'gene-LOC111085809': [1490535, 1497003],
#  'gene-LOC106462747': [1559954, 1569255],
#  'gene-LOC106459935': [1581879, 1627947],
#  'gene-LOC106462977': [1636406, 1647058],
#  'gene-LOC106460031': [1654657, 1768298],
#  'gene-LOC106464952': [1848370, 2020643],
#  'gene-LOC106465252': [2032493, 2179787],
#  'gene-LOC106460136': [2192918, 2273970],
#  'gene-LOC106463085': [2298637, 2303209],
#  'gene-LOC106460237': [2349773, 2413572],
#  'gene-LOC106460337': [2445495, 2494354],
#  'gene-LOC106460441': [2507418, 2516832],
#  'gene-LOC106460536': [2611064, 2622905],
#  'gene-LOC106465521': [2658508, 2734867],
#  'gene-LOC106465622': [2767992, 2819493],
#  'gene-LOC106460637': [2853845, 2981403],
#  'gene-LOC106460726': [3020660, 3158786],
#  'gene-LOC106460829': [3163699, 3317871],
#  'gene-LOC106460925': [3365469, 3445459],
#  'gene-LOC106461018': [3459906, 3493001],
#  'gene-LOC106463175': [3507081, 3517196],
#  'gene-LOC106461115': [3531239, 3537169],
#  'gene-LOC106461215': [3553769, 3638069],
#  'gene-LOC106463269': [3659510, 3683688],
#  'gene-LOC106461308': [3716280, 3722412],
#  'gene-LOC106461411': [3739757, 3747072],
#  'gene-LOC106463371': [3758497, 3769112],
#  'gene-LOC106463535': [3779243, 3797530],
#  'gene-LOC106463635': [3813026, 3816930],
#  'gene-LOC106461511': [3819776, 3860548],
#  'gene-LOC106461606': [3873321, 3885232],
#  'gene-LOC106463730': [3894028, 3928372],
#  'gene-LOC106461705': [3943043, 4010118],
#  'gene-LOC106461803': [4024845, 4032330],
#  'gene-LOC106461899': [4064276, 4111550],
#  'gene-LOC106462001': [4122062, 4159819],
#  'gene-LOC106463896': [4221129, 4232647],
#  'gene-LOC106463986': [4260291, 4293693],
#  'gene-LOC106464087': [4304828, 4315719],
#  'gene-LOC111087314': [112320, 249646],
#  'gene-LOC106466034': [528677, 649682],
#  'gene-LOC106466144': [708554, 730833],
#  'gene-LOC106467439': [978999, 1075569],
#  'gene-LOC106467537': [1266571, 1315717],
#  'gene-LOC106467705': [1374557, 1389651],
#  'gene-LOC106466242': [1421772, 1451426],
#  'gene-LOC106466334': [1534978, 1536225],
#  'gene-LOC106466433': [1599293, 1639507],
#  'gene-LOC106466535': [1726522, 2089349],
#  'gene-LOC106466639': [2233795, 2259029],
#  'gene-LOC106466744': [2504194, 2600730],
#  'gene-LOC106467913': [2751525, 2792207],
#  'gene-LOC106467014': [2803784, 2823175],
#  'gene-LOC106466847': [2868303, 2970943],
#  'gene-LOC106468014': [3011301, 3075089],
#  'gene-LOC106467182': [3087534, 3089613],
#  'gene-LOC106467339': [3114209, 3185204],
#  'gene-LOC106468109': [69021, 116307],
#  'gene-LOC106468317': [128450, 235580],
#  'gene-LOC106468416': [236350, 442229],
#  'gene-LOC106468298': [247655, 254458],
#  'gene-LOC106468521': [442265, 498785],
#  'gene-LOC111088675': [547150, 565324],
#  'gene-LOC111088563': [590433, 624414],
#  'gene-LOC106468628': [638045, 680053],
#  'gene-LOC106468724': [713039, 732998],
#  'gene-LOC106468826': [788261, 869638],
#  'gene-LOC106468929': [903330, 1075047],
#  'gene-LOC106469035': [1094400, 1273183],
#  'gene-LOC106469136': [1290693, 1304657],
#  'gene-LOC106470180': [1354089, 1422019],
#  'gene-LOC106469435': [1934157, 1967496],
#  'gene-LOC106469538': [2043094, 2058901],
#  'gene-LOC111088717': [2067368, 2078920],
#  'gene-LOC106469641': [2221132, 2243319],
#  'gene-LOC111088768': [2279379, 2281839],
#  'gene-LOC111088787': [2294889, 2304339],
#  'gene-LOC106469739': [2356486, 2483861],
#  'gene-LOC111088393': [2495980, 2595563],
#  'gene-LOC106469845': [2633900, 2732257],
#  'gene-LOC106469941': [2744888, 2757967],
#  'gene-LOC106471594': [36298, 67229],
#  'gene-LOC106470276': [122093, 124096],
#  'gene-LOC106471696': [140246, 177531],
#  'gene-LOC106470377': [197852, 220254],
#  'gene-LOC106470475': [682170, 735124],
#  'gene-LOC106470573': [738420, 797926],
#  'gene-LOC106470675': [1160932, 1161582],
#  'gene-LOC111089007': [1292192, 1293454],
#  'gene-LOC106470778': [1324211, 1401023],
#  'gene-LOC106471802': [1420239, 1439539],
#  'gene-LOC106471907': [1442479, 1517700],
#  'gene-LOC111089435': [1529359, 1541411],
#  'gene-LOC106472076': [1568743, 1583199],
#  'gene-LOC106472181': [1602335, 1614703],
#  'gene-LOC106472351': [1625820, 1632094],
#  'gene-LOC111089202': [1649496, 1652750],
#  'gene-LOC106470877': [1710972, 1712381],
#  'gene-LOC106470974': [1730017, 1740418],
#  'gene-LOC106471078': [1764220, 1775958],
#  'gene-LOC106471184': [1881043, 2002152],
#  'gene-LOC106472548': [2148592, 2183904],
#  'gene-LOC106472449': [2201021, 2238538],
#  'gene-LOC106471286': [2260338, 2269848],
#  'gene-LOC106471393': [2383890, 2515904],
#  'gene-LOC106471496': [2516035, 2576822],
#  'gene-LOC106473514': [59020, 61639],
#  'gene-LOC111083486': [177301, 180402],
#  'gene-LOC106473798': [202884, 264386],
#  'gene-LOC111083386': [313360, 314933],
#  'gene-LOC106472684': [322515, 323842],
#  'gene-LOC106472785': [364664, 365203],
#  'gene-LOC111083546': [491637, 492592],
#  'gene-LOC106473896': [633569, 680564],
#  'gene-LOC106474278': [692015, 715498],
#  'gene-LOC106472885': [774585, 853063],
#  'gene-LOC106474067': [902646, 954167],
#  'gene-LOC111083578': [1024284, 1068900],
#  'gene-LOC106474380': [1111197, 1234703],
#  'gene-LOC106472993': [1443571, 1533625],
#  'gene-LOC106474170': [1721145, 1783651],
#  'gene-LOC106473199': [1883840, 2028244],
#  'gene-LOC106473410': [2296068, 2388773],
#  'gene-LOC106474653': [3263, 101887],
#  'gene-LOC106475608': [161860, 163679],
#  'gene-LOC106474856': [175641, 245629],
#  'gene-LOC106474963': [257986, 310865],
#  'gene-LOC106476137': [613475, 813303],
#  'gene-LOC106475073': [1437754, 1493187],
#  'gene-LOC106475173': [1547682, 1551455],
#  'gene-LOC106476241': [1571708, 1587293],
#  'gene-LOC106475714': [1599748, 1600398],
#  'gene-LOC106475285': [1761203, 1903903],
#  'gene-LOC106475393': [1951795, 1985586],
#  'gene-LOC106476350': [2014314, 2072992],
#  'gene-LOC106475503': [2096119, 2139962],
#  'gene-LOC106476030': [2205944, 2206816],
#  'gene-LOC106477316': [28477, 68938],
#  'gene-LOC106476458': [163160, 250305],
#  'gene-LOC106476562': [495828, 629302],
#  'gene-LOC106476666': [681359, 681730],
#  'gene-LOC106476773': [912003, 914641],
#  'gene-LOC106476885': [991254, 1206970],
#  'gene-LOC106476991': [1261728, 1335295],
#  'gene-LOC106477104': [1500302, 1558175],
#  'gene-LOC111084911': [1744214, 1859436],
#  'gene-LOC106477211': [2073274, 2086559],
#  'gene-LOC106478057': [103242, 150874],
#  'gene-LOC106477493': [199134, 343119],
#  'gene-LOC106477600': [591028, 650108],
#  'gene-LOC106478122': [664357, 705361],
#  'gene-LOC106478067': [715084, 773505],
#  'gene-LOC106478078': [810196, 866171],
#  'gene-LOC106477701': [949466, 950455],
#  'gene-LOC106478088': [965676, 966635],
#  'gene-LOC106477788': [976181, 989232],
#  'gene-LOC106477867': [1097102, 1099220],
#  'gene-LOC106477941': [1142586, 1148838],
#  'gene-LOC106478006': [1200536, 1209377],
#  'gene-LOC111084965': [1239802, 1240499],
#  'gene-LOC106478095': [1249955, 1387398],
#  'gene-LOC111084931': [1288121, 1317078],
#  'gene-LOC106478111': [1407641, 1434561],
#  'gene-LOC106478028': [1463941, 1507788],
#  'gene-LOC106478037': [1986367, 1988430],
#  'gene-LOC106478138': [12502, 45587],
#  'gene-LOC106478147': [179443, 208062],
#  'gene-LOC106478156': [225358, 326717],
#  'gene-LOC106478167': [406544, 470203],
#  'gene-LOC106478177': [492778, 625438],
#  'gene-LOC106478188': [656753, 734737],
#  'gene-LOC106478207': [1040179, 1135597],
#  'gene-LOC106478228': [1254722, 1262453],
#  'gene-LOC106478217': [1692327, 1842703],
#  'gene-LOC106478252': [1868841, 1874964],
#  'gene-LOC106478261': [1891678, 1976126],
#  'gene-LOC106478271': [3277, 27093],
#  'gene-LOC111085003': [33738, 64676],
#  'gene-LOC106478283': [90402, 149610],
#  'gene-LOC106478293': [182938, 199167],
#  'gene-LOC111085007': [248809, 294763],
#  'gene-LOC106478304': [346102, 385522],
#  'gene-LOC106478391': [398583, 419433],
#  'gene-LOC106478313': [440871, 556000],
#  'gene-LOC111085061': [595803, 647635],
#  'gene-LOC106478331': [649559, 688249],
#  'gene-LOC111085023': [690205, 696634],
#  'gene-LOC106478400': [752189, 779858],
#  'gene-LOC106478414': [813559, 840792],
#  'gene-LOC106478426': [1052458, 1053982],
#  'gene-LOC106478342': [1189216, 1189965],
#  'gene-LOC106478352': [1311317, 1312006],
#  'gene-LOC106478361': [1364769, 1491440],
#  'gene-LOC106478371': [1540316, 1589135],
#  'gene-LOC106478380': [1602026, 1669112],
#  'gene-LOC111085040': [1706724, 1711056],
#  'gene-LOC106478442': [1733885, 1767615],
#  'gene-LOC106478458': [1953148, 1964327],
#  'gene-LOC111085051': [1974578, 1984149],
#  'gene-LOC111085054': [2003404, 2013355],
#  'gene-LOC106478591': [20113, 44241],
#  'gene-LOC106478469': [59824, 73007],
#  'gene-LOC106478480': [163221, 183271],
#  'gene-LOC106478491': [189219, 324372],
#  'gene-LOC106478498': [349643, 450648],
#  'gene-LOC106478601': [491488, 514109],
#  'gene-LOC106478618': [519392, 548719],
#  'gene-LOC106478722': [605255, 727892],
#  'gene-LOC106478509': [752814, 763007],
#  'gene-LOC106478520': [779824, 840477],
#  'gene-LOC106478531': [873547, 874728],
#  'gene-LOC106478635': [880455, 899082],
#  'gene-LOC106478644': [905945, 920130],
#  'gene-LOC106478542': [992968, 1021157],
#  'gene-LOC106478552': [1045003, 1070231],
#  'gene-LOC106478563': [1149780, 1158860],
#  'gene-LOC111085105': [1594490, 1596325],
#  'gene-LOC111085134': [1599317, 1626134],
#  'gene-LOC106478655': [1630912, 1659379],
#  'gene-LOC106478666': [1685241, 1722840],
#  'gene-LOC106478570': [1807026, 1846551],
#  'gene-LOC106478580': [1896266, 1955332],
#  'gene-LOC106478688': [1965716, 1990070],
#  'gene-LOC111085215': [196451, 207488],
#  'gene-LOC111085221': [256337, 279136],
#  'gene-LOC106478753': [314406, 332052],
#  'gene-LOC106478851': [339855, 373420],
#  'gene-LOC106478763': [388132, 445910],
#  'gene-LOC106478860': [467753, 500963],
#  'gene-LOC106478902': [634605, 713345],
#  'gene-LOC111085220': [728031, 735367],
#  'gene-LOC106478783': [811038, 846268],
#  'gene-LOC106456838': [861328, 896406],
#  'gene-LOC106478792': [1090362, 1148985],
#  'gene-LOC106456859': [1181832, 1200845],
#  'gene-LOC106478802': [1324724, 1417000],
#  'gene-LOC106456871': [1540038, 1599209],
#  'gene-LOC106456881': [1636465, 1648010],
#  'gene-LOC106478871': [1693430, 1713967],
#  'gene-LOC106478878': [1727188, 1753257],
#  'gene-LOC106478812': [1759803, 1778234],
#  'gene-LOC106478888': [1778825, 1787467],
#  'gene-LOC111085209': [1806340, 1843215],
#  'gene-LOC106478823': [1872568, 1947605],
#  'gene-LOC106456907': [256155, 422017],
#  'gene-LOC106456917': [465759, 726848],
#  'gene-LOC106456928': [929797, 1029744],
#  'gene-LOC111085228': [1243309, 1255087],
#  'gene-LOC111085238': [1280614, 1285691],
#  'gene-LOC106456987': [1295868, 1336218],
#  'gene-LOC106456937': [1365089, 1382581],
#  'gene-LOC106456949': [1388091, 1432861],
#  'gene-LOC106456959': [1580534, 1581577],
#  'gene-LOC106456978': [1716527, 1731549],
#  'gene-LOC106456969': [1737814, 1802876],
#  'gene-LOC106456997': [76756, 159543],
#  'gene-LOC106457173': [209527, 279286],
#  'gene-LOC106457183': [279760, 290544],
#  'gene-LOC106457195': [592664, 961029],
#  'gene-LOC106457016': [1009177, 1025656],
#  'gene-LOC106457101': [1127435, 1137895],
#  'gene-LOC106457111': [1152011, 1154991],
#  'gene-LOC106457039': [1159533, 1186104],
#  'gene-LOC106457048': [1215609, 1242747],
#  'gene-LOC106457126': [1261024, 1296383],
#  'gene-LOC106457059': [1373686, 1428907],
#  'gene-LOC106457069': [1448289, 1493153],
#  'gene-LOC106457137': [1509760, 1540553],
#  'gene-LOC111085299': [1673897, 1751942],
#  'gene-LOC106457147': [1772227, 1838154],
#  'gene-LOC106457158': [1890419, 1896054],
#  'gene-LOC106457081': [1930224, 1932288],
#  'gene-LOC106457090': [1954559, 1967312],
#  'gene-LOC106457221': [95947, 142821],
#  'gene-LOC106457230': [383955, 448068],
#  'gene-LOC106457240': [781945, 803302],
#  'gene-LOC106457250': [1179044, 1194748],
#  'gene-LOC106457316': [1424986, 1462409],
#  'gene-LOC106457262': [1492863, 1614846],
#  'gene-LOC106457274': [1648918, 1663956],
#  'gene-LOC106457286': [1771425, 1892879],
#  'gene-LOC106457323': [105056, 112702],
#  'gene-LOC106457411': [128682, 132562],
#  'gene-LOC106457333': [153890, 204290],
#  'gene-LOC106457343': [248768, 349505],
#  'gene-LOC106457352': [365539, 367200],
#  'gene-LOC106457359': [467516, 499756],
#  'gene-LOC106457370': [701857, 726010],
#  'gene-LOC106457444': [786946, 794026],
#  'gene-LOC106457454': [798002, 903221],
#  'gene-LOC106457421': [922371, 923213],
#  'gene-LOC106457473': [1038884, 1040623],
#  'gene-LOC106457436': [1068929, 1095356],
#  'gene-LOC111085345': [1365014, 1385715],
#  'gene-LOC106457379': [1327309, 1328439],
#  'gene-LOC106457390': [1724207, 1732084],
#  'gene-LOC106457402': [1762180, 1768313],
#  'gene-LOC106457482': [1777601, 1891259],
#  'gene-LOC106457497': [40189, 112796],
#  'gene-LOC106457508': [124780, 125286],
#  'gene-LOC106457519': [146122, 166139],
#  'gene-LOC111085377': [200858, 234413],
#  'gene-LOC111085379': [239994, 272379],
#  'gene-LOC111085390': [356764, 471170],
#  'gene-LOC106457527': [558595, 559746],
#  'gene-LOC106457575': [629976, 648995],
#  'gene-LOC106457536': [709282, 745646],
#  'gene-LOC106457547': [747855, 800748],
#  'gene-LOC106457585': [1018274, 1129437],
#  'gene-LOC106457557': [1213031, 1351354],
#  'gene-LOC111085368': [1436118, 1464111],
#  'gene-LOC106457567': [1517415, 1546057],
#  'gene-LOC111085396': [1552744, 1608461],
#  'gene-LOC106457601': [1843276, 1863599],
#  'gene-LOC111085447': [65760, 73969],
#  'gene-LOC106457612': [94644, 266955],
#  'gene-LOC106457634': [351504, 404264],
#  'gene-LOC106457691': [423119, 458261],
#  'gene-LOC106457700': [477061, 600711],
#  'gene-LOC106457718': [647960, 762886],
#  'gene-LOC106457644': [813215, 899190],
#  'gene-LOC106457654': [910786, 961673],
#  'gene-LOC106457789': [963835, 977201],
#  'gene-LOC106457664': [995169, 1028563],
#  'gene-LOC106457726': [1042143, 1066528],
#  'gene-LOC106457736': [1141127, 1194967],
#  'gene-LOC111085402': [1325868, 1349026],
#  'gene-LOC106457673': [1362469, 1372953],
#  'gene-LOC106457683': [1389023, 1407839],
#  'gene-LOC106457799': [1474650, 1508161],
#  'gene-LOC106457747': [1528592, 1545052],
#  'gene-LOC106457757': [1563669, 1643752],
#  'gene-LOC106457769': [1678399, 1687658],
#  'gene-LOC106457780': [1692768, 1710857],
#  'gene-LOC111085406': [1720447, 1735585],
#  'gene-LOC111085408': [1837427, 1899171],
#  'gene-LOC111085461': [170669, 191910],
#  'gene-LOC106457807': [298572, 308766],
#  'gene-LOC106457874': [337561, 377409],
#  'gene-LOC106457817': [384504, 448447],
#  'gene-LOC106457828': [648407, 767799],
#  'gene-LOC106457838': [1016454, 1170525],
#  'gene-LOC106457849': [1591211, 1620303],
#  'gene-LOC106457899': [5130, 46004],
#  'gene-LOC106458116': [53148, 66651],
#  'gene-LOC106457910': [104221, 124640],
#  'gene-LOC106457919': [187955, 230237],
#  'gene-LOC106458142': [247331, 332724],
#  'gene-LOC106457930': [342091, 393090],
#  'gene-LOC106458123': [410465, 436117],
#  'gene-LOC106457953': [464004, 465650],
#  'gene-LOC106457964': [550897, 586651],
#  'gene-LOC106457973': [557365, 559204],
#  'gene-LOC106458152': [584796, 631097],
#  'gene-LOC106457983': [677299, 744468],
#  'gene-LOC106457993': [751418, 791524],
#  'gene-LOC111085517': [879775, 901566],
#  'gene-LOC106458004': [1027104, 1027727],
#  'gene-LOC106458014': [1219612, 1220319],
#  'gene-LOC106458025': [1342549, 1343379],
#  'gene-LOC106458034': [1403563, 1404027],
#  'gene-LOC106458162': [1411432, 1424805],
#  'gene-LOC106458044': [1442423, 1521852],
#  'gene-LOC106458130': [1536343, 1557384],
#  'gene-LOC106458064': [1558394, 1619336],
#  'gene-LOC106458074': [1643957, 1700920],
#  'gene-LOC106458086': [1715255, 1785479],
#  'gene-LOC106458096': [1802921, 1823620],
#  'gene-LOC106458105': [1837091, 1863270],
#  'gene-LOC106458180': [60919, 180996],
#  'gene-LOC106458247': [347659, 369949],
#  'gene-LOC106458198': [377370, 447278],
#  'gene-LOC106458261': [466771, 485455],
#  'gene-LOC111085553': [573293, 623880],
#  'gene-LOC106458271': [647588, 648520],
#  'gene-LOC106458207': [740208, 741179],
#  'gene-LOC106458218': [793579, 794409],
#  'gene-LOC106458229': [892905, 912729],
#  'gene-LOC106458298': [1206877, 1331184],
#  'gene-LOC106458279': [1376658, 1393537],
#  'gene-LOC106458239': [1446053, 1723214],
#  'gene-LOC106458288': [1753119, 1799428],
#  'gene-LOC106458401': [21994, 22950],
#  'gene-LOC106458330': [66580, 102707],
#  'gene-LOC106458405': [167671, 363900],
#  'gene-LOC106458415': [394948, 426847],
#  'gene-LOC106458341': [500636, 581295],
#  'gene-LOC106458351': [600011, 710941],
#  'gene-LOC106458362': [959153, 966784],
#  'gene-LOC106458371': [1200826, 1306172],
#  'gene-LOC106458381': [1281247, 1437112],
#  'gene-LOC106458432': [1606825, 1682124],
#  'gene-LOC111085598': [1729588, 1743147],
#  'gene-LOC106458391': [1758404, 1797892],
#  'gene-LOC106458452': [13068, 183710],
#  'gene-LOC106458460': [196213, 211189],
#  'gene-LOC106458610': [213073, 237087],
#  'gene-LOC111085605': [242304, 298899],
#  'gene-LOC111085609': [313665, 384136],
#  'gene-LOC106458471': [429314, 485550],
#  'gene-LOC106458481': [540718, 584260],
#  'gene-LOC106458554': [596366, 623399],
#  'gene-LOC106458622': [686965, 710657],
#  'gene-LOC106458490': [737742, 869624],
#  'gene-LOC106458583': [758283, 759020],
#  'gene-LOC111085601': [878306, 879206],
#  'gene-LOC106458499': [950042, 958628],
#  'gene-LOC106458510': [1011063, 1018372],
#  'gene-LOC106458520': [1039568, 1085175],
#  'gene-LOC106458531': [1200864, 1334905],
#  'gene-LOC106458594': [1516736, 1541442],
#  'gene-LOC111085639': [1622984, 1623814],
#  'gene-LOC106458651': [1669652, 1725368],
#  'gene-LOC106458542': [1741023, 1768320],
#  'gene-LOC106458805': [8126, 28686],
#  'gene-LOC106458866': [25777, 57767],
#  'gene-LOC106458817': [63442, 78573],
#  'gene-LOC106458831': [82739, 104263],
#  'gene-LOC106458680': [111877, 158802],
#  'gene-LOC106458888': [206497, 276223],
#  'gene-LOC106458689': [393710, 488861],
#  'gene-LOC106458694': [590711, 627099],
#  'gene-LOC106458705': [643053, 649968],
#  'gene-LOC106458718': [712179, 735663],
#  'gene-LOC106458727': [805321, 830044],
#  'gene-LOC106458737': [843693, 895601],
#  'gene-LOC106458749': [963896, 978181],
#  'gene-LOC106458841': [980332, 1002610],
#  'gene-LOC106458757': [1025120, 1060547],
#  'gene-LOC106458851': [1152404, 1171533],
#  'gene-LOC106458775': [1200211, 1202049],
#  'gene-LOC106458785': [1606152, 1630442],
#  'gene-LOC106458796': [1751027, 1767727],
#  'gene-LOC106458910': [276240, 308208],
#  'gene-LOC106458921': [323230, 366463],
#  'gene-LOC111085688': [381517, 397610],
#  'gene-LOC111085691': [402171, 415347],
#  'gene-LOC106458931': [429252, 445699],
#  'gene-LOC106458939': [451164, 501330],
#  'gene-LOC106459062': [515229, 538716],
#  'gene-LOC106458960': [544878, 554469],
#  'gene-LOC106459117': [557673, 581568],
#  'gene-LOC106459081': [597567, 643717],
#  'gene-LOC106458971': [650098, 687062],
#  'gene-LOC106458982': [693174, 708287],
#  'gene-LOC106459090': [743011, 743559],
#  'gene-LOC106458993': [749233, 824098],
#  'gene-LOC106459004': [845918, 1105158],
#  'gene-LOC106459012': [1371359, 1393988],
#  'gene-LOC106459099': [1403748, 1421871],
#  'gene-LOC106459022': [1450819, 1478036],
#  'gene-LOC111085726': [1491190, 1508227],
#  'gene-LOC106459032': [1530345, 1531730],
#  'gene-LOC111085730': [1616773, 1617486],
#  'gene-LOC106459041': [1715078, 1769057],
#  'gene-LOC106459141': [300119, 371947],
#  'gene-LOC106459147': [533233, 780295],
#  'gene-LOC106459158': [808021, 811565],
#  'gene-LOC106459248': [833044, 951768],
#  'gene-LOC106459168': [975501, 978975],
#  'gene-LOC106459177': [991962, 1033807],
#  'gene-LOC106459185': [1050425, 1051872],
#  'gene-LOC106459196': [1051874, 1087220],
#  'gene-LOC106459293': [1092262, 1123362],
#  'gene-LOC106459205': [1144877, 1245356],
#  'gene-LOC106459259': [1355259, 1392661],
#  'gene-LOC111085770': [1520988, 1533051],
#  'gene-LOC106459269': [1542855, 1556103],
#  'gene-LOC106459213': [1611473, 1667949],
#  'gene-LOC106459272': [1678815, 1679941],
#  'gene-LOC106459282': [1699098, 1732467],
#  'gene-LOC106459224': [1736881, 1748860],
#  'gene-LOC106459235': [1764289, 1781041],
#  'gene-LOC111085771': [10268, 33187],
#  'gene-LOC106459304': [77352, 145132],
#  'gene-LOC106459322': [172549, 292060],
#  'gene-LOC111085783': [227108, 230997],
#  'gene-LOC106459326': [394196, 500843],
#  'gene-LOC106459401': [531912, 577379],
#  'gene-LOC106459417': [607588, 647969],
#  'gene-LOC106459440': [1147368, 1172277],
#  'gene-LOC106459348': [1285591, 1286193],
#  'gene-LOC106459359': [1380212, 1388868],
#  'gene-LOC106459428': [1401530, 1530317],
#  'gene-LOC106459369': [1629716, 1631353],
#  'gene-LOC106459380': [1695221, 1704557],
#  'gene-LOC106459391': [1725703, 1726788],
#  'gene-LOC111085836': [1258, 25456],
#  'gene-LOC106459456': [82307, 84451],
#  'gene-LOC106459578': [164336, 217423],
#  'gene-LOC111085837': [322540, 371977],
#  'gene-LOC106459467': [581068, 594703],
#  'gene-LOC106459476': [619019, 675769],
#  'gene-LOC106459588': [694634, 735791],
#  'gene-LOC111085817': [778382, 806882],
#  'gene-LOC106459487': [950268, 964347],
#  'gene-LOC106459596': [972545, 978712],
#  'gene-LOC106459525': [994681, 1033472],
#  'gene-LOC106459496': [1061420, 1062793],
#  'gene-LOC106459537': [1095498, 1138272],
#  'gene-LOC106459547': [1237224, 1249532],
#  'gene-LOC106459558': [1259923, 1274866],
#  'gene-LOC106459505': [1516299, 1519337],
#  'gene-LOC106459569': [1608009, 1617294],
#  'gene-LOC106459516': [1632236, 1741857],
#  'gene-LOC106459656': [16819, 41030],
#  'gene-LOC106459607': [111510, 112814],
#  'gene-LOC106459618': [319045, 389768],
#  'gene-LOC111085850': [412379, 450468],
#  'gene-LOC106459667': [460938, 462000],
#  'gene-LOC106459629': [537216, 537869],
#  'gene-LOC106459682': [548035, 554690],
#  'gene-LOC106459640': [750868, 867558],
#  'gene-LOC106459701': [1099227, 1169859],
#  'gene-LOC106459710': [1428156, 1462846],
#  'gene-LOC106459647': [1599466, 1664529],
#  'gene-LOC106459725': [1705601, 1728310],
#  'gene-LOC106459733': [18137, 56489],
#  'gene-LOC106459823': [62602, 129834],
#  'gene-LOC106459833': [148361, 193959],
#  'gene-LOC106459753': [202893, 221974],
#  'gene-LOC111085884': [351157, 359496],
#  'gene-LOC106459844': [529583, 551558],
#  'gene-LOC106459851': [562048, 600361],
#  'gene-LOC106459764': [618853, 643512],
#  'gene-LOC111085901': [643594, 670999],
#  'gene-LOC106459864': [751840, 752799],
#  'gene-LOC111085917': [760427, 765052],
#  'gene-LOC106459774': [765866, 790557],
#  'gene-LOC111085908': [819709, 828571],
#  'gene-LOC106459782': [989318, 1062320],
#  'gene-LOC106459793': [1197536, 1551502],
#  'gene-LOC106459803': [1620080, 1641399],
#  'gene-LOC106459877': [1661657, 1677645],
#  'gene-LOC106459812': [1699716, 1703103],
#  'gene-LOC106459981': [19213, 84397],
#  'gene-LOC106459996': [84881, 137544],
#  'gene-LOC106459888': [206001, 322972],
#  'gene-LOC111085957': [538665, 563442],
#  'gene-LOC106459961': [583343, 635360],
#  'gene-LOC106459899': [640378, 740140],
#  'gene-LOC111085938': [801174, 850920],
#  'gene-LOC106459911': [1033206, 1053334],
#  'gene-LOC106459922': [1070761, 1071372],
#  'gene-LOC106460006': [1073772, 1112656],
#  'gene-LOC106460017': [1316494, 1333405],
#  'gene-LOC106459950': [1379702, 1521861],
#  'gene-LOC106459970': [1535025, 1605666],
#  'gene-LOC106460156': [54411, 55676],
#  'gene-LOC106460032': [71209, 84917],
#  'gene-LOC106460227': [123683, 142263],
#  'gene-LOC106460043': [162484, 199918],
#  'gene-LOC111085967': [226267, 265803],
#  'gene-LOC106460052': [343731, 439522],
#  'gene-LOC106460062': [442607, 464244],
#  'gene-LOC106460167': [546699, 593361],
#  'gene-LOC106460073': [625629, 710910],
#  'gene-LOC106460176': [773542, 788983],
#  'gene-LOC106460187': [794680, 825360],
#  'gene-LOC106460199': [839105, 873208],
#  'gene-LOC106460095': [909192, 938415],
#  'gene-LOC106460209': [964330, 965253],
#  'gene-LOC106460104': [1038483, 1039403],
#  'gene-LOC106460115': [1158700, 1159548],
#  'gene-LOC106460125': [1226290, 1297949],
#  'gene-LOC106460238': [1324814, 1561571],
#  'gene-LOC106460146': [1584732, 1616586],
#  'gene-LOC106460220': [1630960, 1659278],
#  'gene-LOC106460446': [4577, 30795],
#  'gene-LOC106460254': [63920, 170428],
#  'gene-LOC106460263': [180815, 212324],
#  'gene-LOC106460457': [216526, 223272],
#  'gene-LOC111086058': [257078, 269275],
#  'gene-LOC111086069': [270422, 293530],
#  'gene-LOC106460273': [382570, 486551],
#  'gene-LOC106460345': [523771, 533317],
#  'gene-LOC106460363': [548021, 562589],
#  'gene-LOC106460283': [568753, 660612],
#  'gene-LOC106460293': [670586, 729438],
#  'gene-LOC106460467': [874755, 903667],
#  'gene-LOC106460301': [990384, 991430],
#  'gene-LOC106460312': [1176769, 1252164],
#  'gene-LOC106460493': [1308524, 1317190],
#  'gene-LOC106460398': [1330321, 1362010],
#  'gene-LOC106460406': [1366261, 1406294],
#  'gene-LOC106460323': [1424478, 1439498],
#  'gene-LOC106460423': [1489982, 1520836],
#  'gene-LOC106460333': [1558868, 1631563],
#  'gene-LOC106460434': [1650117, 1655517],
#  'gene-LOC106460623': [12208, 50558],
#  'gene-LOC106460513': [88814, 138659],
#  'gene-LOC106460522': [332668, 341601],
#  'gene-LOC106460532': [537200, 561389],
#  'gene-LOC106460543': [606157, 626374],
#  'gene-LOC106460554': [749697, 752377],
#  'gene-LOC111086107': [766197, 776987],
#  'gene-LOC106460564': [797976, 815250],
#  'gene-LOC106460575': [839212, 848700],
#  'gene-LOC106460642': [880030, 983019],
#  'gene-LOC106460585': [1001488, 1020905],
#  'gene-LOC106460596': [1119239, 1190280],
#  'gene-LOC106460655': [1207076, 1254859],
#  'gene-LOC106460605': [1330835, 1367369],
#  'gene-LOC106460663': [1378726, 1401082],
#  'gene-LOC106460615': [1422878, 1427406],
#  'gene-LOC111086099': [1458797, 1485494],
#  'gene-LOC111086155': [5766, 15628],
#  'gene-LOC106460679': [127843, 224064],
#  'gene-LOC106460749': [476559, 582175],
#  'gene-LOC106460688': [748433, 792830],
#  'gene-LOC106460696': [810331, 870762],
#  'gene-LOC106460706': [943103, 961519],
#  'gene-LOC106460716': [979271, 992934],
#  'gene-LOC106460760': [1110625, 1270480],
#  'gene-LOC111086134': [1292013, 1314545],
#  'gene-LOC111086145': [1325470, 1367428],
#  'gene-LOC111086147': [1375102, 1422787],
#  'gene-LOC106460770': [1429767, 1446243],
#  'gene-LOC106460802': [1462806, 1476981],
#  'gene-LOC111086149': [1493462, 1526742],
#  'gene-LOC106460791': [1534369, 1615589],
#  'gene-LOC106460813': [4077, 70678],
#  'gene-LOC106460956': [89011, 104502],
#  'gene-LOC111086209': [120206, 121944],
#  'gene-LOC106461043': [123626, 148099],
#  'gene-LOC106460821': [199050, 213117],
#  'gene-LOC106460833': [258438, 283510],
#  'gene-LOC106460845': [289625, 298277],
#  'gene-LOC106460973': [327543, 350383],
#  'gene-LOC106460853': [430428, 515978],
#  'gene-LOC106460862': [523117, 553803],
#  'gene-LOC106460982': [664965, 675117],
#  'gene-LOC106460870': [692665, 695730],
#  'gene-LOC106460879': [729733, 799645],
#  'gene-LOC106460887': [825115, 843816],
#  'gene-LOC106460897': [905631, 949415],
#  'gene-LOC111086214': [960790, 966642],
#  'gene-LOC106460992': [1000056, 1002528],
#  'gene-LOC111086229': [1016419, 1019430],
#  'gene-LOC111086182': [1038140, 1040487],
#  'gene-LOC106460908': [1060556, 1074128],
#  'gene-LOC106461002': [1079666, 1142398],
#  'gene-LOC106461011': [1152853, 1202097],
#  'gene-LOC106460918': [1213957, 1214820],
#  'gene-LOC106460929': [1227600, 1231363],
#  'gene-LOC111086219': [1253620, 1265041],
#  'gene-LOC106460939': [1265960, 1284131],
#  'gene-LOC106461019': [1309662, 1330497],
#  'gene-LOC106461028': [1346019, 1360975],
#  'gene-LOC106461058': [1371780, 1397624],
#  'gene-LOC106461096': [1449137, 1485047],
#  'gene-LOC106461104': [1588454, 1611401],
#  'gene-LOC106461116': [13184, 28429],
#  'gene-LOC106461224': [444221, 467698],
#  'gene-LOC106461128': [478117, 500140],
#  'gene-LOC106461145': [580104, 667563],
#  'gene-LOC106461155': [699686, 740502],
#  'gene-LOC106461165': [743244, 774955],
#  'gene-LOC106461175': [838431, 888654],
#  'gene-LOC106461185': [932788, 1023236],
#  'gene-LOC106461206': [1181674, 1215133],
#  'gene-LOC106461216': [1318979, 1424585],
#  'gene-LOC111086249': [2755, 18977],
#  'gene-LOC106461245': [38048, 43638],
#  'gene-LOC106461256': [59622, 88959],
#  'gene-LOC111086283': [96868, 141162],
#  'gene-LOC111086258': [149615, 162852],
#  'gene-LOC106461265': [172849, 188829],
#  'gene-LOC106461373': [416221, 525477],
#  'gene-LOC106461273': [553979, 702193],
#  'gene-LOC111086273': [723647, 731535],
#  'gene-LOC106461284': [744064, 852346],
#  'gene-LOC106461294': [859565, 887807],
#  'gene-LOC106461384': [900797, 955234],
#  'gene-LOC106461403': [1014374, 1064852],
#  'gene-LOC106461394': [980369, 987718],
#  'gene-LOC106461313': [1068105, 1184577],
#  'gene-LOC106461324': [1199438, 1218927],
#  'gene-LOC106461345': [1326029, 1354410],
#  'gene-LOC106461415': [1364031, 1403914],
#  'gene-LOC106461351': [1482501, 1482827],
#  'gene-LOC106461425': [523, 1659],
#  'gene-LOC106461531': [221905, 272987],
#  'gene-LOC106461454': [318534, 345131],
#  'gene-LOC106461547': [530082, 547393],
#  'gene-LOC106461474': [718174, 841918],
#  'gene-LOC106461485': [995418, 1114271],
#  'gene-LOC106461558': [1143766, 1154166],
#  'gene-LOC106461496': [1236869, 1355725],
#  'gene-LOC111086316': [1370101, 1384536],
#  'gene-LOC106461506': [1409186, 1426361],
#  'gene-LOC106461566': [1440044, 1497450],
#  'gene-LOC106461514': [1504124, 1504786],
#  'gene-LOC106461588': [1510159, 1524442],
#  'gene-LOC106461523': [1552852, 1564288],
#  'gene-LOC106461708': [8111, 74490],
#  'gene-LOC106461620': [132218, 275390],
#  'gene-LOC106461718': [297228, 317961],
#  'gene-LOC106461631': [346563, 347135],
#  'gene-LOC106461642': [469212, 469976],
#  'gene-LOC106461729': [611883, 613302],
#  'gene-LOC106461649': [866734, 874103],
#  'gene-LOC106461738': [873864, 877800],
#  'gene-LOC106461748': [891428, 893024],
#  'gene-LOC106461758': [913594, 914544],
#  'gene-LOC106461670': [965693, 1057691],
#  'gene-LOC106461679': [1086677, 1288844],
#  'gene-LOC106461786': [1313086, 1398958],
#  'gene-LOC106461810': [59691, 168093],
#  'gene-LOC106461820': [181772, 196008],
#  'gene-LOC106461887': [217877, 251535],
#  'gene-LOC106461830': [266031, 299945],
#  'gene-LOC106461895': [326413, 342606],
#  'gene-LOC106461840': [362964, 370787],
#  'gene-LOC106461848': [389023, 461078],
#  'gene-LOC106461858': [476996, 495981],
#  'gene-LOC106461906': [767632, 796464],
#  'gene-LOC106461965': [879568, 953271],
#  'gene-LOC106461952': [954989, 973267],
#  'gene-LOC106461866': [1179920, 1286746],
#  'gene-LOC111086406': [1317572, 1363966],
#  'gene-LOC106461876': [1460516, 1501351],
#  'gene-LOC106461923': [1514225, 1516827],
#  'gene-LOC106461933': [1523522, 1527685],
#  'gene-LOC106461942': [1538146, 1547757],
#  'gene-LOC106461973': [99724, 240854],
#  'gene-LOC106461983': [305985, 306395],
#  'gene-LOC106461994': [384105, 497683],
#  'gene-LOC106462005': [781616, 802058],
#  'gene-LOC106462015': [826772, 952737],
#  'gene-LOC106462023': [998556, 1139772],
#  'gene-LOC106462034': [1141415, 1154681],
#  'gene-LOC111086444': [1236475, 1259826],
#  'gene-LOC106462043': [1288744, 1325291],
#  'gene-LOC106462075': [1346029, 1377836],
#  'gene-LOC111086449': [1446730, 1449018],
#  'gene-LOC106462052': [1452419, 1459812],
#  'gene-LOC106462062': [1477420, 1498163],
#  'gene-LOC106462087': [77725, 122967],
#  'gene-LOC106462097': [140986, 496658],
#  'gene-LOC106462117': [654610, 687602],
#  'gene-LOC106462127': [945615, 1065821],
#  'gene-LOC106462136': [1114270, 1416059],
#  'gene-LOC106462204': [762, 12997],
#  'gene-LOC111086482': [41924, 44134],
#  'gene-LOC106462215': [121102, 173221],
#  'gene-LOC106462232': [188155, 212343],
#  'gene-LOC106462266': [223695, 290499],
#  'gene-LOC106462242': [300356, 338421],
#  'gene-LOC106462282': [362368, 405943],
#  'gene-LOC106462152': [812956, 872408],
#  'gene-LOC106462161': [875280, 921598],
#  'gene-LOC106462171': [1067658, 1068587],
#  'gene-LOC106462182': [1409065, 1409952],
#  'gene-LOC106462194': [1446503, 1448518],
#  'gene-LOC106462353': [2572, 9811],
#  'gene-LOC106462336': [12778, 83746],
#  'gene-LOC106462293': [102885, 434778],
#  'gene-LOC106462361': [596108, 665218],
#  'gene-LOC111086552': [770251, 848722],
#  'gene-LOC106462303': [987408, 1035321],
#  'gene-LOC106462312': [1420144, 1475167],
#  'gene-LOC106462323': [1484190, 1497280],
#  'gene-LOC106462478': [8617, 29983],
#  'gene-LOC106462392': [73847, 74725],
#  'gene-LOC106462402': [137076, 138077],
#  'gene-LOC106462410': [152381, 153322],
#  'gene-LOC106462490': [179065, 217624],
#  'gene-LOC106462517': [223392, 229665],
#  'gene-LOC106462527': [245004, 280321],
#  'gene-LOC106462537': [309088, 355340],
#  'gene-LOC106462547': [368624, 382637],
#  'gene-LOC106462420': [435885, 488038],
#  'gene-LOC106462557': [496921, 538325],
#  'gene-LOC106462573': [572277, 604536],
#  'gene-LOC106462431': [612938, 676850],
#  'gene-LOC106462582': [764700, 1218581],
#  'gene-LOC106462469': [1222596, 1282096],
#  'gene-LOC106462700': [187341, 303944],
#  'gene-LOC111086618': [322747, 424001],
#  'gene-LOC106462711': [429758, 435934],
#  'gene-LOC106462617': [442754, 504695],
#  'gene-LOC106462720': [507757, 536167],
#  'gene-LOC106462628': [617733, 618995],
#  'gene-LOC106462638': [678930, 695663],
#  'gene-LOC106462648': [776302, 828782],
#  'gene-LOC111086647': [848661, 857193],
#  'gene-LOC106462730': [877040, 919813],
#  'gene-LOC106462658': [999034, 1063512],
#  'gene-LOC111086627': [1033790, 1034458],
#  'gene-LOC106462740': [1068778, 1093209],
#  'gene-LOC106462668': [1109171, 1183231],
#  'gene-LOC106462756': [1192211, 1238369],
#  'gene-LOC106462689': [1315353, 1321705],
#  'gene-LOC106462765': [1329046, 1353855],
#  'gene-LOC106462778': [59367, 211557],
#  'gene-LOC106462836': [244343, 278038],
#  'gene-LOC106462787': [279788, 303835],
#  'gene-LOC106462798': [708073, 762665],
#  'gene-LOC111086671': [1115295, 1158004],
#  'gene-LOC106462827': [1172441, 1196758],
#  'gene-LOC106462808': [1267472, 1274350],
#  'gene-LOC106462819': [1302941, 1427187],
#  'gene-LOC111086668': [1486683, 1504665],
#  'gene-LOC106462855': [261465, 281802],
#  'gene-LOC106462864': [332497, 363872],
#  'gene-LOC106462927': [433370, 459160],
#  'gene-LOC106462944': [476902, 504699],
#  'gene-LOC106462875': [530573, 549081],
#  'gene-LOC111086694': [559625, 571700],
#  'gene-LOC106462886': [604263, 615339],
#  'gene-LOC111086698': [683269, 693988],
#  'gene-LOC106462897': [728930, 812684],
#  'gene-LOC106462906': [913819, 975626],
#  'gene-LOC106462960': [1131258, 1180979],
#  'gene-LOC106462916': [1189846, 1299427],
#  'gene-LOC106462978': [1438312, 1446071],
#  'gene-LOC106462989': [1239, 21701],
#  'gene-LOC106463001': [70365, 324892],
#  'gene-LOC106463097': [560450, 586588],
#  'gene-LOC106463011': [606068, 618447],
#  'gene-LOC106463113': [681994, 743175],
#  'gene-LOC106463020': [778628, 816613],
#  'gene-LOC106463052': [876926, 923478],
#  'gene-LOC106463031': [948466, 956125],
#  'gene-LOC106463128': [973290, 1040895],
#  'gene-LOC106463064': [1082172, 1106347],
#  'gene-LOC106463042': [1271042, 1369027],
#  'gene-LOC106463073': [1377885, 1415189],
#  'gene-LOC106463086': [1447054, 1464705],
#  'gene-LOC106463155': [27399, 119667],
#  'gene-LOC106463163': [201684, 226608],
#  'gene-LOC106463219': [263686, 283069],
#  'gene-LOC106463228': [312506, 333438],
#  'gene-LOC111086756': [547326, 612045],
#  'gene-LOC106463237': [827113, 845966],
#  'gene-LOC106463176': [854000, 914710],
#  'gene-LOC111086764': [1091850, 1122445],
#  'gene-LOC111086768': [958820, 989979],
#  'gene-LOC111086789': [990418, 990894],
#  'gene-LOC106463273': [1195475, 1200825],
#  'gene-LOC106463263': [1259985, 1276853],
#  'gene-LOC106463246': [1282965, 1300895],
#  'gene-LOC106463188': [1303519, 1360668],
#  'gene-LOC111086781': [1392789, 1430702],
#  'gene-LOC106463207': [1441419, 1466768],
#  'gene-LOC111086795': [7270, 63776],
#  'gene-LOC106463290': [36680, 38014],
#  'gene-LOC106463300': [65427, 65918],
#  'gene-LOC106463311': [202840, 205035],
#  'gene-LOC106463383': [313835, 317068],
#  'gene-LOC106463322': [528245, 593880],
#  'gene-LOC106463331': [620868, 699323],
#  'gene-LOC106463401': [908076, 927923],
#  'gene-LOC106463340': [1050673, 1128892],
#  'gene-LOC106463417': [1256417, 1296843],
#  'gene-LOC106463350': [1301006, 1361024],
#  'gene-LOC106463361': [1361569, 1386940],
#  'gene-LOC106463372': [1430063, 1441674],
#  'gene-LOC106463440': [195783, 254466],
#  'gene-LOC106463459': [298900, 300729],
#  'gene-LOC106463468': [320382, 394052],
#  'gene-LOC106463545': [559533, 602851],
#  'gene-LOC106463515': [644298, 651892],
#  'gene-LOC106463523': [673722, 681115],
#  'gene-LOC106463475': [718702, 733055],
#  'gene-LOC106463485': [758529, 772179],
#  'gene-LOC106463536': [835477, 840718],
#  'gene-LOC111086856': [887057, 888368],
#  'gene-LOC106463495': [1008167, 1015475],
#  'gene-LOC111086849': [1334653, 1386655],
#  'gene-LOC106463504': [1437497, 1437919],
#  'gene-LOC106463553': [7980, 145860],
#  'gene-LOC106463564': [341271, 443413],
#  'gene-LOC106463575': [494441, 508996],
#  'gene-LOC106463586': [734348, 794683],
#  'gene-LOC106463664': [877613, 912110],
#  'gene-LOC106463603': [968560, 990788],
#  'gene-LOC106463614': [1005042, 1007612],
#  'gene-LOC106463626': [1123333, 1140479],
#  'gene-LOC106463636': [1158083, 1158400],
#  'gene-LOC106463646': [1168607, 1230989],
#  'gene-LOC106463673': [1275522, 1300147],
#  'gene-LOC106463682': [1341466, 1399245],
#  'gene-LOC106463654': [1407111, 1407440],
#  'gene-LOC111086892': [1413567, 1415313],
#  'gene-LOC111086881': [1415502, 1419009],
#  'gene-LOC106463777': [2332, 9526],
#  'gene-LOC106463698': [30070, 100530],
#  'gene-LOC106463706': [115107, 171129],
#  'gene-LOC106463830': [200191, 235777],
#  'gene-LOC106463717': [247424, 272540],
#  'gene-LOC106463794': [363735, 396568],
#  'gene-LOC111086925': [987948, 992912],
#  'gene-LOC106463748': [1143506, 1156764],
#  'gene-LOC106463803': [1162532, 1182172],
#  'gene-LOC106463757': [1224818, 1312443],
#  'gene-LOC106463840': [1322117, 1356901],
#  'gene-LOC106463767': [1369051, 1388388],
#  'gene-LOC106463824': [1397432, 1427455],
#  'gene-LOC106463849': [740, 3012],
#  'gene-LOC106463930': [11109, 30522],
#  'gene-LOC106463859': [37662, 44511],
#  'gene-LOC106463870': [71541, 114881],
#  'gene-LOC111086932': [167649, 263266],
#  'gene-LOC106463960': [366983, 368194],
#  'gene-LOC106463880': [539430, 548570],
#  'gene-LOC106463891': [581066, 603126],
#  'gene-LOC106463966': [675472, 800196],
#  'gene-LOC106463975': [901908, 912705],
#  'gene-LOC106463903': [965228, 1039215],
#  'gene-LOC106463912': [1096279, 1137005],
#  'gene-LOC106463920': [1398957, 1467385],
#  'gene-LOC111086960': [1433217, 1433603],
#  'gene-LOC106464053': [1169, 32043],
#  'gene-LOC106464062': [62161, 138053],
#  'gene-LOC106463992': [167480, 173227],
#  'gene-LOC106464123': [202352, 287270],
#  'gene-LOC106464073': [291709, 338055],
#  'gene-LOC106464083': [369485, 377169],
#  'gene-LOC106464150': [446970, 468146],
#  'gene-LOC106464003': [491674, 505396],
#  'gene-LOC106464095': [513671, 520491],
#  'gene-LOC106464013': [540744, 552252],
#  'gene-LOC106464023': [676892, 681907],
#  'gene-LOC106464032': [701622, 721962],
#  'gene-LOC106464113': [1208605, 1212186],
#  'gene-LOC106464042': [1325014, 1434146],
#  'gene-LOC106464182': [8605, 80716],
#  'gene-LOC106464197': [141248, 156493],
#  'gene-LOC106464227': [206164, 278243],
#  'gene-LOC111087037': [285380, 340249],
#  'gene-LOC106464238': [350938, 394085],
#  'gene-LOC106464207': [416155, 424095],
#  'gene-LOC106464249': [483192, 484454],
#  'gene-LOC106464269': [560917, 569419],
#  'gene-LOC106464217': [796505, 797554],
#  ...}

# %%
gene_scaff_dict
# Out:
# {'gene-LOC106456832': 'NW_013665610.1',
#  'gene-LOC106466742': 'NW_013665610.1',
#  'gene-LOC106477029': 'NW_013665610.1',
#  'gene-LOC106456833': 'NW_013665610.1',
#  'gene-LOC111085464': 'NW_013665610.1',
#  'gene-LOC106457832': 'NW_013665610.1',
#  'gene-LOC106457563': 'NW_013665610.1',
#  'gene-LOC106457663': 'NW_013665610.1',
#  'gene-LOC106457765': 'NW_013665610.1',
#  'gene-LOC106458816': 'NW_013665610.1',
#  'gene-LOC106459800': 'NW_013665610.1',
#  'gene-LOC106460795': 'NW_013665610.1',
#  'gene-LOC106478102': 'NW_013665610.1',
#  'gene-LOC111087465': 'NW_013665610.1',
#  'gene-LOC106461769': 'NW_013665610.1',
#  'gene-LOC106462746': 'NW_013665610.1',
#  'gene-LOC106478203': 'NW_013665610.1',
#  'gene-LOC111089463': 'NW_013665610.1',
#  'gene-LOC106458041': 'NW_013665610.1',
#  'gene-LOC106463729': 'NW_013665610.1',
#  'gene-LOC106458387': 'NW_013665610.1',
#  'gene-LOC106464713': 'NW_013665610.1',
#  'gene-LOC106478309': 'NW_013665610.1',
#  'gene-LOC106478541': 'NW_013665610.1',
#  'gene-LOC106465725': 'NW_013665610.1',
#  'gene-LOC106466743': 'NW_013665610.1',
#  'gene-LOC106467741': 'NW_013665610.1',
#  'gene-LOC106478641': 'NW_013665610.1',
#  'gene-LOC106458621': 'NW_013665610.1',
#  'gene-LOC106478743': 'NW_013665610.1',
#  'gene-LOC106468760': 'NW_013665610.1',
#  'gene-LOC106469774': 'NW_013665610.1',
#  'gene-LOC106470777': 'NW_013665610.1',
#  'gene-LOC106471801': 'NW_013665610.1',
#  'gene-LOC106472817': 'NW_013665610.1',
#  'gene-LOC106473861': 'NW_013665610.1',
#  'gene-LOC106478843': 'NW_013665610.1',
#  'gene-LOC106456866': 'NW_013665610.1',
#  'gene-LOC106458717': 'NW_013665610.1',
#  'gene-LOC106457032': 'NW_013665610.1',
#  'gene-LOC106474893': 'NW_013665610.1',
#  'gene-LOC106458879': 'NW_013665610.1',
#  'gene-LOC106457270': 'NW_013665610.1',
#  'gene-LOC106477030': 'NW_013665610.1',
#  'gene-LOC106457365': 'NW_013665610.1',
#  'gene-LOC106477983': 'NW_013665610.1',
#  'gene-LOC106457465': 'NW_013665610.1',
#  'gene-LOC111085736': 'NW_013665610.1',
#  'gene-LOC106459044': 'NW_013665611.1',
#  'gene-LOC106462096': 'NW_013665611.1',
#  'gene-LOC106464376': 'NW_013665611.1',
#  'gene-LOC106464206': 'NW_013665611.1',
#  'gene-LOC106464474': 'NW_013665611.1',
#  'gene-LOC106459239': 'NW_013665611.1',
#  'gene-LOC106459331': 'NW_013665611.1',
#  'gene-LOC106464783': 'NW_013665611.1',
#  'gene-LOC106462193': 'NW_013665611.1',
#  'gene-LOC106459436': 'NW_013665611.1',
#  'gene-LOC106459536': 'NW_013665611.1',
#  'gene-LOC111087181': 'NW_013665611.1',
#  'gene-LOC106462483': 'NW_013665611.1',
#  'gene-LOC106459639': 'NW_013665611.1',
#  'gene-LOC106459732': 'NW_013665611.1',
#  'gene-LOC111085809': 'NW_013665611.1',
#  'gene-LOC106462747': 'NW_013665611.1',
#  'gene-LOC106459935': 'NW_013665611.1',
#  'gene-LOC106462977': 'NW_013665611.1',
#  'gene-LOC106460031': 'NW_013665611.1',
#  'gene-LOC106464952': 'NW_013665611.1',
#  'gene-LOC106465252': 'NW_013665611.1',
#  'gene-LOC106460136': 'NW_013665611.1',
#  'gene-LOC106463085': 'NW_013665611.1',
#  'gene-LOC106460237': 'NW_013665611.1',
#  'gene-LOC106460337': 'NW_013665611.1',
#  'gene-LOC106460441': 'NW_013665611.1',
#  'gene-LOC106460536': 'NW_013665611.1',
#  'gene-LOC106465521': 'NW_013665611.1',
#  'gene-LOC106465622': 'NW_013665611.1',
#  'gene-LOC106460637': 'NW_013665611.1',
#  'gene-LOC106460726': 'NW_013665611.1',
#  'gene-LOC106460829': 'NW_013665611.1',
#  'gene-LOC106460925': 'NW_013665611.1',
#  'gene-LOC106461018': 'NW_013665611.1',
#  'gene-LOC106463175': 'NW_013665611.1',
#  'gene-LOC106461115': 'NW_013665611.1',
#  'gene-LOC106461215': 'NW_013665611.1',
#  'gene-LOC106463269': 'NW_013665611.1',
#  'gene-LOC106461308': 'NW_013665611.1',
#  'gene-LOC106461411': 'NW_013665611.1',
#  'gene-LOC106463371': 'NW_013665611.1',
#  'gene-LOC106463535': 'NW_013665611.1',
#  'gene-LOC106463635': 'NW_013665611.1',
#  'gene-LOC106461511': 'NW_013665611.1',
#  'gene-LOC106461606': 'NW_013665611.1',
#  'gene-LOC106463730': 'NW_013665611.1',
#  'gene-LOC106461705': 'NW_013665611.1',
#  'gene-LOC106461803': 'NW_013665611.1',
#  'gene-LOC106461899': 'NW_013665611.1',
#  'gene-LOC106462001': 'NW_013665611.1',
#  'gene-LOC106463896': 'NW_013665611.1',
#  'gene-LOC106463986': 'NW_013665611.1',
#  'gene-LOC106464087': 'NW_013665611.1',
#  'gene-LOC111087314': 'NW_013665612.1',
#  'gene-LOC106466034': 'NW_013665612.1',
#  'gene-LOC106466144': 'NW_013665612.1',
#  'gene-LOC106467439': 'NW_013665612.1',
#  'gene-LOC106467537': 'NW_013665612.1',
#  'gene-LOC106467705': 'NW_013665612.1',
#  'gene-LOC106466242': 'NW_013665612.1',
#  'gene-LOC106466334': 'NW_013665612.1',
#  'gene-LOC106466433': 'NW_013665612.1',
#  'gene-LOC106466535': 'NW_013665612.1',
#  'gene-LOC106466639': 'NW_013665612.1',
#  'gene-LOC106466744': 'NW_013665612.1',
#  'gene-LOC106467913': 'NW_013665612.1',
#  'gene-LOC106467014': 'NW_013665612.1',
#  'gene-LOC106466847': 'NW_013665612.1',
#  'gene-LOC106468014': 'NW_013665612.1',
#  'gene-LOC106467182': 'NW_013665612.1',
#  'gene-LOC106467339': 'NW_013665612.1',
#  'gene-LOC106468109': 'NW_013665613.1',
#  'gene-LOC106468317': 'NW_013665613.1',
#  'gene-LOC106468416': 'NW_013665613.1',
#  'gene-LOC106468298': 'NW_013665613.1',
#  'gene-LOC106468521': 'NW_013665613.1',
#  'gene-LOC111088675': 'NW_013665613.1',
#  'gene-LOC111088563': 'NW_013665613.1',
#  'gene-LOC106468628': 'NW_013665613.1',
#  'gene-LOC106468724': 'NW_013665613.1',
#  'gene-LOC106468826': 'NW_013665613.1',
#  'gene-LOC106468929': 'NW_013665613.1',
#  'gene-LOC106469035': 'NW_013665613.1',
#  'gene-LOC106469136': 'NW_013665613.1',
#  'gene-LOC106470180': 'NW_013665613.1',
#  'gene-LOC106469435': 'NW_013665613.1',
#  'gene-LOC106469538': 'NW_013665613.1',
#  'gene-LOC111088717': 'NW_013665613.1',
#  'gene-LOC106469641': 'NW_013665613.1',
#  'gene-LOC111088768': 'NW_013665613.1',
#  'gene-LOC111088787': 'NW_013665613.1',
#  'gene-LOC106469739': 'NW_013665613.1',
#  'gene-LOC111088393': 'NW_013665613.1',
#  'gene-LOC106469845': 'NW_013665613.1',
#  'gene-LOC106469941': 'NW_013665613.1',
#  'gene-LOC106471594': 'NW_013665614.1',
#  'gene-LOC106470276': 'NW_013665614.1',
#  'gene-LOC106471696': 'NW_013665614.1',
#  'gene-LOC106470377': 'NW_013665614.1',
#  'gene-LOC106470475': 'NW_013665614.1',
#  'gene-LOC106470573': 'NW_013665614.1',
#  'gene-LOC106470675': 'NW_013665614.1',
#  'gene-LOC111089007': 'NW_013665614.1',
#  'gene-LOC106470778': 'NW_013665614.1',
#  'gene-LOC106471802': 'NW_013665614.1',
#  'gene-LOC106471907': 'NW_013665614.1',
#  'gene-LOC111089435': 'NW_013665614.1',
#  'gene-LOC106472076': 'NW_013665614.1',
#  'gene-LOC106472181': 'NW_013665614.1',
#  'gene-LOC106472351': 'NW_013665614.1',
#  'gene-LOC111089202': 'NW_013665614.1',
#  'gene-LOC106470877': 'NW_013665614.1',
#  'gene-LOC106470974': 'NW_013665614.1',
#  'gene-LOC106471078': 'NW_013665614.1',
#  'gene-LOC106471184': 'NW_013665614.1',
#  'gene-LOC106472548': 'NW_013665614.1',
#  'gene-LOC106472449': 'NW_013665614.1',
#  'gene-LOC106471286': 'NW_013665614.1',
#  'gene-LOC106471393': 'NW_013665614.1',
#  'gene-LOC106471496': 'NW_013665614.1',
#  'gene-LOC106473514': 'NW_013665615.1',
#  'gene-LOC111083486': 'NW_013665615.1',
#  'gene-LOC106473798': 'NW_013665615.1',
#  'gene-LOC111083386': 'NW_013665615.1',
#  'gene-LOC106472684': 'NW_013665615.1',
#  'gene-LOC106472785': 'NW_013665615.1',
#  'gene-LOC111083546': 'NW_013665615.1',
#  'gene-LOC106473896': 'NW_013665615.1',
#  'gene-LOC106474278': 'NW_013665615.1',
#  'gene-LOC106472885': 'NW_013665615.1',
#  'gene-LOC106474067': 'NW_013665615.1',
#  'gene-LOC111083578': 'NW_013665615.1',
#  'gene-LOC106474380': 'NW_013665615.1',
#  'gene-LOC106472993': 'NW_013665615.1',
#  'gene-LOC106474170': 'NW_013665615.1',
#  'gene-LOC106473199': 'NW_013665615.1',
#  'gene-LOC106473410': 'NW_013665615.1',
#  'gene-LOC106474653': 'NW_013665616.1',
#  'gene-LOC106475608': 'NW_013665616.1',
#  'gene-LOC106474856': 'NW_013665616.1',
#  'gene-LOC106474963': 'NW_013665616.1',
#  'gene-LOC106476137': 'NW_013665616.1',
#  'gene-LOC106475073': 'NW_013665616.1',
#  'gene-LOC106475173': 'NW_013665616.1',
#  'gene-LOC106476241': 'NW_013665616.1',
#  'gene-LOC106475714': 'NW_013665616.1',
#  'gene-LOC106475285': 'NW_013665616.1',
#  'gene-LOC106475393': 'NW_013665616.1',
#  'gene-LOC106476350': 'NW_013665616.1',
#  'gene-LOC106475503': 'NW_013665616.1',
#  'gene-LOC106476030': 'NW_013665616.1',
#  'gene-LOC106477316': 'NW_013665617.1',
#  'gene-LOC106476458': 'NW_013665617.1',
#  'gene-LOC106476562': 'NW_013665617.1',
#  'gene-LOC106476666': 'NW_013665617.1',
#  'gene-LOC106476773': 'NW_013665617.1',
#  'gene-LOC106476885': 'NW_013665617.1',
#  'gene-LOC106476991': 'NW_013665617.1',
#  'gene-LOC106477104': 'NW_013665617.1',
#  'gene-LOC111084911': 'NW_013665617.1',
#  'gene-LOC106477211': 'NW_013665617.1',
#  'gene-LOC106478057': 'NW_013665618.1',
#  'gene-LOC106477493': 'NW_013665618.1',
#  'gene-LOC106477600': 'NW_013665618.1',
#  'gene-LOC106478122': 'NW_013665618.1',
#  'gene-LOC106478067': 'NW_013665618.1',
#  'gene-LOC106478078': 'NW_013665618.1',
#  'gene-LOC106477701': 'NW_013665618.1',
#  'gene-LOC106478088': 'NW_013665618.1',
#  'gene-LOC106477788': 'NW_013665618.1',
#  'gene-LOC106477867': 'NW_013665618.1',
#  'gene-LOC106477941': 'NW_013665618.1',
#  'gene-LOC106478006': 'NW_013665618.1',
#  'gene-LOC111084965': 'NW_013665618.1',
#  'gene-LOC106478095': 'NW_013665618.1',
#  'gene-LOC111084931': 'NW_013665618.1',
#  'gene-LOC106478111': 'NW_013665618.1',
#  'gene-LOC106478028': 'NW_013665618.1',
#  'gene-LOC106478037': 'NW_013665618.1',
#  'gene-LOC106478138': 'NW_013665619.1',
#  'gene-LOC106478147': 'NW_013665619.1',
#  'gene-LOC106478156': 'NW_013665619.1',
#  'gene-LOC106478167': 'NW_013665619.1',
#  'gene-LOC106478177': 'NW_013665619.1',
#  'gene-LOC106478188': 'NW_013665619.1',
#  'gene-LOC106478207': 'NW_013665619.1',
#  'gene-LOC106478228': 'NW_013665619.1',
#  'gene-LOC106478217': 'NW_013665619.1',
#  'gene-LOC106478252': 'NW_013665619.1',
#  'gene-LOC106478261': 'NW_013665619.1',
#  'gene-LOC106478271': 'NW_013665620.1',
#  'gene-LOC111085003': 'NW_013665620.1',
#  'gene-LOC106478283': 'NW_013665620.1',
#  'gene-LOC106478293': 'NW_013665620.1',
#  'gene-LOC111085007': 'NW_013665620.1',
#  'gene-LOC106478304': 'NW_013665620.1',
#  'gene-LOC106478391': 'NW_013665620.1',
#  'gene-LOC106478313': 'NW_013665620.1',
#  'gene-LOC111085061': 'NW_013665620.1',
#  'gene-LOC106478331': 'NW_013665620.1',
#  'gene-LOC111085023': 'NW_013665620.1',
#  'gene-LOC106478400': 'NW_013665620.1',
#  'gene-LOC106478414': 'NW_013665620.1',
#  'gene-LOC106478426': 'NW_013665620.1',
#  'gene-LOC106478342': 'NW_013665620.1',
#  'gene-LOC106478352': 'NW_013665620.1',
#  'gene-LOC106478361': 'NW_013665620.1',
#  'gene-LOC106478371': 'NW_013665620.1',
#  'gene-LOC106478380': 'NW_013665620.1',
#  'gene-LOC111085040': 'NW_013665620.1',
#  'gene-LOC106478442': 'NW_013665620.1',
#  'gene-LOC106478458': 'NW_013665620.1',
#  'gene-LOC111085051': 'NW_013665620.1',
#  'gene-LOC111085054': 'NW_013665620.1',
#  'gene-LOC106478591': 'NW_013665621.1',
#  'gene-LOC106478469': 'NW_013665621.1',
#  'gene-LOC106478480': 'NW_013665621.1',
#  'gene-LOC106478491': 'NW_013665621.1',
#  'gene-LOC106478498': 'NW_013665621.1',
#  'gene-LOC106478601': 'NW_013665621.1',
#  'gene-LOC106478618': 'NW_013665621.1',
#  'gene-LOC106478722': 'NW_013665621.1',
#  'gene-LOC106478509': 'NW_013665621.1',
#  'gene-LOC106478520': 'NW_013665621.1',
#  'gene-LOC106478531': 'NW_013665621.1',
#  'gene-LOC106478635': 'NW_013665621.1',
#  'gene-LOC106478644': 'NW_013665621.1',
#  'gene-LOC106478542': 'NW_013665621.1',
#  'gene-LOC106478552': 'NW_013665621.1',
#  'gene-LOC106478563': 'NW_013665621.1',
#  'gene-LOC111085105': 'NW_013665621.1',
#  'gene-LOC111085134': 'NW_013665621.1',
#  'gene-LOC106478655': 'NW_013665621.1',
#  'gene-LOC106478666': 'NW_013665621.1',
#  'gene-LOC106478570': 'NW_013665621.1',
#  'gene-LOC106478580': 'NW_013665621.1',
#  'gene-LOC106478688': 'NW_013665621.1',
#  'gene-LOC111085215': 'NW_013665622.1',
#  'gene-LOC111085221': 'NW_013665622.1',
#  'gene-LOC106478753': 'NW_013665622.1',
#  'gene-LOC106478851': 'NW_013665622.1',
#  'gene-LOC106478763': 'NW_013665622.1',
#  'gene-LOC106478860': 'NW_013665622.1',
#  'gene-LOC106478902': 'NW_013665622.1',
#  'gene-LOC111085220': 'NW_013665622.1',
#  'gene-LOC106478783': 'NW_013665622.1',
#  'gene-LOC106456838': 'NW_013665622.1',
#  'gene-LOC106478792': 'NW_013665622.1',
#  'gene-LOC106456859': 'NW_013665622.1',
#  'gene-LOC106478802': 'NW_013665622.1',
#  'gene-LOC106456871': 'NW_013665622.1',
#  'gene-LOC106456881': 'NW_013665622.1',
#  'gene-LOC106478871': 'NW_013665622.1',
#  'gene-LOC106478878': 'NW_013665622.1',
#  'gene-LOC106478812': 'NW_013665622.1',
#  'gene-LOC106478888': 'NW_013665622.1',
#  'gene-LOC111085209': 'NW_013665622.1',
#  'gene-LOC106478823': 'NW_013665622.1',
#  'gene-LOC106456907': 'NW_013665623.1',
#  'gene-LOC106456917': 'NW_013665623.1',
#  'gene-LOC106456928': 'NW_013665623.1',
#  'gene-LOC111085228': 'NW_013665623.1',
#  'gene-LOC111085238': 'NW_013665623.1',
#  'gene-LOC106456987': 'NW_013665623.1',
#  'gene-LOC106456937': 'NW_013665623.1',
#  'gene-LOC106456949': 'NW_013665623.1',
#  'gene-LOC106456959': 'NW_013665623.1',
#  'gene-LOC106456978': 'NW_013665623.1',
#  'gene-LOC106456969': 'NW_013665623.1',
#  'gene-LOC106456997': 'NW_013665624.1',
#  'gene-LOC106457173': 'NW_013665624.1',
#  'gene-LOC106457183': 'NW_013665624.1',
#  'gene-LOC106457195': 'NW_013665624.1',
#  'gene-LOC106457016': 'NW_013665624.1',
#  'gene-LOC106457101': 'NW_013665624.1',
#  'gene-LOC106457111': 'NW_013665624.1',
#  'gene-LOC106457039': 'NW_013665624.1',
#  'gene-LOC106457048': 'NW_013665624.1',
#  'gene-LOC106457126': 'NW_013665624.1',
#  'gene-LOC106457059': 'NW_013665624.1',
#  'gene-LOC106457069': 'NW_013665624.1',
#  'gene-LOC106457137': 'NW_013665624.1',
#  'gene-LOC111085299': 'NW_013665624.1',
#  'gene-LOC106457147': 'NW_013665624.1',
#  'gene-LOC106457158': 'NW_013665624.1',
#  'gene-LOC106457081': 'NW_013665624.1',
#  'gene-LOC106457090': 'NW_013665624.1',
#  'gene-LOC106457221': 'NW_013665625.1',
#  'gene-LOC106457230': 'NW_013665625.1',
#  'gene-LOC106457240': 'NW_013665625.1',
#  'gene-LOC106457250': 'NW_013665625.1',
#  'gene-LOC106457316': 'NW_013665625.1',
#  'gene-LOC106457262': 'NW_013665625.1',
#  'gene-LOC106457274': 'NW_013665625.1',
#  'gene-LOC106457286': 'NW_013665625.1',
#  'gene-LOC106457323': 'NW_013665626.1',
#  'gene-LOC106457411': 'NW_013665626.1',
#  'gene-LOC106457333': 'NW_013665626.1',
#  'gene-LOC106457343': 'NW_013665626.1',
#  'gene-LOC106457352': 'NW_013665626.1',
#  'gene-LOC106457359': 'NW_013665626.1',
#  'gene-LOC106457370': 'NW_013665626.1',
#  'gene-LOC106457444': 'NW_013665626.1',
#  'gene-LOC106457454': 'NW_013665626.1',
#  'gene-LOC106457421': 'NW_013665626.1',
#  'gene-LOC106457473': 'NW_013665626.1',
#  'gene-LOC106457436': 'NW_013665626.1',
#  'gene-LOC111085345': 'NW_013665626.1',
#  'gene-LOC106457379': 'NW_013665626.1',
#  'gene-LOC106457390': 'NW_013665626.1',
#  'gene-LOC106457402': 'NW_013665626.1',
#  'gene-LOC106457482': 'NW_013665626.1',
#  'gene-LOC106457497': 'NW_013665627.1',
#  'gene-LOC106457508': 'NW_013665627.1',
#  'gene-LOC106457519': 'NW_013665627.1',
#  'gene-LOC111085377': 'NW_013665627.1',
#  'gene-LOC111085379': 'NW_013665627.1',
#  'gene-LOC111085390': 'NW_013665627.1',
#  'gene-LOC106457527': 'NW_013665627.1',
#  'gene-LOC106457575': 'NW_013665627.1',
#  'gene-LOC106457536': 'NW_013665627.1',
#  'gene-LOC106457547': 'NW_013665627.1',
#  'gene-LOC106457585': 'NW_013665627.1',
#  'gene-LOC106457557': 'NW_013665627.1',
#  'gene-LOC111085368': 'NW_013665627.1',
#  'gene-LOC106457567': 'NW_013665627.1',
#  'gene-LOC111085396': 'NW_013665627.1',
#  'gene-LOC106457601': 'NW_013665627.1',
#  'gene-LOC111085447': 'NW_013665628.1',
#  'gene-LOC106457612': 'NW_013665628.1',
#  'gene-LOC106457634': 'NW_013665628.1',
#  'gene-LOC106457691': 'NW_013665628.1',
#  'gene-LOC106457700': 'NW_013665628.1',
#  'gene-LOC106457718': 'NW_013665628.1',
#  'gene-LOC106457644': 'NW_013665628.1',
#  'gene-LOC106457654': 'NW_013665628.1',
#  'gene-LOC106457789': 'NW_013665628.1',
#  'gene-LOC106457664': 'NW_013665628.1',
#  'gene-LOC106457726': 'NW_013665628.1',
#  'gene-LOC106457736': 'NW_013665628.1',
#  'gene-LOC111085402': 'NW_013665628.1',
#  'gene-LOC106457673': 'NW_013665628.1',
#  'gene-LOC106457683': 'NW_013665628.1',
#  'gene-LOC106457799': 'NW_013665628.1',
#  'gene-LOC106457747': 'NW_013665628.1',
#  'gene-LOC106457757': 'NW_013665628.1',
#  'gene-LOC106457769': 'NW_013665628.1',
#  'gene-LOC106457780': 'NW_013665628.1',
#  'gene-LOC111085406': 'NW_013665628.1',
#  'gene-LOC111085408': 'NW_013665628.1',
#  'gene-LOC111085461': 'NW_013665629.1',
#  'gene-LOC106457807': 'NW_013665629.1',
#  'gene-LOC106457874': 'NW_013665629.1',
#  'gene-LOC106457817': 'NW_013665629.1',
#  'gene-LOC106457828': 'NW_013665629.1',
#  'gene-LOC106457838': 'NW_013665629.1',
#  'gene-LOC106457849': 'NW_013665629.1',
#  'gene-LOC106457899': 'NW_013665630.1',
#  'gene-LOC106458116': 'NW_013665630.1',
#  'gene-LOC106457910': 'NW_013665630.1',
#  'gene-LOC106457919': 'NW_013665630.1',
#  'gene-LOC106458142': 'NW_013665630.1',
#  'gene-LOC106457930': 'NW_013665630.1',
#  'gene-LOC106458123': 'NW_013665630.1',
#  'gene-LOC106457953': 'NW_013665630.1',
#  'gene-LOC106457964': 'NW_013665630.1',
#  'gene-LOC106457973': 'NW_013665630.1',
#  'gene-LOC106458152': 'NW_013665630.1',
#  'gene-LOC106457983': 'NW_013665630.1',
#  'gene-LOC106457993': 'NW_013665630.1',
#  'gene-LOC111085517': 'NW_013665630.1',
#  'gene-LOC106458004': 'NW_013665630.1',
#  'gene-LOC106458014': 'NW_013665630.1',
#  'gene-LOC106458025': 'NW_013665630.1',
#  'gene-LOC106458034': 'NW_013665630.1',
#  'gene-LOC106458162': 'NW_013665630.1',
#  'gene-LOC106458044': 'NW_013665630.1',
#  'gene-LOC106458130': 'NW_013665630.1',
#  'gene-LOC106458064': 'NW_013665630.1',
#  'gene-LOC106458074': 'NW_013665630.1',
#  'gene-LOC106458086': 'NW_013665630.1',
#  'gene-LOC106458096': 'NW_013665630.1',
#  'gene-LOC106458105': 'NW_013665630.1',
#  'gene-LOC106458180': 'NW_013665631.1',
#  'gene-LOC106458247': 'NW_013665631.1',
#  'gene-LOC106458198': 'NW_013665631.1',
#  'gene-LOC106458261': 'NW_013665631.1',
#  'gene-LOC111085553': 'NW_013665631.1',
#  'gene-LOC106458271': 'NW_013665631.1',
#  'gene-LOC106458207': 'NW_013665631.1',
#  'gene-LOC106458218': 'NW_013665631.1',
#  'gene-LOC106458229': 'NW_013665631.1',
#  'gene-LOC106458298': 'NW_013665631.1',
#  'gene-LOC106458279': 'NW_013665631.1',
#  'gene-LOC106458239': 'NW_013665631.1',
#  'gene-LOC106458288': 'NW_013665631.1',
#  'gene-LOC106458401': 'NW_013665632.1',
#  'gene-LOC106458330': 'NW_013665632.1',
#  'gene-LOC106458405': 'NW_013665632.1',
#  'gene-LOC106458415': 'NW_013665632.1',
#  'gene-LOC106458341': 'NW_013665632.1',
#  'gene-LOC106458351': 'NW_013665632.1',
#  'gene-LOC106458362': 'NW_013665632.1',
#  'gene-LOC106458371': 'NW_013665632.1',
#  'gene-LOC106458381': 'NW_013665632.1',
#  'gene-LOC106458432': 'NW_013665632.1',
#  'gene-LOC111085598': 'NW_013665632.1',
#  'gene-LOC106458391': 'NW_013665632.1',
#  'gene-LOC106458452': 'NW_013665633.1',
#  'gene-LOC106458460': 'NW_013665633.1',
#  'gene-LOC106458610': 'NW_013665633.1',
#  'gene-LOC111085605': 'NW_013665633.1',
#  'gene-LOC111085609': 'NW_013665633.1',
#  'gene-LOC106458471': 'NW_013665633.1',
#  'gene-LOC106458481': 'NW_013665633.1',
#  'gene-LOC106458554': 'NW_013665633.1',
#  'gene-LOC106458622': 'NW_013665633.1',
#  'gene-LOC106458490': 'NW_013665633.1',
#  'gene-LOC106458583': 'NW_013665633.1',
#  'gene-LOC111085601': 'NW_013665633.1',
#  'gene-LOC106458499': 'NW_013665633.1',
#  'gene-LOC106458510': 'NW_013665633.1',
#  'gene-LOC106458520': 'NW_013665633.1',
#  'gene-LOC106458531': 'NW_013665633.1',
#  'gene-LOC106458594': 'NW_013665633.1',
#  'gene-LOC111085639': 'NW_013665633.1',
#  'gene-LOC106458651': 'NW_013665633.1',
#  'gene-LOC106458542': 'NW_013665633.1',
#  'gene-LOC106458805': 'NW_013665634.1',
#  'gene-LOC106458866': 'NW_013665634.1',
#  'gene-LOC106458817': 'NW_013665634.1',
#  'gene-LOC106458831': 'NW_013665634.1',
#  'gene-LOC106458680': 'NW_013665634.1',
#  'gene-LOC106458888': 'NW_013665634.1',
#  'gene-LOC106458689': 'NW_013665634.1',
#  'gene-LOC106458694': 'NW_013665634.1',
#  'gene-LOC106458705': 'NW_013665634.1',
#  'gene-LOC106458718': 'NW_013665634.1',
#  'gene-LOC106458727': 'NW_013665634.1',
#  'gene-LOC106458737': 'NW_013665634.1',
#  'gene-LOC106458749': 'NW_013665634.1',
#  'gene-LOC106458841': 'NW_013665634.1',
#  'gene-LOC106458757': 'NW_013665634.1',
#  'gene-LOC106458851': 'NW_013665634.1',
#  'gene-LOC106458775': 'NW_013665634.1',
#  'gene-LOC106458785': 'NW_013665634.1',
#  'gene-LOC106458796': 'NW_013665634.1',
#  'gene-LOC106458910': 'NW_013665635.1',
#  'gene-LOC106458921': 'NW_013665635.1',
#  'gene-LOC111085688': 'NW_013665635.1',
#  'gene-LOC111085691': 'NW_013665635.1',
#  'gene-LOC106458931': 'NW_013665635.1',
#  'gene-LOC106458939': 'NW_013665635.1',
#  'gene-LOC106459062': 'NW_013665635.1',
#  'gene-LOC106458960': 'NW_013665635.1',
#  'gene-LOC106459117': 'NW_013665635.1',
#  'gene-LOC106459081': 'NW_013665635.1',
#  'gene-LOC106458971': 'NW_013665635.1',
#  'gene-LOC106458982': 'NW_013665635.1',
#  'gene-LOC106459090': 'NW_013665635.1',
#  'gene-LOC106458993': 'NW_013665635.1',
#  'gene-LOC106459004': 'NW_013665635.1',
#  'gene-LOC106459012': 'NW_013665635.1',
#  'gene-LOC106459099': 'NW_013665635.1',
#  'gene-LOC106459022': 'NW_013665635.1',
#  'gene-LOC111085726': 'NW_013665635.1',
#  'gene-LOC106459032': 'NW_013665635.1',
#  'gene-LOC111085730': 'NW_013665635.1',
#  'gene-LOC106459041': 'NW_013665635.1',
#  'gene-LOC106459141': 'NW_013665636.1',
#  'gene-LOC106459147': 'NW_013665636.1',
#  'gene-LOC106459158': 'NW_013665636.1',
#  'gene-LOC106459248': 'NW_013665636.1',
#  'gene-LOC106459168': 'NW_013665636.1',
#  'gene-LOC106459177': 'NW_013665636.1',
#  'gene-LOC106459185': 'NW_013665636.1',
#  'gene-LOC106459196': 'NW_013665636.1',
#  'gene-LOC106459293': 'NW_013665636.1',
#  'gene-LOC106459205': 'NW_013665636.1',
#  'gene-LOC106459259': 'NW_013665636.1',
#  'gene-LOC111085770': 'NW_013665636.1',
#  'gene-LOC106459269': 'NW_013665636.1',
#  'gene-LOC106459213': 'NW_013665636.1',
#  'gene-LOC106459272': 'NW_013665636.1',
#  'gene-LOC106459282': 'NW_013665636.1',
#  'gene-LOC106459224': 'NW_013665636.1',
#  'gene-LOC106459235': 'NW_013665636.1',
#  'gene-LOC111085771': 'NW_013665637.1',
#  'gene-LOC106459304': 'NW_013665637.1',
#  'gene-LOC106459322': 'NW_013665637.1',
#  'gene-LOC111085783': 'NW_013665637.1',
#  'gene-LOC106459326': 'NW_013665637.1',
#  'gene-LOC106459401': 'NW_013665637.1',
#  'gene-LOC106459417': 'NW_013665637.1',
#  'gene-LOC106459440': 'NW_013665637.1',
#  'gene-LOC106459348': 'NW_013665637.1',
#  'gene-LOC106459359': 'NW_013665637.1',
#  'gene-LOC106459428': 'NW_013665637.1',
#  'gene-LOC106459369': 'NW_013665637.1',
#  'gene-LOC106459380': 'NW_013665637.1',
#  'gene-LOC106459391': 'NW_013665637.1',
#  'gene-LOC111085836': 'NW_013665638.1',
#  'gene-LOC106459456': 'NW_013665638.1',
#  'gene-LOC106459578': 'NW_013665638.1',
#  'gene-LOC111085837': 'NW_013665638.1',
#  'gene-LOC106459467': 'NW_013665638.1',
#  'gene-LOC106459476': 'NW_013665638.1',
#  'gene-LOC106459588': 'NW_013665638.1',
#  'gene-LOC111085817': 'NW_013665638.1',
#  'gene-LOC106459487': 'NW_013665638.1',
#  'gene-LOC106459596': 'NW_013665638.1',
#  'gene-LOC106459525': 'NW_013665638.1',
#  'gene-LOC106459496': 'NW_013665638.1',
#  'gene-LOC106459537': 'NW_013665638.1',
#  'gene-LOC106459547': 'NW_013665638.1',
#  'gene-LOC106459558': 'NW_013665638.1',
#  'gene-LOC106459505': 'NW_013665638.1',
#  'gene-LOC106459569': 'NW_013665638.1',
#  'gene-LOC106459516': 'NW_013665638.1',
#  'gene-LOC106459656': 'NW_013665639.1',
#  'gene-LOC106459607': 'NW_013665639.1',
#  'gene-LOC106459618': 'NW_013665639.1',
#  'gene-LOC111085850': 'NW_013665639.1',
#  'gene-LOC106459667': 'NW_013665639.1',
#  'gene-LOC106459629': 'NW_013665639.1',
#  'gene-LOC106459682': 'NW_013665639.1',
#  'gene-LOC106459640': 'NW_013665639.1',
#  'gene-LOC106459701': 'NW_013665639.1',
#  'gene-LOC106459710': 'NW_013665639.1',
#  'gene-LOC106459647': 'NW_013665639.1',
#  'gene-LOC106459725': 'NW_013665639.1',
#  'gene-LOC106459733': 'NW_013665640.1',
#  'gene-LOC106459823': 'NW_013665640.1',
#  'gene-LOC106459833': 'NW_013665640.1',
#  'gene-LOC106459753': 'NW_013665640.1',
#  'gene-LOC111085884': 'NW_013665640.1',
#  'gene-LOC106459844': 'NW_013665640.1',
#  'gene-LOC106459851': 'NW_013665640.1',
#  'gene-LOC106459764': 'NW_013665640.1',
#  'gene-LOC111085901': 'NW_013665640.1',
#  'gene-LOC106459864': 'NW_013665640.1',
#  'gene-LOC111085917': 'NW_013665640.1',
#  'gene-LOC106459774': 'NW_013665640.1',
#  'gene-LOC111085908': 'NW_013665640.1',
#  'gene-LOC106459782': 'NW_013665640.1',
#  'gene-LOC106459793': 'NW_013665640.1',
#  'gene-LOC106459803': 'NW_013665640.1',
#  'gene-LOC106459877': 'NW_013665640.1',
#  'gene-LOC106459812': 'NW_013665640.1',
#  'gene-LOC106459981': 'NW_013665641.1',
#  'gene-LOC106459996': 'NW_013665641.1',
#  'gene-LOC106459888': 'NW_013665641.1',
#  'gene-LOC111085957': 'NW_013665641.1',
#  'gene-LOC106459961': 'NW_013665641.1',
#  'gene-LOC106459899': 'NW_013665641.1',
#  'gene-LOC111085938': 'NW_013665641.1',
#  'gene-LOC106459911': 'NW_013665641.1',
#  'gene-LOC106459922': 'NW_013665641.1',
#  'gene-LOC106460006': 'NW_013665641.1',
#  'gene-LOC106460017': 'NW_013665641.1',
#  'gene-LOC106459950': 'NW_013665641.1',
#  'gene-LOC106459970': 'NW_013665641.1',
#  'gene-LOC106460156': 'NW_013665642.1',
#  'gene-LOC106460032': 'NW_013665642.1',
#  'gene-LOC106460227': 'NW_013665642.1',
#  'gene-LOC106460043': 'NW_013665642.1',
#  'gene-LOC111085967': 'NW_013665642.1',
#  'gene-LOC106460052': 'NW_013665642.1',
#  'gene-LOC106460062': 'NW_013665642.1',
#  'gene-LOC106460167': 'NW_013665642.1',
#  'gene-LOC106460073': 'NW_013665642.1',
#  'gene-LOC106460176': 'NW_013665642.1',
#  'gene-LOC106460187': 'NW_013665642.1',
#  'gene-LOC106460199': 'NW_013665642.1',
#  'gene-LOC106460095': 'NW_013665642.1',
#  'gene-LOC106460209': 'NW_013665642.1',
#  'gene-LOC106460104': 'NW_013665642.1',
#  'gene-LOC106460115': 'NW_013665642.1',
#  'gene-LOC106460125': 'NW_013665642.1',
#  'gene-LOC106460238': 'NW_013665642.1',
#  'gene-LOC106460146': 'NW_013665642.1',
#  'gene-LOC106460220': 'NW_013665642.1',
#  'gene-LOC106460446': 'NW_013665643.1',
#  'gene-LOC106460254': 'NW_013665643.1',
#  'gene-LOC106460263': 'NW_013665643.1',
#  'gene-LOC106460457': 'NW_013665643.1',
#  'gene-LOC111086058': 'NW_013665643.1',
#  'gene-LOC111086069': 'NW_013665643.1',
#  'gene-LOC106460273': 'NW_013665643.1',
#  'gene-LOC106460345': 'NW_013665643.1',
#  'gene-LOC106460363': 'NW_013665643.1',
#  'gene-LOC106460283': 'NW_013665643.1',
#  'gene-LOC106460293': 'NW_013665643.1',
#  'gene-LOC106460467': 'NW_013665643.1',
#  'gene-LOC106460301': 'NW_013665643.1',
#  'gene-LOC106460312': 'NW_013665643.1',
#  'gene-LOC106460493': 'NW_013665643.1',
#  'gene-LOC106460398': 'NW_013665643.1',
#  'gene-LOC106460406': 'NW_013665643.1',
#  'gene-LOC106460323': 'NW_013665643.1',
#  'gene-LOC106460423': 'NW_013665643.1',
#  'gene-LOC106460333': 'NW_013665643.1',
#  'gene-LOC106460434': 'NW_013665643.1',
#  'gene-LOC106460623': 'NW_013665644.1',
#  'gene-LOC106460513': 'NW_013665644.1',
#  'gene-LOC106460522': 'NW_013665644.1',
#  'gene-LOC106460532': 'NW_013665644.1',
#  'gene-LOC106460543': 'NW_013665644.1',
#  'gene-LOC106460554': 'NW_013665644.1',
#  'gene-LOC111086107': 'NW_013665644.1',
#  'gene-LOC106460564': 'NW_013665644.1',
#  'gene-LOC106460575': 'NW_013665644.1',
#  'gene-LOC106460642': 'NW_013665644.1',
#  'gene-LOC106460585': 'NW_013665644.1',
#  'gene-LOC106460596': 'NW_013665644.1',
#  'gene-LOC106460655': 'NW_013665644.1',
#  'gene-LOC106460605': 'NW_013665644.1',
#  'gene-LOC106460663': 'NW_013665644.1',
#  'gene-LOC106460615': 'NW_013665644.1',
#  'gene-LOC111086099': 'NW_013665644.1',
#  'gene-LOC111086155': 'NW_013665645.1',
#  'gene-LOC106460679': 'NW_013665645.1',
#  'gene-LOC106460749': 'NW_013665645.1',
#  'gene-LOC106460688': 'NW_013665645.1',
#  'gene-LOC106460696': 'NW_013665645.1',
#  'gene-LOC106460706': 'NW_013665645.1',
#  'gene-LOC106460716': 'NW_013665645.1',
#  'gene-LOC106460760': 'NW_013665645.1',
#  'gene-LOC111086134': 'NW_013665645.1',
#  'gene-LOC111086145': 'NW_013665645.1',
#  'gene-LOC111086147': 'NW_013665645.1',
#  'gene-LOC106460770': 'NW_013665645.1',
#  'gene-LOC106460802': 'NW_013665645.1',
#  'gene-LOC111086149': 'NW_013665645.1',
#  'gene-LOC106460791': 'NW_013665645.1',
#  'gene-LOC106460813': 'NW_013665646.1',
#  'gene-LOC106460956': 'NW_013665646.1',
#  'gene-LOC111086209': 'NW_013665646.1',
#  'gene-LOC106461043': 'NW_013665646.1',
#  'gene-LOC106460821': 'NW_013665646.1',
#  'gene-LOC106460833': 'NW_013665646.1',
#  'gene-LOC106460845': 'NW_013665646.1',
#  'gene-LOC106460973': 'NW_013665646.1',
#  'gene-LOC106460853': 'NW_013665646.1',
#  'gene-LOC106460862': 'NW_013665646.1',
#  'gene-LOC106460982': 'NW_013665646.1',
#  'gene-LOC106460870': 'NW_013665646.1',
#  'gene-LOC106460879': 'NW_013665646.1',
#  'gene-LOC106460887': 'NW_013665646.1',
#  'gene-LOC106460897': 'NW_013665646.1',
#  'gene-LOC111086214': 'NW_013665646.1',
#  'gene-LOC106460992': 'NW_013665646.1',
#  'gene-LOC111086229': 'NW_013665646.1',
#  'gene-LOC111086182': 'NW_013665646.1',
#  'gene-LOC106460908': 'NW_013665646.1',
#  'gene-LOC106461002': 'NW_013665646.1',
#  'gene-LOC106461011': 'NW_013665646.1',
#  'gene-LOC106460918': 'NW_013665646.1',
#  'gene-LOC106460929': 'NW_013665646.1',
#  'gene-LOC111086219': 'NW_013665646.1',
#  'gene-LOC106460939': 'NW_013665646.1',
#  'gene-LOC106461019': 'NW_013665646.1',
#  'gene-LOC106461028': 'NW_013665646.1',
#  'gene-LOC106461058': 'NW_013665646.1',
#  'gene-LOC106461096': 'NW_013665646.1',
#  'gene-LOC106461104': 'NW_013665646.1',
#  'gene-LOC106461116': 'NW_013665647.1',
#  'gene-LOC106461224': 'NW_013665647.1',
#  'gene-LOC106461128': 'NW_013665647.1',
#  'gene-LOC106461145': 'NW_013665647.1',
#  'gene-LOC106461155': 'NW_013665647.1',
#  'gene-LOC106461165': 'NW_013665647.1',
#  'gene-LOC106461175': 'NW_013665647.1',
#  'gene-LOC106461185': 'NW_013665647.1',
#  'gene-LOC106461206': 'NW_013665647.1',
#  'gene-LOC106461216': 'NW_013665647.1',
#  'gene-LOC111086249': 'NW_013665648.1',
#  'gene-LOC106461245': 'NW_013665648.1',
#  'gene-LOC106461256': 'NW_013665648.1',
#  'gene-LOC111086283': 'NW_013665648.1',
#  'gene-LOC111086258': 'NW_013665648.1',
#  'gene-LOC106461265': 'NW_013665648.1',
#  'gene-LOC106461373': 'NW_013665648.1',
#  'gene-LOC106461273': 'NW_013665648.1',
#  'gene-LOC111086273': 'NW_013665648.1',
#  'gene-LOC106461284': 'NW_013665648.1',
#  'gene-LOC106461294': 'NW_013665648.1',
#  'gene-LOC106461384': 'NW_013665648.1',
#  'gene-LOC106461403': 'NW_013665648.1',
#  'gene-LOC106461394': 'NW_013665648.1',
#  'gene-LOC106461313': 'NW_013665648.1',
#  'gene-LOC106461324': 'NW_013665648.1',
#  'gene-LOC106461345': 'NW_013665648.1',
#  'gene-LOC106461415': 'NW_013665648.1',
#  'gene-LOC106461351': 'NW_013665648.1',
#  'gene-LOC106461425': 'NW_013665649.1',
#  'gene-LOC106461531': 'NW_013665649.1',
#  'gene-LOC106461454': 'NW_013665649.1',
#  'gene-LOC106461547': 'NW_013665649.1',
#  'gene-LOC106461474': 'NW_013665649.1',
#  'gene-LOC106461485': 'NW_013665649.1',
#  'gene-LOC106461558': 'NW_013665649.1',
#  'gene-LOC106461496': 'NW_013665649.1',
#  'gene-LOC111086316': 'NW_013665649.1',
#  'gene-LOC106461506': 'NW_013665649.1',
#  'gene-LOC106461566': 'NW_013665649.1',
#  'gene-LOC106461514': 'NW_013665649.1',
#  'gene-LOC106461588': 'NW_013665649.1',
#  'gene-LOC106461523': 'NW_013665649.1',
#  'gene-LOC106461708': 'NW_013665650.1',
#  'gene-LOC106461620': 'NW_013665650.1',
#  'gene-LOC106461718': 'NW_013665650.1',
#  'gene-LOC106461631': 'NW_013665650.1',
#  'gene-LOC106461642': 'NW_013665650.1',
#  'gene-LOC106461729': 'NW_013665650.1',
#  'gene-LOC106461649': 'NW_013665650.1',
#  'gene-LOC106461738': 'NW_013665650.1',
#  'gene-LOC106461748': 'NW_013665650.1',
#  'gene-LOC106461758': 'NW_013665650.1',
#  'gene-LOC106461670': 'NW_013665650.1',
#  'gene-LOC106461679': 'NW_013665650.1',
#  'gene-LOC106461786': 'NW_013665650.1',
#  'gene-LOC106461810': 'NW_013665651.1',
#  'gene-LOC106461820': 'NW_013665651.1',
#  'gene-LOC106461887': 'NW_013665651.1',
#  'gene-LOC106461830': 'NW_013665651.1',
#  'gene-LOC106461895': 'NW_013665651.1',
#  'gene-LOC106461840': 'NW_013665651.1',
#  'gene-LOC106461848': 'NW_013665651.1',
#  'gene-LOC106461858': 'NW_013665651.1',
#  'gene-LOC106461906': 'NW_013665651.1',
#  'gene-LOC106461965': 'NW_013665651.1',
#  'gene-LOC106461952': 'NW_013665651.1',
#  'gene-LOC106461866': 'NW_013665651.1',
#  'gene-LOC111086406': 'NW_013665651.1',
#  'gene-LOC106461876': 'NW_013665651.1',
#  'gene-LOC106461923': 'NW_013665651.1',
#  'gene-LOC106461933': 'NW_013665651.1',
#  'gene-LOC106461942': 'NW_013665651.1',
#  'gene-LOC106461973': 'NW_013665652.1',
#  'gene-LOC106461983': 'NW_013665652.1',
#  'gene-LOC106461994': 'NW_013665652.1',
#  'gene-LOC106462005': 'NW_013665652.1',
#  'gene-LOC106462015': 'NW_013665652.1',
#  'gene-LOC106462023': 'NW_013665652.1',
#  'gene-LOC106462034': 'NW_013665652.1',
#  'gene-LOC111086444': 'NW_013665652.1',
#  'gene-LOC106462043': 'NW_013665652.1',
#  'gene-LOC106462075': 'NW_013665652.1',
#  'gene-LOC111086449': 'NW_013665652.1',
#  'gene-LOC106462052': 'NW_013665652.1',
#  'gene-LOC106462062': 'NW_013665652.1',
#  'gene-LOC106462087': 'NW_013665653.1',
#  'gene-LOC106462097': 'NW_013665653.1',
#  'gene-LOC106462117': 'NW_013665653.1',
#  'gene-LOC106462127': 'NW_013665653.1',
#  'gene-LOC106462136': 'NW_013665653.1',
#  'gene-LOC106462204': 'NW_013665654.1',
#  'gene-LOC111086482': 'NW_013665654.1',
#  'gene-LOC106462215': 'NW_013665654.1',
#  'gene-LOC106462232': 'NW_013665654.1',
#  'gene-LOC106462266': 'NW_013665654.1',
#  'gene-LOC106462242': 'NW_013665654.1',
#  'gene-LOC106462282': 'NW_013665654.1',
#  'gene-LOC106462152': 'NW_013665654.1',
#  'gene-LOC106462161': 'NW_013665654.1',
#  'gene-LOC106462171': 'NW_013665654.1',
#  'gene-LOC106462182': 'NW_013665654.1',
#  'gene-LOC106462194': 'NW_013665654.1',
#  'gene-LOC106462353': 'NW_013665655.1',
#  'gene-LOC106462336': 'NW_013665655.1',
#  'gene-LOC106462293': 'NW_013665655.1',
#  'gene-LOC106462361': 'NW_013665655.1',
#  'gene-LOC111086552': 'NW_013665655.1',
#  'gene-LOC106462303': 'NW_013665655.1',
#  'gene-LOC106462312': 'NW_013665655.1',
#  'gene-LOC106462323': 'NW_013665655.1',
#  'gene-LOC106462478': 'NW_013665656.1',
#  'gene-LOC106462392': 'NW_013665656.1',
#  'gene-LOC106462402': 'NW_013665656.1',
#  'gene-LOC106462410': 'NW_013665656.1',
#  'gene-LOC106462490': 'NW_013665656.1',
#  'gene-LOC106462517': 'NW_013665656.1',
#  'gene-LOC106462527': 'NW_013665656.1',
#  'gene-LOC106462537': 'NW_013665656.1',
#  'gene-LOC106462547': 'NW_013665656.1',
#  'gene-LOC106462420': 'NW_013665656.1',
#  'gene-LOC106462557': 'NW_013665656.1',
#  'gene-LOC106462573': 'NW_013665656.1',
#  'gene-LOC106462431': 'NW_013665656.1',
#  'gene-LOC106462582': 'NW_013665656.1',
#  'gene-LOC106462469': 'NW_013665656.1',
#  'gene-LOC106462700': 'NW_013665657.1',
#  'gene-LOC111086618': 'NW_013665657.1',
#  'gene-LOC106462711': 'NW_013665657.1',
#  'gene-LOC106462617': 'NW_013665657.1',
#  'gene-LOC106462720': 'NW_013665657.1',
#  'gene-LOC106462628': 'NW_013665657.1',
#  'gene-LOC106462638': 'NW_013665657.1',
#  'gene-LOC106462648': 'NW_013665657.1',
#  'gene-LOC111086647': 'NW_013665657.1',
#  'gene-LOC106462730': 'NW_013665657.1',
#  'gene-LOC106462658': 'NW_013665657.1',
#  'gene-LOC111086627': 'NW_013665657.1',
#  'gene-LOC106462740': 'NW_013665657.1',
#  'gene-LOC106462668': 'NW_013665657.1',
#  'gene-LOC106462756': 'NW_013665657.1',
#  'gene-LOC106462689': 'NW_013665657.1',
#  'gene-LOC106462765': 'NW_013665657.1',
#  'gene-LOC106462778': 'NW_013665658.1',
#  'gene-LOC106462836': 'NW_013665658.1',
#  'gene-LOC106462787': 'NW_013665658.1',
#  'gene-LOC106462798': 'NW_013665658.1',
#  'gene-LOC111086671': 'NW_013665658.1',
#  'gene-LOC106462827': 'NW_013665658.1',
#  'gene-LOC106462808': 'NW_013665658.1',
#  'gene-LOC106462819': 'NW_013665658.1',
#  'gene-LOC111086668': 'NW_013665658.1',
#  'gene-LOC106462855': 'NW_013665659.1',
#  'gene-LOC106462864': 'NW_013665659.1',
#  'gene-LOC106462927': 'NW_013665659.1',
#  'gene-LOC106462944': 'NW_013665659.1',
#  'gene-LOC106462875': 'NW_013665659.1',
#  'gene-LOC111086694': 'NW_013665659.1',
#  'gene-LOC106462886': 'NW_013665659.1',
#  'gene-LOC111086698': 'NW_013665659.1',
#  'gene-LOC106462897': 'NW_013665659.1',
#  'gene-LOC106462906': 'NW_013665659.1',
#  'gene-LOC106462960': 'NW_013665659.1',
#  'gene-LOC106462916': 'NW_013665659.1',
#  'gene-LOC106462978': 'NW_013665659.1',
#  'gene-LOC106462989': 'NW_013665660.1',
#  'gene-LOC106463001': 'NW_013665660.1',
#  'gene-LOC106463097': 'NW_013665660.1',
#  'gene-LOC106463011': 'NW_013665660.1',
#  'gene-LOC106463113': 'NW_013665660.1',
#  'gene-LOC106463020': 'NW_013665660.1',
#  'gene-LOC106463052': 'NW_013665660.1',
#  'gene-LOC106463031': 'NW_013665660.1',
#  'gene-LOC106463128': 'NW_013665660.1',
#  'gene-LOC106463064': 'NW_013665660.1',
#  'gene-LOC106463042': 'NW_013665660.1',
#  'gene-LOC106463073': 'NW_013665660.1',
#  'gene-LOC106463086': 'NW_013665660.1',
#  'gene-LOC106463155': 'NW_013665661.1',
#  'gene-LOC106463163': 'NW_013665661.1',
#  'gene-LOC106463219': 'NW_013665661.1',
#  'gene-LOC106463228': 'NW_013665661.1',
#  'gene-LOC111086756': 'NW_013665661.1',
#  'gene-LOC106463237': 'NW_013665661.1',
#  'gene-LOC106463176': 'NW_013665661.1',
#  'gene-LOC111086764': 'NW_013665661.1',
#  'gene-LOC111086768': 'NW_013665661.1',
#  'gene-LOC111086789': 'NW_013665661.1',
#  'gene-LOC106463273': 'NW_013665661.1',
#  'gene-LOC106463263': 'NW_013665661.1',
#  'gene-LOC106463246': 'NW_013665661.1',
#  'gene-LOC106463188': 'NW_013665661.1',
#  'gene-LOC111086781': 'NW_013665661.1',
#  'gene-LOC106463207': 'NW_013665661.1',
#  'gene-LOC111086795': 'NW_013665662.1',
#  'gene-LOC106463290': 'NW_013665662.1',
#  'gene-LOC106463300': 'NW_013665662.1',
#  'gene-LOC106463311': 'NW_013665662.1',
#  'gene-LOC106463383': 'NW_013665662.1',
#  'gene-LOC106463322': 'NW_013665662.1',
#  'gene-LOC106463331': 'NW_013665662.1',
#  'gene-LOC106463401': 'NW_013665662.1',
#  'gene-LOC106463340': 'NW_013665662.1',
#  'gene-LOC106463417': 'NW_013665662.1',
#  'gene-LOC106463350': 'NW_013665662.1',
#  'gene-LOC106463361': 'NW_013665662.1',
#  'gene-LOC106463372': 'NW_013665662.1',
#  'gene-LOC106463440': 'NW_013665663.1',
#  'gene-LOC106463459': 'NW_013665663.1',
#  'gene-LOC106463468': 'NW_013665663.1',
#  'gene-LOC106463545': 'NW_013665663.1',
#  'gene-LOC106463515': 'NW_013665663.1',
#  'gene-LOC106463523': 'NW_013665663.1',
#  'gene-LOC106463475': 'NW_013665663.1',
#  'gene-LOC106463485': 'NW_013665663.1',
#  'gene-LOC106463536': 'NW_013665663.1',
#  'gene-LOC111086856': 'NW_013665663.1',
#  'gene-LOC106463495': 'NW_013665663.1',
#  'gene-LOC111086849': 'NW_013665663.1',
#  'gene-LOC106463504': 'NW_013665663.1',
#  'gene-LOC106463553': 'NW_013665664.1',
#  'gene-LOC106463564': 'NW_013665664.1',
#  'gene-LOC106463575': 'NW_013665664.1',
#  'gene-LOC106463586': 'NW_013665664.1',
#  'gene-LOC106463664': 'NW_013665664.1',
#  'gene-LOC106463603': 'NW_013665664.1',
#  'gene-LOC106463614': 'NW_013665664.1',
#  'gene-LOC106463626': 'NW_013665664.1',
#  'gene-LOC106463636': 'NW_013665664.1',
#  'gene-LOC106463646': 'NW_013665664.1',
#  'gene-LOC106463673': 'NW_013665664.1',
#  'gene-LOC106463682': 'NW_013665664.1',
#  'gene-LOC106463654': 'NW_013665664.1',
#  'gene-LOC111086892': 'NW_013665664.1',
#  'gene-LOC111086881': 'NW_013665664.1',
#  'gene-LOC106463777': 'NW_013665665.1',
#  'gene-LOC106463698': 'NW_013665665.1',
#  'gene-LOC106463706': 'NW_013665665.1',
#  'gene-LOC106463830': 'NW_013665665.1',
#  'gene-LOC106463717': 'NW_013665665.1',
#  'gene-LOC106463794': 'NW_013665665.1',
#  'gene-LOC111086925': 'NW_013665665.1',
#  'gene-LOC106463748': 'NW_013665665.1',
#  'gene-LOC106463803': 'NW_013665665.1',
#  'gene-LOC106463757': 'NW_013665665.1',
#  'gene-LOC106463840': 'NW_013665665.1',
#  'gene-LOC106463767': 'NW_013665665.1',
#  'gene-LOC106463824': 'NW_013665665.1',
#  'gene-LOC106463849': 'NW_013665666.1',
#  'gene-LOC106463930': 'NW_013665666.1',
#  'gene-LOC106463859': 'NW_013665666.1',
#  'gene-LOC106463870': 'NW_013665666.1',
#  'gene-LOC111086932': 'NW_013665666.1',
#  'gene-LOC106463960': 'NW_013665666.1',
#  'gene-LOC106463880': 'NW_013665666.1',
#  'gene-LOC106463891': 'NW_013665666.1',
#  'gene-LOC106463966': 'NW_013665666.1',
#  'gene-LOC106463975': 'NW_013665666.1',
#  'gene-LOC106463903': 'NW_013665666.1',
#  'gene-LOC106463912': 'NW_013665666.1',
#  'gene-LOC106463920': 'NW_013665666.1',
#  'gene-LOC111086960': 'NW_013665666.1',
#  'gene-LOC106464053': 'NW_013665667.1',
#  'gene-LOC106464062': 'NW_013665667.1',
#  'gene-LOC106463992': 'NW_013665667.1',
#  'gene-LOC106464123': 'NW_013665667.1',
#  'gene-LOC106464073': 'NW_013665667.1',
#  'gene-LOC106464083': 'NW_013665667.1',
#  'gene-LOC106464150': 'NW_013665667.1',
#  'gene-LOC106464003': 'NW_013665667.1',
#  'gene-LOC106464095': 'NW_013665667.1',
#  'gene-LOC106464013': 'NW_013665667.1',
#  'gene-LOC106464023': 'NW_013665667.1',
#  'gene-LOC106464032': 'NW_013665667.1',
#  'gene-LOC106464113': 'NW_013665667.1',
#  'gene-LOC106464042': 'NW_013665667.1',
#  'gene-LOC106464182': 'NW_013665668.1',
#  'gene-LOC106464197': 'NW_013665668.1',
#  'gene-LOC106464227': 'NW_013665668.1',
#  'gene-LOC111087037': 'NW_013665668.1',
#  'gene-LOC106464238': 'NW_013665668.1',
#  'gene-LOC106464207': 'NW_013665668.1',
#  'gene-LOC106464249': 'NW_013665668.1',
#  'gene-LOC106464269': 'NW_013665668.1',
#  'gene-LOC106464217': 'NW_013665668.1',
#  ...}

# %% [markdown]
# ### Function to retrieve CNEs within distance windows

# %%
def find_nearby_cnes(cds_coords_dict, species_id, dist_threshold_list, gene_scaff_dict):
    # Create dict to hold results
    distances_to_cnes = {}
    for threshold in dist_threshold_list:
        distances_to_cnes[threshold] = {}
    # Read CNE coordinates
    cne_coords = pd.read_csv(coord_dir + species_id + '_orig_coords.tsv', sep="\t")
    print("Find nearby CNEs")
    # Loop through each gene
    for cds_name, cds_coord in cds_coords_dict.items():
        # Retrieve gene scaffold, ID, and coordinates
        for threshold in dist_threshold_list:
            distances_to_cnes [threshold][cds_name] = []
        scaffold = gene_scaff_dict[cds_name]
        cds_start = cds_coord[0]
        cds_end = cds_coord[1]
        # Set dist_to_cne variable to check for closer CNEs. Start with absurdly high value
        # Check if scaffold contains CNEs and if yes retrieve them
        if scaffold in list(cne_coords['scaffold']):
            cnes_on_scaff_df = cne_coords[cne_coords['scaffold'] == scaffold]
            for idx, cne in cnes_on_scaff_df.iterrows():
                # Calculate distance between each CNE on scaffold and current gene
                cne_start = cne['orig_start']
                cne_end = cne['orig_end']
                distance = seq_dist(cne_start,cne_end, cds_start, cds_end)
                # Retrieve CNE if within distance threshold
                for threshold in dist_threshold_list:
                    if distance < threshold:
                        distances_to_cnes[threshold][cds_name].append(cne['cne_id'])
    return(distances_to_cnes)

# %% [markdown]
# ### Retrieve nearby CNEs for each gene and distance threshold + calculate stats

# %%
df = pd.DataFrame(columns=['species', 'distance_threshold', 'mean_nearby_cnes', 'min_nearby_cnes', 'max_nearby_cnes'])
all_species_nearby_cnes = {}
for species in species_list:
    print("species:" , species)    
    cds_coords, gene_scaff_dict = parse_cds(species)
    nearby_cnes = find_nearby_cnes(cds_coords, species, dist_threshold_list, gene_scaff_dict)
    all_species_nearby_cnes[species] = nearby_cnes
    for threshold, dist_dict in nearby_cnes.items():
        cne_counts = []
        mean_nearby_cnes = 0
        min_nearby_cnes = 0
        max_cne_counts = 0
        print("distance threshold: ", threshold)
        for gene, cne_list in dist_dict.items():
            cne_count = len(cne_list)
            cne_counts.append(cne_count)
        if len(cne_counts)>0:
            mean_nearby_cnes = round(mean(cne_counts), 2)
            min_nearby_cnes = min(cne_counts)
            max_cne_counts = max(cne_counts)
        row = [species, threshold, mean_nearby_cnes, min_nearby_cnes, max_cne_counts]
        df.loc[len(df), :] = row
        print(row)
# Write stats to file
df.to_csv("all_species_nearby_cnes.tsv", sep="\t", index=False)
# Out:
# species: apis
# Find nearby CNEs
# distance threshold:  10000
# ['apis', 10000, 0.04, 0, 4]
# distance threshold:  25000
# ['apis', 25000, 0.08, 0, 4]
# distance threshold:  50000
# ['apis', 50000, 0.14, 0, 4]
# distance threshold:  75000
# ['apis', 75000, 0.2, 0, 4]
# distance threshold:  100000
# ['apis', 100000, 0.26, 0, 5]
# distance threshold:  200000
# ['apis', 200000, 0.5, 0, 7]
# distance threshold:  300000
# ['apis', 300000, 0.74, 0, 8]
# distance threshold:  400000
# ['apis', 400000, 0.96, 0, 11]
# distance threshold:  500000
# ['apis', 500000, 1.18, 0, 14]
# species: aaeg
# Find nearby CNEs
# distance threshold:  10000
# ['aaeg', 10000, 0.05, 0, 14]
# distance threshold:  25000
# ['aaeg', 25000, 0.07, 0, 14]
# distance threshold:  50000
# ['aaeg', 50000, 0.11, 0, 14]
# distance threshold:  75000
# ['aaeg', 75000, 0.16, 0, 14]
# distance threshold:  100000
# ['aaeg', 100000, 0.2, 0, 14]
# distance threshold:  200000
# ['aaeg', 200000, 0.37, 0, 16]
# distance threshold:  300000
# ['aaeg', 300000, 0.54, 0, 18]
# distance threshold:  400000
# ['aaeg', 400000, 0.71, 0, 25]
# distance threshold:  500000
# ['aaeg', 500000, 0.86, 0, 25]
# species: aamp
# Find nearby CNEs
# distance threshold:  10000
# ['aamp', 10000, 0.06, 0, 13]
# distance threshold:  25000
# ['aamp', 25000, 0.13, 0, 13]
# distance threshold:  50000
# ['aamp', 50000, 0.23, 0, 13]
# distance threshold:  75000
# ['aamp', 75000, 0.32, 0, 13]
# distance threshold:  100000
# ['aamp', 100000, 0.4, 0, 13]
# distance threshold:  200000
# ['aamp', 200000, 0.65, 0, 14]
# distance threshold:  300000
# ['aamp', 300000, 0.85, 0, 14]
# distance threshold:  400000
# ['aamp', 400000, 0.98, 0, 14]
# distance threshold:  500000
# ['aamp', 500000, 1.07, 0, 14]
# species: amel
# Find nearby CNEs
# distance threshold:  10000
# ['amel', 10000, 1.64, 0, 325]
# distance threshold:  25000
# ['amel', 25000, 3.15, 0, 341]
# distance threshold:  50000
# ['amel', 50000, 6.19, 0, 350]
# distance threshold:  75000
# ['amel', 75000, 9.6, 0, 350]
# distance threshold:  100000
# ['amel', 100000, 13.23, 0, 351]
# distance threshold:  200000
# ['amel', 200000, 29.29, 0, 356]
# distance threshold:  300000
# ['amel', 300000, 46.41, 0, 406]
# distance threshold:  400000
# ['amel', 400000, 63.4, 0, 435]
# distance threshold:  500000
# ['amel', 500000, 80.94, 0, 474]
# species: alic
# Find nearby CNEs
# distance threshold:  10000
# ['alic', 10000, 0.07, 0, 14]
# distance threshold:  25000
# ['alic', 25000, 0.12, 0, 14]
# distance threshold:  50000
# ['alic', 50000, 0.21, 0, 14]
# distance threshold:  75000
# ['alic', 75000, 0.3, 0, 14]
# distance threshold:  100000
# ['alic', 100000, 0.39, 0, 14]
# distance threshold:  200000
# ['alic', 200000, 0.72, 0, 15]
# distance threshold:  300000
# ['alic', 300000, 1.06, 0, 17]
# distance threshold:  400000
# ['alic', 400000, 1.39, 0, 17]
# distance threshold:  500000
# ['alic', 500000, 1.72, 0, 18]
# species: anas
# Find nearby CNEs
# distance threshold:  10000
# ['anas', 10000, 0.08, 0, 15]
# distance threshold:  25000
# ['anas', 25000, 0.14, 0, 15]
# distance threshold:  50000
# ['anas', 50000, 0.23, 0, 17]
# distance threshold:  75000
# ['anas', 75000, 0.28, 0, 19]
# distance threshold:  100000
# ['anas', 100000, 0.33, 0, 19]
# distance threshold:  200000
# ['anas', 200000, 0.42, 0, 19]
# distance threshold:  300000
# ['anas', 300000, 0.45, 0, 19]
# distance threshold:  400000
# ['anas', 400000, 0.46, 0, 19]
# distance threshold:  500000
# ['anas', 500000, 0.47, 0, 19]
# species: cscu
# Find nearby CNEs
# distance threshold:  10000
# ['cscu', 10000, 0.74, 0, 33]
# distance threshold:  25000
# ['cscu', 25000, 1.26, 0, 33]
# distance threshold:  50000
# ['cscu', 50000, 2.07, 0, 35]
# distance threshold:  75000
# ['cscu', 75000, 2.81, 0, 35]
# distance threshold:  100000
# ['cscu', 100000, 3.49, 0, 37]
# distance threshold:  200000
# ['cscu', 200000, 5.67, 0, 41]
# distance threshold:  300000
# ['cscu', 300000, 7.29, 0, 46]
# distance threshold:  400000
# ['cscu', 400000, 8.48, 0, 48]
# distance threshold:  500000
# ['cscu', 500000, 9.36, 0, 54]
# species: cdip
# Find nearby CNEs
# distance threshold:  10000
# ['cdip', 10000, 0.01, 0, 2]
# distance threshold:  25000
# ['cdip', 25000, 0.02, 0, 3]
# distance threshold:  50000
# ['cdip', 50000, 0.03, 0, 3]
# distance threshold:  75000
# ['cdip', 75000, 0.05, 0, 3]
# distance threshold:  100000
# ['cdip', 100000, 0.06, 0, 3]
# distance threshold:  200000
# ['cdip', 200000, 0.12, 0, 3]
# distance threshold:  300000
# ['cdip', 300000, 0.15, 0, 3]
# distance threshold:  400000
# ['cdip', 400000, 0.18, 0, 3]
# distance threshold:  500000
# ['cdip', 500000, 0.2, 0, 3]
# species: csec
# Find nearby CNEs
# distance threshold:  10000
# ['csec', 10000, 0.15, 0, 10]
# distance threshold:  25000
# ['csec', 25000, 0.22, 0, 10]
# distance threshold:  50000
# ['csec', 50000, 0.34, 0, 10]
# distance threshold:  75000
# ['csec', 75000, 0.45, 0, 12]
# distance threshold:  100000
# ['csec', 100000, 0.54, 0, 12]
# distance threshold:  200000
# ['csec', 200000, 0.87, 0, 13]
# distance threshold:  300000
# ['csec', 300000, 1.14, 0, 14]
# distance threshold:  400000
# ['csec', 400000, 1.35, 0, 15]
# distance threshold:  500000
# ['csec', 500000, 1.53, 0, 16]
# species: cfel
# Find nearby CNEs
# distance threshold:  10000
# ['cfel', 10000, 0.19, 0, 15]
# distance threshold:  25000
# ['cfel', 25000, 0.35, 0, 16]
# distance threshold:  50000
# ['cfel', 50000, 0.59, 0, 31]
# distance threshold:  75000
# ['cfel', 75000, 0.82, 0, 64]
# distance threshold:  100000
# ['cfel', 100000, 1.04, 0, 64]
# distance threshold:  200000
# ['cfel', 200000, 1.95, 0, 71]
# distance threshold:  300000
# ['cfel', 300000, 2.82, 0, 73]
# distance threshold:  400000
# ['cfel', 400000, 3.69, 0, 75]
# distance threshold:  500000
# ['cfel', 500000, 4.54, 0, 75]
# species: dmel
# Find nearby CNEs
# distance threshold:  10000
# ['dmel', 10000, 0.01, 0, 2]
# distance threshold:  25000
# ['dmel', 25000, 0.03, 0, 2]
# distance threshold:  50000
# ['dmel', 50000, 0.07, 0, 3]
# distance threshold:  75000
# ['dmel', 75000, 0.1, 0, 3]
# distance threshold:  100000
# ['dmel', 100000, 0.14, 0, 4]
# distance threshold:  200000
# ['dmel', 200000, 0.29, 0, 4]
# distance threshold:  300000
# ['dmel', 300000, 0.44, 0, 6]
# distance threshold:  400000
# ['dmel', 400000, 0.6, 0, 7]
# distance threshold:  500000
# ['dmel', 500000, 0.75, 0, 7]
# species: eaff
# Find nearby CNEs
# distance threshold:  10000
# ['eaff', 10000, 0.09, 0, 7]
# distance threshold:  25000
# ['eaff', 25000, 0.18, 0, 8]
# distance threshold:  50000
# ['eaff', 50000, 0.3, 0, 8]
# distance threshold:  75000
# ['eaff', 75000, 0.41, 0, 8]
# distance threshold:  100000
# ['eaff', 100000, 0.5, 0, 8]
# distance threshold:  200000
# ['eaff', 200000, 0.75, 0, 8]
# distance threshold:  300000
# ['eaff', 300000, 0.88, 0, 8]
# distance threshold:  400000
# ['eaff', 400000, 0.95, 0, 8]
# distance threshold:  500000
# ['eaff', 500000, 0.99, 0, 8]
# species: gocc
# Find nearby CNEs
# distance threshold:  10000
# ['gocc', 10000, 0.01, 0, 2]
# distance threshold:  25000
# ['gocc', 25000, 0.04, 0, 2]
# distance threshold:  50000
# ['gocc', 50000, 0.06, 0, 2]
# distance threshold:  75000
# ['gocc', 75000, 0.08, 0, 2]
# distance threshold:  100000
# ['gocc', 100000, 0.1, 0, 2]
# distance threshold:  200000
# ['gocc', 200000, 0.17, 0, 4]
# distance threshold:  300000
# ['gocc', 300000, 0.23, 0, 4]
# distance threshold:  400000
# ['gocc', 400000, 0.29, 0, 5]
# distance threshold:  500000
# ['gocc', 500000, 0.33, 0, 5]
# species: hazt
# Find nearby CNEs
# distance threshold:  10000
# ['hazt', 10000, 0.06, 0, 6]
# distance threshold:  25000
# ['hazt', 25000, 0.13, 0, 15]
# distance threshold:  50000
# ['hazt', 50000, 0.24, 0, 19]
# distance threshold:  75000
# ['hazt', 75000, 0.34, 0, 19]
# distance threshold:  100000
# ['hazt', 100000, 0.42, 0, 19]
# distance threshold:  200000
# ['hazt', 200000, 0.64, 0, 20]
# distance threshold:  300000
# ['hazt', 300000, 0.77, 0, 20]
# distance threshold:  400000
# ['hazt', 400000, 0.85, 0, 20]
# distance threshold:  500000
# ['hazt', 500000, 0.9, 0, 20]
# species: lpol
# Find nearby CNEs
# distance threshold:  10000
# ['lpol', 10000, 0.02, 0, 4]
# distance threshold:  25000
# ['lpol', 25000, 0.04, 0, 6]
# distance threshold:  50000
# ['lpol', 50000, 0.05, 0, 6]
# distance threshold:  75000
# ['lpol', 75000, 0.07, 0, 6]
# distance threshold:  100000
# ['lpol', 100000, 0.08, 0, 6]
# distance threshold:  200000
# ['lpol', 200000, 0.12, 0, 7]
# distance threshold:  300000
# ['lpol', 300000, 0.14, 0, 7]
# distance threshold:  400000
# ['lpol', 400000, 0.16, 0, 7]
# distance threshold:  500000
# ['lpol', 500000, 0.17, 0, 7]
# species: ahyp
# Find nearby CNEs
# distance threshold:  10000
# ['ahyp', 10000, 0.08, 0, 10]
# distance threshold:  25000
# ['ahyp', 25000, 0.16, 0, 10]
# distance threshold:  50000
# ['ahyp', 50000, 0.29, 0, 14]
# distance threshold:  75000
# ['ahyp', 75000, 0.42, 0, 15]
# distance threshold:  100000
# ['ahyp', 100000, 0.54, 0, 17]
# distance threshold:  200000
# ['ahyp', 200000, 0.99, 0, 20]
# distance threshold:  300000
# ['ahyp', 300000, 1.42, 0, 20]
# distance threshold:  400000
# ['ahyp', 400000, 1.85, 0, 21]
# distance threshold:  500000
# ['ahyp', 500000, 2.27, 0, 21]
# species: obir
# Find nearby CNEs
# distance threshold:  10000
# ['obir', 10000, 1.27, 0, 251]
# distance threshold:  25000
# ['obir', 25000, 2.58, 0, 260]
# distance threshold:  50000
# ['obir', 50000, 5.23, 0, 280]
# distance threshold:  75000
# ['obir', 75000, 8.28, 0, 304]
# distance threshold:  100000
# ['obir', 100000, 11.6, 0, 313]
# distance threshold:  200000
# ['obir', 200000, 26.58, 0, 353]
# distance threshold:  300000
# ['obir', 300000, 42.28, 0, 408]
# distance threshold:  400000
# ['obir', 400000, 58.7, 0, 439]
# distance threshold:  500000
# ['obir', 500000, 75.44, 0, 515]
# species: phum
# Find nearby CNEs
# distance threshold:  10000
# ['phum', 10000, 0.03, 0, 6]
# distance threshold:  25000
# ['phum', 25000, 0.08, 0, 6]
# distance threshold:  50000
# ['phum', 50000, 0.14, 0, 6]
# distance threshold:  75000
# ['phum', 75000, 0.19, 0, 6]
# distance threshold:  100000
# ['phum', 100000, 0.24, 0, 6]
# distance threshold:  200000
# ['phum', 200000, 0.4, 0, 6]
# distance threshold:  300000
# ['phum', 300000, 0.52, 0, 7]
# distance threshold:  400000
# ['phum', 400000, 0.62, 0, 7]
# distance threshold:  500000
# ['phum', 500000, 0.69, 0, 7]
# species: pvan
# Find nearby CNEs
# distance threshold:  10000
# ['pvan', 10000, 0.15, 0, 35]
# distance threshold:  25000
# ['pvan', 25000, 0.28, 0, 38]
# distance threshold:  50000
# ['pvan', 50000, 0.47, 0, 60]
# distance threshold:  75000
# ['pvan', 75000, 0.66, 0, 81]
# distance threshold:  100000
# ['pvan', 100000, 0.83, 0, 81]
# distance threshold:  200000
# ['pvan', 200000, 1.41, 0, 87]
# distance threshold:  300000
# ['pvan', 300000, 1.87, 0, 87]
# distance threshold:  400000
# ['pvan', 400000, 2.24, 0, 93]
# distance threshold:  500000
# ['pvan', 500000, 2.5, 0, 93]
# species: ptri
# Find nearby CNEs
# distance threshold:  10000
# ['ptri', 10000, 0.11, 0, 20]
# distance threshold:  25000
# ['ptri', 25000, 0.17, 0, 20]
# distance threshold:  50000
# ['ptri', 50000, 0.22, 0, 20]
# distance threshold:  75000
# ['ptri', 75000, 0.24, 0, 20]
# distance threshold:  100000
# ['ptri', 100000, 0.25, 0, 20]
# distance threshold:  200000
# ['ptri', 200000, 0.26, 0, 20]
# distance threshold:  300000
# ['ptri', 300000, 0.26, 0, 20]
# distance threshold:  400000
# ['ptri', 400000, 0.26, 0, 20]
# distance threshold:  500000
# ['ptri', 500000, 0.26, 0, 20]
# species: smim
# Find nearby CNEs
# distance threshold:  10000
# ['smim', 10000, 0.48, 0, 17]
# distance threshold:  25000
# ['smim', 25000, 0.79, 0, 33]
# distance threshold:  50000
# ['smim', 50000, 1.24, 0, 34]
# distance threshold:  75000
# ['smim', 75000, 1.64, 0, 34]
# distance threshold:  100000
# ['smim', 100000, 2.0, 0, 34]
# distance threshold:  200000
# ['smim', 200000, 3.09, 0, 37]
# distance threshold:  300000
# ['smim', 300000, 3.84, 0, 38]
# distance threshold:  400000
# ['smim', 400000, 4.33, 0, 38]
# distance threshold:  500000
# ['smim', 500000, 4.68, 0, 38]
# species: smar
# Find nearby CNEs
# distance threshold:  10000
# ['smar', 10000, 0.18, 0, 5]
# distance threshold:  25000
# ['smar', 25000, 0.39, 0, 5]
# distance threshold:  50000
# ['smar', 50000, 0.67, 0, 8]
# distance threshold:  75000
# ['smar', 75000, 0.92, 0, 11]
# distance threshold:  100000
# ['smar', 100000, 1.13, 0, 11]
# distance threshold:  200000
# ['smar', 200000, 1.71, 0, 13]
# distance threshold:  300000
# ['smar', 300000, 2.07, 0, 15]
# distance threshold:  400000
# ['smar', 400000, 2.33, 0, 15]
# distance threshold:  500000
# ['smar', 500000, 2.49, 0, 15]
# species: tpal
# Find nearby CNEs
# distance threshold:  10000
# ['tpal', 10000, 0.04, 0, 5]
# distance threshold:  25000
# ['tpal', 25000, 0.09, 0, 14]
# distance threshold:  50000
# ['tpal', 50000, 0.18, 0, 21]
# distance threshold:  75000
# ['tpal', 75000, 0.26, 0, 26]
# distance threshold:  100000
# ['tpal', 100000, 0.34, 0, 28]
# distance threshold:  200000
# ['tpal', 200000, 0.68, 0, 36]
# distance threshold:  300000
# ['tpal', 300000, 1.01, 0, 37]
# distance threshold:  400000
# ['tpal', 400000, 1.35, 0, 38]
# distance threshold:  500000
# ['tpal', 500000, 1.67, 0, 38]
# species: tcas
# Find nearby CNEs
# distance threshold:  10000
# ['tcas', 10000, 0.07, 0, 7]
# distance threshold:  25000
# ['tcas', 25000, 0.15, 0, 8]
# distance threshold:  50000
# ['tcas', 50000, 0.28, 0, 8]
# distance threshold:  75000
# ['tcas', 75000, 0.42, 0, 8]
# distance threshold:  100000
# ['tcas', 100000, 0.55, 0, 9]
# distance threshold:  200000
# ['tcas', 200000, 1.12, 0, 10]
# distance threshold:  300000
# ['tcas', 300000, 1.69, 0, 11]
# distance threshold:  400000
# ['tcas', 400000, 2.25, 0, 11]
# distance threshold:  500000
# ['tcas', 500000, 2.83, 0, 12]

# %%
### Write dictionary of gene-nearby CNEs to file

# %%
with open('all_species_nearby_cnes.pickle', 'wb') as handle:
    pickle.dump(all_species_nearby_cnes, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
#with open('all_species_nearby_cnes.pickle', 'rb') as handle:
#    all_species_nearby_cnes = pickle.load(handle)

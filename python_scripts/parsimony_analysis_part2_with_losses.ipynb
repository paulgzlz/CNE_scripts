# %% [markdown]
# ### Goal
#
# Analyze the output of pastml to identify:
# - convergent clusters: CNE state = 1 (present) only at tips (species). CNE state = 0 (absent) at all nodes of the tree.
# - True conserved elements + potential convergence: CNE state = 1 at some node(s) but 0 at the common ancestor of all species that possess the CNE.
# - True conserved elements: CNE state = 1 at some common ancestor of all species that possess the CNE.
#
# ### Input
#
# - pastml_output_dict.txt : output of parsimony_analysis_part1.py
# - phylogenetic tree represented as dictionary of parent-child relationships
#
# ### Output
#
# - convergent_clusters.pickle : dictionary of convergent clusters
# - cluster_lcas.pickle : dictionary of last ocmmon ancestor of each cluster

# %%
from pastml.acr import pastml_pipeline
import csv
import itertools
import pandas as pd
import sys
import pickle
import ast
from collections import Counter
import csv
from collections import defaultdict

# %% [markdown]
# #### Read dictionary

# %%
with open("pastml_output_dict.txt", "r") as data:
    dictionary = ast.literal_eval(data.read())

# %% [markdown]
# #### Pickle dictionary

# %%
with open('pastml_output_dict.pickle', 'wb') as handle:
    pickle.dump(dictionary, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %% [markdown]
# #### Retrieve pickled dictionary

# %%
#with open('pastml_output_dict.pickle', 'rb') as handle:
#    dictionary = pickle.load(handle)

# %% [markdown]
# #### Species list

# %%
species_list = ['dgig',
                'ofav',
                'pdam',
                'spis',
                'adig', 
                'nvec',
                'epal',
                'aten', 
                'mvir',
                'aaur', 
                'chem',
                'hvul',
                'hsym'                                                                                       
               ]

# %% [markdown]
# #### Dictionary of parent-child relationships ("tree")
#
# All species and nodes must be represented

# %%
tax_dict = {
    'aaur': 'acraspeda',
    'adig': 'scleractinia',
    'aten': 'enthemonae',
    'chem': 'leptothecata',
    'dgig': 'anthozoa',
    'epal': 'enthemonae',
    'hsym': 'leptothecata',
    'hvul': 'hydrozoa',
    'mvir': 'acraspeda',
    'nvec': 'actiniaria',
    'ofav': 'robusta',
    'pdam': 'pocilloporidae',
    'spis': 'pocilloporidae',
    'pocilloporidae': 'robusta',
    'robusta': 'scleractinia',
    'scleractinia': 'hexacorallia',
    'enthemonae': 'actiniaria',
    'actiniaria': 'hexacorallia',
    'hexacorallia': 'anthozoa',
    'anthozoa': 'cnidaria',
    'hydractinia': 'anthoathecata',
    'leptothecata': 'hydrozoa',
    'hydrozoa': 'medusozoa',
    'acraspeda': 'medusozoa',
    'medusozoa': 'cnidaria'
}

# %% [markdown]
# #### Parse character state dictionary

# %%
cluster_nodes = {}
for node_dict in dictionary['nodes']:
    for a, b in node_dict.items():
        #print(b)
        #if isinstance(b, type(dict)): #and 'node_name' in b:
        if 'node_name' in b:
            node_name = b['node_name']
            cluster_states = b['tooltip'].split("<br>")
            for cluster in cluster_states:
                cluster_id = cluster.split(":")[0]
                state = cluster.split(":")[1].replace(" ", "")
                if cluster_id in cluster_nodes:
                    cluster_nodes[cluster_id][node_name] = state
                else:
                    cluster_nodes[cluster_id] = {}
                    cluster_nodes[cluster_id][node_name] = state
#cluster_nodes

# %%
cluster_nodes['cluster_10']
# Out:
# {'aaur': '0',
#  'acraspeda': '0',
#  'actiniaria': '0',
#  'adig': '1',
#  'anthozoa': '0',
#  'aten': '0',
#  'chem': '0',
#  'cnidaria': '0',
#  'dgig': '0',
#  'enthemonae': '0',
#  'epal': '0',
#  'hexacorallia': '0',
#  'hsym': '0',
#  'hvul': '0',
#  'hydrozoa': '0',
#  'leptothecata': '0',
#  'medusozoa': '0',
#  'mvir': '0',
#  'nvec': '0',
#  'ofav': '0',
#  'pdam': '1',
#  'pocilloporidae': '1',
#  'robusta': '0or1',
#  'scleractinia': '0or1',
#  'spis': '1'}

# %% [markdown]
# #### Retrieve clusters where state is 0 for all nodes (only 1 at the tips)

# %%
convergent_clusters = [] # clusters where CNEs appear only at the tips
conserved_clusters = [] # clusters that appear at some deeper node
conserved_clust_nodes = {} # {cluster1:{species:[species_a, species_b, etc.], nodes:[node_x, node_y]}, cluster_2...}
conserved_clust_species = {}
for cluster, node_states in cluster_nodes.items():
    #print(cluster)
    node_count = 0
    for node, state in node_states.items():
        #print("node:",node, "state:", state)
        if node not in species_list and (state == '1' or state == '0or1'):
            node_count+=1
            conserved_clust_nodes.setdefault(cluster, []).append(node)   # [cluster][nodes].append(node)
        if node in species_list and state == '1':
            conserved_clust_species.setdefault(cluster, []).append(node) 
    if node_count == 0:
        convergent_clusters.append(cluster)
    else:
        conserved_clusters.append(cluster)

# %%
conserved_clust_nodes # nodes for which cluster state is 1 or '0 or 1'
# Out:
# {'cluster_1': ['cnidaria',
#   'anthozoa',
#   'medusozoa',
#   'hexacorallia',
#   'acraspeda',
#   'hydrozoa',
#   'scleractinia',
#   'actiniaria',
#   'leptothecata',
#   'robusta',
#   'enthemonae',
#   'pocilloporidae'],
#  'cluster_10': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_100': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_1000': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10000': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10001': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10002': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10003': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10004': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10005': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10006': ['hexacorallia', 'scleractinia', 'robusta', 'enthemonae'],
#  'cluster_10007': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10008': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10009': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1001': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10010': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10011': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10012': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10013': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10014': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10015': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10016': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10017': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10018': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10019': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1002': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10020': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10021': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10022': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10023': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10024': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10025': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10026': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10027': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10028': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10029': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1003': ['hexacorallia',
#   'scleractinia',
#   'actiniaria',
#   'robusta',
#   'enthemonae',
#   'pocilloporidae'],
#  'cluster_10030': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10031': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10032': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10033': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10034': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10035': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10036': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10037': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10038': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10039': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_1004': ['hexacorallia', 'scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10040': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10041': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10042': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10043': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10044': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10045': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10046': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10047': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10048': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10049': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1005': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10050': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10051': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10052': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10053': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10054': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10055': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10056': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10057': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10058': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10059': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1006': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'enthemonae',
#   'pocilloporidae'],
#  'cluster_10060': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10061': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10062': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10063': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10064': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10065': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10066': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10067': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10068': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10069': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1007': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10070': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10071': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10072': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10073': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10074': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10075': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10076': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10077': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10078': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10079': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_1008': ['hexacorallia', 'scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10080': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10081': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10082': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10083': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10084': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10085': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10086': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10087': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10088': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10089': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10090': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10091': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10092': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10093': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10094': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10095': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10096': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10097': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10098': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10099': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_101': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_1010': ['cnidaria',
#   'anthozoa',
#   'medusozoa',
#   'hexacorallia',
#   'hydrozoa',
#   'scleractinia',
#   'actiniaria',
#   'robusta',
#   'enthemonae',
#   'pocilloporidae'],
#  'cluster_10100': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10101': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10102': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10103': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10104': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10105': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10106': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10107': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10108': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10109': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1011': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10110': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10111': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10112': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10113': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10114': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10115': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10116': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10117': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10118': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10119': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1012': ['hexacorallia',
#   'scleractinia',
#   'actiniaria',
#   'robusta',
#   'enthemonae',
#   'pocilloporidae'],
#  'cluster_10120': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10121': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10122': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10123': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10124': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10125': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10126': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10127': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10128': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10129': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10130': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10131': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10132': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10133': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10134': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10135': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10136': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10137': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10138': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10139': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10140': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10141': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10142': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10143': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10144': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10145': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10146': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10147': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10148': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10149': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1015': ['cnidaria',
#   'anthozoa',
#   'hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10150': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10151': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10152': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10153': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10154': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10155': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10156': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10157': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10158': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10159': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1016': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10160': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10161': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10162': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10163': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10164': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10165': ['hexacorallia',
#   'scleractinia',
#   'actiniaria',
#   'robusta',
#   'enthemonae',
#   'pocilloporidae'],
#  'cluster_10166': ['cnidaria',
#   'anthozoa',
#   'hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10167': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10168': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10169': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1017': ['cnidaria',
#   'anthozoa',
#   'medusozoa',
#   'hexacorallia',
#   'acraspeda',
#   'scleractinia',
#   'actiniaria',
#   'robusta',
#   'enthemonae',
#   'pocilloporidae'],
#  'cluster_10170': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10171': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10172': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10173': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10174': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10175': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10176': ['hexacorallia',
#   'scleractinia',
#   'actiniaria',
#   'robusta',
#   'enthemonae',
#   'pocilloporidae'],
#  'cluster_10177': ['hexacorallia',
#   'scleractinia',
#   'actiniaria',
#   'robusta',
#   'enthemonae',
#   'pocilloporidae'],
#  'cluster_10178': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10179': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10180': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10181': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10182': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10183': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10184': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10185': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10186': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10187': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10188': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10189': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1019': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10190': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10191': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10192': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10193': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10194': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10195': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10196': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10197': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10198': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10199': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_102': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_1020': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'enthemonae',
#   'pocilloporidae'],
#  'cluster_10200': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10201': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10202': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10203': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10204': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10205': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10206': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10207': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10208': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10209': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1021': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10210': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10211': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10212': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10213': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10214': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10215': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10216': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10217': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10218': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10219': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1022': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10220': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10221': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10222': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10223': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10224': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10225': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10226': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10227': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10228': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10229': ['cnidaria',
#   'anthozoa',
#   'hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_1023': ['cnidaria',
#   'anthozoa',
#   'hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10230': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10231': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10232': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10233': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10234': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10235': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10236': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10237': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10238': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10239': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1024': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10240': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10241': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10242': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10243': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10244': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10245': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10246': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10247': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10248': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10249': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10250': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10251': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10252': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10253': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10254': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10255': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10256': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10257': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10258': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10259': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10260': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10261': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10262': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10263': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10264': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10265': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10266': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10267': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10268': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10269': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1027': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10270': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10271': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10272': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10273': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10274': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10275': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10276': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10277': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10278': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10279': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1028': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10280': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10281': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10282': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10283': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10284': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10285': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10286': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10287': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10288': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10289': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1029': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10290': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10291': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10292': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10293': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10294': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10295': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10296': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10297': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10298': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10299': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_103': ['hexacorallia',
#   'acraspeda',
#   'scleractinia',
#   'actiniaria',
#   'robusta',
#   'enthemonae',
#   'pocilloporidae'],
#  'cluster_1030': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10300': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10301': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10302': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10303': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10304': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10305': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10306': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10307': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10308': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10309': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1031': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10310': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10311': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10312': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10313': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10314': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10315': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10316': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10317': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10318': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10319': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_1032': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10320': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10321': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10322': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10323': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10324': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10325': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10326': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10327': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10328': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10329': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1033': ['hexacorallia', 'scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10330': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10331': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10332': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10333': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10334': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10335': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10336': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10337': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10338': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10339': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1034': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10340': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10341': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10342': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10343': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10344': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10345': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10346': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10347': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10348': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10349': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1035': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'enthemonae',
#   'pocilloporidae'],
#  'cluster_10350': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10351': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10352': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10353': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10354': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10355': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10356': ['cnidaria',
#   'anthozoa',
#   'hexacorallia',
#   'scleractinia',
#   'actiniaria',
#   'robusta',
#   'enthemonae',
#   'pocilloporidae'],
#  'cluster_10357': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10358': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10359': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10360': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10361': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10362': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10363': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10364': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10365': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10366': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10367': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10368': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10369': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10370': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10371': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10372': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10373': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10374': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10375': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10376': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10377': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10378': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10379': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_1038': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10380': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10381': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10382': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10383': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10384': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10385': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10386': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10387': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10388': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10389': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1039': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'enthemonae',
#   'pocilloporidae'],
#  'cluster_10390': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10391': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10392': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10393': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10394': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10395': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10396': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10397': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10398': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10399': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_104': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_1040': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10400': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10401': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10402': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10403': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10404': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10405': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10406': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10407': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10408': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10409': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10410': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10411': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10412': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10413': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10414': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10415': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10416': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10417': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10418': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10419': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1042': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10420': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10421': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10422': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10423': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10424': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10425': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10426': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10427': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10428': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10429': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1043': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10430': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10431': ['anthozoa',
#   'hexacorallia',
#   'scleractinia',
#   'actiniaria',
#   'robusta',
#   'enthemonae'],
#  'cluster_10432': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10433': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10434': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10435': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10436': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10437': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10438': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10439': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1044': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10440': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10441': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10442': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10443': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10444': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'enthemonae',
#   'pocilloporidae'],
#  'cluster_10445': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10446': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10447': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10448': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'enthemonae',
#   'pocilloporidae'],
#  'cluster_10449': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_1045': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10450': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10451': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10452': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10453': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10454': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10455': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10456': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10457': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10458': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10459': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10460': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10461': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10462': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10463': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10464': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10465': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10466': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10467': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10468': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10469': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1047': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10470': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10471': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10472': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10473': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10474': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10475': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10476': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10477': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10478': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10479': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10480': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10481': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10482': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10483': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10484': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10485': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10486': ['hexacorallia', 'scleractinia', 'robusta', 'enthemonae'],
#  'cluster_10487': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10488': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10489': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_1049': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10490': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10491': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10492': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10493': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10494': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10495': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10496': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10497': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10498': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10499': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_105': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_1050': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10500': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10501': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10502': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10503': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10504': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10505': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10506': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10507': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10508': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10509': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10510': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10511': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10512': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10513': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10514': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10515': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10516': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10517': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10518': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10519': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10520': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10521': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10522': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10523': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10524': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10525': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10526': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10527': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10528': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10529': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1053': ['cnidaria',
#   'anthozoa',
#   'hexacorallia',
#   'scleractinia',
#   'actiniaria',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10530': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10531': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10532': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10533': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10534': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10535': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10536': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10537': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10538': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10539': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1054': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10540': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10541': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10542': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10543': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10544': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10545': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10546': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10547': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10548': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10549': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_1055': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10550': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10551': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'enthemonae',
#   'pocilloporidae'],
#  'cluster_10552': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10553': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10554': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10555': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10556': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10557': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10558': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10559': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1056': ['hexacorallia', 'scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10560': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10561': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10562': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10563': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10564': ['cnidaria',
#   'anthozoa',
#   'hexacorallia',
#   'scleractinia',
#   'robusta'],
#  'cluster_10565': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10566': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10567': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10568': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10569': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_1057': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10570': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10571': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10572': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10573': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10574': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10575': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10576': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10577': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10578': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10579': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10580': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10581': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10582': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10583': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10584': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10585': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10586': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10587': ['cnidaria',
#   'anthozoa',
#   'hexacorallia',
#   'scleractinia',
#   'robusta'],
#  'cluster_10588': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10589': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10590': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10591': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10592': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10593': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10594': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10595': ['hexacorallia',
#   'scleractinia',
#   'actiniaria',
#   'robusta',
#   'enthemonae',
#   'pocilloporidae'],
#  'cluster_10596': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10597': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10598': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10599': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_106': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_1060': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10600': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10601': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10602': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10603': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10604': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10605': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10606': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10607': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10608': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10609': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_1061': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10610': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10611': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10612': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10613': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10614': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10615': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10616': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10617': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10618': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10619': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10620': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10621': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10622': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10623': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10624': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10625': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10626': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10627': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10628': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10629': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1063': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10630': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10631': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10632': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10633': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10634': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10635': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10636': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10637': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10638': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10639': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1064': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10640': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10641': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10642': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10643': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10644': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10645': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10646': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10647': ['hexacorallia', 'scleractinia', 'robusta'],
# ...
#   'acraspeda',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10700': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10701': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10702': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10703': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10704': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10705': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10706': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10707': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10708': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10709': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1071': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10710': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10711': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10712': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10713': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10714': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10715': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10716': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10717': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10718': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10719': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1072': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10720': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10721': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10722': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10723': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10724': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10725': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10726': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10727': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10728': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10729': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_1073': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10730': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10731': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10732': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10733': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10734': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10735': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10736': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10737': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10738': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10739': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10740': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10741': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10742': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10743': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10744': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10745': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10746': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10747': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10748': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10749': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1075': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10750': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10751': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10752': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10753': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10754': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10755': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10756': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10757': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10758': ['cnidaria',
#   'medusozoa',
#   'hexacorallia',
#   'acraspeda',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10759': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_1076': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10760': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10761': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10762': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10763': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10764': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10765': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10766': ['anthozoa',
#   'hexacorallia',
#   'scleractinia',
#   'actiniaria',
#   'robusta',
#   'enthemonae'],
#  'cluster_10767': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10768': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10769': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10770': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10771': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10772': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10773': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10774': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10775': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10776': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10777': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10778': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10779': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10780': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10781': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10782': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'enthemonae',
#   'pocilloporidae'],
#  'cluster_10783': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10784': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10785': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10786': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10787': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10788': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10789': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10790': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10791': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10792': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10793': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10794': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10795': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10796': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10797': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10798': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10799': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_108': ['hexacorallia',
#   'scleractinia',
#   'actiniaria',
#   'robusta',
#   'enthemonae',
#   'pocilloporidae'],
#  'cluster_1080': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10800': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10801': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10802': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10803': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10804': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10805': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10806': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10807': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10808': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10809': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10810': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10811': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10812': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10813': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10814': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10815': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10816': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10817': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10818': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10819': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1082': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10820': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10821': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10822': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10823': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10824': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10825': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10826': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10827': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10828': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10829': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1083': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10830': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10831': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10832': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10833': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10834': ['hexacorallia', 'scleractinia', 'robusta', 'enthemonae'],
#  'cluster_10835': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10836': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10837': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10838': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10839': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1084': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10840': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10841': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10842': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10843': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10844': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10845': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10846': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10847': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10848': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10849': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10850': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10851': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10852': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10853': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10854': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10855': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10856': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10857': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10858': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10859': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_1086': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10860': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10861': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10862': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10863': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10864': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10865': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10866': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10867': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10868': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10869': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1087': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10870': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10871': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10872': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10873': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10874': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10875': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10876': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10877': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10878': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10879': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10880': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10881': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10882': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10883': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10884': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10885': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'enthemonae',
#   'pocilloporidae'],
#  'cluster_10886': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10887': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10888': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10889': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_1089': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10890': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10891': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10892': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10893': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10894': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10895': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10896': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10897': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10898': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10899': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_109': ['hexacorallia',
#   'scleractinia',
#   'actiniaria',
#   'robusta',
#   'enthemonae',
#   'pocilloporidae'],
#  'cluster_1090': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10900': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10901': ['hexacorallia', 'scleractinia', 'actiniaria', 'robusta'],
#  'cluster_10902': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10903': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10904': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'enthemonae',
#   'pocilloporidae'],
#  'cluster_10905': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10906': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10907': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10908': ['hexacorallia',
#   'scleractinia',
#   'robusta',
#   'pocilloporidae'],
#  'cluster_10909': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10910': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10911': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10912': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10913': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10914': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10915': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10916': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10917': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10918': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_10919': ['hexacorallia', 'scleractinia', 'robusta'],
#  'cluster_1092': ['scleractinia', 'robusta', 'pocilloporidae'],
#  'cluster_10920': ['hexacorallia', 'scleractinia', 'robusta'],
#  ...}

# %%
conserved_clust_nodes['cluster_23']
# Out:
# ['hexacorallia',
#  'acraspeda',
#  'scleractinia',
#  'robusta',
#  'enthemonae',
#  'pocilloporidae']

# %%
conserved_clust_species # species for which state is 1
# Out:
# {'cluster_1': ['dgig',
#   'mvir',
#   'aaur',
#   'hvul',
#   'adig',
#   'nvec',
#   'chem',
#   'ofav',
#   'epal',
#   'aten',
#   'pdam',
#   'spis'],
#  'cluster_10': ['adig', 'pdam', 'spis'],
#  'cluster_100': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_1000': ['adig', 'pdam', 'spis'],
#  'cluster_10000': ['adig', 'ofav', 'spis'],
#  'cluster_10001': ['adig', 'ofav'],
#  'cluster_10002': ['adig', 'ofav'],
#  'cluster_10003': ['adig', 'ofav', 'spis'],
#  'cluster_10004': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10005': ['adig', 'ofav'],
#  'cluster_10006': ['adig', 'ofav', 'epal'],
#  'cluster_10007': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10008': ['adig', 'ofav'],
#  'cluster_10009': ['adig', 'ofav'],
#  'cluster_1001': ['adig', 'pdam', 'spis'],
#  'cluster_10010': ['adig', 'ofav'],
#  'cluster_10011': ['adig', 'ofav'],
#  'cluster_10012': ['adig', 'ofav'],
#  'cluster_10013': ['adig', 'ofav'],
#  'cluster_10014': ['adig', 'ofav'],
#  'cluster_10015': ['adig', 'ofav'],
#  'cluster_10016': ['adig', 'ofav'],
#  'cluster_10017': ['adig', 'ofav'],
#  'cluster_10018': ['adig', 'ofav'],
#  'cluster_10019': ['adig', 'ofav'],
#  'cluster_1002': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10020': ['adig', 'ofav', 'spis'],
#  'cluster_10021': ['adig', 'ofav'],
#  'cluster_10022': ['adig', 'ofav'],
#  'cluster_10023': ['adig', 'ofav'],
#  'cluster_10024': ['adig', 'ofav'],
#  'cluster_10025': ['adig', 'ofav'],
#  'cluster_10026': ['adig', 'ofav'],
#  'cluster_10027': ['adig', 'ofav'],
#  'cluster_10028': ['adig', 'ofav'],
#  'cluster_10029': ['adig', 'ofav'],
#  'cluster_1003': ['adig', 'ofav', 'epal', 'aten', 'pdam', 'spis'],
#  'cluster_10030': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10031': ['adig', 'ofav'],
#  'cluster_10032': ['adig', 'ofav'],
#  'cluster_10033': ['adig', 'ofav', 'spis'],
#  'cluster_10034': ['adig', 'ofav'],
#  'cluster_10035': ['adig', 'ofav'],
#  'cluster_10036': ['adig', 'ofav', 'spis'],
#  'cluster_10037': ['adig', 'ofav'],
#  'cluster_10038': ['adig', 'ofav', 'spis'],
#  'cluster_10039': ['adig', 'ofav', 'spis'],
#  'cluster_1004': ['adig', 'ofav', 'pdam'],
#  'cluster_10040': ['adig', 'ofav'],
#  'cluster_10041': ['adig', 'ofav', 'pdam'],
#  'cluster_10042': ['adig', 'ofav', 'spis'],
#  'cluster_10043': ['adig', 'ofav', 'spis'],
#  'cluster_10044': ['adig', 'ofav', 'spis'],
#  'cluster_10045': ['adig', 'ofav'],
#  'cluster_10046': ['adig', 'ofav'],
#  'cluster_10047': ['adig', 'ofav'],
#  'cluster_10048': ['adig', 'ofav'],
#  'cluster_10049': ['adig', 'ofav'],
#  'cluster_1005': ['adig', 'pdam', 'spis'],
#  'cluster_10050': ['adig', 'ofav'],
#  'cluster_10051': ['adig', 'ofav'],
#  'cluster_10052': ['adig', 'ofav', 'spis'],
#  'cluster_10053': ['adig', 'ofav'],
#  'cluster_10054': ['adig', 'ofav'],
#  'cluster_10055': ['adig', 'ofav'],
#  'cluster_10056': ['adig', 'ofav'],
#  'cluster_10057': ['adig', 'ofav'],
#  'cluster_10058': ['adig', 'ofav', 'spis'],
#  'cluster_10059': ['adig', 'ofav'],
#  'cluster_1006': ['adig', 'ofav', 'aten', 'pdam', 'spis'],
#  'cluster_10060': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10061': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10062': ['adig', 'ofav'],
#  'cluster_10063': ['adig', 'ofav'],
#  'cluster_10064': ['adig', 'ofav'],
#  'cluster_10065': ['adig', 'ofav'],
#  'cluster_10066': ['adig', 'ofav'],
#  'cluster_10067': ['adig', 'ofav', 'spis'],
#  'cluster_10068': ['adig', 'ofav', 'spis'],
#  'cluster_10069': ['adig', 'ofav'],
#  'cluster_1007': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10070': ['adig', 'ofav', 'spis'],
#  'cluster_10071': ['adig', 'ofav'],
#  'cluster_10072': ['adig', 'ofav'],
#  'cluster_10073': ['adig', 'ofav'],
#  'cluster_10074': ['adig', 'ofav', 'spis'],
#  'cluster_10075': ['adig', 'ofav'],
#  'cluster_10076': ['adig', 'ofav'],
#  'cluster_10077': ['adig', 'ofav', 'spis'],
#  'cluster_10078': ['adig', 'ofav'],
#  'cluster_10079': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_1008': ['adig', 'ofav', 'pdam'],
#  'cluster_10080': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10081': ['adig', 'ofav'],
#  'cluster_10082': ['adig', 'ofav'],
#  'cluster_10083': ['adig', 'ofav'],
#  'cluster_10084': ['adig', 'ofav'],
#  'cluster_10085': ['adig', 'ofav'],
#  'cluster_10086': ['adig', 'ofav'],
#  'cluster_10087': ['adig', 'ofav'],
#  'cluster_10088': ['adig', 'ofav'],
#  'cluster_10089': ['adig', 'ofav', 'spis'],
#  'cluster_1009': ['adig', 'pdam'],
#  'cluster_10090': ['adig', 'ofav'],
#  'cluster_10091': ['adig', 'ofav'],
#  'cluster_10092': ['adig', 'ofav'],
#  'cluster_10093': ['adig', 'ofav'],
#  'cluster_10094': ['adig', 'ofav'],
#  'cluster_10095': ['adig', 'ofav'],
#  'cluster_10096': ['adig', 'ofav'],
#  'cluster_10097': ['adig', 'ofav'],
#  'cluster_10098': ['adig', 'ofav'],
#  'cluster_10099': ['adig', 'ofav'],
#  'cluster_101': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_1010': ['dgig', 'hvul', 'adig', 'ofav', 'aten', 'pdam', 'spis'],
#  'cluster_10100': ['adig', 'ofav'],
#  'cluster_10101': ['adig', 'ofav'],
#  'cluster_10102': ['adig', 'ofav', 'spis'],
#  'cluster_10103': ['adig', 'ofav', 'spis'],
#  'cluster_10104': ['adig', 'ofav', 'spis'],
#  'cluster_10105': ['adig', 'ofav'],
#  'cluster_10106': ['adig', 'ofav'],
#  'cluster_10107': ['adig', 'ofav'],
#  'cluster_10108': ['adig', 'ofav'],
#  'cluster_10109': ['adig', 'ofav'],
#  'cluster_1011': ['adig', 'pdam', 'spis'],
#  'cluster_10110': ['adig', 'ofav'],
#  'cluster_10111': ['adig', 'ofav'],
#  'cluster_10112': ['adig', 'ofav'],
#  'cluster_10113': ['adig', 'ofav'],
#  'cluster_10114': ['adig', 'ofav'],
#  'cluster_10115': ['adig', 'ofav'],
#  'cluster_10116': ['adig', 'ofav'],
#  'cluster_10117': ['adig', 'ofav'],
#  'cluster_10118': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10119': ['adig', 'ofav'],
#  'cluster_1012': ['adig', 'nvec', 'ofav', 'aten', 'pdam', 'spis'],
#  'cluster_10120': ['adig', 'ofav', 'pdam'],
#  'cluster_10121': ['adig', 'ofav'],
#  'cluster_10122': ['adig', 'ofav'],
#  'cluster_10123': ['adig', 'ofav'],
#  'cluster_10124': ['adig', 'ofav'],
#  'cluster_10125': ['adig', 'ofav'],
#  'cluster_10126': ['adig', 'ofav'],
#  'cluster_10127': ['adig', 'ofav'],
#  'cluster_10128': ['adig', 'ofav', 'pdam'],
#  'cluster_10129': ['adig', 'ofav'],
#  'cluster_1013': ['adig', 'pdam'],
#  'cluster_10130': ['adig', 'ofav'],
#  'cluster_10131': ['adig', 'ofav'],
#  'cluster_10132': ['adig', 'ofav'],
#  'cluster_10133': ['adig', 'ofav'],
#  'cluster_10134': ['adig', 'ofav'],
#  'cluster_10135': ['adig', 'ofav'],
#  'cluster_10136': ['adig', 'ofav'],
#  'cluster_10137': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10138': ['adig', 'ofav'],
#  'cluster_10139': ['adig', 'ofav', 'spis'],
#  'cluster_1014': ['adig', 'pdam'],
#  'cluster_10140': ['adig', 'ofav'],
#  'cluster_10141': ['adig', 'ofav'],
#  'cluster_10142': ['adig', 'ofav'],
#  'cluster_10143': ['adig', 'ofav'],
#  'cluster_10144': ['adig', 'ofav'],
#  'cluster_10145': ['adig', 'ofav'],
#  'cluster_10146': ['adig', 'ofav'],
#  'cluster_10147': ['adig', 'ofav'],
#  'cluster_10148': ['adig', 'ofav'],
#  'cluster_10149': ['adig', 'ofav'],
#  'cluster_1015': ['dgig', 'adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10150': ['adig', 'ofav', 'spis'],
#  'cluster_10151': ['adig', 'ofav', 'spis'],
#  'cluster_10152': ['adig', 'ofav'],
#  'cluster_10153': ['adig', 'ofav'],
#  'cluster_10154': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10155': ['adig', 'ofav'],
#  'cluster_10156': ['adig', 'ofav'],
#  'cluster_10157': ['adig', 'ofav'],
#  'cluster_10158': ['adig', 'ofav'],
#  'cluster_10159': ['adig', 'ofav'],
#  'cluster_1016': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10160': ['adig', 'ofav'],
#  'cluster_10161': ['adig', 'ofav'],
#  'cluster_10162': ['adig', 'ofav'],
#  'cluster_10163': ['adig', 'ofav'],
#  'cluster_10164': ['adig', 'ofav'],
#  'cluster_10165': ['adig', 'ofav', 'epal', 'aten', 'pdam', 'spis'],
#  'cluster_10166': ['dgig', 'adig', 'ofav', 'spis'],
#  'cluster_10167': ['adig', 'ofav', 'spis'],
#  'cluster_10168': ['adig', 'ofav'],
#  'cluster_10169': ['adig', 'ofav'],
#  'cluster_1017': ['dgig', 'aaur', 'adig', 'epal', 'aten', 'pdam', 'spis'],
#  'cluster_10170': ['adig', 'ofav'],
#  'cluster_10171': ['adig', 'ofav'],
#  'cluster_10172': ['adig', 'ofav', 'spis'],
#  'cluster_10173': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10174': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10175': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10176': ['adig', 'nvec', 'ofav', 'epal', 'aten', 'pdam', 'spis'],
#  'cluster_10177': ['adig', 'ofav', 'epal', 'aten', 'pdam', 'spis'],
#  'cluster_10178': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10179': ['adig', 'ofav'],
#  'cluster_1018': ['adig', 'pdam'],
#  'cluster_10180': ['adig', 'ofav'],
#  'cluster_10181': ['adig', 'ofav', 'spis'],
#  'cluster_10182': ['adig', 'ofav'],
#  'cluster_10183': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10184': ['adig', 'ofav'],
#  'cluster_10185': ['adig', 'ofav'],
#  'cluster_10186': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10187': ['adig', 'ofav'],
#  'cluster_10188': ['adig', 'ofav'],
#  'cluster_10189': ['adig', 'ofav'],
#  'cluster_1019': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10190': ['adig', 'ofav'],
#  'cluster_10191': ['adig', 'ofav'],
#  'cluster_10192': ['adig', 'ofav', 'spis'],
#  'cluster_10193': ['adig', 'ofav'],
#  'cluster_10194': ['adig', 'ofav', 'spis'],
#  'cluster_10195': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10196': ['adig', 'ofav'],
#  'cluster_10197': ['adig', 'ofav'],
#  'cluster_10198': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10199': ['adig', 'ofav'],
#  'cluster_102': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_1020': ['adig', 'ofav', 'aten', 'pdam'],
#  'cluster_10200': ['adig', 'ofav'],
#  'cluster_10201': ['adig', 'ofav'],
#  'cluster_10202': ['adig', 'ofav'],
#  'cluster_10203': ['adig', 'ofav'],
#  'cluster_10204': ['adig', 'ofav'],
#  'cluster_10205': ['adig', 'ofav', 'pdam'],
#  'cluster_10206': ['adig', 'ofav', 'spis'],
#  'cluster_10207': ['adig', 'ofav'],
#  'cluster_10208': ['adig', 'ofav'],
#  'cluster_10209': ['adig', 'ofav'],
#  'cluster_1021': ['adig', 'pdam', 'spis'],
#  'cluster_10210': ['adig', 'ofav', 'spis'],
#  'cluster_10211': ['adig', 'ofav'],
#  'cluster_10212': ['adig', 'ofav'],
#  'cluster_10213': ['adig', 'ofav'],
#  'cluster_10214': ['adig', 'ofav'],
#  'cluster_10215': ['adig', 'ofav'],
#  'cluster_10216': ['adig', 'ofav'],
#  'cluster_10217': ['adig', 'ofav'],
#  'cluster_10218': ['adig', 'ofav'],
#  'cluster_10219': ['adig', 'ofav'],
#  'cluster_1022': ['adig', 'pdam', 'spis'],
#  'cluster_10220': ['adig', 'ofav'],
#  'cluster_10221': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10222': ['adig', 'ofav', 'spis'],
#  'cluster_10223': ['adig', 'ofav'],
#  'cluster_10224': ['adig', 'ofav'],
#  'cluster_10225': ['adig', 'ofav'],
#  'cluster_10226': ['adig', 'ofav'],
#  'cluster_10227': ['adig', 'ofav'],
#  'cluster_10228': ['adig', 'ofav'],
#  'cluster_10229': ['dgig', 'adig', 'ofav', 'pdam', 'spis'],
#  'cluster_1023': ['dgig', 'adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10230': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10231': ['adig', 'ofav'],
#  'cluster_10232': ['adig', 'ofav'],
#  'cluster_10233': ['adig', 'ofav'],
#  'cluster_10234': ['adig', 'ofav'],
#  'cluster_10235': ['adig', 'ofav'],
#  'cluster_10236': ['adig', 'ofav'],
#  'cluster_10237': ['adig', 'ofav'],
#  'cluster_10238': ['adig', 'ofav'],
#  'cluster_10239': ['adig', 'ofav'],
#  'cluster_1024': ['adig', 'pdam', 'spis'],
#  'cluster_10240': ['adig', 'ofav'],
#  'cluster_10241': ['adig', 'ofav'],
#  'cluster_10242': ['adig', 'ofav'],
#  'cluster_10243': ['adig', 'ofav'],
#  'cluster_10244': ['adig', 'ofav', 'spis'],
#  'cluster_10245': ['adig', 'ofav'],
#  'cluster_10246': ['adig', 'ofav', 'spis'],
#  'cluster_10247': ['adig', 'ofav', 'pdam'],
#  'cluster_10248': ['adig', 'ofav'],
#  'cluster_10249': ['adig', 'ofav'],
#  'cluster_1025': ['adig', 'pdam'],
#  'cluster_10250': ['adig', 'ofav'],
#  'cluster_10251': ['adig', 'ofav'],
#  'cluster_10252': ['adig', 'ofav'],
#  'cluster_10253': ['adig', 'ofav'],
#  'cluster_10254': ['adig', 'ofav'],
#  'cluster_10255': ['adig', 'ofav'],
#  'cluster_10256': ['adig', 'ofav'],
#  'cluster_10257': ['adig', 'ofav', 'spis'],
#  'cluster_10258': ['adig', 'ofav'],
#  'cluster_10259': ['adig', 'ofav'],
#  'cluster_1026': ['adig', 'pdam'],
#  'cluster_10260': ['adig', 'ofav'],
#  'cluster_10261': ['adig', 'ofav'],
#  'cluster_10262': ['adig', 'ofav', 'spis'],
#  'cluster_10263': ['adig', 'ofav'],
#  'cluster_10264': ['adig', 'ofav'],
#  'cluster_10265': ['adig', 'ofav'],
#  'cluster_10266': ['adig', 'ofav', 'spis'],
#  'cluster_10267': ['adig', 'ofav'],
#  'cluster_10268': ['adig', 'ofav', 'spis'],
#  'cluster_10269': ['adig', 'ofav'],
#  'cluster_1027': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10270': ['adig', 'ofav'],
#  'cluster_10271': ['adig', 'ofav'],
#  'cluster_10272': ['adig', 'ofav'],
#  'cluster_10273': ['adig', 'ofav'],
#  'cluster_10274': ['adig', 'ofav'],
#  'cluster_10275': ['adig', 'ofav', 'spis'],
#  'cluster_10276': ['adig', 'ofav'],
#  'cluster_10277': ['adig', 'ofav'],
#  'cluster_10278': ['adig', 'ofav'],
#  'cluster_10279': ['adig', 'ofav'],
#  'cluster_1028': ['adig', 'pdam', 'spis'],
#  'cluster_10280': ['adig', 'ofav'],
#  'cluster_10281': ['adig', 'ofav'],
#  'cluster_10282': ['adig', 'ofav'],
#  'cluster_10283': ['adig', 'ofav'],
#  'cluster_10284': ['adig', 'ofav'],
#  'cluster_10285': ['adig', 'ofav'],
#  'cluster_10286': ['adig', 'ofav'],
#  'cluster_10287': ['adig', 'ofav'],
#  'cluster_10288': ['adig', 'ofav'],
#  'cluster_10289': ['adig', 'ofav'],
#  'cluster_1029': ['adig', 'pdam', 'spis'],
#  'cluster_10290': ['adig', 'ofav'],
#  'cluster_10291': ['adig', 'ofav'],
#  'cluster_10292': ['adig', 'ofav', 'pdam'],
#  'cluster_10293': ['adig', 'ofav', 'pdam'],
#  'cluster_10294': ['adig', 'ofav'],
#  'cluster_10295': ['adig', 'ofav'],
#  'cluster_10296': ['adig', 'ofav'],
#  'cluster_10297': ['adig', 'ofav'],
#  'cluster_10298': ['adig', 'ofav'],
#  'cluster_10299': ['adig', 'ofav'],
#  'cluster_103': ['aaur', 'adig', 'ofav', 'epal', 'aten', 'pdam', 'spis'],
#  'cluster_1030': ['adig', 'pdam', 'spis'],
#  'cluster_10300': ['adig', 'ofav', 'spis'],
#  'cluster_10301': ['adig', 'ofav', 'pdam'],
#  'cluster_10302': ['adig', 'ofav'],
#  'cluster_10303': ['adig', 'ofav'],
#  'cluster_10304': ['adig', 'ofav'],
#  'cluster_10305': ['adig', 'ofav'],
#  'cluster_10306': ['adig', 'ofav'],
#  'cluster_10307': ['adig', 'ofav'],
#  'cluster_10308': ['adig', 'ofav'],
#  'cluster_10309': ['adig', 'ofav'],
#  'cluster_1031': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10310': ['adig', 'ofav'],
#  'cluster_10311': ['adig', 'ofav'],
#  'cluster_10312': ['adig', 'ofav'],
#  'cluster_10313': ['adig', 'ofav'],
#  'cluster_10314': ['adig', 'ofav'],
#  'cluster_10315': ['adig', 'ofav'],
#  'cluster_10316': ['adig', 'ofav'],
#  'cluster_10317': ['adig', 'ofav'],
#  'cluster_10318': ['adig', 'ofav'],
#  'cluster_10319': ['adig', 'ofav', 'spis'],
#  'cluster_1032': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10320': ['adig', 'ofav'],
#  'cluster_10321': ['adig', 'ofav'],
#  'cluster_10322': ['adig', 'ofav'],
#  'cluster_10323': ['adig', 'ofav'],
#  'cluster_10324': ['adig', 'ofav'],
#  'cluster_10325': ['adig', 'ofav'],
#  'cluster_10326': ['adig', 'ofav'],
#  'cluster_10327': ['adig', 'ofav'],
#  'cluster_10328': ['adig', 'ofav'],
#  'cluster_10329': ['adig', 'ofav'],
#  'cluster_1033': ['adig', 'ofav', 'pdam'],
#  'cluster_10330': ['adig', 'ofav'],
#  'cluster_10331': ['adig', 'ofav', 'pdam'],
#  'cluster_10332': ['adig', 'ofav'],
#  'cluster_10333': ['adig', 'ofav'],
#  'cluster_10334': ['adig', 'ofav'],
#  'cluster_10335': ['adig', 'ofav'],
#  'cluster_10336': ['adig', 'ofav'],
#  'cluster_10337': ['adig', 'ofav'],
#  'cluster_10338': ['adig', 'ofav'],
#  'cluster_10339': ['adig', 'ofav'],
#  'cluster_1034': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10340': ['adig', 'ofav', 'spis'],
#  'cluster_10341': ['adig', 'ofav'],
#  'cluster_10342': ['adig', 'ofav'],
#  'cluster_10343': ['adig', 'ofav'],
#  'cluster_10344': ['adig', 'ofav'],
#  'cluster_10345': ['adig', 'ofav'],
#  'cluster_10346': ['adig', 'ofav'],
#  'cluster_10347': ['adig', 'ofav'],
#  'cluster_10348': ['adig', 'ofav'],
#  'cluster_10349': ['adig', 'ofav'],
#  'cluster_1035': ['adig', 'epal', 'pdam', 'spis'],
#  'cluster_10350': ['adig', 'ofav'],
#  'cluster_10351': ['adig', 'ofav'],
#  'cluster_10352': ['adig', 'ofav'],
#  'cluster_10353': ['adig', 'ofav', 'spis'],
#  'cluster_10354': ['adig', 'ofav'],
#  'cluster_10355': ['adig', 'ofav'],
#  'cluster_10356': ['dgig',
#   'adig',
#   'nvec',
#   'chem',
#   'ofav',
#   'epal',
#   'pdam',
#   'spis'],
#  'cluster_10357': ['adig', 'ofav'],
#  'cluster_10358': ['adig', 'ofav'],
#  'cluster_10359': ['adig', 'ofav'],
#  'cluster_1036': ['adig', 'pdam'],
#  'cluster_10360': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10361': ['adig', 'ofav'],
#  'cluster_10362': ['adig', 'ofav'],
#  'cluster_10363': ['adig', 'ofav'],
#  'cluster_10364': ['adig', 'ofav'],
#  'cluster_10365': ['adig', 'ofav'],
#  'cluster_10366': ['adig', 'ofav'],
#  'cluster_10367': ['adig', 'ofav'],
#  'cluster_10368': ['adig', 'ofav'],
#  'cluster_10369': ['adig', 'ofav'],
#  'cluster_1037': ['adig', 'pdam'],
#  'cluster_10370': ['adig', 'ofav'],
#  'cluster_10371': ['adig', 'ofav'],
#  'cluster_10372': ['adig', 'ofav'],
#  'cluster_10373': ['adig', 'ofav'],
#  'cluster_10374': ['adig', 'ofav'],
#  'cluster_10375': ['adig', 'ofav'],
#  'cluster_10376': ['adig', 'ofav', 'spis'],
#  'cluster_10377': ['adig', 'ofav'],
#  'cluster_10378': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10379': ['adig', 'ofav', 'spis'],
#  'cluster_1038': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10380': ['adig', 'ofav'],
#  'cluster_10381': ['adig', 'ofav', 'pdam'],
#  'cluster_10382': ['adig', 'ofav'],
#  'cluster_10383': ['adig', 'ofav'],
#  'cluster_10384': ['adig', 'ofav'],
#  'cluster_10385': ['adig', 'ofav'],
#  'cluster_10386': ['adig', 'ofav'],
#  'cluster_10387': ['adig', 'ofav'],
#  'cluster_10388': ['adig', 'ofav'],
#  'cluster_10389': ['adig', 'ofav'],
#  'cluster_1039': ['adig', 'ofav', 'epal', 'pdam'],
#  'cluster_10390': ['adig', 'ofav'],
#  'cluster_10391': ['adig', 'ofav'],
#  'cluster_10392': ['adig', 'ofav'],
#  'cluster_10393': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10394': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10395': ['adig', 'ofav'],
#  'cluster_10396': ['adig', 'ofav'],
#  'cluster_10397': ['adig', 'ofav'],
#  'cluster_10398': ['adig', 'hsym', 'ofav', 'pdam', 'spis'],
#  'cluster_10399': ['adig', 'ofav'],
#  'cluster_104': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_1040': ['adig', 'pdam', 'spis'],
#  'cluster_10400': ['adig', 'ofav'],
#  'cluster_10401': ['adig', 'ofav'],
#  'cluster_10402': ['adig', 'ofav'],
#  'cluster_10403': ['adig', 'ofav'],
#  'cluster_10404': ['adig', 'ofav'],
#  'cluster_10405': ['adig', 'ofav', 'spis'],
#  'cluster_10406': ['adig', 'ofav'],
#  'cluster_10407': ['adig', 'ofav'],
#  'cluster_10408': ['adig', 'ofav'],
#  'cluster_10409': ['adig', 'ofav'],
#  'cluster_1041': ['adig', 'pdam'],
#  'cluster_10410': ['adig', 'ofav'],
#  'cluster_10411': ['adig', 'ofav'],
#  'cluster_10412': ['adig', 'ofav'],
#  'cluster_10413': ['adig', 'ofav'],
#  'cluster_10414': ['adig', 'ofav'],
#  'cluster_10415': ['adig', 'ofav'],
#  'cluster_10416': ['adig', 'ofav'],
#  'cluster_10417': ['adig', 'ofav'],
#  'cluster_10418': ['adig', 'ofav'],
#  'cluster_10419': ['adig', 'ofav'],
#  'cluster_1042': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10420': ['adig', 'ofav'],
#  'cluster_10421': ['adig', 'ofav'],
#  'cluster_10422': ['adig', 'ofav'],
#  'cluster_10423': ['adig', 'ofav'],
#  'cluster_10424': ['adig', 'ofav'],
#  'cluster_10425': ['adig', 'ofav'],
#  'cluster_10426': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10427': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10428': ['adig', 'ofav'],
#  'cluster_10429': ['adig', 'ofav'],
#  'cluster_1043': ['adig', 'pdam', 'spis'],
#  'cluster_10430': ['adig', 'ofav'],
#  'cluster_10431': ['adig', 'nvec', 'ofav', 'epal'],
#  'cluster_10432': ['adig', 'ofav', 'spis'],
#  'cluster_10433': ['adig', 'ofav', 'spis'],
#  'cluster_10434': ['adig', 'ofav', 'spis'],
#  'cluster_10435': ['adig', 'ofav', 'spis'],
#  'cluster_10436': ['adig', 'ofav'],
#  'cluster_10437': ['adig', 'ofav', 'pdam'],
#  'cluster_10438': ['adig', 'ofav'],
#  'cluster_10439': ['adig', 'ofav'],
#  'cluster_1044': ['adig', 'pdam', 'spis'],
#  'cluster_10440': ['adig', 'ofav'],
#  'cluster_10441': ['adig', 'ofav'],
#  'cluster_10442': ['adig', 'ofav'],
#  'cluster_10443': ['adig', 'ofav'],
#  'cluster_10444': ['adig', 'ofav', 'aten', 'spis'],
#  'cluster_10445': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10446': ['adig', 'ofav'],
#  'cluster_10447': ['adig', 'ofav'],
#  'cluster_10448': ['adig', 'ofav', 'aten', 'pdam', 'spis'],
#  'cluster_10449': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_1045': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10450': ['adig', 'ofav'],
#  'cluster_10451': ['adig', 'ofav'],
#  'cluster_10452': ['adig', 'ofav', 'spis'],
#  'cluster_10453': ['adig', 'ofav'],
#  'cluster_10454': ['adig', 'ofav'],
#  'cluster_10455': ['adig', 'ofav'],
#  'cluster_10456': ['adig', 'ofav'],
#  'cluster_10457': ['adig', 'ofav'],
#  'cluster_10458': ['adig', 'ofav'],
#  'cluster_10459': ['adig', 'ofav'],
#  'cluster_1046': ['adig', 'pdam'],
#  'cluster_10460': ['adig', 'ofav'],
#  'cluster_10461': ['adig', 'ofav'],
#  'cluster_10462': ['adig', 'ofav'],
#  'cluster_10463': ['adig', 'ofav'],
#  'cluster_10464': ['adig', 'ofav'],
#  'cluster_10465': ['adig', 'ofav'],
#  'cluster_10466': ['adig', 'ofav'],
#  'cluster_10467': ['adig', 'ofav'],
#  'cluster_10468': ['adig', 'ofav'],
#  'cluster_10469': ['adig', 'ofav'],
#  'cluster_1047': ['adig', 'pdam', 'spis'],
#  'cluster_10470': ['adig', 'ofav'],
#  'cluster_10471': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10472': ['adig', 'ofav'],
#  'cluster_10473': ['adig', 'ofav'],
#  'cluster_10474': ['adig', 'ofav'],
#  'cluster_10475': ['adig', 'ofav'],
#  'cluster_10476': ['adig', 'ofav'],
#  'cluster_10477': ['adig', 'ofav'],
#  'cluster_10478': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10479': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_1048': ['adig', 'pdam'],
#  'cluster_10480': ['adig', 'ofav'],
#  'cluster_10481': ['adig', 'ofav', 'spis'],
#  'cluster_10482': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10483': ['adig', 'ofav'],
#  'cluster_10484': ['adig', 'ofav'],
#  'cluster_10485': ['adig', 'ofav'],
#  'cluster_10486': ['adig', 'ofav', 'epal'],
#  'cluster_10487': ['adig', 'ofav'],
#  'cluster_10488': ['adig', 'ofav', 'spis'],
#  'cluster_10489': ['adig', 'ofav', 'spis'],
#  'cluster_1049': ['adig', 'pdam', 'spis'],
#  'cluster_10490': ['adig', 'ofav'],
#  'cluster_10491': ['adig', 'ofav'],
#  'cluster_10492': ['adig', 'ofav'],
#  'cluster_10493': ['adig', 'ofav'],
#  'cluster_10494': ['adig', 'ofav'],
#  'cluster_10495': ['adig', 'ofav'],
#  'cluster_10496': ['adig', 'ofav'],
#  'cluster_10497': ['adig', 'ofav'],
#  'cluster_10498': ['adig', 'ofav'],
#  'cluster_10499': ['adig', 'ofav'],
#  'cluster_105': ['adig', 'pdam', 'spis'],
#  'cluster_1050': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10500': ['adig', 'ofav', 'spis'],
#  'cluster_10501': ['adig', 'ofav'],
#  'cluster_10502': ['adig', 'ofav'],
#  'cluster_10503': ['adig', 'ofav', 'spis'],
#  'cluster_10504': ['adig', 'ofav'],
#  'cluster_10505': ['adig', 'ofav'],
#  'cluster_10506': ['adig', 'ofav'],
#  'cluster_10507': ['adig', 'ofav'],
#  'cluster_10508': ['adig', 'ofav'],
#  'cluster_10509': ['adig', 'ofav'],
#  'cluster_1051': ['adig', 'pdam'],
#  'cluster_10510': ['adig', 'ofav'],
#  'cluster_10511': ['adig', 'ofav'],
#  'cluster_10512': ['adig', 'ofav'],
#  'cluster_10513': ['adig', 'ofav'],
#  'cluster_10514': ['adig', 'ofav', 'spis'],
#  'cluster_10515': ['adig', 'ofav'],
#  'cluster_10516': ['adig', 'ofav'],
#  'cluster_10517': ['adig', 'ofav'],
#  'cluster_10518': ['adig', 'ofav'],
#  'cluster_10519': ['adig', 'ofav'],
#  'cluster_1052': ['adig', 'pdam'],
#  'cluster_10520': ['adig', 'ofav'],
#  'cluster_10521': ['adig', 'ofav'],
#  'cluster_10522': ['adig', 'ofav'],
#  'cluster_10523': ['adig', 'ofav', 'spis'],
#  'cluster_10524': ['adig', 'ofav'],
#  'cluster_10525': ['adig', 'ofav'],
#  'cluster_10526': ['adig', 'ofav'],
#  'cluster_10527': ['adig', 'ofav'],
#  'cluster_10528': ['adig', 'ofav'],
#  'cluster_10529': ['adig', 'ofav'],
#  'cluster_1053': ['dgig', 'adig', 'nvec', 'ofav', 'pdam', 'spis'],
#  'cluster_10530': ['adig', 'ofav'],
#  'cluster_10531': ['adig', 'ofav'],
#  'cluster_10532': ['adig', 'ofav'],
#  'cluster_10533': ['adig', 'ofav'],
#  'cluster_10534': ['adig', 'ofav'],
#  'cluster_10535': ['adig', 'ofav'],
#  'cluster_10536': ['adig', 'ofav'],
#  'cluster_10537': ['adig', 'ofav'],
#  'cluster_10538': ['adig', 'ofav'],
#  'cluster_10539': ['adig', 'ofav'],
#  'cluster_1054': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10540': ['adig', 'ofav'],
#  'cluster_10541': ['adig', 'ofav'],
#  'cluster_10542': ['adig', 'ofav'],
#  'cluster_10543': ['adig', 'ofav'],
#  'cluster_10544': ['adig', 'ofav'],
#  'cluster_10545': ['adig', 'ofav'],
#  'cluster_10546': ['adig', 'ofav'],
#  'cluster_10547': ['adig', 'ofav'],
#  'cluster_10548': ['adig', 'ofav'],
#  'cluster_10549': ['adig', 'ofav', 'spis'],
#  'cluster_1055': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10550': ['adig', 'ofav'],
#  'cluster_10551': ['adig', 'ofav', 'epal', 'pdam', 'spis'],
#  'cluster_10552': ['adig', 'ofav'],
#  'cluster_10553': ['adig', 'ofav'],
#  'cluster_10554': ['adig', 'ofav'],
#  'cluster_10555': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10556': ['adig', 'ofav'],
#  'cluster_10557': ['adig', 'ofav'],
#  'cluster_10558': ['adig', 'ofav'],
#  'cluster_10559': ['adig', 'ofav'],
#  'cluster_1056': ['adig', 'ofav', 'pdam'],
#  'cluster_10560': ['adig', 'ofav'],
#  'cluster_10561': ['adig', 'ofav'],
#  'cluster_10562': ['adig', 'ofav'],
#  'cluster_10563': ['adig', 'ofav'],
#  'cluster_10564': ['dgig', 'adig', 'ofav'],
#  'cluster_10565': ['adig', 'ofav'],
#  'cluster_10566': ['adig', 'ofav', 'spis'],
#  'cluster_10567': ['adig', 'ofav'],
#  'cluster_10568': ['adig', 'ofav'],
#  'cluster_10569': ['adig', 'ofav', 'spis'],
#  'cluster_1057': ['adig', 'pdam', 'spis'],
#  'cluster_10570': ['adig', 'ofav'],
#  'cluster_10571': ['adig', 'ofav'],
#  'cluster_10572': ['adig', 'ofav'],
#  'cluster_10573': ['adig', 'ofav'],
#  'cluster_10574': ['adig', 'ofav'],
#  'cluster_10575': ['adig', 'ofav'],
#  'cluster_10576': ['adig', 'ofav'],
#  'cluster_10577': ['adig', 'ofav'],
#  'cluster_10578': ['adig', 'ofav'],
#  'cluster_10579': ['adig', 'ofav'],
#  'cluster_1058': ['adig', 'pdam'],
#  'cluster_10580': ['adig', 'ofav'],
#  'cluster_10581': ['adig', 'ofav'],
#  'cluster_10582': ['adig', 'ofav'],
#  'cluster_10583': ['adig', 'ofav'],
#  'cluster_10584': ['adig', 'ofav'],
#  'cluster_10585': ['adig', 'ofav'],
#  'cluster_10586': ['adig', 'ofav'],
#  'cluster_10587': ['dgig', 'adig', 'ofav'],
#  'cluster_10588': ['adig', 'ofav'],
#  'cluster_10589': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_1059': ['adig', 'pdam'],
#  'cluster_10590': ['adig', 'ofav'],
#  'cluster_10591': ['adig', 'ofav'],
#  'cluster_10592': ['adig', 'ofav'],
#  'cluster_10593': ['adig', 'ofav'],
#  'cluster_10594': ['adig', 'ofav'],
#  'cluster_10595': ['adig', 'nvec', 'ofav', 'epal', 'aten', 'pdam', 'spis'],
#  'cluster_10596': ['adig', 'ofav'],
#  'cluster_10597': ['adig', 'ofav'],
#  'cluster_10598': ['adig', 'ofav'],
#  'cluster_10599': ['adig', 'ofav'],
#  'cluster_106': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_1060': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10600': ['adig', 'ofav'],
#  'cluster_10601': ['adig', 'ofav'],
#  'cluster_10602': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10603': ['adig', 'ofav'],
#  'cluster_10604': ['adig', 'ofav'],
#  'cluster_10605': ['adig', 'ofav'],
#  'cluster_10606': ['adig', 'ofav'],
#  'cluster_10607': ['adig', 'ofav'],
#  'cluster_10608': ['adig', 'ofav'],
#  'cluster_10609': ['adig', 'ofav', 'spis'],
#  'cluster_1061': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10610': ['adig', 'ofav'],
#  'cluster_10611': ['adig', 'ofav'],
#  'cluster_10612': ['adig', 'ofav'],
#  'cluster_10613': ['adig', 'ofav', 'spis'],
#  'cluster_10614': ['adig', 'ofav'],
#  'cluster_10615': ['adig', 'ofav'],
#  'cluster_10616': ['adig', 'ofav'],
#  'cluster_10617': ['adig', 'ofav'],
#  'cluster_10618': ['adig', 'ofav'],
#  'cluster_10619': ['adig', 'ofav'],
#  'cluster_1062': ['adig', 'pdam'],
#  'cluster_10620': ['adig', 'ofav'],
#  'cluster_10621': ['adig', 'ofav'],
#  'cluster_10622': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10623': ['adig', 'ofav'],
#  'cluster_10624': ['adig', 'ofav'],
#  'cluster_10625': ['adig', 'ofav'],
#  'cluster_10626': ['adig', 'ofav'],
#  'cluster_10627': ['adig', 'ofav', 'spis'],
#  'cluster_10628': ['adig', 'ofav'],
#  'cluster_10629': ['adig', 'ofav'],
#  'cluster_1063': ['adig', 'pdam', 'spis'],
#  'cluster_10630': ['adig', 'ofav'],
#  'cluster_10631': ['adig', 'ofav'],
#  'cluster_10632': ['adig', 'ofav'],
#  'cluster_10633': ['adig', 'ofav'],
#  'cluster_10634': ['adig', 'ofav'],
#  'cluster_10635': ['adig', 'ofav'],
#  'cluster_10636': ['adig', 'ofav'],
#  'cluster_10637': ['adig', 'ofav'],
#  'cluster_10638': ['adig', 'ofav'],
#  'cluster_10639': ['adig', 'ofav'],
#  'cluster_1064': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10640': ['adig', 'ofav'],
#  'cluster_10641': ['adig', 'ofav'],
#  'cluster_10642': ['adig', 'ofav'],
#  'cluster_10643': ['adig', 'ofav'],
#  'cluster_10644': ['adig', 'ofav'],
#  'cluster_10645': ['adig', 'ofav'],
#  'cluster_10646': ['adig', 'ofav'],
#  'cluster_10647': ['adig', 'ofav'],
#  'cluster_10648': ['adig', 'ofav'],
#  'cluster_10649': ['adig', 'ofav'],
#  'cluster_1065': ['adig', 'ofav', 'pdam'],
#  'cluster_10650': ['adig', 'ofav'],
#  'cluster_10651': ['adig', 'ofav', 'pdam'],
#  'cluster_10652': ['adig', 'ofav'],
#  'cluster_10653': ['adig', 'ofav', 'spis'],
#  'cluster_10654': ['adig', 'ofav'],
#  'cluster_10655': ['adig', 'ofav'],
#  'cluster_10656': ['adig', 'ofav'],
#  'cluster_10657': ['adig', 'ofav'],
#  'cluster_10658': ['adig', 'ofav'],
#  'cluster_10659': ['adig', 'ofav'],
#  'cluster_1066': ['adig', 'nvec', 'ofav', 'pdam', 'spis'],
#  'cluster_10660': ['adig', 'ofav'],
#  'cluster_10661': ['adig', 'ofav'],
#  'cluster_10662': ['adig', 'ofav'],
#  'cluster_10663': ['adig', 'ofav', 'spis'],
#  'cluster_10664': ['adig', 'ofav', 'spis'],
#  'cluster_10665': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10666': ['adig', 'ofav'],
#  'cluster_10667': ['adig', 'ofav'],
#  'cluster_10668': ['adig', 'ofav'],
#  'cluster_10669': ['adig', 'ofav'],
#  'cluster_1067': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10670': ['adig', 'ofav'],
#  'cluster_10671': ['adig', 'ofav'],
#  'cluster_10672': ['adig', 'ofav'],
#  'cluster_10673': ['adig', 'ofav'],
#  'cluster_10674': ['adig', 'ofav'],
#  'cluster_10675': ['adig', 'ofav'],
#  'cluster_10676': ['adig', 'ofav'],
#  'cluster_10677': ['adig', 'ofav'],
#  'cluster_10678': ['adig', 'ofav'],
#  'cluster_10679': ['adig', 'ofav'],
#  'cluster_1068': ['adig', 'pdam'],
#  'cluster_10680': ['adig', 'ofav'],
#  'cluster_10681': ['adig', 'ofav'],
#  'cluster_10682': ['adig', 'ofav'],
#  'cluster_10683': ['adig', 'ofav'],
#  'cluster_10684': ['adig', 'ofav', 'spis'],
#  'cluster_10685': ['adig', 'ofav'],
#  'cluster_10686': ['adig', 'ofav'],
#  'cluster_10687': ['adig', 'ofav'],
#  'cluster_10688': ['adig', 'ofav'],
#  'cluster_10689': ['adig', 'ofav', 'spis'],
#  'cluster_1069': ['adig', 'pdam'],
#  'cluster_10690': ['adig', 'ofav'],
#  'cluster_10691': ['adig', 'ofav'],
#  'cluster_10692': ['adig', 'ofav'],
#  'cluster_10693': ['adig', 'ofav'],
#  'cluster_10694': ['adig', 'ofav'],
#  'cluster_10695': ['adig', 'ofav'],
#  'cluster_10696': ['adig', 'ofav'],
#  'cluster_10697': ['adig', 'ofav'],
#  'cluster_10698': ['adig', 'ofav'],
#  'cluster_10699': ['adig', 'ofav'],
#  'cluster_107': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_1070': ['mvir', 'adig', 'pdam', 'spis'],
#  'cluster_10700': ['adig', 'ofav'],
#  'cluster_10701': ['adig', 'ofav'],
#  'cluster_10702': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10703': ['adig', 'ofav'],
#  'cluster_10704': ['adig', 'ofav'],
#  'cluster_10705': ['adig', 'ofav'],
#  'cluster_10706': ['adig', 'ofav'],
#  'cluster_10707': ['adig', 'ofav'],
#  'cluster_10708': ['adig', 'ofav'],
#  'cluster_10709': ['adig', 'ofav'],
#  'cluster_1071': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10710': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10711': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10712': ['adig', 'ofav'],
#  'cluster_10713': ['adig', 'ofav', 'pdam'],
#  'cluster_10714': ['adig', 'ofav'],
#  'cluster_10715': ['adig', 'ofav'],
#  'cluster_10716': ['adig', 'ofav'],
#  'cluster_10717': ['adig', 'ofav'],
#  'cluster_10718': ['adig', 'ofav'],
#  'cluster_10719': ['adig', 'ofav'],
#  'cluster_1072': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10720': ['adig', 'ofav'],
#  'cluster_10721': ['adig', 'ofav'],
#  'cluster_10722': ['adig', 'ofav'],
#  'cluster_10723': ['adig', 'ofav'],
#  'cluster_10724': ['adig', 'ofav'],
#  'cluster_10725': ['adig', 'ofav'],
#  'cluster_10726': ['adig', 'ofav'],
#  'cluster_10727': ['adig', 'ofav', 'spis'],
#  'cluster_10728': ['adig', 'ofav', 'spis'],
#  'cluster_10729': ['adig', 'ofav', 'spis'],
#  'cluster_1073': ['adig', 'pdam', 'spis'],
#  'cluster_10730': ['adig', 'ofav'],
#  'cluster_10731': ['adig', 'ofav'],
#  'cluster_10732': ['adig', 'ofav'],
#  'cluster_10733': ['adig', 'ofav'],
#  'cluster_10734': ['adig', 'ofav'],
#  'cluster_10735': ['adig', 'ofav'],
#  'cluster_10736': ['adig', 'ofav', 'spis'],
#  'cluster_10737': ['adig', 'ofav'],
#  'cluster_10738': ['adig', 'ofav'],
#  'cluster_10739': ['adig', 'ofav'],
#  'cluster_1074': ['adig', 'pdam'],
#  'cluster_10740': ['adig', 'ofav'],
#  'cluster_10741': ['adig', 'ofav'],
#  'cluster_10742': ['adig', 'ofav', 'spis'],
#  'cluster_10743': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10744': ['adig', 'ofav', 'spis'],
#  'cluster_10745': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10746': ['adig', 'ofav'],
#  'cluster_10747': ['adig', 'ofav'],
#  'cluster_10748': ['adig', 'ofav'],
#  'cluster_10749': ['adig', 'ofav'],
#  'cluster_1075': ['adig', 'pdam', 'spis'],
#  'cluster_10750': ['adig', 'ofav'],
#  'cluster_10751': ['adig', 'ofav'],
#  'cluster_10752': ['adig', 'ofav'],
#  'cluster_10753': ['adig', 'ofav'],
#  'cluster_10754': ['adig', 'ofav'],
#  'cluster_10755': ['adig', 'ofav', 'spis'],
#  'cluster_10756': ['adig', 'ofav'],
#  'cluster_10757': ['adig', 'ofav'],
#  'cluster_10758': ['mvir', 'adig', 'ofav', 'spis'],
#  'cluster_10759': ['adig', 'ofav', 'spis'],
#  'cluster_1076': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10760': ['adig', 'ofav'],
#  'cluster_10761': ['adig', 'chem', 'ofav', 'pdam', 'spis'],
#  'cluster_10762': ['adig', 'ofav'],
#  'cluster_10763': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10764': ['adig', 'ofav'],
#  'cluster_10765': ['adig', 'ofav'],
#  'cluster_10766': ['adig', 'nvec', 'ofav', 'epal'],
#  'cluster_10767': ['adig', 'ofav'],
#  'cluster_10768': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10769': ['adig', 'ofav'],
#  'cluster_1077': ['adig', 'pdam'],
#  'cluster_10770': ['adig', 'ofav'],
#  'cluster_10771': ['adig', 'ofav'],
#  'cluster_10772': ['adig', 'ofav'],
#  'cluster_10773': ['adig', 'ofav'],
#  'cluster_10774': ['adig', 'ofav'],
#  'cluster_10775': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10776': ['adig', 'ofav'],
#  'cluster_10777': ['adig', 'ofav'],
#  'cluster_10778': ['adig', 'ofav'],
#  'cluster_10779': ['adig', 'ofav', 'spis'],
#  'cluster_1078': ['adig', 'pdam'],
#  'cluster_10780': ['adig', 'ofav', 'spis'],
#  'cluster_10781': ['adig', 'ofav'],
#  'cluster_10782': ['adig', 'ofav', 'epal', 'spis'],
#  'cluster_10783': ['adig', 'ofav'],
#  'cluster_10784': ['adig', 'ofav'],
#  'cluster_10785': ['adig', 'ofav'],
#  'cluster_10786': ['adig', 'ofav'],
#  'cluster_10787': ['adig', 'ofav'],
#  'cluster_10788': ['adig', 'ofav'],
#  'cluster_10789': ['adig', 'ofav'],
#  'cluster_1079': ['adig', 'pdam'],
#  'cluster_10790': ['adig', 'ofav'],
#  'cluster_10791': ['adig', 'ofav'],
#  'cluster_10792': ['adig', 'ofav', 'spis'],
#  'cluster_10793': ['adig', 'ofav'],
#  'cluster_10794': ['adig', 'ofav'],
#  'cluster_10795': ['adig', 'ofav'],
#  'cluster_10796': ['adig', 'ofav'],
#  'cluster_10797': ['adig', 'ofav'],
#  'cluster_10798': ['adig', 'ofav', 'spis'],
#  'cluster_10799': ['adig', 'ofav'],
#  'cluster_108': ['adig', 'nvec', 'ofav', 'epal', 'aten', 'pdam', 'spis'],
#  'cluster_1080': ['adig', 'pdam', 'spis'],
#  'cluster_10800': ['adig', 'ofav'],
#  'cluster_10801': ['adig', 'ofav'],
#  'cluster_10802': ['adig', 'ofav'],
#  'cluster_10803': ['adig', 'ofav'],
#  'cluster_10804': ['adig', 'ofav'],
#  'cluster_10805': ['adig', 'ofav'],
#  'cluster_10806': ['adig', 'ofav'],
#  'cluster_10807': ['adig', 'ofav'],
#  'cluster_10808': ['adig', 'ofav'],
#  'cluster_10809': ['adig', 'ofav'],
#  'cluster_1081': ['adig', 'pdam'],
#  'cluster_10810': ['adig', 'ofav'],
#  'cluster_10811': ['adig', 'ofav'],
#  'cluster_10812': ['adig', 'ofav'],
#  'cluster_10813': ['adig', 'ofav'],
#  'cluster_10814': ['adig', 'ofav'],
#  'cluster_10815': ['adig', 'ofav'],
#  'cluster_10816': ['adig', 'ofav'],
#  'cluster_10817': ['adig', 'ofav'],
#  'cluster_10818': ['adig', 'ofav'],
#  'cluster_10819': ['adig', 'ofav'],
#  'cluster_1082': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10820': ['adig', 'ofav'],
#  'cluster_10821': ['adig', 'ofav'],
#  'cluster_10822': ['adig', 'ofav'],
#  'cluster_10823': ['adig', 'ofav'],
#  'cluster_10824': ['adig', 'ofav'],
#  'cluster_10825': ['adig', 'ofav', 'spis'],
#  'cluster_10826': ['adig', 'ofav'],
#  'cluster_10827': ['adig', 'ofav'],
#  'cluster_10828': ['adig', 'ofav'],
#  'cluster_10829': ['adig', 'ofav'],
#  'cluster_1083': ['adig', 'pdam', 'spis'],
#  'cluster_10830': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10831': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10832': ['adig', 'ofav'],
#  'cluster_10833': ['adig', 'ofav'],
#  'cluster_10834': ['adig', 'ofav', 'aten'],
#  'cluster_10835': ['adig', 'ofav'],
#  'cluster_10836': ['adig', 'ofav'],
#  'cluster_10837': ['adig', 'ofav'],
#  'cluster_10838': ['adig', 'ofav'],
#  'cluster_10839': ['adig', 'ofav'],
#  'cluster_1084': ['adig', 'pdam', 'spis'],
#  'cluster_10840': ['adig', 'ofav'],
#  'cluster_10841': ['adig', 'ofav'],
#  'cluster_10842': ['adig', 'ofav'],
#  'cluster_10843': ['adig', 'ofav'],
#  'cluster_10844': ['adig', 'ofav'],
#  'cluster_10845': ['adig', 'ofav'],
#  'cluster_10846': ['adig', 'ofav'],
#  'cluster_10847': ['adig', 'ofav'],
#  'cluster_10848': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10849': ['adig', 'ofav', 'spis'],
#  'cluster_1085': ['adig', 'pdam'],
#  'cluster_10850': ['adig', 'ofav'],
#  'cluster_10851': ['adig', 'ofav'],
#  'cluster_10852': ['adig', 'ofav'],
#  'cluster_10853': ['adig', 'ofav', 'spis'],
#  'cluster_10854': ['adig', 'ofav'],
#  'cluster_10855': ['adig', 'ofav'],
#  'cluster_10856': ['adig', 'ofav'],
#  'cluster_10857': ['adig', 'ofav'],
#  'cluster_10858': ['adig', 'ofav'],
#  'cluster_10859': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_1086': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10860': ['adig', 'ofav'],
#  'cluster_10861': ['adig', 'ofav'],
#  'cluster_10862': ['adig', 'ofav'],
#  'cluster_10863': ['adig', 'ofav'],
#  'cluster_10864': ['adig', 'ofav'],
#  'cluster_10865': ['adig', 'ofav'],
#  'cluster_10866': ['adig', 'ofav'],
#  'cluster_10867': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10868': ['adig', 'ofav'],
#  'cluster_10869': ['adig', 'ofav'],
#  'cluster_1087': ['adig', 'pdam', 'spis'],
#  'cluster_10870': ['adig', 'ofav'],
#  'cluster_10871': ['adig', 'ofav'],
#  'cluster_10872': ['adig', 'ofav'],
#  'cluster_10873': ['adig', 'ofav'],
#  'cluster_10874': ['adig', 'ofav'],
#  'cluster_10875': ['adig', 'ofav', 'spis'],
#  'cluster_10876': ['adig', 'ofav'],
#  'cluster_10877': ['adig', 'ofav'],
#  'cluster_10878': ['adig', 'ofav'],
#  'cluster_10879': ['adig', 'ofav'],
#  'cluster_1088': ['adig', 'pdam'],
#  'cluster_10880': ['adig', 'ofav'],
#  'cluster_10881': ['adig', 'ofav'],
#  'cluster_10882': ['adig', 'ofav'],
#  'cluster_10883': ['adig', 'ofav'],
#  'cluster_10884': ['adig', 'ofav'],
#  'cluster_10885': ['adig', 'ofav', 'epal', 'pdam', 'spis'],
#  'cluster_10886': ['adig', 'ofav'],
#  'cluster_10887': ['adig', 'ofav', 'spis'],
#  'cluster_10888': ['adig', 'ofav', 'spis'],
#  'cluster_10889': ['adig', 'ofav', 'pdam'],
#  'cluster_1089': ['adig', 'ofav', 'pdam', 'spis'],
#  'cluster_10890': ['adig', 'ofav'],
#  'cluster_10891': ['adig', 'ofav'],
#  'cluster_10892': ['adig', 'ofav'],
#  'cluster_10893': ['adig', 'ofav'],
#  'cluster_10894': ['adig', 'ofav'],
#  'cluster_10895': ['adig', 'ofav'],
#  'cluster_10896': ['adig', 'ofav'],
#  'cluster_10897': ['adig', 'ofav'],
#  'cluster_10898': ['adig', 'ofav'],
#  ...}

# %% [markdown]
# #### For each cluster:
# - find common ancestor of all species
# - check state at that node
# - if node is 0, cluster is considered convergent

# %% [markdown]
# #### Function that retrieves all common ancestors of a set of species

# %%
def find_common_ancestors(sp_list, tree):
    result = None 
    all_ancestors = []
    for species in sp_list:
        ancestor = species
        ancestors = {species}
        while True:
            try:
                ancestor = tree[ancestor]  # get the species' ancestor
                ancestors.add(ancestor)  # store it in the ancestors set
            except KeyError:
                all_ancestors.append(ancestors) # add all ancestors of species to all_ancestors_list
                break
    # Now all_ancestors is a list of all sets of ancestors (one set per species)
    common = set.intersection(*all_ancestors)
    return common

# %% [markdown]
# #### Function that determines which common ancestor is the most recent
#
# Run with ancestor set and original ancestor set as same set of ancestors. One set will change during recursion, the other will remain unchanged.
# To do: find a more elegant way to do this.

# %%
def most_recent_ancestor(ancestor_set, sp_list, tax_dict, original_ancestor_set):
    original_ancestor_set = original_ancestor_set.copy()
    for ancestor in ancestor_set.copy(): # copy to avoid changing length of set during iteration
        # create list of all parents of that ancestor in case none of them are in ancestor set
        parent_set = set()
        for parent, child in tax_dict.items():
            if child == ancestor: # Find parent of current ancestor
                parent_set.add(parent)
                if parent in ancestor_set and parent not in sp_list: # Jump to next parent in ancestor set
                    ancestor_set.discard(child)
                    if len(ancestor_set) == 1: # job done
                        return(parent)
                    else:
                        most_recent_ancestor(ancestor_set, sp_list, tax_dict, original_ancestor_set) # run function again with reduced ancestor set
                elif parent in sp_list:
                    return(child)
        if not parent_set & original_ancestor_set:
            return(ancestor)

# %% [markdown]
# #### Retrieve most recent common ancestor of all clusters
# At the same time, identify clusters where common ancestor of all species does not have cluster (one of the species acquired convergently)

# %%
len(conserved_clust_species)
# Out:
# 30189

# %%
cluster_lcas = {}
additional_convergent_clusters = []
for cluster, sp_list in conserved_clust_species.items():
    #if cluster in conserved_clusters:
        common_ancestors = find_common_ancestors(sp_list, tax_dict)
        lca = most_recent_ancestor(common_ancestors, sp_list, tax_dict, common_ancestors)
        if cluster in conserved_clust_nodes and lca not in conserved_clust_nodes[cluster]:
            additional_convergent_clusters.append(cluster)
        elif cluster not in convergent_clusters: 
            cluster_lcas[cluster] = lca

# %%
len(cluster_lcas)
# Out:
# 18140

# %%
'cluster_23' in additional_convergent_clusters
# Out:
# True

# %% [markdown]
# #### Count losses

# %%
cluster_lcas
# Out:
# {'cluster_1': 'cnidaria',
#  'cluster_10': 'scleractinia',
#  'cluster_100': 'scleractinia',
#  'cluster_1000': 'scleractinia',
#  'cluster_10000': 'scleractinia',
#  'cluster_10001': 'scleractinia',
#  'cluster_10002': 'scleractinia',
#  'cluster_10003': 'scleractinia',
#  'cluster_10004': 'scleractinia',
#  'cluster_10005': 'scleractinia',
#  'cluster_10006': 'hexacorallia',
#  'cluster_10007': 'scleractinia',
#  'cluster_10008': 'scleractinia',
#  'cluster_10009': 'scleractinia',
#  'cluster_1001': 'scleractinia',
#  'cluster_10010': 'scleractinia',
#  'cluster_10011': 'scleractinia',
#  'cluster_10012': 'scleractinia',
#  'cluster_10013': 'scleractinia',
#  'cluster_10014': 'scleractinia',
#  'cluster_10015': 'scleractinia',
#  'cluster_10016': 'scleractinia',
#  'cluster_10017': 'scleractinia',
#  'cluster_10018': 'scleractinia',
#  'cluster_10019': 'scleractinia',
#  'cluster_1002': 'scleractinia',
#  'cluster_10020': 'scleractinia',
#  'cluster_10021': 'scleractinia',
#  'cluster_10022': 'scleractinia',
#  'cluster_10023': 'scleractinia',
#  'cluster_10024': 'scleractinia',
#  'cluster_10025': 'scleractinia',
#  'cluster_10026': 'scleractinia',
#  'cluster_10027': 'scleractinia',
#  'cluster_10028': 'scleractinia',
#  'cluster_10029': 'scleractinia',
#  'cluster_1003': 'hexacorallia',
#  'cluster_10030': 'scleractinia',
#  'cluster_10031': 'scleractinia',
#  'cluster_10032': 'scleractinia',
#  'cluster_10033': 'scleractinia',
#  'cluster_10034': 'scleractinia',
#  'cluster_10035': 'scleractinia',
#  'cluster_10036': 'scleractinia',
#  'cluster_10037': 'scleractinia',
#  'cluster_10038': 'scleractinia',
#  'cluster_10039': 'scleractinia',
#  'cluster_1004': 'scleractinia',
#  'cluster_10040': 'scleractinia',
#  'cluster_10041': 'scleractinia',
#  'cluster_10042': 'scleractinia',
#  'cluster_10043': 'scleractinia',
#  'cluster_10044': 'scleractinia',
#  'cluster_10045': 'scleractinia',
#  'cluster_10046': 'scleractinia',
#  'cluster_10047': 'scleractinia',
#  'cluster_10048': 'scleractinia',
#  'cluster_10049': 'scleractinia',
#  'cluster_1005': 'scleractinia',
#  'cluster_10050': 'scleractinia',
#  'cluster_10051': 'scleractinia',
#  'cluster_10052': 'scleractinia',
#  'cluster_10053': 'scleractinia',
#  'cluster_10054': 'scleractinia',
#  'cluster_10055': 'scleractinia',
#  'cluster_10056': 'scleractinia',
#  'cluster_10057': 'scleractinia',
#  'cluster_10058': 'scleractinia',
#  'cluster_10059': 'scleractinia',
#  'cluster_1006': 'hexacorallia',
#  'cluster_10060': 'scleractinia',
#  'cluster_10061': 'scleractinia',
#  'cluster_10062': 'scleractinia',
#  'cluster_10063': 'scleractinia',
#  'cluster_10064': 'scleractinia',
#  'cluster_10065': 'scleractinia',
#  'cluster_10066': 'scleractinia',
#  'cluster_10067': 'scleractinia',
#  'cluster_10068': 'scleractinia',
#  'cluster_10069': 'scleractinia',
#  'cluster_1007': 'scleractinia',
#  'cluster_10070': 'scleractinia',
#  'cluster_10071': 'scleractinia',
#  'cluster_10072': 'scleractinia',
#  'cluster_10073': 'scleractinia',
#  'cluster_10074': 'scleractinia',
#  'cluster_10075': 'scleractinia',
#  'cluster_10076': 'scleractinia',
#  'cluster_10077': 'scleractinia',
#  'cluster_10078': 'scleractinia',
#  'cluster_10079': 'scleractinia',
#  'cluster_1008': 'scleractinia',
#  'cluster_10080': 'scleractinia',
#  'cluster_10081': 'scleractinia',
#  'cluster_10082': 'scleractinia',
#  'cluster_10083': 'scleractinia',
#  'cluster_10084': 'scleractinia',
#  'cluster_10085': 'scleractinia',
#  'cluster_10086': 'scleractinia',
#  'cluster_10087': 'scleractinia',
#  'cluster_10088': 'scleractinia',
#  'cluster_10089': 'scleractinia',
#  'cluster_10090': 'scleractinia',
#  'cluster_10091': 'scleractinia',
#  'cluster_10092': 'scleractinia',
#  'cluster_10093': 'scleractinia',
#  'cluster_10094': 'scleractinia',
#  'cluster_10095': 'scleractinia',
#  'cluster_10096': 'scleractinia',
#  'cluster_10097': 'scleractinia',
#  'cluster_10098': 'scleractinia',
#  'cluster_10099': 'scleractinia',
#  'cluster_101': 'scleractinia',
#  'cluster_1010': 'cnidaria',
#  'cluster_10100': 'scleractinia',
#  'cluster_10101': 'scleractinia',
#  'cluster_10102': 'scleractinia',
#  'cluster_10103': 'scleractinia',
#  'cluster_10104': 'scleractinia',
#  'cluster_10105': 'scleractinia',
#  'cluster_10106': 'scleractinia',
#  'cluster_10107': 'scleractinia',
#  'cluster_10108': 'scleractinia',
#  'cluster_10109': 'scleractinia',
#  'cluster_1011': 'scleractinia',
#  'cluster_10110': 'scleractinia',
#  'cluster_10111': 'scleractinia',
#  'cluster_10112': 'scleractinia',
#  'cluster_10113': 'scleractinia',
#  'cluster_10114': 'scleractinia',
#  'cluster_10115': 'scleractinia',
#  'cluster_10116': 'scleractinia',
#  'cluster_10117': 'scleractinia',
#  'cluster_10118': 'scleractinia',
#  'cluster_10119': 'scleractinia',
#  'cluster_1012': 'hexacorallia',
#  'cluster_10120': 'scleractinia',
#  'cluster_10121': 'scleractinia',
#  'cluster_10122': 'scleractinia',
#  'cluster_10123': 'scleractinia',
#  'cluster_10124': 'scleractinia',
#  'cluster_10125': 'scleractinia',
#  'cluster_10126': 'scleractinia',
#  'cluster_10127': 'scleractinia',
#  'cluster_10128': 'scleractinia',
#  'cluster_10129': 'scleractinia',
#  'cluster_10130': 'scleractinia',
#  'cluster_10131': 'scleractinia',
#  'cluster_10132': 'scleractinia',
#  'cluster_10133': 'scleractinia',
#  'cluster_10134': 'scleractinia',
#  'cluster_10135': 'scleractinia',
#  'cluster_10136': 'scleractinia',
#  'cluster_10137': 'scleractinia',
#  'cluster_10138': 'scleractinia',
#  'cluster_10139': 'scleractinia',
#  'cluster_10140': 'scleractinia',
#  'cluster_10141': 'scleractinia',
#  'cluster_10142': 'scleractinia',
#  'cluster_10143': 'scleractinia',
#  'cluster_10144': 'scleractinia',
#  'cluster_10145': 'scleractinia',
#  'cluster_10146': 'scleractinia',
#  'cluster_10147': 'scleractinia',
#  'cluster_10148': 'scleractinia',
#  'cluster_10149': 'scleractinia',
#  'cluster_1015': 'anthozoa',
#  'cluster_10150': 'scleractinia',
#  'cluster_10151': 'scleractinia',
#  'cluster_10152': 'scleractinia',
#  'cluster_10153': 'scleractinia',
#  'cluster_10154': 'scleractinia',
#  'cluster_10155': 'scleractinia',
#  'cluster_10156': 'scleractinia',
#  'cluster_10157': 'scleractinia',
#  'cluster_10158': 'scleractinia',
#  'cluster_10159': 'scleractinia',
#  'cluster_1016': 'scleractinia',
#  'cluster_10160': 'scleractinia',
#  'cluster_10161': 'scleractinia',
#  'cluster_10162': 'scleractinia',
#  'cluster_10163': 'scleractinia',
#  'cluster_10164': 'scleractinia',
#  'cluster_10165': 'hexacorallia',
#  'cluster_10166': 'anthozoa',
#  'cluster_10167': 'scleractinia',
#  'cluster_10168': 'scleractinia',
#  'cluster_10169': 'scleractinia',
#  'cluster_1017': 'cnidaria',
#  'cluster_10170': 'scleractinia',
#  'cluster_10171': 'scleractinia',
#  'cluster_10172': 'scleractinia',
#  'cluster_10173': 'scleractinia',
#  'cluster_10174': 'scleractinia',
#  'cluster_10175': 'scleractinia',
#  'cluster_10176': 'hexacorallia',
#  'cluster_10177': 'hexacorallia',
#  'cluster_10178': 'scleractinia',
#  'cluster_10179': 'scleractinia',
#  'cluster_10180': 'scleractinia',
#  'cluster_10181': 'scleractinia',
#  'cluster_10182': 'scleractinia',
#  'cluster_10183': 'scleractinia',
#  'cluster_10184': 'scleractinia',
#  'cluster_10185': 'scleractinia',
#  'cluster_10186': 'scleractinia',
#  'cluster_10187': 'scleractinia',
#  'cluster_10188': 'scleractinia',
#  'cluster_10189': 'scleractinia',
#  'cluster_1019': 'scleractinia',
#  'cluster_10190': 'scleractinia',
#  'cluster_10191': 'scleractinia',
#  'cluster_10192': 'scleractinia',
#  'cluster_10193': 'scleractinia',
#  'cluster_10194': 'scleractinia',
#  'cluster_10195': 'scleractinia',
#  'cluster_10196': 'scleractinia',
#  'cluster_10197': 'scleractinia',
#  'cluster_10198': 'scleractinia',
#  'cluster_10199': 'scleractinia',
#  'cluster_102': 'scleractinia',
#  'cluster_1020': 'hexacorallia',
#  'cluster_10200': 'scleractinia',
#  'cluster_10201': 'scleractinia',
#  'cluster_10202': 'scleractinia',
#  'cluster_10203': 'scleractinia',
#  'cluster_10204': 'scleractinia',
#  'cluster_10205': 'scleractinia',
#  'cluster_10206': 'scleractinia',
#  'cluster_10207': 'scleractinia',
#  'cluster_10208': 'scleractinia',
#  'cluster_10209': 'scleractinia',
#  'cluster_1021': 'scleractinia',
#  'cluster_10210': 'scleractinia',
#  'cluster_10211': 'scleractinia',
#  'cluster_10212': 'scleractinia',
#  'cluster_10213': 'scleractinia',
#  'cluster_10214': 'scleractinia',
#  'cluster_10215': 'scleractinia',
#  'cluster_10216': 'scleractinia',
#  'cluster_10217': 'scleractinia',
#  'cluster_10218': 'scleractinia',
#  'cluster_10219': 'scleractinia',
#  'cluster_1022': 'scleractinia',
#  'cluster_10220': 'scleractinia',
#  'cluster_10221': 'scleractinia',
#  'cluster_10222': 'scleractinia',
#  'cluster_10223': 'scleractinia',
#  'cluster_10224': 'scleractinia',
#  'cluster_10225': 'scleractinia',
#  'cluster_10226': 'scleractinia',
#  'cluster_10227': 'scleractinia',
#  'cluster_10228': 'scleractinia',
#  'cluster_10229': 'anthozoa',
#  'cluster_1023': 'anthozoa',
#  'cluster_10230': 'scleractinia',
#  'cluster_10231': 'scleractinia',
#  'cluster_10232': 'scleractinia',
#  'cluster_10233': 'scleractinia',
#  'cluster_10234': 'scleractinia',
#  'cluster_10235': 'scleractinia',
#  'cluster_10236': 'scleractinia',
#  'cluster_10237': 'scleractinia',
#  'cluster_10238': 'scleractinia',
#  'cluster_10239': 'scleractinia',
#  'cluster_1024': 'scleractinia',
#  'cluster_10240': 'scleractinia',
#  'cluster_10241': 'scleractinia',
#  'cluster_10242': 'scleractinia',
#  'cluster_10243': 'scleractinia',
#  'cluster_10244': 'scleractinia',
#  'cluster_10245': 'scleractinia',
#  'cluster_10246': 'scleractinia',
#  'cluster_10247': 'scleractinia',
#  'cluster_10248': 'scleractinia',
#  'cluster_10249': 'scleractinia',
#  'cluster_10250': 'scleractinia',
#  'cluster_10251': 'scleractinia',
#  'cluster_10252': 'scleractinia',
#  'cluster_10253': 'scleractinia',
#  'cluster_10254': 'scleractinia',
#  'cluster_10255': 'scleractinia',
#  'cluster_10256': 'scleractinia',
#  'cluster_10257': 'scleractinia',
#  'cluster_10258': 'scleractinia',
#  'cluster_10259': 'scleractinia',
#  'cluster_10260': 'scleractinia',
#  'cluster_10261': 'scleractinia',
#  'cluster_10262': 'scleractinia',
#  'cluster_10263': 'scleractinia',
#  'cluster_10264': 'scleractinia',
#  'cluster_10265': 'scleractinia',
#  'cluster_10266': 'scleractinia',
#  'cluster_10267': 'scleractinia',
#  'cluster_10268': 'scleractinia',
#  'cluster_10269': 'scleractinia',
#  'cluster_1027': 'scleractinia',
#  'cluster_10270': 'scleractinia',
#  'cluster_10271': 'scleractinia',
#  'cluster_10272': 'scleractinia',
#  'cluster_10273': 'scleractinia',
#  'cluster_10274': 'scleractinia',
#  'cluster_10275': 'scleractinia',
#  'cluster_10276': 'scleractinia',
#  'cluster_10277': 'scleractinia',
#  'cluster_10278': 'scleractinia',
#  'cluster_10279': 'scleractinia',
#  'cluster_1028': 'scleractinia',
#  'cluster_10280': 'scleractinia',
#  'cluster_10281': 'scleractinia',
#  'cluster_10282': 'scleractinia',
#  'cluster_10283': 'scleractinia',
#  'cluster_10284': 'scleractinia',
#  'cluster_10285': 'scleractinia',
#  'cluster_10286': 'scleractinia',
#  'cluster_10287': 'scleractinia',
#  'cluster_10288': 'scleractinia',
#  'cluster_10289': 'scleractinia',
#  'cluster_1029': 'scleractinia',
#  'cluster_10290': 'scleractinia',
#  'cluster_10291': 'scleractinia',
#  'cluster_10292': 'scleractinia',
#  'cluster_10293': 'scleractinia',
#  'cluster_10294': 'scleractinia',
#  'cluster_10295': 'scleractinia',
#  'cluster_10296': 'scleractinia',
#  'cluster_10297': 'scleractinia',
#  'cluster_10298': 'scleractinia',
#  'cluster_10299': 'scleractinia',
#  'cluster_1030': 'scleractinia',
#  'cluster_10300': 'scleractinia',
#  'cluster_10301': 'scleractinia',
#  'cluster_10302': 'scleractinia',
#  'cluster_10303': 'scleractinia',
#  'cluster_10304': 'scleractinia',
#  'cluster_10305': 'scleractinia',
#  'cluster_10306': 'scleractinia',
#  'cluster_10307': 'scleractinia',
#  'cluster_10308': 'scleractinia',
#  'cluster_10309': 'scleractinia',
#  'cluster_1031': 'scleractinia',
#  'cluster_10310': 'scleractinia',
#  'cluster_10311': 'scleractinia',
#  'cluster_10312': 'scleractinia',
#  'cluster_10313': 'scleractinia',
#  'cluster_10314': 'scleractinia',
#  'cluster_10315': 'scleractinia',
#  'cluster_10316': 'scleractinia',
#  'cluster_10317': 'scleractinia',
#  'cluster_10318': 'scleractinia',
#  'cluster_10319': 'scleractinia',
#  'cluster_1032': 'scleractinia',
#  'cluster_10320': 'scleractinia',
#  'cluster_10321': 'scleractinia',
#  'cluster_10322': 'scleractinia',
#  'cluster_10323': 'scleractinia',
#  'cluster_10324': 'scleractinia',
#  'cluster_10325': 'scleractinia',
#  'cluster_10326': 'scleractinia',
#  'cluster_10327': 'scleractinia',
#  'cluster_10328': 'scleractinia',
#  'cluster_10329': 'scleractinia',
#  'cluster_1033': 'scleractinia',
#  'cluster_10330': 'scleractinia',
#  'cluster_10331': 'scleractinia',
#  'cluster_10332': 'scleractinia',
#  'cluster_10333': 'scleractinia',
#  'cluster_10334': 'scleractinia',
#  'cluster_10335': 'scleractinia',
#  'cluster_10336': 'scleractinia',
#  'cluster_10337': 'scleractinia',
#  'cluster_10338': 'scleractinia',
#  'cluster_10339': 'scleractinia',
#  'cluster_1034': 'scleractinia',
#  'cluster_10340': 'scleractinia',
#  'cluster_10341': 'scleractinia',
#  'cluster_10342': 'scleractinia',
#  'cluster_10343': 'scleractinia',
#  'cluster_10344': 'scleractinia',
#  'cluster_10345': 'scleractinia',
#  'cluster_10346': 'scleractinia',
#  'cluster_10347': 'scleractinia',
#  'cluster_10348': 'scleractinia',
#  'cluster_10349': 'scleractinia',
#  'cluster_1035': 'hexacorallia',
#  'cluster_10350': 'scleractinia',
#  'cluster_10351': 'scleractinia',
#  'cluster_10352': 'scleractinia',
#  'cluster_10353': 'scleractinia',
#  'cluster_10354': 'scleractinia',
#  'cluster_10355': 'scleractinia',
#  'cluster_10356': 'cnidaria',
#  'cluster_10357': 'scleractinia',
#  'cluster_10358': 'scleractinia',
#  'cluster_10359': 'scleractinia',
#  'cluster_10360': 'scleractinia',
#  'cluster_10361': 'scleractinia',
#  'cluster_10362': 'scleractinia',
#  'cluster_10363': 'scleractinia',
#  'cluster_10364': 'scleractinia',
#  'cluster_10365': 'scleractinia',
#  'cluster_10366': 'scleractinia',
#  'cluster_10367': 'scleractinia',
#  'cluster_10368': 'scleractinia',
#  'cluster_10369': 'scleractinia',
#  'cluster_10370': 'scleractinia',
#  'cluster_10371': 'scleractinia',
#  'cluster_10372': 'scleractinia',
#  'cluster_10373': 'scleractinia',
#  'cluster_10374': 'scleractinia',
#  'cluster_10375': 'scleractinia',
#  'cluster_10376': 'scleractinia',
#  'cluster_10377': 'scleractinia',
#  'cluster_10378': 'scleractinia',
#  'cluster_10379': 'scleractinia',
#  'cluster_1038': 'scleractinia',
#  'cluster_10380': 'scleractinia',
#  'cluster_10381': 'scleractinia',
#  'cluster_10382': 'scleractinia',
#  'cluster_10383': 'scleractinia',
#  'cluster_10384': 'scleractinia',
#  'cluster_10385': 'scleractinia',
#  'cluster_10386': 'scleractinia',
#  'cluster_10387': 'scleractinia',
#  'cluster_10388': 'scleractinia',
#  'cluster_10389': 'scleractinia',
#  'cluster_1039': 'hexacorallia',
#  'cluster_10390': 'scleractinia',
#  'cluster_10391': 'scleractinia',
#  'cluster_10392': 'scleractinia',
#  'cluster_10393': 'scleractinia',
#  'cluster_10394': 'scleractinia',
#  'cluster_10395': 'scleractinia',
#  'cluster_10396': 'scleractinia',
#  'cluster_10397': 'scleractinia',
#  'cluster_10399': 'scleractinia',
#  'cluster_104': 'scleractinia',
#  'cluster_1040': 'scleractinia',
#  'cluster_10400': 'scleractinia',
#  'cluster_10401': 'scleractinia',
#  'cluster_10402': 'scleractinia',
#  'cluster_10403': 'scleractinia',
#  'cluster_10404': 'scleractinia',
#  'cluster_10405': 'scleractinia',
#  'cluster_10406': 'scleractinia',
#  'cluster_10407': 'scleractinia',
#  'cluster_10408': 'scleractinia',
#  'cluster_10409': 'scleractinia',
#  'cluster_10410': 'scleractinia',
#  'cluster_10411': 'scleractinia',
#  'cluster_10412': 'scleractinia',
#  'cluster_10413': 'scleractinia',
#  'cluster_10414': 'scleractinia',
#  'cluster_10415': 'scleractinia',
#  'cluster_10416': 'scleractinia',
#  'cluster_10417': 'scleractinia',
#  'cluster_10418': 'scleractinia',
#  'cluster_10419': 'scleractinia',
#  'cluster_1042': 'scleractinia',
#  'cluster_10420': 'scleractinia',
#  'cluster_10421': 'scleractinia',
#  'cluster_10422': 'scleractinia',
#  'cluster_10423': 'scleractinia',
#  'cluster_10424': 'scleractinia',
#  'cluster_10425': 'scleractinia',
#  'cluster_10426': 'scleractinia',
#  'cluster_10427': 'scleractinia',
#  'cluster_10428': 'scleractinia',
#  'cluster_10429': 'scleractinia',
#  'cluster_1043': 'scleractinia',
#  'cluster_10430': 'scleractinia',
#  'cluster_10431': 'hexacorallia',
#  'cluster_10432': 'scleractinia',
#  'cluster_10433': 'scleractinia',
#  'cluster_10434': 'scleractinia',
#  'cluster_10435': 'scleractinia',
#  'cluster_10436': 'scleractinia',
#  'cluster_10437': 'scleractinia',
#  'cluster_10438': 'scleractinia',
#  'cluster_10439': 'scleractinia',
#  'cluster_1044': 'scleractinia',
#  'cluster_10440': 'scleractinia',
#  'cluster_10441': 'scleractinia',
#  'cluster_10442': 'scleractinia',
#  'cluster_10443': 'scleractinia',
#  'cluster_10444': 'hexacorallia',
#  'cluster_10445': 'scleractinia',
#  'cluster_10446': 'scleractinia',
#  'cluster_10447': 'scleractinia',
#  'cluster_10448': 'hexacorallia',
#  'cluster_10449': 'scleractinia',
#  'cluster_1045': 'scleractinia',
#  'cluster_10450': 'scleractinia',
#  'cluster_10451': 'scleractinia',
#  'cluster_10452': 'scleractinia',
#  'cluster_10453': 'scleractinia',
#  'cluster_10454': 'scleractinia',
#  'cluster_10455': 'scleractinia',
#  'cluster_10456': 'scleractinia',
#  'cluster_10457': 'scleractinia',
#  'cluster_10458': 'scleractinia',
#  'cluster_10459': 'scleractinia',
#  'cluster_10460': 'scleractinia',
#  'cluster_10461': 'scleractinia',
#  'cluster_10462': 'scleractinia',
#  'cluster_10463': 'scleractinia',
#  'cluster_10464': 'scleractinia',
#  'cluster_10465': 'scleractinia',
#  'cluster_10466': 'scleractinia',
#  'cluster_10467': 'scleractinia',
#  'cluster_10468': 'scleractinia',
#  'cluster_10469': 'scleractinia',
#  'cluster_1047': 'scleractinia',
#  'cluster_10470': 'scleractinia',
#  'cluster_10471': 'scleractinia',
#  'cluster_10472': 'scleractinia',
#  'cluster_10473': 'scleractinia',
#  'cluster_10474': 'scleractinia',
#  'cluster_10475': 'scleractinia',
#  'cluster_10476': 'scleractinia',
#  'cluster_10477': 'scleractinia',
#  'cluster_10478': 'scleractinia',
#  'cluster_10479': 'scleractinia',
#  'cluster_10480': 'scleractinia',
#  'cluster_10481': 'scleractinia',
#  'cluster_10482': 'scleractinia',
#  'cluster_10483': 'scleractinia',
#  'cluster_10484': 'scleractinia',
#  'cluster_10485': 'scleractinia',
#  'cluster_10486': 'hexacorallia',
#  'cluster_10487': 'scleractinia',
#  'cluster_10488': 'scleractinia',
#  'cluster_10489': 'scleractinia',
#  'cluster_1049': 'scleractinia',
#  'cluster_10490': 'scleractinia',
#  'cluster_10491': 'scleractinia',
#  'cluster_10492': 'scleractinia',
#  'cluster_10493': 'scleractinia',
#  'cluster_10494': 'scleractinia',
#  'cluster_10495': 'scleractinia',
#  'cluster_10496': 'scleractinia',
#  'cluster_10497': 'scleractinia',
#  'cluster_10498': 'scleractinia',
#  'cluster_10499': 'scleractinia',
#  'cluster_105': 'scleractinia',
#  'cluster_1050': 'scleractinia',
#  'cluster_10500': 'scleractinia',
#  'cluster_10501': 'scleractinia',
#  'cluster_10502': 'scleractinia',
#  'cluster_10503': 'scleractinia',
#  'cluster_10504': 'scleractinia',
#  'cluster_10505': 'scleractinia',
#  'cluster_10506': 'scleractinia',
#  'cluster_10507': 'scleractinia',
#  'cluster_10508': 'scleractinia',
#  'cluster_10509': 'scleractinia',
#  'cluster_10510': 'scleractinia',
#  'cluster_10511': 'scleractinia',
#  'cluster_10512': 'scleractinia',
#  'cluster_10513': 'scleractinia',
#  'cluster_10514': 'scleractinia',
#  'cluster_10515': 'scleractinia',
#  'cluster_10516': 'scleractinia',
#  'cluster_10517': 'scleractinia',
#  'cluster_10518': 'scleractinia',
#  'cluster_10519': 'scleractinia',
#  'cluster_10520': 'scleractinia',
#  'cluster_10521': 'scleractinia',
#  'cluster_10522': 'scleractinia',
#  'cluster_10523': 'scleractinia',
#  'cluster_10524': 'scleractinia',
#  'cluster_10525': 'scleractinia',
#  'cluster_10526': 'scleractinia',
#  'cluster_10527': 'scleractinia',
#  'cluster_10528': 'scleractinia',
#  'cluster_10529': 'scleractinia',
#  'cluster_1053': 'anthozoa',
#  'cluster_10530': 'scleractinia',
#  'cluster_10531': 'scleractinia',
#  'cluster_10532': 'scleractinia',
#  'cluster_10533': 'scleractinia',
#  'cluster_10534': 'scleractinia',
#  'cluster_10535': 'scleractinia',
#  'cluster_10536': 'scleractinia',
#  'cluster_10537': 'scleractinia',
#  'cluster_10538': 'scleractinia',
#  'cluster_10539': 'scleractinia',
#  'cluster_1054': 'scleractinia',
#  'cluster_10540': 'scleractinia',
#  'cluster_10541': 'scleractinia',
#  'cluster_10542': 'scleractinia',
#  'cluster_10543': 'scleractinia',
#  'cluster_10544': 'scleractinia',
#  'cluster_10545': 'scleractinia',
#  'cluster_10546': 'scleractinia',
#  'cluster_10547': 'scleractinia',
#  'cluster_10548': 'scleractinia',
#  'cluster_10549': 'scleractinia',
#  'cluster_1055': 'scleractinia',
#  'cluster_10550': 'scleractinia',
#  'cluster_10551': 'hexacorallia',
#  'cluster_10552': 'scleractinia',
#  'cluster_10553': 'scleractinia',
#  'cluster_10554': 'scleractinia',
#  'cluster_10555': 'scleractinia',
#  'cluster_10556': 'scleractinia',
#  'cluster_10557': 'scleractinia',
#  'cluster_10558': 'scleractinia',
#  'cluster_10559': 'scleractinia',
#  'cluster_1056': 'scleractinia',
#  'cluster_10560': 'scleractinia',
#  'cluster_10561': 'scleractinia',
#  'cluster_10562': 'scleractinia',
#  'cluster_10563': 'scleractinia',
#  'cluster_10564': 'anthozoa',
#  'cluster_10565': 'scleractinia',
#  'cluster_10566': 'scleractinia',
#  'cluster_10567': 'scleractinia',
#  'cluster_10568': 'scleractinia',
#  'cluster_10569': 'scleractinia',
#  'cluster_1057': 'scleractinia',
#  'cluster_10570': 'scleractinia',
#  'cluster_10571': 'scleractinia',
#  'cluster_10572': 'scleractinia',
#  'cluster_10573': 'scleractinia',
#  'cluster_10574': 'scleractinia',
#  'cluster_10575': 'scleractinia',
#  'cluster_10576': 'scleractinia',
#  'cluster_10577': 'scleractinia',
#  'cluster_10578': 'scleractinia',
#  'cluster_10579': 'scleractinia',
#  'cluster_10580': 'scleractinia',
#  'cluster_10581': 'scleractinia',
#  'cluster_10582': 'scleractinia',
#  'cluster_10583': 'scleractinia',
#  'cluster_10584': 'scleractinia',
#  'cluster_10585': 'scleractinia',
#  'cluster_10586': 'scleractinia',
#  'cluster_10587': 'anthozoa',
#  'cluster_10588': 'scleractinia',
#  'cluster_10589': 'scleractinia',
#  'cluster_10590': 'scleractinia',
#  'cluster_10591': 'scleractinia',
#  'cluster_10592': 'scleractinia',
#  'cluster_10593': 'scleractinia',
#  'cluster_10594': 'scleractinia',
#  'cluster_10595': 'hexacorallia',
#  'cluster_10596': 'scleractinia',
#  'cluster_10597': 'scleractinia',
#  'cluster_10598': 'scleractinia',
#  'cluster_10599': 'scleractinia',
#  'cluster_106': 'scleractinia',
#  'cluster_1060': 'scleractinia',
#  'cluster_10600': 'scleractinia',
#  'cluster_10601': 'scleractinia',
#  'cluster_10602': 'scleractinia',
#  'cluster_10603': 'scleractinia',
#  'cluster_10604': 'scleractinia',
#  'cluster_10605': 'scleractinia',
#  'cluster_10606': 'scleractinia',
#  'cluster_10607': 'scleractinia',
#  'cluster_10608': 'scleractinia',
#  'cluster_10609': 'scleractinia',
#  'cluster_1061': 'scleractinia',
#  'cluster_10610': 'scleractinia',
#  'cluster_10611': 'scleractinia',
#  'cluster_10612': 'scleractinia',
#  'cluster_10613': 'scleractinia',
#  'cluster_10614': 'scleractinia',
#  'cluster_10615': 'scleractinia',
#  'cluster_10616': 'scleractinia',
#  'cluster_10617': 'scleractinia',
#  'cluster_10618': 'scleractinia',
#  'cluster_10619': 'scleractinia',
#  'cluster_10620': 'scleractinia',
#  'cluster_10621': 'scleractinia',
#  'cluster_10622': 'scleractinia',
#  'cluster_10623': 'scleractinia',
#  'cluster_10624': 'scleractinia',
#  'cluster_10625': 'scleractinia',
#  'cluster_10626': 'scleractinia',
#  'cluster_10627': 'scleractinia',
#  'cluster_10628': 'scleractinia',
#  'cluster_10629': 'scleractinia',
#  'cluster_1063': 'scleractinia',
#  'cluster_10630': 'scleractinia',
#  'cluster_10631': 'scleractinia',
#  'cluster_10632': 'scleractinia',
#  'cluster_10633': 'scleractinia',
#  'cluster_10634': 'scleractinia',
#  'cluster_10635': 'scleractinia',
#  'cluster_10636': 'scleractinia',
#  'cluster_10637': 'scleractinia',
#  'cluster_10638': 'scleractinia',
#  'cluster_10639': 'scleractinia',
#  'cluster_1064': 'scleractinia',
#  'cluster_10640': 'scleractinia',
#  'cluster_10641': 'scleractinia',
#  'cluster_10642': 'scleractinia',
#  'cluster_10643': 'scleractinia',
#  'cluster_10644': 'scleractinia',
#  'cluster_10645': 'scleractinia',
#  'cluster_10646': 'scleractinia',
#  'cluster_10647': 'scleractinia',
#  'cluster_10648': 'scleractinia',
#  'cluster_10649': 'scleractinia',
#  'cluster_1065': 'scleractinia',
#  'cluster_10650': 'scleractinia',
#  'cluster_10651': 'scleractinia',
#  'cluster_10652': 'scleractinia',
#  'cluster_10653': 'scleractinia',
#  'cluster_10654': 'scleractinia',
#  'cluster_10655': 'scleractinia',
#  'cluster_10656': 'scleractinia',
#  'cluster_10657': 'scleractinia',
#  'cluster_10658': 'scleractinia',
#  'cluster_10659': 'scleractinia',
#  'cluster_1066': 'hexacorallia',
#  'cluster_10660': 'scleractinia',
#  'cluster_10661': 'scleractinia',
#  'cluster_10662': 'scleractinia',
#  'cluster_10663': 'scleractinia',
#  'cluster_10664': 'scleractinia',
#  'cluster_10665': 'scleractinia',
#  'cluster_10666': 'scleractinia',
#  'cluster_10667': 'scleractinia',
#  'cluster_10668': 'scleractinia',
#  'cluster_10669': 'scleractinia',
#  'cluster_1067': 'scleractinia',
#  'cluster_10670': 'scleractinia',
#  'cluster_10671': 'scleractinia',
#  'cluster_10672': 'scleractinia',
#  'cluster_10673': 'scleractinia',
#  'cluster_10674': 'scleractinia',
#  'cluster_10675': 'scleractinia',
#  'cluster_10676': 'scleractinia',
#  'cluster_10677': 'scleractinia',
#  'cluster_10678': 'scleractinia',
#  'cluster_10679': 'scleractinia',
#  'cluster_10680': 'scleractinia',
#  'cluster_10681': 'scleractinia',
#  'cluster_10682': 'scleractinia',
#  'cluster_10683': 'scleractinia',
#  'cluster_10684': 'scleractinia',
#  'cluster_10685': 'scleractinia',
#  'cluster_10686': 'scleractinia',
#  'cluster_10687': 'scleractinia',
#  'cluster_10688': 'scleractinia',
#  'cluster_10689': 'scleractinia',
#  'cluster_10690': 'scleractinia',
#  'cluster_10691': 'scleractinia',
#  'cluster_10692': 'scleractinia',
#  'cluster_10693': 'scleractinia',
#  'cluster_10694': 'scleractinia',
#  'cluster_10695': 'scleractinia',
#  'cluster_10696': 'scleractinia',
#  'cluster_10697': 'scleractinia',
#  'cluster_10698': 'scleractinia',
#  'cluster_10699': 'scleractinia',
#  'cluster_107': 'scleractinia',
#  'cluster_10700': 'scleractinia',
#  'cluster_10701': 'scleractinia',
#  'cluster_10702': 'scleractinia',
#  'cluster_10703': 'scleractinia',
#  'cluster_10704': 'scleractinia',
#  'cluster_10705': 'scleractinia',
#  'cluster_10706': 'scleractinia',
#  'cluster_10707': 'scleractinia',
#  'cluster_10708': 'scleractinia',
#  'cluster_10709': 'scleractinia',
#  'cluster_1071': 'scleractinia',
#  'cluster_10710': 'scleractinia',
#  'cluster_10711': 'scleractinia',
#  'cluster_10712': 'scleractinia',
#  'cluster_10713': 'scleractinia',
#  'cluster_10714': 'scleractinia',
#  'cluster_10715': 'scleractinia',
#  'cluster_10716': 'scleractinia',
#  'cluster_10717': 'scleractinia',
#  'cluster_10718': 'scleractinia',
#  'cluster_10719': 'scleractinia',
#  'cluster_1072': 'scleractinia',
#  'cluster_10720': 'scleractinia',
#  'cluster_10721': 'scleractinia',
#  'cluster_10722': 'scleractinia',
#  'cluster_10723': 'scleractinia',
#  'cluster_10724': 'scleractinia',
#  'cluster_10725': 'scleractinia',
#  'cluster_10726': 'scleractinia',
#  'cluster_10727': 'scleractinia',
#  'cluster_10728': 'scleractinia',
#  'cluster_10729': 'scleractinia',
#  'cluster_1073': 'scleractinia',
#  'cluster_10730': 'scleractinia',
#  'cluster_10731': 'scleractinia',
#  'cluster_10732': 'scleractinia',
#  'cluster_10733': 'scleractinia',
#  'cluster_10734': 'scleractinia',
#  'cluster_10735': 'scleractinia',
#  'cluster_10736': 'scleractinia',
#  'cluster_10737': 'scleractinia',
#  'cluster_10738': 'scleractinia',
#  'cluster_10739': 'scleractinia',
#  'cluster_10740': 'scleractinia',
#  'cluster_10741': 'scleractinia',
#  'cluster_10742': 'scleractinia',
#  'cluster_10743': 'scleractinia',
#  'cluster_10744': 'scleractinia',
#  'cluster_10745': 'scleractinia',
#  'cluster_10746': 'scleractinia',
#  'cluster_10747': 'scleractinia',
#  'cluster_10748': 'scleractinia',
#  'cluster_10749': 'scleractinia',
#  'cluster_1075': 'scleractinia',
#  'cluster_10750': 'scleractinia',
#  'cluster_10751': 'scleractinia',
#  'cluster_10752': 'scleractinia',
#  'cluster_10753': 'scleractinia',
#  'cluster_10754': 'scleractinia',
#  'cluster_10755': 'scleractinia',
#  'cluster_10756': 'scleractinia',
#  'cluster_10757': 'scleractinia',
#  'cluster_10758': 'cnidaria',
#  'cluster_10759': 'scleractinia',
#  'cluster_1076': 'scleractinia',
#  'cluster_10760': 'scleractinia',
#  'cluster_10762': 'scleractinia',
#  'cluster_10763': 'scleractinia',
#  'cluster_10764': 'scleractinia',
#  'cluster_10765': 'scleractinia',
#  'cluster_10766': 'hexacorallia',
#  'cluster_10767': 'scleractinia',
#  'cluster_10768': 'scleractinia',
#  'cluster_10769': 'scleractinia',
#  'cluster_10770': 'scleractinia',
#  'cluster_10771': 'scleractinia',
#  'cluster_10772': 'scleractinia',
#  'cluster_10773': 'scleractinia',
#  'cluster_10774': 'scleractinia',
#  'cluster_10775': 'scleractinia',
#  'cluster_10776': 'scleractinia',
#  'cluster_10777': 'scleractinia',
#  'cluster_10778': 'scleractinia',
#  'cluster_10779': 'scleractinia',
#  'cluster_10780': 'scleractinia',
#  'cluster_10781': 'scleractinia',
#  'cluster_10782': 'hexacorallia',
#  'cluster_10783': 'scleractinia',
#  'cluster_10784': 'scleractinia',
#  'cluster_10785': 'scleractinia',
#  'cluster_10786': 'scleractinia',
#  'cluster_10787': 'scleractinia',
#  'cluster_10788': 'scleractinia',
#  'cluster_10789': 'scleractinia',
#  'cluster_10790': 'scleractinia',
#  'cluster_10791': 'scleractinia',
#  'cluster_10792': 'scleractinia',
#  'cluster_10793': 'scleractinia',
#  'cluster_10794': 'scleractinia',
#  'cluster_10795': 'scleractinia',
#  'cluster_10796': 'scleractinia',
#  'cluster_10797': 'scleractinia',
#  'cluster_10798': 'scleractinia',
#  'cluster_10799': 'scleractinia',
#  'cluster_108': 'hexacorallia',
#  'cluster_1080': 'scleractinia',
#  'cluster_10800': 'scleractinia',
#  'cluster_10801': 'scleractinia',
#  'cluster_10802': 'scleractinia',
#  'cluster_10803': 'scleractinia',
#  'cluster_10804': 'scleractinia',
#  'cluster_10805': 'scleractinia',
#  'cluster_10806': 'scleractinia',
#  'cluster_10807': 'scleractinia',
#  'cluster_10808': 'scleractinia',
#  'cluster_10809': 'scleractinia',
#  'cluster_10810': 'scleractinia',
#  'cluster_10811': 'scleractinia',
#  'cluster_10812': 'scleractinia',
#  'cluster_10813': 'scleractinia',
#  'cluster_10814': 'scleractinia',
#  'cluster_10815': 'scleractinia',
#  'cluster_10816': 'scleractinia',
#  'cluster_10817': 'scleractinia',
#  'cluster_10818': 'scleractinia',
#  'cluster_10819': 'scleractinia',
#  'cluster_1082': 'scleractinia',
#  'cluster_10820': 'scleractinia',
#  'cluster_10821': 'scleractinia',
#  'cluster_10822': 'scleractinia',
#  'cluster_10823': 'scleractinia',
#  'cluster_10824': 'scleractinia',
#  'cluster_10825': 'scleractinia',
#  'cluster_10826': 'scleractinia',
#  'cluster_10827': 'scleractinia',
#  'cluster_10828': 'scleractinia',
#  'cluster_10829': 'scleractinia',
#  'cluster_1083': 'scleractinia',
#  'cluster_10830': 'scleractinia',
#  'cluster_10831': 'scleractinia',
#  'cluster_10832': 'scleractinia',
#  'cluster_10833': 'scleractinia',
#  'cluster_10834': 'hexacorallia',
#  'cluster_10835': 'scleractinia',
#  'cluster_10836': 'scleractinia',
#  'cluster_10837': 'scleractinia',
#  'cluster_10838': 'scleractinia',
#  'cluster_10839': 'scleractinia',
#  'cluster_1084': 'scleractinia',
#  'cluster_10840': 'scleractinia',
#  'cluster_10841': 'scleractinia',
#  'cluster_10842': 'scleractinia',
#  'cluster_10843': 'scleractinia',
#  'cluster_10844': 'scleractinia',
#  'cluster_10845': 'scleractinia',
#  'cluster_10846': 'scleractinia',
#  'cluster_10847': 'scleractinia',
#  'cluster_10848': 'scleractinia',
#  'cluster_10849': 'scleractinia',
#  'cluster_10850': 'scleractinia',
#  'cluster_10851': 'scleractinia',
#  'cluster_10852': 'scleractinia',
#  'cluster_10853': 'scleractinia',
#  'cluster_10854': 'scleractinia',
#  'cluster_10855': 'scleractinia',
#  'cluster_10856': 'scleractinia',
#  'cluster_10857': 'scleractinia',
#  'cluster_10858': 'scleractinia',
#  'cluster_10859': 'scleractinia',
#  'cluster_1086': 'scleractinia',
#  'cluster_10860': 'scleractinia',
#  'cluster_10861': 'scleractinia',
#  'cluster_10862': 'scleractinia',
#  'cluster_10863': 'scleractinia',
#  'cluster_10864': 'scleractinia',
#  'cluster_10865': 'scleractinia',
#  'cluster_10866': 'scleractinia',
#  'cluster_10867': 'scleractinia',
#  'cluster_10868': 'scleractinia',
#  'cluster_10869': 'scleractinia',
#  'cluster_1087': 'scleractinia',
#  'cluster_10870': 'scleractinia',
#  'cluster_10871': 'scleractinia',
#  'cluster_10872': 'scleractinia',
#  'cluster_10873': 'scleractinia',
#  'cluster_10874': 'scleractinia',
#  'cluster_10875': 'scleractinia',
#  'cluster_10876': 'scleractinia',
#  'cluster_10877': 'scleractinia',
#  'cluster_10878': 'scleractinia',
#  'cluster_10879': 'scleractinia',
#  'cluster_10880': 'scleractinia',
#  'cluster_10881': 'scleractinia',
#  'cluster_10882': 'scleractinia',
#  'cluster_10883': 'scleractinia',
#  'cluster_10884': 'scleractinia',
#  'cluster_10885': 'hexacorallia',
#  'cluster_10886': 'scleractinia',
#  'cluster_10887': 'scleractinia',
#  'cluster_10888': 'scleractinia',
#  'cluster_10889': 'scleractinia',
#  'cluster_1089': 'scleractinia',
#  'cluster_10890': 'scleractinia',
#  'cluster_10891': 'scleractinia',
#  'cluster_10892': 'scleractinia',
#  'cluster_10893': 'scleractinia',
#  'cluster_10894': 'scleractinia',
#  'cluster_10895': 'scleractinia',
#  'cluster_10896': 'scleractinia',
#  'cluster_10897': 'scleractinia',
#  'cluster_10898': 'scleractinia',
#  'cluster_10899': 'scleractinia',
#  'cluster_109': 'hexacorallia',
#  'cluster_1090': 'scleractinia',
#  'cluster_10900': 'scleractinia',
#  'cluster_10901': 'hexacorallia',
#  'cluster_10902': 'scleractinia',
#  'cluster_10903': 'scleractinia',
#  'cluster_10904': 'hexacorallia',
#  'cluster_10905': 'scleractinia',
#  'cluster_10906': 'scleractinia',
#  'cluster_10907': 'scleractinia',
#  'cluster_10908': 'scleractinia',
#  'cluster_10909': 'scleractinia',
#  'cluster_10910': 'scleractinia',
#  'cluster_10911': 'scleractinia',
#  'cluster_10912': 'scleractinia',
#  'cluster_10913': 'scleractinia',
#  'cluster_10914': 'scleractinia',
#  'cluster_10915': 'scleractinia',
#  'cluster_10916': 'scleractinia',
#  'cluster_10917': 'scleractinia',
#  'cluster_10918': 'scleractinia',
#  'cluster_10919': 'scleractinia',
#  'cluster_1092': 'scleractinia',
#  'cluster_10920': 'scleractinia',
#  'cluster_10921': 'scleractinia',
#  'cluster_10922': 'scleractinia',
#  'cluster_10923': 'scleractinia',
#  'cluster_10924': 'scleractinia',
#  ...}

# %%
def daughter_species(node, daughter_list):
    #print("node: ", node)
    #print("daughter_list: ", daughter_list)
    for child, parent in tax_dict.items():
        if parent == node and child not in species_list:
            #print("found parent: ", parent, "child is: ", child)
            new_parent = child
            #print("run function again with ", new_parent, daughter_list)
            daughter_species(new_parent, daughter_list)
        if parent == node and child in species_list:
            #print("FOund parent, child is species: ", child)
            daughter_list.append(child)
            #print("new_daughter_list is:", daughter_list)
    #print("return daughter_list:", daughter_list)
    return(daughter_list)

# %%
cne_losses = {}
for cluster, lca in cluster_lcas.items():
    lca_daughters = daughter_species(lca, [])
    for species in lca_daughters:
        if species not in conserved_clust_species[cluster]:
            #print("cne lost in ", species)
            cne_losses.setdefault(cluster, []).append(species)
cne_losses
# Out:
# {'cluster_1': ['hsym'],
#  'cluster_10': ['ofav'],
#  'cluster_1000': ['ofav'],
#  'cluster_10000': ['pdam'],
#  'cluster_10001': ['pdam', 'spis'],
#  'cluster_10002': ['pdam', 'spis'],
#  'cluster_10003': ['pdam'],
#  'cluster_10005': ['pdam', 'spis'],
#  'cluster_10006': ['pdam', 'spis', 'nvec', 'aten'],
#  'cluster_10008': ['pdam', 'spis'],
#  'cluster_10009': ['pdam', 'spis'],
#  'cluster_1001': ['ofav'],
#  'cluster_10010': ['pdam', 'spis'],
#  'cluster_10011': ['pdam', 'spis'],
#  'cluster_10012': ['pdam', 'spis'],
#  'cluster_10013': ['pdam', 'spis'],
#  'cluster_10014': ['pdam', 'spis'],
#  'cluster_10015': ['pdam', 'spis'],
#  'cluster_10016': ['pdam', 'spis'],
#  'cluster_10017': ['pdam', 'spis'],
#  'cluster_10018': ['pdam', 'spis'],
#  'cluster_10019': ['pdam', 'spis'],
#  'cluster_10020': ['pdam'],
#  'cluster_10021': ['pdam', 'spis'],
#  'cluster_10022': ['pdam', 'spis'],
#  'cluster_10023': ['pdam', 'spis'],
#  'cluster_10024': ['pdam', 'spis'],
#  'cluster_10025': ['pdam', 'spis'],
#  'cluster_10026': ['pdam', 'spis'],
#  'cluster_10027': ['pdam', 'spis'],
#  'cluster_10028': ['pdam', 'spis'],
#  'cluster_10029': ['pdam', 'spis'],
#  'cluster_1003': ['nvec'],
#  'cluster_10031': ['pdam', 'spis'],
#  'cluster_10032': ['pdam', 'spis'],
#  'cluster_10033': ['pdam'],
#  'cluster_10034': ['pdam', 'spis'],
#  'cluster_10035': ['pdam', 'spis'],
#  'cluster_10036': ['pdam'],
#  'cluster_10037': ['pdam', 'spis'],
#  'cluster_10038': ['pdam'],
#  'cluster_10039': ['pdam'],
#  'cluster_1004': ['spis'],
#  'cluster_10040': ['pdam', 'spis'],
#  'cluster_10041': ['spis'],
#  'cluster_10042': ['pdam'],
#  'cluster_10043': ['pdam'],
#  'cluster_10044': ['pdam'],
#  'cluster_10045': ['pdam', 'spis'],
#  'cluster_10046': ['pdam', 'spis'],
#  'cluster_10047': ['pdam', 'spis'],
#  'cluster_10048': ['pdam', 'spis'],
#  'cluster_10049': ['pdam', 'spis'],
#  'cluster_1005': ['ofav'],
#  'cluster_10050': ['pdam', 'spis'],
#  'cluster_10051': ['pdam', 'spis'],
#  'cluster_10052': ['pdam'],
#  'cluster_10053': ['pdam', 'spis'],
#  'cluster_10054': ['pdam', 'spis'],
#  'cluster_10055': ['pdam', 'spis'],
#  'cluster_10056': ['pdam', 'spis'],
#  'cluster_10057': ['pdam', 'spis'],
#  'cluster_10058': ['pdam'],
#  'cluster_10059': ['pdam', 'spis'],
#  'cluster_1006': ['nvec', 'epal'],
#  'cluster_10062': ['pdam', 'spis'],
#  'cluster_10063': ['pdam', 'spis'],
#  'cluster_10064': ['pdam', 'spis'],
#  'cluster_10065': ['pdam', 'spis'],
#  'cluster_10066': ['pdam', 'spis'],
#  'cluster_10067': ['pdam'],
#  'cluster_10068': ['pdam'],
#  'cluster_10069': ['pdam', 'spis'],
#  'cluster_10070': ['pdam'],
#  'cluster_10071': ['pdam', 'spis'],
#  'cluster_10072': ['pdam', 'spis'],
#  'cluster_10073': ['pdam', 'spis'],
#  'cluster_10074': ['pdam'],
#  'cluster_10075': ['pdam', 'spis'],
#  'cluster_10076': ['pdam', 'spis'],
#  'cluster_10077': ['pdam'],
#  'cluster_10078': ['pdam', 'spis'],
#  'cluster_1008': ['spis'],
#  'cluster_10081': ['pdam', 'spis'],
#  'cluster_10082': ['pdam', 'spis'],
#  'cluster_10083': ['pdam', 'spis'],
#  'cluster_10084': ['pdam', 'spis'],
#  'cluster_10085': ['pdam', 'spis'],
#  'cluster_10086': ['pdam', 'spis'],
#  'cluster_10087': ['pdam', 'spis'],
#  'cluster_10088': ['pdam', 'spis'],
#  'cluster_10089': ['pdam'],
#  'cluster_10090': ['pdam', 'spis'],
#  'cluster_10091': ['pdam', 'spis'],
#  'cluster_10092': ['pdam', 'spis'],
#  'cluster_10093': ['pdam', 'spis'],
#  'cluster_10094': ['pdam', 'spis'],
#  'cluster_10095': ['pdam', 'spis'],
#  'cluster_10096': ['pdam', 'spis'],
#  'cluster_10097': ['pdam', 'spis'],
#  'cluster_10098': ['pdam', 'spis'],
#  'cluster_10099': ['pdam', 'spis'],
#  'cluster_1010': ['nvec', 'epal', 'chem', 'hsym', 'aaur', 'mvir'],
#  'cluster_10100': ['pdam', 'spis'],
#  'cluster_10101': ['pdam', 'spis'],
#  'cluster_10102': ['pdam'],
#  'cluster_10103': ['pdam'],
#  'cluster_10104': ['pdam'],
#  'cluster_10105': ['pdam', 'spis'],
#  'cluster_10106': ['pdam', 'spis'],
#  'cluster_10107': ['pdam', 'spis'],
#  'cluster_10108': ['pdam', 'spis'],
#  'cluster_10109': ['pdam', 'spis'],
#  'cluster_1011': ['ofav'],
#  'cluster_10110': ['pdam', 'spis'],
#  'cluster_10111': ['pdam', 'spis'],
#  'cluster_10112': ['pdam', 'spis'],
#  'cluster_10113': ['pdam', 'spis'],
#  'cluster_10114': ['pdam', 'spis'],
#  'cluster_10115': ['pdam', 'spis'],
#  'cluster_10116': ['pdam', 'spis'],
#  'cluster_10117': ['pdam', 'spis'],
#  'cluster_10119': ['pdam', 'spis'],
#  'cluster_1012': ['epal'],
#  'cluster_10120': ['spis'],
#  'cluster_10121': ['pdam', 'spis'],
#  'cluster_10122': ['pdam', 'spis'],
#  'cluster_10123': ['pdam', 'spis'],
#  'cluster_10124': ['pdam', 'spis'],
#  'cluster_10125': ['pdam', 'spis'],
#  'cluster_10126': ['pdam', 'spis'],
#  'cluster_10127': ['pdam', 'spis'],
#  'cluster_10128': ['spis'],
#  'cluster_10129': ['pdam', 'spis'],
#  'cluster_10130': ['pdam', 'spis'],
#  'cluster_10131': ['pdam', 'spis'],
#  'cluster_10132': ['pdam', 'spis'],
#  'cluster_10133': ['pdam', 'spis'],
#  'cluster_10134': ['pdam', 'spis'],
#  'cluster_10135': ['pdam', 'spis'],
#  'cluster_10136': ['pdam', 'spis'],
#  'cluster_10138': ['pdam', 'spis'],
#  'cluster_10139': ['pdam'],
#  'cluster_10140': ['pdam', 'spis'],
#  'cluster_10141': ['pdam', 'spis'],
#  'cluster_10142': ['pdam', 'spis'],
#  'cluster_10143': ['pdam', 'spis'],
#  'cluster_10144': ['pdam', 'spis'],
#  'cluster_10145': ['pdam', 'spis'],
#  'cluster_10146': ['pdam', 'spis'],
#  'cluster_10147': ['pdam', 'spis'],
#  'cluster_10148': ['pdam', 'spis'],
#  'cluster_10149': ['pdam', 'spis'],
#  'cluster_1015': ['nvec', 'aten', 'epal'],
#  'cluster_10150': ['pdam'],
#  'cluster_10151': ['pdam'],
#  'cluster_10152': ['pdam', 'spis'],
#  'cluster_10153': ['pdam', 'spis'],
#  'cluster_10155': ['pdam', 'spis'],
#  'cluster_10156': ['pdam', 'spis'],
#  'cluster_10157': ['pdam', 'spis'],
#  'cluster_10158': ['pdam', 'spis'],
#  'cluster_10159': ['pdam', 'spis'],
#  'cluster_10160': ['pdam', 'spis'],
#  'cluster_10161': ['pdam', 'spis'],
#  'cluster_10162': ['pdam', 'spis'],
#  'cluster_10163': ['pdam', 'spis'],
#  'cluster_10164': ['pdam', 'spis'],
#  'cluster_10165': ['nvec'],
#  'cluster_10166': ['pdam', 'nvec', 'aten', 'epal'],
#  'cluster_10167': ['pdam'],
#  'cluster_10168': ['pdam', 'spis'],
#  'cluster_10169': ['pdam', 'spis'],
#  'cluster_1017': ['ofav', 'nvec', 'hvul', 'chem', 'hsym', 'mvir'],
#  'cluster_10170': ['pdam', 'spis'],
#  'cluster_10171': ['pdam', 'spis'],
#  'cluster_10172': ['pdam'],
#  'cluster_10177': ['nvec'],
#  'cluster_10179': ['pdam', 'spis'],
#  'cluster_10180': ['pdam', 'spis'],
#  'cluster_10181': ['pdam'],
#  'cluster_10182': ['pdam', 'spis'],
#  'cluster_10184': ['pdam', 'spis'],
#  'cluster_10185': ['pdam', 'spis'],
#  'cluster_10187': ['pdam', 'spis'],
#  'cluster_10188': ['pdam', 'spis'],
#  'cluster_10189': ['pdam', 'spis'],
#  'cluster_10190': ['pdam', 'spis'],
#  'cluster_10191': ['pdam', 'spis'],
#  'cluster_10192': ['pdam'],
#  'cluster_10193': ['pdam', 'spis'],
#  'cluster_10194': ['pdam'],
#  'cluster_10196': ['pdam', 'spis'],
#  'cluster_10197': ['pdam', 'spis'],
#  'cluster_10199': ['pdam', 'spis'],
#  'cluster_1020': ['spis', 'nvec', 'epal'],
#  'cluster_10200': ['pdam', 'spis'],
#  'cluster_10201': ['pdam', 'spis'],
#  'cluster_10202': ['pdam', 'spis'],
#  'cluster_10203': ['pdam', 'spis'],
#  'cluster_10204': ['pdam', 'spis'],
#  'cluster_10205': ['spis'],
#  'cluster_10206': ['pdam'],
#  'cluster_10207': ['pdam', 'spis'],
#  'cluster_10208': ['pdam', 'spis'],
#  'cluster_10209': ['pdam', 'spis'],
#  'cluster_1021': ['ofav'],
#  'cluster_10210': ['pdam'],
#  'cluster_10211': ['pdam', 'spis'],
#  'cluster_10212': ['pdam', 'spis'],
#  'cluster_10213': ['pdam', 'spis'],
#  'cluster_10214': ['pdam', 'spis'],
#  'cluster_10215': ['pdam', 'spis'],
#  'cluster_10216': ['pdam', 'spis'],
#  'cluster_10217': ['pdam', 'spis'],
#  'cluster_10218': ['pdam', 'spis'],
#  'cluster_10219': ['pdam', 'spis'],
#  'cluster_1022': ['ofav'],
#  'cluster_10220': ['pdam', 'spis'],
#  'cluster_10222': ['pdam'],
#  'cluster_10223': ['pdam', 'spis'],
#  'cluster_10224': ['pdam', 'spis'],
#  'cluster_10225': ['pdam', 'spis'],
#  'cluster_10226': ['pdam', 'spis'],
#  'cluster_10227': ['pdam', 'spis'],
#  'cluster_10228': ['pdam', 'spis'],
#  'cluster_10229': ['nvec', 'aten', 'epal'],
#  'cluster_1023': ['nvec', 'aten', 'epal'],
#  'cluster_10231': ['pdam', 'spis'],
#  'cluster_10232': ['pdam', 'spis'],
#  'cluster_10233': ['pdam', 'spis'],
#  'cluster_10234': ['pdam', 'spis'],
#  'cluster_10235': ['pdam', 'spis'],
#  'cluster_10236': ['pdam', 'spis'],
#  'cluster_10237': ['pdam', 'spis'],
#  'cluster_10238': ['pdam', 'spis'],
#  'cluster_10239': ['pdam', 'spis'],
#  'cluster_1024': ['ofav'],
#  'cluster_10240': ['pdam', 'spis'],
#  'cluster_10241': ['pdam', 'spis'],
#  'cluster_10242': ['pdam', 'spis'],
#  'cluster_10243': ['pdam', 'spis'],
#  'cluster_10244': ['pdam'],
#  'cluster_10245': ['pdam', 'spis'],
#  'cluster_10246': ['pdam'],
#  'cluster_10247': ['spis'],
#  'cluster_10248': ['pdam', 'spis'],
#  'cluster_10249': ['pdam', 'spis'],
#  'cluster_10250': ['pdam', 'spis'],
#  'cluster_10251': ['pdam', 'spis'],
#  'cluster_10252': ['pdam', 'spis'],
#  'cluster_10253': ['pdam', 'spis'],
#  'cluster_10254': ['pdam', 'spis'],
#  'cluster_10255': ['pdam', 'spis'],
#  'cluster_10256': ['pdam', 'spis'],
#  'cluster_10257': ['pdam'],
#  'cluster_10258': ['pdam', 'spis'],
#  'cluster_10259': ['pdam', 'spis'],
#  'cluster_10260': ['pdam', 'spis'],
#  'cluster_10261': ['pdam', 'spis'],
#  'cluster_10262': ['pdam'],
#  'cluster_10263': ['pdam', 'spis'],
#  'cluster_10264': ['pdam', 'spis'],
#  'cluster_10265': ['pdam', 'spis'],
#  'cluster_10266': ['pdam'],
#  'cluster_10267': ['pdam', 'spis'],
#  'cluster_10268': ['pdam'],
#  'cluster_10269': ['pdam', 'spis'],
#  'cluster_10270': ['pdam', 'spis'],
#  'cluster_10271': ['pdam', 'spis'],
#  'cluster_10272': ['pdam', 'spis'],
#  'cluster_10273': ['pdam', 'spis'],
#  'cluster_10274': ['pdam', 'spis'],
#  'cluster_10275': ['pdam'],
#  'cluster_10276': ['pdam', 'spis'],
#  'cluster_10277': ['pdam', 'spis'],
#  'cluster_10278': ['pdam', 'spis'],
#  'cluster_10279': ['pdam', 'spis'],
#  'cluster_1028': ['ofav'],
#  'cluster_10280': ['pdam', 'spis'],
#  'cluster_10281': ['pdam', 'spis'],
#  'cluster_10282': ['pdam', 'spis'],
#  'cluster_10283': ['pdam', 'spis'],
#  'cluster_10284': ['pdam', 'spis'],
#  'cluster_10285': ['pdam', 'spis'],
#  'cluster_10286': ['pdam', 'spis'],
#  'cluster_10287': ['pdam', 'spis'],
#  'cluster_10288': ['pdam', 'spis'],
#  'cluster_10289': ['pdam', 'spis'],
#  'cluster_1029': ['ofav'],
#  'cluster_10290': ['pdam', 'spis'],
#  'cluster_10291': ['pdam', 'spis'],
#  'cluster_10292': ['spis'],
#  'cluster_10293': ['spis'],
#  'cluster_10294': ['pdam', 'spis'],
#  'cluster_10295': ['pdam', 'spis'],
#  'cluster_10296': ['pdam', 'spis'],
#  'cluster_10297': ['pdam', 'spis'],
#  'cluster_10298': ['pdam', 'spis'],
#  'cluster_10299': ['pdam', 'spis'],
#  'cluster_1030': ['ofav'],
#  'cluster_10300': ['pdam'],
#  'cluster_10301': ['spis'],
#  'cluster_10302': ['pdam', 'spis'],
#  'cluster_10303': ['pdam', 'spis'],
#  'cluster_10304': ['pdam', 'spis'],
#  'cluster_10305': ['pdam', 'spis'],
#  'cluster_10306': ['pdam', 'spis'],
#  'cluster_10307': ['pdam', 'spis'],
#  'cluster_10308': ['pdam', 'spis'],
#  'cluster_10309': ['pdam', 'spis'],
#  'cluster_10310': ['pdam', 'spis'],
#  'cluster_10311': ['pdam', 'spis'],
#  'cluster_10312': ['pdam', 'spis'],
#  'cluster_10313': ['pdam', 'spis'],
#  'cluster_10314': ['pdam', 'spis'],
#  'cluster_10315': ['pdam', 'spis'],
#  'cluster_10316': ['pdam', 'spis'],
#  'cluster_10317': ['pdam', 'spis'],
#  'cluster_10318': ['pdam', 'spis'],
#  'cluster_10319': ['pdam'],
#  'cluster_10320': ['pdam', 'spis'],
#  'cluster_10321': ['pdam', 'spis'],
#  'cluster_10322': ['pdam', 'spis'],
#  'cluster_10323': ['pdam', 'spis'],
#  'cluster_10324': ['pdam', 'spis'],
#  'cluster_10325': ['pdam', 'spis'],
#  'cluster_10326': ['pdam', 'spis'],
#  'cluster_10327': ['pdam', 'spis'],
#  'cluster_10328': ['pdam', 'spis'],
#  'cluster_10329': ['pdam', 'spis'],
#  'cluster_1033': ['spis'],
#  'cluster_10330': ['pdam', 'spis'],
#  'cluster_10331': ['spis'],
#  'cluster_10332': ['pdam', 'spis'],
#  'cluster_10333': ['pdam', 'spis'],
#  'cluster_10334': ['pdam', 'spis'],
#  'cluster_10335': ['pdam', 'spis'],
#  'cluster_10336': ['pdam', 'spis'],
#  'cluster_10337': ['pdam', 'spis'],
#  'cluster_10338': ['pdam', 'spis'],
#  'cluster_10339': ['pdam', 'spis'],
#  'cluster_10340': ['pdam'],
#  'cluster_10341': ['pdam', 'spis'],
#  'cluster_10342': ['pdam', 'spis'],
#  'cluster_10343': ['pdam', 'spis'],
#  'cluster_10344': ['pdam', 'spis'],
#  'cluster_10345': ['pdam', 'spis'],
#  'cluster_10346': ['pdam', 'spis'],
#  'cluster_10347': ['pdam', 'spis'],
#  'cluster_10348': ['pdam', 'spis'],
#  'cluster_10349': ['pdam', 'spis'],
#  'cluster_1035': ['ofav', 'nvec', 'aten'],
#  'cluster_10350': ['pdam', 'spis'],
#  'cluster_10351': ['pdam', 'spis'],
#  'cluster_10352': ['pdam', 'spis'],
#  'cluster_10353': ['pdam'],
#  'cluster_10354': ['pdam', 'spis'],
#  'cluster_10355': ['pdam', 'spis'],
#  'cluster_10356': ['aten', 'hvul', 'hsym', 'aaur', 'mvir'],
#  'cluster_10357': ['pdam', 'spis'],
#  'cluster_10358': ['pdam', 'spis'],
#  'cluster_10359': ['pdam', 'spis'],
#  'cluster_10361': ['pdam', 'spis'],
#  'cluster_10362': ['pdam', 'spis'],
#  'cluster_10363': ['pdam', 'spis'],
#  'cluster_10364': ['pdam', 'spis'],
#  'cluster_10365': ['pdam', 'spis'],
#  'cluster_10366': ['pdam', 'spis'],
#  'cluster_10367': ['pdam', 'spis'],
#  'cluster_10368': ['pdam', 'spis'],
#  'cluster_10369': ['pdam', 'spis'],
#  'cluster_10370': ['pdam', 'spis'],
#  'cluster_10371': ['pdam', 'spis'],
#  'cluster_10372': ['pdam', 'spis'],
#  'cluster_10373': ['pdam', 'spis'],
#  'cluster_10374': ['pdam', 'spis'],
#  'cluster_10375': ['pdam', 'spis'],
#  'cluster_10376': ['pdam'],
#  'cluster_10377': ['pdam', 'spis'],
#  'cluster_10379': ['pdam'],
#  'cluster_10380': ['pdam', 'spis'],
#  'cluster_10381': ['spis'],
#  'cluster_10382': ['pdam', 'spis'],
#  'cluster_10383': ['pdam', 'spis'],
#  'cluster_10384': ['pdam', 'spis'],
#  'cluster_10385': ['pdam', 'spis'],
#  'cluster_10386': ['pdam', 'spis'],
#  'cluster_10387': ['pdam', 'spis'],
#  'cluster_10388': ['pdam', 'spis'],
#  'cluster_10389': ['pdam', 'spis'],
#  'cluster_1039': ['spis', 'nvec', 'aten'],
#  'cluster_10390': ['pdam', 'spis'],
#  'cluster_10391': ['pdam', 'spis'],
#  'cluster_10392': ['pdam', 'spis'],
#  'cluster_10395': ['pdam', 'spis'],
#  'cluster_10396': ['pdam', 'spis'],
#  'cluster_10397': ['pdam', 'spis'],
#  'cluster_10399': ['pdam', 'spis'],
#  'cluster_1040': ['ofav'],
#  'cluster_10400': ['pdam', 'spis'],
#  'cluster_10401': ['pdam', 'spis'],
#  'cluster_10402': ['pdam', 'spis'],
#  'cluster_10403': ['pdam', 'spis'],
#  'cluster_10404': ['pdam', 'spis'],
#  'cluster_10405': ['pdam'],
#  'cluster_10406': ['pdam', 'spis'],
#  'cluster_10407': ['pdam', 'spis'],
#  'cluster_10408': ['pdam', 'spis'],
#  'cluster_10409': ['pdam', 'spis'],
#  'cluster_10410': ['pdam', 'spis'],
#  'cluster_10411': ['pdam', 'spis'],
#  'cluster_10412': ['pdam', 'spis'],
#  'cluster_10413': ['pdam', 'spis'],
#  'cluster_10414': ['pdam', 'spis'],
#  'cluster_10415': ['pdam', 'spis'],
#  'cluster_10416': ['pdam', 'spis'],
#  'cluster_10417': ['pdam', 'spis'],
#  'cluster_10418': ['pdam', 'spis'],
#  'cluster_10419': ['pdam', 'spis'],
#  'cluster_10420': ['pdam', 'spis'],
#  'cluster_10421': ['pdam', 'spis'],
#  'cluster_10422': ['pdam', 'spis'],
#  'cluster_10423': ['pdam', 'spis'],
#  'cluster_10424': ['pdam', 'spis'],
#  'cluster_10425': ['pdam', 'spis'],
#  'cluster_10428': ['pdam', 'spis'],
#  'cluster_10429': ['pdam', 'spis'],
#  'cluster_1043': ['ofav'],
#  'cluster_10430': ['pdam', 'spis'],
#  'cluster_10431': ['pdam', 'spis', 'aten'],
#  'cluster_10432': ['pdam'],
#  'cluster_10433': ['pdam'],
#  'cluster_10434': ['pdam'],
#  'cluster_10435': ['pdam'],
#  'cluster_10436': ['pdam', 'spis'],
#  'cluster_10437': ['spis'],
#  'cluster_10438': ['pdam', 'spis'],
#  'cluster_10439': ['pdam', 'spis'],
#  'cluster_1044': ['ofav'],
#  'cluster_10440': ['pdam', 'spis'],
#  'cluster_10441': ['pdam', 'spis'],
#  'cluster_10442': ['pdam', 'spis'],
#  'cluster_10443': ['pdam', 'spis'],
#  'cluster_10444': ['pdam', 'nvec', 'epal'],
#  'cluster_10446': ['pdam', 'spis'],
#  'cluster_10447': ['pdam', 'spis'],
#  'cluster_10448': ['nvec', 'epal'],
#  'cluster_10450': ['pdam', 'spis'],
#  'cluster_10451': ['pdam', 'spis'],
#  'cluster_10452': ['pdam'],
#  'cluster_10453': ['pdam', 'spis'],
#  'cluster_10454': ['pdam', 'spis'],
#  'cluster_10455': ['pdam', 'spis'],
#  'cluster_10456': ['pdam', 'spis'],
#  'cluster_10457': ['pdam', 'spis'],
#  'cluster_10458': ['pdam', 'spis'],
#  'cluster_10459': ['pdam', 'spis'],
#  'cluster_10460': ['pdam', 'spis'],
#  'cluster_10461': ['pdam', 'spis'],
#  'cluster_10462': ['pdam', 'spis'],
#  'cluster_10463': ['pdam', 'spis'],
#  'cluster_10464': ['pdam', 'spis'],
#  'cluster_10465': ['pdam', 'spis'],
#  'cluster_10466': ['pdam', 'spis'],
#  'cluster_10467': ['pdam', 'spis'],
#  'cluster_10468': ['pdam', 'spis'],
#  'cluster_10469': ['pdam', 'spis'],
#  'cluster_1047': ['ofav'],
#  'cluster_10470': ['pdam', 'spis'],
#  'cluster_10472': ['pdam', 'spis'],
#  'cluster_10473': ['pdam', 'spis'],
#  'cluster_10474': ['pdam', 'spis'],
#  'cluster_10475': ['pdam', 'spis'],
#  'cluster_10476': ['pdam', 'spis'],
#  'cluster_10477': ['pdam', 'spis'],
#  'cluster_10480': ['pdam', 'spis'],
#  'cluster_10481': ['pdam'],
#  'cluster_10483': ['pdam', 'spis'],
#  'cluster_10484': ['pdam', 'spis'],
#  'cluster_10485': ['pdam', 'spis'],
#  'cluster_10486': ['pdam', 'spis', 'nvec', 'aten'],
#  'cluster_10487': ['pdam', 'spis'],
#  'cluster_10488': ['pdam'],
#  'cluster_10489': ['pdam'],
#  'cluster_1049': ['ofav'],
#  'cluster_10490': ['pdam', 'spis'],
#  'cluster_10491': ['pdam', 'spis'],
#  'cluster_10492': ['pdam', 'spis'],
#  'cluster_10493': ['pdam', 'spis'],
#  'cluster_10494': ['pdam', 'spis'],
#  'cluster_10495': ['pdam', 'spis'],
#  'cluster_10496': ['pdam', 'spis'],
#  'cluster_10497': ['pdam', 'spis'],
#  'cluster_10498': ['pdam', 'spis'],
#  'cluster_10499': ['pdam', 'spis'],
#  'cluster_105': ['ofav'],
#  'cluster_10500': ['pdam'],
#  'cluster_10501': ['pdam', 'spis'],
#  'cluster_10502': ['pdam', 'spis'],
#  'cluster_10503': ['pdam'],
#  'cluster_10504': ['pdam', 'spis'],
#  'cluster_10505': ['pdam', 'spis'],
#  'cluster_10506': ['pdam', 'spis'],
#  'cluster_10507': ['pdam', 'spis'],
#  'cluster_10508': ['pdam', 'spis'],
#  'cluster_10509': ['pdam', 'spis'],
#  'cluster_10510': ['pdam', 'spis'],
#  'cluster_10511': ['pdam', 'spis'],
#  'cluster_10512': ['pdam', 'spis'],
#  'cluster_10513': ['pdam', 'spis'],
#  'cluster_10514': ['pdam'],
#  'cluster_10515': ['pdam', 'spis'],
#  'cluster_10516': ['pdam', 'spis'],
#  'cluster_10517': ['pdam', 'spis'],
#  'cluster_10518': ['pdam', 'spis'],
#  'cluster_10519': ['pdam', 'spis'],
#  'cluster_10520': ['pdam', 'spis'],
#  'cluster_10521': ['pdam', 'spis'],
#  'cluster_10522': ['pdam', 'spis'],
#  'cluster_10523': ['pdam'],
#  'cluster_10524': ['pdam', 'spis'],
#  'cluster_10525': ['pdam', 'spis'],
#  'cluster_10526': ['pdam', 'spis'],
#  'cluster_10527': ['pdam', 'spis'],
#  'cluster_10528': ['pdam', 'spis'],
#  'cluster_10529': ['pdam', 'spis'],
#  'cluster_1053': ['aten', 'epal'],
#  'cluster_10530': ['pdam', 'spis'],
#  'cluster_10531': ['pdam', 'spis'],
#  'cluster_10532': ['pdam', 'spis'],
#  'cluster_10533': ['pdam', 'spis'],
#  'cluster_10534': ['pdam', 'spis'],
#  'cluster_10535': ['pdam', 'spis'],
#  'cluster_10536': ['pdam', 'spis'],
#  'cluster_10537': ['pdam', 'spis'],
#  'cluster_10538': ['pdam', 'spis'],
#  'cluster_10539': ['pdam', 'spis'],
#  'cluster_10540': ['pdam', 'spis'],
#  'cluster_10541': ['pdam', 'spis'],
#  'cluster_10542': ['pdam', 'spis'],
#  'cluster_10543': ['pdam', 'spis'],
#  'cluster_10544': ['pdam', 'spis'],
#  'cluster_10545': ['pdam', 'spis'],
#  'cluster_10546': ['pdam', 'spis'],
#  'cluster_10547': ['pdam', 'spis'],
#  'cluster_10548': ['pdam', 'spis'],
#  'cluster_10549': ['pdam'],
#  'cluster_10550': ['pdam', 'spis'],
#  'cluster_10551': ['nvec', 'aten'],
#  'cluster_10552': ['pdam', 'spis'],
#  'cluster_10553': ['pdam', 'spis'],
#  'cluster_10554': ['pdam', 'spis'],
#  'cluster_10556': ['pdam', 'spis'],
#  'cluster_10557': ['pdam', 'spis'],
#  'cluster_10558': ['pdam', 'spis'],
#  'cluster_10559': ['pdam', 'spis'],
#  'cluster_1056': ['spis'],
#  'cluster_10560': ['pdam', 'spis'],
#  'cluster_10561': ['pdam', 'spis'],
#  'cluster_10562': ['pdam', 'spis'],
#  'cluster_10563': ['pdam', 'spis'],
#  'cluster_10564': ['pdam', 'spis', 'nvec', 'aten', 'epal'],
#  'cluster_10565': ['pdam', 'spis'],
#  'cluster_10566': ['pdam'],
#  'cluster_10567': ['pdam', 'spis'],
#  'cluster_10568': ['pdam', 'spis'],
#  'cluster_10569': ['pdam'],
#  'cluster_1057': ['ofav'],
#  'cluster_10570': ['pdam', 'spis'],
#  'cluster_10571': ['pdam', 'spis'],
#  'cluster_10572': ['pdam', 'spis'],
#  'cluster_10573': ['pdam', 'spis'],
#  'cluster_10574': ['pdam', 'spis'],
#  'cluster_10575': ['pdam', 'spis'],
#  'cluster_10576': ['pdam', 'spis'],
#  'cluster_10577': ['pdam', 'spis'],
#  'cluster_10578': ['pdam', 'spis'],
#  'cluster_10579': ['pdam', 'spis'],
#  'cluster_10580': ['pdam', 'spis'],
#  'cluster_10581': ['pdam', 'spis'],
#  'cluster_10582': ['pdam', 'spis'],
#  'cluster_10583': ['pdam', 'spis'],
#  'cluster_10584': ['pdam', 'spis'],
#  'cluster_10585': ['pdam', 'spis'],
#  'cluster_10586': ['pdam', 'spis'],
#  'cluster_10587': ['pdam', 'spis', 'nvec', 'aten', 'epal'],
#  'cluster_10588': ['pdam', 'spis'],
#  'cluster_10590': ['pdam', 'spis'],
#  'cluster_10591': ['pdam', 'spis'],
#  'cluster_10592': ['pdam', 'spis'],
#  'cluster_10593': ['pdam', 'spis'],
#  'cluster_10594': ['pdam', 'spis'],
#  'cluster_10596': ['pdam', 'spis'],
#  'cluster_10597': ['pdam', 'spis'],
#  'cluster_10598': ['pdam', 'spis'],
#  'cluster_10599': ['pdam', 'spis'],
#  'cluster_10600': ['pdam', 'spis'],
#  'cluster_10601': ['pdam', 'spis'],
#  'cluster_10603': ['pdam', 'spis'],
#  'cluster_10604': ['pdam', 'spis'],
#  'cluster_10605': ['pdam', 'spis'],
#  'cluster_10606': ['pdam', 'spis'],
#  'cluster_10607': ['pdam', 'spis'],
#  'cluster_10608': ['pdam', 'spis'],
#  'cluster_10609': ['pdam'],
#  'cluster_10610': ['pdam', 'spis'],
#  'cluster_10611': ['pdam', 'spis'],
#  'cluster_10612': ['pdam', 'spis'],
#  'cluster_10613': ['pdam'],
#  'cluster_10614': ['pdam', 'spis'],
#  'cluster_10615': ['pdam', 'spis'],
#  'cluster_10616': ['pdam', 'spis'],
#  'cluster_10617': ['pdam', 'spis'],
#  'cluster_10618': ['pdam', 'spis'],
#  'cluster_10619': ['pdam', 'spis'],
#  'cluster_10620': ['pdam', 'spis'],
#  'cluster_10621': ['pdam', 'spis'],
#  'cluster_10623': ['pdam', 'spis'],
#  'cluster_10624': ['pdam', 'spis'],
#  'cluster_10625': ['pdam', 'spis'],
#  'cluster_10626': ['pdam', 'spis'],
#  'cluster_10627': ['pdam'],
#  'cluster_10628': ['pdam', 'spis'],
#  'cluster_10629': ['pdam', 'spis'],
#  'cluster_1063': ['ofav'],
#  'cluster_10630': ['pdam', 'spis'],
#  'cluster_10631': ['pdam', 'spis'],
#  'cluster_10632': ['pdam', 'spis'],
#  'cluster_10633': ['pdam', 'spis'],
#  'cluster_10634': ['pdam', 'spis'],
#  'cluster_10635': ['pdam', 'spis'],
#  'cluster_10636': ['pdam', 'spis'],
#  'cluster_10637': ['pdam', 'spis'],
#  'cluster_10638': ['pdam', 'spis'],
#  'cluster_10639': ['pdam', 'spis'],
#  'cluster_10640': ['pdam', 'spis'],
#  'cluster_10641': ['pdam', 'spis'],
#  'cluster_10642': ['pdam', 'spis'],
#  'cluster_10643': ['pdam', 'spis'],
#  'cluster_10644': ['pdam', 'spis'],
#  'cluster_10645': ['pdam', 'spis'],
#  'cluster_10646': ['pdam', 'spis'],
#  'cluster_10647': ['pdam', 'spis'],
#  'cluster_10648': ['pdam', 'spis'],
#  'cluster_10649': ['pdam', 'spis'],
#  'cluster_1065': ['spis'],
#  'cluster_10650': ['pdam', 'spis'],
#  'cluster_10651': ['spis'],
#  'cluster_10652': ['pdam', 'spis'],
#  'cluster_10653': ['pdam'],
#  'cluster_10654': ['pdam', 'spis'],
#  'cluster_10655': ['pdam', 'spis'],
#  'cluster_10656': ['pdam', 'spis'],
#  'cluster_10657': ['pdam', 'spis'],
#  'cluster_10658': ['pdam', 'spis'],
#  'cluster_10659': ['pdam', 'spis'],
#  'cluster_1066': ['aten', 'epal'],
#  'cluster_10660': ['pdam', 'spis'],
#  'cluster_10661': ['pdam', 'spis'],
#  'cluster_10662': ['pdam', 'spis'],
#  'cluster_10663': ['pdam'],
#  'cluster_10664': ['pdam'],
#  'cluster_10666': ['pdam', 'spis'],
#  'cluster_10667': ['pdam', 'spis'],
#  'cluster_10668': ['pdam', 'spis'],
#  'cluster_10669': ['pdam', 'spis'],
#  'cluster_10670': ['pdam', 'spis'],
#  'cluster_10671': ['pdam', 'spis'],
#  'cluster_10672': ['pdam', 'spis'],
#  'cluster_10673': ['pdam', 'spis'],
#  'cluster_10674': ['pdam', 'spis'],
#  'cluster_10675': ['pdam', 'spis'],
#  'cluster_10676': ['pdam', 'spis'],
#  'cluster_10677': ['pdam', 'spis'],
#  'cluster_10678': ['pdam', 'spis'],
#  'cluster_10679': ['pdam', 'spis'],
#  'cluster_10680': ['pdam', 'spis'],
#  'cluster_10681': ['pdam', 'spis'],
#  'cluster_10682': ['pdam', 'spis'],
#  'cluster_10683': ['pdam', 'spis'],
#  'cluster_10684': ['pdam'],
#  'cluster_10685': ['pdam', 'spis'],
#  'cluster_10686': ['pdam', 'spis'],
#  'cluster_10687': ['pdam', 'spis'],
#  'cluster_10688': ['pdam', 'spis'],
#  'cluster_10689': ['pdam'],
#  'cluster_10690': ['pdam', 'spis'],
#  'cluster_10691': ['pdam', 'spis'],
#  'cluster_10692': ['pdam', 'spis'],
#  'cluster_10693': ['pdam', 'spis'],
#  'cluster_10694': ['pdam', 'spis'],
#  'cluster_10695': ['pdam', 'spis'],
#  'cluster_10696': ['pdam', 'spis'],
#  'cluster_10697': ['pdam', 'spis'],
#  'cluster_10698': ['pdam', 'spis'],
#  'cluster_10699': ['pdam', 'spis'],
#  'cluster_10700': ['pdam', 'spis'],
#  'cluster_10701': ['pdam', 'spis'],
#  'cluster_10703': ['pdam', 'spis'],
#  'cluster_10704': ['pdam', 'spis'],
#  'cluster_10705': ['pdam', 'spis'],
#  'cluster_10706': ['pdam', 'spis'],
#  'cluster_10707': ['pdam', 'spis'],
#  'cluster_10708': ['pdam', 'spis'],
#  'cluster_10709': ['pdam', 'spis'],
#  'cluster_10712': ['pdam', 'spis'],
#  'cluster_10713': ['spis'],
#  'cluster_10714': ['pdam', 'spis'],
#  'cluster_10715': ['pdam', 'spis'],
#  'cluster_10716': ['pdam', 'spis'],
#  'cluster_10717': ['pdam', 'spis'],
#  'cluster_10718': ['pdam', 'spis'],
#  'cluster_10719': ['pdam', 'spis'],
#  'cluster_10720': ['pdam', 'spis'],
#  'cluster_10721': ['pdam', 'spis'],
#  'cluster_10722': ['pdam', 'spis'],
#  'cluster_10723': ['pdam', 'spis'],
#  'cluster_10724': ['pdam', 'spis'],
#  'cluster_10725': ['pdam', 'spis'],
#  'cluster_10726': ['pdam', 'spis'],
#  'cluster_10727': ['pdam'],
#  'cluster_10728': ['pdam'],
#  'cluster_10729': ['pdam'],
#  'cluster_1073': ['ofav'],
#  'cluster_10730': ['pdam', 'spis'],
#  'cluster_10731': ['pdam', 'spis'],
#  'cluster_10732': ['pdam', 'spis'],
#  'cluster_10733': ['pdam', 'spis'],
#  'cluster_10734': ['pdam', 'spis'],
#  'cluster_10735': ['pdam', 'spis'],
#  'cluster_10736': ['pdam'],
#  'cluster_10737': ['pdam', 'spis'],
#  'cluster_10738': ['pdam', 'spis'],
#  'cluster_10739': ['pdam', 'spis'],
#  'cluster_10740': ['pdam', 'spis'],
#  'cluster_10741': ['pdam', 'spis'],
#  'cluster_10742': ['pdam'],
#  'cluster_10744': ['pdam'],
#  'cluster_10746': ['pdam', 'spis'],
#  'cluster_10747': ['pdam', 'spis'],
#  'cluster_10748': ['pdam', 'spis'],
#  'cluster_10749': ['pdam', 'spis'],
#  'cluster_1075': ['ofav'],
#  'cluster_10750': ['pdam', 'spis'],
#  'cluster_10751': ['pdam', 'spis'],
#  'cluster_10752': ['pdam', 'spis'],
#  'cluster_10753': ['pdam', 'spis'],
#  'cluster_10754': ['pdam', 'spis'],
#  'cluster_10755': ['pdam'],
#  'cluster_10756': ['pdam', 'spis'],
#  'cluster_10757': ['pdam', 'spis'],
#  'cluster_10758': ['dgig',
#   'pdam',
#   'nvec',
#   'aten',
#   'epal',
#   'hvul',
#   'chem',
#   'hsym',
#   'aaur'],
#  'cluster_10759': ['pdam'],
#  'cluster_10760': ['pdam', 'spis'],
#  'cluster_10762': ['pdam', 'spis'],
#  'cluster_10764': ['pdam', 'spis'],
#  'cluster_10765': ['pdam', 'spis'],
#  'cluster_10766': ['pdam', 'spis', 'aten'],
#  'cluster_10767': ['pdam', 'spis'],
#  'cluster_10769': ['pdam', 'spis'],
#  'cluster_10770': ['pdam', 'spis'],
#  'cluster_10771': ['pdam', 'spis'],
#  'cluster_10772': ['pdam', 'spis'],
#  'cluster_10773': ['pdam', 'spis'],
#  'cluster_10774': ['pdam', 'spis'],
#  'cluster_10776': ['pdam', 'spis'],
#  'cluster_10777': ['pdam', 'spis'],
#  'cluster_10778': ['pdam', 'spis'],
#  'cluster_10779': ['pdam'],
#  'cluster_10780': ['pdam'],
#  'cluster_10781': ['pdam', 'spis'],
#  'cluster_10782': ['pdam', 'nvec', 'aten'],
#  'cluster_10783': ['pdam', 'spis'],
#  'cluster_10784': ['pdam', 'spis'],
#  'cluster_10785': ['pdam', 'spis'],
#  'cluster_10786': ['pdam', 'spis'],
#  'cluster_10787': ['pdam', 'spis'],
#  'cluster_10788': ['pdam', 'spis'],
#  'cluster_10789': ['pdam', 'spis'],
#  'cluster_10790': ['pdam', 'spis'],
#  'cluster_10791': ['pdam', 'spis'],
#  'cluster_10792': ['pdam'],
#  'cluster_10793': ['pdam', 'spis'],
#  'cluster_10794': ['pdam', 'spis'],
#  'cluster_10795': ['pdam', 'spis'],
#  'cluster_10796': ['pdam', 'spis'],
#  'cluster_10797': ['pdam', 'spis'],
#  'cluster_10798': ['pdam'],
#  'cluster_10799': ['pdam', 'spis'],
#  'cluster_1080': ['ofav'],
#  'cluster_10800': ['pdam', 'spis'],
#  'cluster_10801': ['pdam', 'spis'],
#  'cluster_10802': ['pdam', 'spis'],
#  'cluster_10803': ['pdam', 'spis'],
#  'cluster_10804': ['pdam', 'spis'],
#  'cluster_10805': ['pdam', 'spis'],
#  'cluster_10806': ['pdam', 'spis'],
#  'cluster_10807': ['pdam', 'spis'],
#  'cluster_10808': ['pdam', 'spis'],
#  'cluster_10809': ['pdam', 'spis'],
#  'cluster_10810': ['pdam', 'spis'],
#  'cluster_10811': ['pdam', 'spis'],
#  'cluster_10812': ['pdam', 'spis'],
#  'cluster_10813': ['pdam', 'spis'],
#  'cluster_10814': ['pdam', 'spis'],
#  'cluster_10815': ['pdam', 'spis'],
#  'cluster_10816': ['pdam', 'spis'],
#  'cluster_10817': ['pdam', 'spis'],
#  'cluster_10818': ['pdam', 'spis'],
#  'cluster_10819': ['pdam', 'spis'],
#  'cluster_10820': ['pdam', 'spis'],
#  'cluster_10821': ['pdam', 'spis'],
#  'cluster_10822': ['pdam', 'spis'],
#  'cluster_10823': ['pdam', 'spis'],
#  'cluster_10824': ['pdam', 'spis'],
#  'cluster_10825': ['pdam'],
#  'cluster_10826': ['pdam', 'spis'],
#  'cluster_10827': ['pdam', 'spis'],
#  'cluster_10828': ['pdam', 'spis'],
#  'cluster_10829': ['pdam', 'spis'],
#  'cluster_1083': ['ofav'],
#  'cluster_10832': ['pdam', 'spis'],
#  'cluster_10833': ['pdam', 'spis'],
#  'cluster_10834': ['pdam', 'spis', 'nvec', 'epal'],
#  'cluster_10835': ['pdam', 'spis'],
#  'cluster_10836': ['pdam', 'spis'],
#  'cluster_10837': ['pdam', 'spis'],
#  'cluster_10838': ['pdam', 'spis'],
#  'cluster_10839': ['pdam', 'spis'],
#  'cluster_1084': ['ofav'],
#  'cluster_10840': ['pdam', 'spis'],
#  'cluster_10841': ['pdam', 'spis'],
#  'cluster_10842': ['pdam', 'spis'],
#  'cluster_10843': ['pdam', 'spis'],
#  'cluster_10844': ['pdam', 'spis'],
#  'cluster_10845': ['pdam', 'spis'],
#  'cluster_10846': ['pdam', 'spis'],
#  'cluster_10847': ['pdam', 'spis'],
#  'cluster_10849': ['pdam'],
#  'cluster_10850': ['pdam', 'spis'],
#  'cluster_10851': ['pdam', 'spis'],
#  'cluster_10852': ['pdam', 'spis'],
#  'cluster_10853': ['pdam'],
#  'cluster_10854': ['pdam', 'spis'],
#  'cluster_10855': ['pdam', 'spis'],
#  'cluster_10856': ['pdam', 'spis'],
#  'cluster_10857': ['pdam', 'spis'],
#  'cluster_10858': ['pdam', 'spis'],
#  'cluster_10860': ['pdam', 'spis'],
#  'cluster_10861': ['pdam', 'spis'],
#  'cluster_10862': ['pdam', 'spis'],
#  'cluster_10863': ['pdam', 'spis'],
#  'cluster_10864': ['pdam', 'spis'],
#  'cluster_10865': ['pdam', 'spis'],
#  'cluster_10866': ['pdam', 'spis'],
#  'cluster_10868': ['pdam', 'spis'],
#  'cluster_10869': ['pdam', 'spis'],
#  'cluster_1087': ['ofav'],
#  'cluster_10870': ['pdam', 'spis'],
#  'cluster_10871': ['pdam', 'spis'],
#  'cluster_10872': ['pdam', 'spis'],
#  'cluster_10873': ['pdam', 'spis'],
#  'cluster_10874': ['pdam', 'spis'],
#  'cluster_10875': ['pdam'],
#  'cluster_10876': ['pdam', 'spis'],
#  'cluster_10877': ['pdam', 'spis'],
#  'cluster_10878': ['pdam', 'spis'],
#  'cluster_10879': ['pdam', 'spis'],
#  'cluster_10880': ['pdam', 'spis'],
#  'cluster_10881': ['pdam', 'spis'],
#  'cluster_10882': ['pdam', 'spis'],
#  'cluster_10883': ['pdam', 'spis'],
#  'cluster_10884': ['pdam', 'spis'],
#  'cluster_10885': ['nvec', 'aten'],
#  'cluster_10886': ['pdam', 'spis'],
#  'cluster_10887': ['pdam'],
#  'cluster_10888': ['pdam'],
#  'cluster_10889': ['spis'],
#  'cluster_10890': ['pdam', 'spis'],
#  'cluster_10891': ['pdam', 'spis'],
#  'cluster_10892': ['pdam', 'spis'],
#  'cluster_10893': ['pdam', 'spis'],
#  'cluster_10894': ['pdam', 'spis'],
#  'cluster_10895': ['pdam', 'spis'],
#  'cluster_10896': ['pdam', 'spis'],
#  'cluster_10897': ['pdam', 'spis'],
#  'cluster_10898': ['pdam', 'spis'],
#  'cluster_10899': ['pdam', 'spis'],
#  'cluster_109': ['aten'],
#  'cluster_10900': ['pdam'],
#  'cluster_10901': ['pdam', 'spis', 'aten', 'epal'],
#  'cluster_10902': ['pdam'],
#  'cluster_10903': ['pdam', 'spis'],
#  'cluster_10904': ['nvec', 'epal'],
#  'cluster_10906': ['pdam'],
#  'cluster_10907': ['pdam', 'spis'],
#  'cluster_10908': ['pdam'],
#  'cluster_10909': ['pdam', 'spis'],
#  'cluster_10910': ['pdam', 'spis'],
#  'cluster_10911': ['pdam', 'spis'],
#  'cluster_10912': ['pdam', 'spis'],
#  'cluster_10913': ['pdam', 'spis'],
#  'cluster_10914': ['pdam', 'spis'],
#  'cluster_10915': ['pdam', 'spis'],
#  'cluster_10916': ['pdam', 'spis'],
#  'cluster_10917': ['pdam', 'spis'],
#  'cluster_10918': ['pdam', 'spis'],
#  'cluster_10919': ['pdam', 'spis'],
#  'cluster_10920': ['pdam', 'spis'],
#  'cluster_10921': ['pdam', 'spis'],
#  'cluster_10922': ['pdam', 'spis'],
#  'cluster_10923': ['pdam'],
#  'cluster_10924': ['pdam'],
#  'cluster_10925': ['pdam', 'spis'],
#  'cluster_10926': ['pdam', 'spis'],
#  'cluster_10927': ['pdam', 'spis'],
#  'cluster_10928': ['pdam', 'spis'],
#  'cluster_10929': ['pdam', 'spis'],
#  'cluster_1093': ['ofav'],
#  'cluster_10930': ['pdam', 'spis'],
#  'cluster_10931': ['pdam', 'spis'],
#  'cluster_10932': ['pdam', 'spis'],
#  'cluster_10933': ['pdam', 'spis'],
#  'cluster_10934': ['pdam'],
#  'cluster_10935': ['pdam', 'spis'],
#  'cluster_10936': ['pdam', 'spis'],
#  'cluster_10937': ['pdam'],
#  'cluster_10938': ['pdam', 'spis'],
#  'cluster_10939': ['pdam', 'spis'],
#  'cluster_10940': ['pdam', 'spis'],
#  'cluster_10942': ['pdam', 'spis'],
#  'cluster_10943': ['pdam'],
#  'cluster_10944': ['pdam', 'spis'],
#  'cluster_10945': ['pdam'],
#  'cluster_10946': ['pdam', 'spis'],
#  'cluster_10947': ['pdam', 'spis'],
#  'cluster_10948': ['pdam', 'spis'],
#  'cluster_1095': ['ofav'],
#  'cluster_10950': ['pdam', 'spis'],
#  'cluster_10951': ['pdam', 'spis'],
#  'cluster_10952': ['pdam', 'spis'],
#  'cluster_10953': ['pdam', 'spis'],
#  'cluster_10954': ['pdam', 'spis'],
#  'cluster_10955': ['pdam', 'spis'],
#  'cluster_10956': ['pdam', 'spis'],
#  'cluster_10957': ['pdam', 'spis'],
#  'cluster_10958': ['pdam', 'spis'],
#  'cluster_10959': ['pdam', 'spis'],
#  'cluster_1096': ['spis'],
#  'cluster_10960': ['pdam', 'spis', 'nvec'],
#  'cluster_10961': ['pdam', 'spis'],
#  'cluster_10962': ['pdam', 'spis'],
#  'cluster_10963': ['pdam', 'spis'],
#  'cluster_10964': ['pdam', 'spis'],
#  'cluster_10965': ['pdam', 'spis'],
#  'cluster_10966': ['pdam', 'spis'],
#  'cluster_10967': ['pdam', 'spis'],
#  'cluster_10968': ['pdam', 'spis'],
#  'cluster_10970': ['dgig',
#   'pdam',
#   'spis',
#   'nvec',
#   'hvul',
#   'chem',
#   'hsym',
#   'mvir'],
#  'cluster_10971': ['pdam', 'spis'],
#  'cluster_10972': ['pdam', 'spis'],
#  'cluster_10973': ['pdam', 'spis'],
#  'cluster_10974': ['pdam', 'spis'],
#  'cluster_10975': ['pdam', 'spis'],
#  'cluster_10976': ['pdam', 'spis'],
#  'cluster_10977': ['pdam'],
#  'cluster_10978': ['pdam', 'spis'],
#  'cluster_10979': ['pdam', 'spis'],
#  'cluster_1098': ['ofav'],
#  'cluster_10980': ['pdam', 'spis'],
#  'cluster_10981': ['pdam', 'spis'],
#  'cluster_10982': ['pdam', 'spis', 'nvec', 'aten', 'epal'],
#  'cluster_10984': ['pdam'],
#  'cluster_10985': ['pdam', 'spis'],
#  'cluster_10986': ['pdam', 'spis'],
#  'cluster_10987': ['pdam', 'spis'],
#  'cluster_10988': ['pdam', 'spis'],
#  'cluster_10989': ['pdam', 'spis'],
#  'cluster_10990': ['pdam'],
#  'cluster_10991': ['pdam'],
#  'cluster_10992': ['pdam', 'spis'],
#  'cluster_10993': ['pdam', 'spis', 'nvec', 'epal'],
#  'cluster_10994': ['pdam', 'spis'],
#  'cluster_10995': ['pdam', 'spis'],
#  'cluster_10996': ['pdam', 'spis'],
#  'cluster_10997': ['pdam', 'spis'],
#  'cluster_10998': ['pdam', 'spis'],
#  'cluster_11': ['spis'],
#  'cluster_1100': ['nvec'],
#  'cluster_11000': ['pdam', 'spis'],
#  'cluster_11001': ['pdam', 'spis'],
#  'cluster_11002': ['pdam', 'spis'],
#  'cluster_11003': ['pdam', 'spis'],
#  'cluster_11004': ['pdam', 'spis'],
#  'cluster_11005': ['pdam', 'spis'],
#  'cluster_11006': ['pdam', 'spis'],
#  'cluster_11007': ['pdam', 'spis'],
#  'cluster_11008': ['pdam', 'spis'],
#  'cluster_11009': ['pdam', 'spis'],
#  ...}

# %%
lca_losses = defaultdict(int)
for cluster, species in cne_losses.items():
    lca = cluster_lcas[cluster]
    lca_losses[lca] += len(species)

# %%
lca_losses
# Out:
# defaultdict(int,
#             {'actiniaria': 402,
#              'anthozoa': 3501,
#              'cnidaria': 3308,
#              'hexacorallia': 2629,
#              'hydrozoa': 449,
#              'medusozoa': 157,
#              'robusta': 3040,
#              'scleractinia': 13225})

# %% [markdown]
# #### Common ancestor distribution

# %%
counts = Counter(cluster_lcas.values())
for node in set(cluster_lcas.values()):
    print(node, counts[node])
# Out:
# hydrozoa 469
# scleractinia 9516
# robusta 5484
# anthozoa 733
# medusozoa 81
# hexacorallia 918
# actiniaria 474
# cnidaria 465

# %%
lca_counts_df = pd.DataFrame(counts.items(), columns=['node', 'cluster_count']).sort_values(by='node')
lca_counts_df.to_csv("lca_counts.tsv", sep="\t", index=False)

# %%
lca_counts_df
# Out:
#            node  cluster_count
# 4    actiniaria            474
# 3      anthozoa            733
# 0      cnidaria            465
# 2  hexacorallia            918
# 6      hydrozoa            469
# 5     medusozoa             81
# 7       robusta           5484
# 1  scleractinia           9516

# %% [markdown]
# #### Number of convergent clusters

# %%
# Total number of clusters (excluding single CE clusters)
#len(pastml_data.columns)-1

# %%
len(cluster_nodes)
# Out:
# 30189

# %%
len(cluster_lcas) # non-convergent clusters
# Out:
# 18140

# %%
len(convergent_clusters) # 1 only at the tips
# Out:
# 11419

# %%
len(additional_convergent_clusters) # 1 at some node but CNE absent at last common ancestor
# Out:
# 630

# %%
# sum chould be equal to total number of clusters
11 + 66 + 5 # all is well
# Out:
# 82

# %% [markdown]
# #### Write output to files

# %%
with open('convergent_clusters.pickle', 'wb') as handle:
    pickle.dump(convergent_clusters, handle)

# %%
cluster_lcas
# Out:
# {'cluster_1': 'cnidaria',
#  'cluster_10': 'scleractinia',
#  'cluster_100': 'scleractinia',
#  'cluster_1000': 'scleractinia',
#  'cluster_10000': 'scleractinia',
#  'cluster_10001': 'scleractinia',
#  'cluster_10002': 'scleractinia',
#  'cluster_10003': 'scleractinia',
#  'cluster_10004': 'scleractinia',
#  'cluster_10005': 'scleractinia',
#  'cluster_10006': 'hexacorallia',
#  'cluster_10007': 'scleractinia',
#  'cluster_10008': 'scleractinia',
#  'cluster_10009': 'scleractinia',
#  'cluster_1001': 'scleractinia',
#  'cluster_10010': 'scleractinia',
#  'cluster_10011': 'scleractinia',
#  'cluster_10012': 'scleractinia',
#  'cluster_10013': 'scleractinia',
#  'cluster_10014': 'scleractinia',
#  'cluster_10015': 'scleractinia',
#  'cluster_10016': 'scleractinia',
#  'cluster_10017': 'scleractinia',
#  'cluster_10018': 'scleractinia',
#  'cluster_10019': 'scleractinia',
#  'cluster_1002': 'scleractinia',
#  'cluster_10020': 'scleractinia',
#  'cluster_10021': 'scleractinia',
#  'cluster_10022': 'scleractinia',
#  'cluster_10023': 'scleractinia',
#  'cluster_10024': 'scleractinia',
#  'cluster_10025': 'scleractinia',
#  'cluster_10026': 'scleractinia',
#  'cluster_10027': 'scleractinia',
#  'cluster_10028': 'scleractinia',
#  'cluster_10029': 'scleractinia',
#  'cluster_1003': 'hexacorallia',
#  'cluster_10030': 'scleractinia',
#  'cluster_10031': 'scleractinia',
#  'cluster_10032': 'scleractinia',
#  'cluster_10033': 'scleractinia',
#  'cluster_10034': 'scleractinia',
#  'cluster_10035': 'scleractinia',
#  'cluster_10036': 'scleractinia',
#  'cluster_10037': 'scleractinia',
#  'cluster_10038': 'scleractinia',
#  'cluster_10039': 'scleractinia',
#  'cluster_1004': 'scleractinia',
#  'cluster_10040': 'scleractinia',
#  'cluster_10041': 'scleractinia',
#  'cluster_10042': 'scleractinia',
#  'cluster_10043': 'scleractinia',
#  'cluster_10044': 'scleractinia',
#  'cluster_10045': 'scleractinia',
#  'cluster_10046': 'scleractinia',
#  'cluster_10047': 'scleractinia',
#  'cluster_10048': 'scleractinia',
#  'cluster_10049': 'scleractinia',
#  'cluster_1005': 'scleractinia',
#  'cluster_10050': 'scleractinia',
#  'cluster_10051': 'scleractinia',
#  'cluster_10052': 'scleractinia',
#  'cluster_10053': 'scleractinia',
#  'cluster_10054': 'scleractinia',
#  'cluster_10055': 'scleractinia',
#  'cluster_10056': 'scleractinia',
#  'cluster_10057': 'scleractinia',
#  'cluster_10058': 'scleractinia',
#  'cluster_10059': 'scleractinia',
#  'cluster_1006': 'hexacorallia',
#  'cluster_10060': 'scleractinia',
#  'cluster_10061': 'scleractinia',
#  'cluster_10062': 'scleractinia',
#  'cluster_10063': 'scleractinia',
#  'cluster_10064': 'scleractinia',
#  'cluster_10065': 'scleractinia',
#  'cluster_10066': 'scleractinia',
#  'cluster_10067': 'scleractinia',
#  'cluster_10068': 'scleractinia',
#  'cluster_10069': 'scleractinia',
#  'cluster_1007': 'scleractinia',
#  'cluster_10070': 'scleractinia',
#  'cluster_10071': 'scleractinia',
#  'cluster_10072': 'scleractinia',
#  'cluster_10073': 'scleractinia',
#  'cluster_10074': 'scleractinia',
#  'cluster_10075': 'scleractinia',
#  'cluster_10076': 'scleractinia',
#  'cluster_10077': 'scleractinia',
#  'cluster_10078': 'scleractinia',
#  'cluster_10079': 'scleractinia',
#  'cluster_1008': 'scleractinia',
#  'cluster_10080': 'scleractinia',
#  'cluster_10081': 'scleractinia',
#  'cluster_10082': 'scleractinia',
#  'cluster_10083': 'scleractinia',
#  'cluster_10084': 'scleractinia',
#  'cluster_10085': 'scleractinia',
#  'cluster_10086': 'scleractinia',
#  'cluster_10087': 'scleractinia',
#  'cluster_10088': 'scleractinia',
#  'cluster_10089': 'scleractinia',
#  'cluster_10090': 'scleractinia',
#  'cluster_10091': 'scleractinia',
#  'cluster_10092': 'scleractinia',
#  'cluster_10093': 'scleractinia',
#  'cluster_10094': 'scleractinia',
#  'cluster_10095': 'scleractinia',
#  'cluster_10096': 'scleractinia',
#  'cluster_10097': 'scleractinia',
#  'cluster_10098': 'scleractinia',
#  'cluster_10099': 'scleractinia',
#  'cluster_101': 'scleractinia',
#  'cluster_1010': 'cnidaria',
#  'cluster_10100': 'scleractinia',
#  'cluster_10101': 'scleractinia',
#  'cluster_10102': 'scleractinia',
#  'cluster_10103': 'scleractinia',
#  'cluster_10104': 'scleractinia',
#  'cluster_10105': 'scleractinia',
#  'cluster_10106': 'scleractinia',
#  'cluster_10107': 'scleractinia',
#  'cluster_10108': 'scleractinia',
#  'cluster_10109': 'scleractinia',
#  'cluster_1011': 'scleractinia',
#  'cluster_10110': 'scleractinia',
#  'cluster_10111': 'scleractinia',
#  'cluster_10112': 'scleractinia',
#  'cluster_10113': 'scleractinia',
#  'cluster_10114': 'scleractinia',
#  'cluster_10115': 'scleractinia',
#  'cluster_10116': 'scleractinia',
#  'cluster_10117': 'scleractinia',
#  'cluster_10118': 'scleractinia',
#  'cluster_10119': 'scleractinia',
#  'cluster_1012': 'hexacorallia',
#  'cluster_10120': 'scleractinia',
#  'cluster_10121': 'scleractinia',
#  'cluster_10122': 'scleractinia',
#  'cluster_10123': 'scleractinia',
#  'cluster_10124': 'scleractinia',
#  'cluster_10125': 'scleractinia',
#  'cluster_10126': 'scleractinia',
#  'cluster_10127': 'scleractinia',
#  'cluster_10128': 'scleractinia',
#  'cluster_10129': 'scleractinia',
#  'cluster_10130': 'scleractinia',
#  'cluster_10131': 'scleractinia',
#  'cluster_10132': 'scleractinia',
#  'cluster_10133': 'scleractinia',
#  'cluster_10134': 'scleractinia',
#  'cluster_10135': 'scleractinia',
#  'cluster_10136': 'scleractinia',
#  'cluster_10137': 'scleractinia',
#  'cluster_10138': 'scleractinia',
#  'cluster_10139': 'scleractinia',
#  'cluster_10140': 'scleractinia',
#  'cluster_10141': 'scleractinia',
#  'cluster_10142': 'scleractinia',
#  'cluster_10143': 'scleractinia',
#  'cluster_10144': 'scleractinia',
#  'cluster_10145': 'scleractinia',
#  'cluster_10146': 'scleractinia',
#  'cluster_10147': 'scleractinia',
#  'cluster_10148': 'scleractinia',
#  'cluster_10149': 'scleractinia',
#  'cluster_1015': 'anthozoa',
#  'cluster_10150': 'scleractinia',
#  'cluster_10151': 'scleractinia',
#  'cluster_10152': 'scleractinia',
#  'cluster_10153': 'scleractinia',
#  'cluster_10154': 'scleractinia',
#  'cluster_10155': 'scleractinia',
#  'cluster_10156': 'scleractinia',
#  'cluster_10157': 'scleractinia',
#  'cluster_10158': 'scleractinia',
#  'cluster_10159': 'scleractinia',
#  'cluster_1016': 'scleractinia',
#  'cluster_10160': 'scleractinia',
#  'cluster_10161': 'scleractinia',
#  'cluster_10162': 'scleractinia',
#  'cluster_10163': 'scleractinia',
#  'cluster_10164': 'scleractinia',
#  'cluster_10165': 'hexacorallia',
#  'cluster_10166': 'anthozoa',
#  'cluster_10167': 'scleractinia',
#  'cluster_10168': 'scleractinia',
#  'cluster_10169': 'scleractinia',
#  'cluster_1017': 'cnidaria',
#  'cluster_10170': 'scleractinia',
#  'cluster_10171': 'scleractinia',
#  'cluster_10172': 'scleractinia',
#  'cluster_10173': 'scleractinia',
#  'cluster_10174': 'scleractinia',
#  'cluster_10175': 'scleractinia',
#  'cluster_10176': 'hexacorallia',
#  'cluster_10177': 'hexacorallia',
#  'cluster_10178': 'scleractinia',
#  'cluster_10179': 'scleractinia',
#  'cluster_10180': 'scleractinia',
#  'cluster_10181': 'scleractinia',
#  'cluster_10182': 'scleractinia',
#  'cluster_10183': 'scleractinia',
#  'cluster_10184': 'scleractinia',
#  'cluster_10185': 'scleractinia',
#  'cluster_10186': 'scleractinia',
#  'cluster_10187': 'scleractinia',
#  'cluster_10188': 'scleractinia',
#  'cluster_10189': 'scleractinia',
#  'cluster_1019': 'scleractinia',
#  'cluster_10190': 'scleractinia',
#  'cluster_10191': 'scleractinia',
#  'cluster_10192': 'scleractinia',
#  'cluster_10193': 'scleractinia',
#  'cluster_10194': 'scleractinia',
#  'cluster_10195': 'scleractinia',
#  'cluster_10196': 'scleractinia',
#  'cluster_10197': 'scleractinia',
#  'cluster_10198': 'scleractinia',
#  'cluster_10199': 'scleractinia',
#  'cluster_102': 'scleractinia',
#  'cluster_1020': 'hexacorallia',
#  'cluster_10200': 'scleractinia',
#  'cluster_10201': 'scleractinia',
#  'cluster_10202': 'scleractinia',
#  'cluster_10203': 'scleractinia',
#  'cluster_10204': 'scleractinia',
#  'cluster_10205': 'scleractinia',
#  'cluster_10206': 'scleractinia',
#  'cluster_10207': 'scleractinia',
#  'cluster_10208': 'scleractinia',
#  'cluster_10209': 'scleractinia',
#  'cluster_1021': 'scleractinia',
#  'cluster_10210': 'scleractinia',
#  'cluster_10211': 'scleractinia',
#  'cluster_10212': 'scleractinia',
#  'cluster_10213': 'scleractinia',
#  'cluster_10214': 'scleractinia',
#  'cluster_10215': 'scleractinia',
#  'cluster_10216': 'scleractinia',
#  'cluster_10217': 'scleractinia',
#  'cluster_10218': 'scleractinia',
#  'cluster_10219': 'scleractinia',
#  'cluster_1022': 'scleractinia',
#  'cluster_10220': 'scleractinia',
#  'cluster_10221': 'scleractinia',
#  'cluster_10222': 'scleractinia',
#  'cluster_10223': 'scleractinia',
#  'cluster_10224': 'scleractinia',
#  'cluster_10225': 'scleractinia',
#  'cluster_10226': 'scleractinia',
#  'cluster_10227': 'scleractinia',
#  'cluster_10228': 'scleractinia',
#  'cluster_10229': 'anthozoa',
#  'cluster_1023': 'anthozoa',
#  'cluster_10230': 'scleractinia',
#  'cluster_10231': 'scleractinia',
#  'cluster_10232': 'scleractinia',
#  'cluster_10233': 'scleractinia',
#  'cluster_10234': 'scleractinia',
#  'cluster_10235': 'scleractinia',
#  'cluster_10236': 'scleractinia',
#  'cluster_10237': 'scleractinia',
#  'cluster_10238': 'scleractinia',
#  'cluster_10239': 'scleractinia',
#  'cluster_1024': 'scleractinia',
#  'cluster_10240': 'scleractinia',
#  'cluster_10241': 'scleractinia',
#  'cluster_10242': 'scleractinia',
#  'cluster_10243': 'scleractinia',
#  'cluster_10244': 'scleractinia',
#  'cluster_10245': 'scleractinia',
#  'cluster_10246': 'scleractinia',
#  'cluster_10247': 'scleractinia',
#  'cluster_10248': 'scleractinia',
#  'cluster_10249': 'scleractinia',
#  'cluster_10250': 'scleractinia',
#  'cluster_10251': 'scleractinia',
#  'cluster_10252': 'scleractinia',
#  'cluster_10253': 'scleractinia',
#  'cluster_10254': 'scleractinia',
#  'cluster_10255': 'scleractinia',
#  'cluster_10256': 'scleractinia',
#  'cluster_10257': 'scleractinia',
#  'cluster_10258': 'scleractinia',
#  'cluster_10259': 'scleractinia',
#  'cluster_10260': 'scleractinia',
#  'cluster_10261': 'scleractinia',
#  'cluster_10262': 'scleractinia',
#  'cluster_10263': 'scleractinia',
#  'cluster_10264': 'scleractinia',
#  'cluster_10265': 'scleractinia',
#  'cluster_10266': 'scleractinia',
#  'cluster_10267': 'scleractinia',
#  'cluster_10268': 'scleractinia',
#  'cluster_10269': 'scleractinia',
#  'cluster_1027': 'scleractinia',
#  'cluster_10270': 'scleractinia',
#  'cluster_10271': 'scleractinia',
#  'cluster_10272': 'scleractinia',
#  'cluster_10273': 'scleractinia',
#  'cluster_10274': 'scleractinia',
#  'cluster_10275': 'scleractinia',
#  'cluster_10276': 'scleractinia',
#  'cluster_10277': 'scleractinia',
#  'cluster_10278': 'scleractinia',
#  'cluster_10279': 'scleractinia',
#  'cluster_1028': 'scleractinia',
#  'cluster_10280': 'scleractinia',
#  'cluster_10281': 'scleractinia',
#  'cluster_10282': 'scleractinia',
#  'cluster_10283': 'scleractinia',
#  'cluster_10284': 'scleractinia',
#  'cluster_10285': 'scleractinia',
#  'cluster_10286': 'scleractinia',
#  'cluster_10287': 'scleractinia',
#  'cluster_10288': 'scleractinia',
#  'cluster_10289': 'scleractinia',
#  'cluster_1029': 'scleractinia',
#  'cluster_10290': 'scleractinia',
#  'cluster_10291': 'scleractinia',
#  'cluster_10292': 'scleractinia',
#  'cluster_10293': 'scleractinia',
#  'cluster_10294': 'scleractinia',
#  'cluster_10295': 'scleractinia',
#  'cluster_10296': 'scleractinia',
#  'cluster_10297': 'scleractinia',
#  'cluster_10298': 'scleractinia',
#  'cluster_10299': 'scleractinia',
#  'cluster_1030': 'scleractinia',
#  'cluster_10300': 'scleractinia',
#  'cluster_10301': 'scleractinia',
#  'cluster_10302': 'scleractinia',
#  'cluster_10303': 'scleractinia',
#  'cluster_10304': 'scleractinia',
#  'cluster_10305': 'scleractinia',
#  'cluster_10306': 'scleractinia',
#  'cluster_10307': 'scleractinia',
#  'cluster_10308': 'scleractinia',
#  'cluster_10309': 'scleractinia',
#  'cluster_1031': 'scleractinia',
#  'cluster_10310': 'scleractinia',
#  'cluster_10311': 'scleractinia',
#  'cluster_10312': 'scleractinia',
#  'cluster_10313': 'scleractinia',
#  'cluster_10314': 'scleractinia',
#  'cluster_10315': 'scleractinia',
#  'cluster_10316': 'scleractinia',
#  'cluster_10317': 'scleractinia',
#  'cluster_10318': 'scleractinia',
#  'cluster_10319': 'scleractinia',
#  'cluster_1032': 'scleractinia',
#  'cluster_10320': 'scleractinia',
#  'cluster_10321': 'scleractinia',
#  'cluster_10322': 'scleractinia',
#  'cluster_10323': 'scleractinia',
#  'cluster_10324': 'scleractinia',
#  'cluster_10325': 'scleractinia',
#  'cluster_10326': 'scleractinia',
#  'cluster_10327': 'scleractinia',
#  'cluster_10328': 'scleractinia',
#  'cluster_10329': 'scleractinia',
#  'cluster_1033': 'scleractinia',
#  'cluster_10330': 'scleractinia',
#  'cluster_10331': 'scleractinia',
#  'cluster_10332': 'scleractinia',
#  'cluster_10333': 'scleractinia',
#  'cluster_10334': 'scleractinia',
#  'cluster_10335': 'scleractinia',
#  'cluster_10336': 'scleractinia',
#  'cluster_10337': 'scleractinia',
#  'cluster_10338': 'scleractinia',
#  'cluster_10339': 'scleractinia',
#  'cluster_1034': 'scleractinia',
#  'cluster_10340': 'scleractinia',
#  'cluster_10341': 'scleractinia',
#  'cluster_10342': 'scleractinia',
#  'cluster_10343': 'scleractinia',
#  'cluster_10344': 'scleractinia',
#  'cluster_10345': 'scleractinia',
#  'cluster_10346': 'scleractinia',
#  'cluster_10347': 'scleractinia',
#  'cluster_10348': 'scleractinia',
#  'cluster_10349': 'scleractinia',
#  'cluster_1035': 'hexacorallia',
#  'cluster_10350': 'scleractinia',
#  'cluster_10351': 'scleractinia',
#  'cluster_10352': 'scleractinia',
#  'cluster_10353': 'scleractinia',
#  'cluster_10354': 'scleractinia',
#  'cluster_10355': 'scleractinia',
#  'cluster_10356': 'cnidaria',
#  'cluster_10357': 'scleractinia',
#  'cluster_10358': 'scleractinia',
#  'cluster_10359': 'scleractinia',
#  'cluster_10360': 'scleractinia',
#  'cluster_10361': 'scleractinia',
#  'cluster_10362': 'scleractinia',
#  'cluster_10363': 'scleractinia',
#  'cluster_10364': 'scleractinia',
#  'cluster_10365': 'scleractinia',
#  'cluster_10366': 'scleractinia',
#  'cluster_10367': 'scleractinia',
#  'cluster_10368': 'scleractinia',
#  'cluster_10369': 'scleractinia',
#  'cluster_10370': 'scleractinia',
#  'cluster_10371': 'scleractinia',
#  'cluster_10372': 'scleractinia',
#  'cluster_10373': 'scleractinia',
#  'cluster_10374': 'scleractinia',
#  'cluster_10375': 'scleractinia',
#  'cluster_10376': 'scleractinia',
#  'cluster_10377': 'scleractinia',
#  'cluster_10378': 'scleractinia',
#  'cluster_10379': 'scleractinia',
#  'cluster_1038': 'scleractinia',
#  'cluster_10380': 'scleractinia',
#  'cluster_10381': 'scleractinia',
#  'cluster_10382': 'scleractinia',
#  'cluster_10383': 'scleractinia',
#  'cluster_10384': 'scleractinia',
#  'cluster_10385': 'scleractinia',
#  'cluster_10386': 'scleractinia',
#  'cluster_10387': 'scleractinia',
#  'cluster_10388': 'scleractinia',
#  'cluster_10389': 'scleractinia',
#  'cluster_1039': 'hexacorallia',
#  'cluster_10390': 'scleractinia',
#  'cluster_10391': 'scleractinia',
#  'cluster_10392': 'scleractinia',
#  'cluster_10393': 'scleractinia',
#  'cluster_10394': 'scleractinia',
#  'cluster_10395': 'scleractinia',
#  'cluster_10396': 'scleractinia',
#  'cluster_10397': 'scleractinia',
#  'cluster_10399': 'scleractinia',
#  'cluster_104': 'scleractinia',
#  'cluster_1040': 'scleractinia',
#  'cluster_10400': 'scleractinia',
#  'cluster_10401': 'scleractinia',
#  'cluster_10402': 'scleractinia',
#  'cluster_10403': 'scleractinia',
#  'cluster_10404': 'scleractinia',
#  'cluster_10405': 'scleractinia',
#  'cluster_10406': 'scleractinia',
#  'cluster_10407': 'scleractinia',
#  'cluster_10408': 'scleractinia',
#  'cluster_10409': 'scleractinia',
#  'cluster_10410': 'scleractinia',
#  'cluster_10411': 'scleractinia',
#  'cluster_10412': 'scleractinia',
#  'cluster_10413': 'scleractinia',
#  'cluster_10414': 'scleractinia',
#  'cluster_10415': 'scleractinia',
#  'cluster_10416': 'scleractinia',
#  'cluster_10417': 'scleractinia',
#  'cluster_10418': 'scleractinia',
#  'cluster_10419': 'scleractinia',
#  'cluster_1042': 'scleractinia',
#  'cluster_10420': 'scleractinia',
#  'cluster_10421': 'scleractinia',
#  'cluster_10422': 'scleractinia',
#  'cluster_10423': 'scleractinia',
#  'cluster_10424': 'scleractinia',
#  'cluster_10425': 'scleractinia',
#  'cluster_10426': 'scleractinia',
#  'cluster_10427': 'scleractinia',
#  'cluster_10428': 'scleractinia',
#  'cluster_10429': 'scleractinia',
#  'cluster_1043': 'scleractinia',
#  'cluster_10430': 'scleractinia',
#  'cluster_10431': 'hexacorallia',
#  'cluster_10432': 'scleractinia',
#  'cluster_10433': 'scleractinia',
#  'cluster_10434': 'scleractinia',
#  'cluster_10435': 'scleractinia',
#  'cluster_10436': 'scleractinia',
#  'cluster_10437': 'scleractinia',
#  'cluster_10438': 'scleractinia',
#  'cluster_10439': 'scleractinia',
#  'cluster_1044': 'scleractinia',
#  'cluster_10440': 'scleractinia',
#  'cluster_10441': 'scleractinia',
#  'cluster_10442': 'scleractinia',
#  'cluster_10443': 'scleractinia',
#  'cluster_10444': 'hexacorallia',
#  'cluster_10445': 'scleractinia',
#  'cluster_10446': 'scleractinia',
#  'cluster_10447': 'scleractinia',
#  'cluster_10448': 'hexacorallia',
#  'cluster_10449': 'scleractinia',
#  'cluster_1045': 'scleractinia',
#  'cluster_10450': 'scleractinia',
#  'cluster_10451': 'scleractinia',
#  'cluster_10452': 'scleractinia',
#  'cluster_10453': 'scleractinia',
#  'cluster_10454': 'scleractinia',
#  'cluster_10455': 'scleractinia',
#  'cluster_10456': 'scleractinia',
#  'cluster_10457': 'scleractinia',
#  'cluster_10458': 'scleractinia',
#  'cluster_10459': 'scleractinia',
#  'cluster_10460': 'scleractinia',
#  'cluster_10461': 'scleractinia',
#  'cluster_10462': 'scleractinia',
#  'cluster_10463': 'scleractinia',
#  'cluster_10464': 'scleractinia',
#  'cluster_10465': 'scleractinia',
#  'cluster_10466': 'scleractinia',
#  'cluster_10467': 'scleractinia',
#  'cluster_10468': 'scleractinia',
#  'cluster_10469': 'scleractinia',
#  'cluster_1047': 'scleractinia',
#  'cluster_10470': 'scleractinia',
#  'cluster_10471': 'scleractinia',
#  'cluster_10472': 'scleractinia',
#  'cluster_10473': 'scleractinia',
#  'cluster_10474': 'scleractinia',
#  'cluster_10475': 'scleractinia',
#  'cluster_10476': 'scleractinia',
#  'cluster_10477': 'scleractinia',
#  'cluster_10478': 'scleractinia',
#  'cluster_10479': 'scleractinia',
#  'cluster_10480': 'scleractinia',
#  'cluster_10481': 'scleractinia',
#  'cluster_10482': 'scleractinia',
#  'cluster_10483': 'scleractinia',
#  'cluster_10484': 'scleractinia',
#  'cluster_10485': 'scleractinia',
#  'cluster_10486': 'hexacorallia',
#  'cluster_10487': 'scleractinia',
#  'cluster_10488': 'scleractinia',
#  'cluster_10489': 'scleractinia',
#  'cluster_1049': 'scleractinia',
#  'cluster_10490': 'scleractinia',
#  'cluster_10491': 'scleractinia',
#  'cluster_10492': 'scleractinia',
#  'cluster_10493': 'scleractinia',
#  'cluster_10494': 'scleractinia',
#  'cluster_10495': 'scleractinia',
#  'cluster_10496': 'scleractinia',
#  'cluster_10497': 'scleractinia',
#  'cluster_10498': 'scleractinia',
#  'cluster_10499': 'scleractinia',
#  'cluster_105': 'scleractinia',
#  'cluster_1050': 'scleractinia',
#  'cluster_10500': 'scleractinia',
#  'cluster_10501': 'scleractinia',
#  'cluster_10502': 'scleractinia',
#  'cluster_10503': 'scleractinia',
#  'cluster_10504': 'scleractinia',
#  'cluster_10505': 'scleractinia',
#  'cluster_10506': 'scleractinia',
#  'cluster_10507': 'scleractinia',
#  'cluster_10508': 'scleractinia',
#  'cluster_10509': 'scleractinia',
#  'cluster_10510': 'scleractinia',
#  'cluster_10511': 'scleractinia',
#  'cluster_10512': 'scleractinia',
#  'cluster_10513': 'scleractinia',
#  'cluster_10514': 'scleractinia',
#  'cluster_10515': 'scleractinia',
#  'cluster_10516': 'scleractinia',
#  'cluster_10517': 'scleractinia',
#  'cluster_10518': 'scleractinia',
#  'cluster_10519': 'scleractinia',
#  'cluster_10520': 'scleractinia',
#  'cluster_10521': 'scleractinia',
#  'cluster_10522': 'scleractinia',
#  'cluster_10523': 'scleractinia',
#  'cluster_10524': 'scleractinia',
#  'cluster_10525': 'scleractinia',
#  'cluster_10526': 'scleractinia',
#  'cluster_10527': 'scleractinia',
#  'cluster_10528': 'scleractinia',
#  'cluster_10529': 'scleractinia',
#  'cluster_1053': 'anthozoa',
#  'cluster_10530': 'scleractinia',
#  'cluster_10531': 'scleractinia',
#  'cluster_10532': 'scleractinia',
#  'cluster_10533': 'scleractinia',
#  'cluster_10534': 'scleractinia',
#  'cluster_10535': 'scleractinia',
#  'cluster_10536': 'scleractinia',
#  'cluster_10537': 'scleractinia',
#  'cluster_10538': 'scleractinia',
#  'cluster_10539': 'scleractinia',
#  'cluster_1054': 'scleractinia',
#  'cluster_10540': 'scleractinia',
#  'cluster_10541': 'scleractinia',
#  'cluster_10542': 'scleractinia',
#  'cluster_10543': 'scleractinia',
#  'cluster_10544': 'scleractinia',
#  'cluster_10545': 'scleractinia',
#  'cluster_10546': 'scleractinia',
#  'cluster_10547': 'scleractinia',
#  'cluster_10548': 'scleractinia',
#  'cluster_10549': 'scleractinia',
#  'cluster_1055': 'scleractinia',
#  'cluster_10550': 'scleractinia',
#  'cluster_10551': 'hexacorallia',
#  'cluster_10552': 'scleractinia',
#  'cluster_10553': 'scleractinia',
#  'cluster_10554': 'scleractinia',
#  'cluster_10555': 'scleractinia',
#  'cluster_10556': 'scleractinia',
#  'cluster_10557': 'scleractinia',
#  'cluster_10558': 'scleractinia',
#  'cluster_10559': 'scleractinia',
#  'cluster_1056': 'scleractinia',
#  'cluster_10560': 'scleractinia',
#  'cluster_10561': 'scleractinia',
#  'cluster_10562': 'scleractinia',
#  'cluster_10563': 'scleractinia',
#  'cluster_10564': 'anthozoa',
#  'cluster_10565': 'scleractinia',
#  'cluster_10566': 'scleractinia',
#  'cluster_10567': 'scleractinia',
#  'cluster_10568': 'scleractinia',
#  'cluster_10569': 'scleractinia',
#  'cluster_1057': 'scleractinia',
#  'cluster_10570': 'scleractinia',
#  'cluster_10571': 'scleractinia',
#  'cluster_10572': 'scleractinia',
#  'cluster_10573': 'scleractinia',
#  'cluster_10574': 'scleractinia',
#  'cluster_10575': 'scleractinia',
#  'cluster_10576': 'scleractinia',
#  'cluster_10577': 'scleractinia',
#  'cluster_10578': 'scleractinia',
#  'cluster_10579': 'scleractinia',
#  'cluster_10580': 'scleractinia',
#  'cluster_10581': 'scleractinia',
#  'cluster_10582': 'scleractinia',
#  'cluster_10583': 'scleractinia',
#  'cluster_10584': 'scleractinia',
#  'cluster_10585': 'scleractinia',
#  'cluster_10586': 'scleractinia',
#  'cluster_10587': 'anthozoa',
#  'cluster_10588': 'scleractinia',
#  'cluster_10589': 'scleractinia',
#  'cluster_10590': 'scleractinia',
#  'cluster_10591': 'scleractinia',
#  'cluster_10592': 'scleractinia',
#  'cluster_10593': 'scleractinia',
#  'cluster_10594': 'scleractinia',
#  'cluster_10595': 'hexacorallia',
#  'cluster_10596': 'scleractinia',
#  'cluster_10597': 'scleractinia',
#  'cluster_10598': 'scleractinia',
#  'cluster_10599': 'scleractinia',
#  'cluster_106': 'scleractinia',
#  'cluster_1060': 'scleractinia',
#  'cluster_10600': 'scleractinia',
#  'cluster_10601': 'scleractinia',
#  'cluster_10602': 'scleractinia',
#  'cluster_10603': 'scleractinia',
#  'cluster_10604': 'scleractinia',
#  'cluster_10605': 'scleractinia',
#  'cluster_10606': 'scleractinia',
#  'cluster_10607': 'scleractinia',
#  'cluster_10608': 'scleractinia',
#  'cluster_10609': 'scleractinia',
#  'cluster_1061': 'scleractinia',
#  'cluster_10610': 'scleractinia',
#  'cluster_10611': 'scleractinia',
#  'cluster_10612': 'scleractinia',
#  'cluster_10613': 'scleractinia',
#  'cluster_10614': 'scleractinia',
#  'cluster_10615': 'scleractinia',
#  'cluster_10616': 'scleractinia',
#  'cluster_10617': 'scleractinia',
#  'cluster_10618': 'scleractinia',
#  'cluster_10619': 'scleractinia',
#  'cluster_10620': 'scleractinia',
#  'cluster_10621': 'scleractinia',
#  'cluster_10622': 'scleractinia',
#  'cluster_10623': 'scleractinia',
#  'cluster_10624': 'scleractinia',
#  'cluster_10625': 'scleractinia',
#  'cluster_10626': 'scleractinia',
#  'cluster_10627': 'scleractinia',
#  'cluster_10628': 'scleractinia',
#  'cluster_10629': 'scleractinia',
#  'cluster_1063': 'scleractinia',
#  'cluster_10630': 'scleractinia',
#  'cluster_10631': 'scleractinia',
#  'cluster_10632': 'scleractinia',
#  'cluster_10633': 'scleractinia',
#  'cluster_10634': 'scleractinia',
#  'cluster_10635': 'scleractinia',
#  'cluster_10636': 'scleractinia',
#  'cluster_10637': 'scleractinia',
#  'cluster_10638': 'scleractinia',
#  'cluster_10639': 'scleractinia',
#  'cluster_1064': 'scleractinia',
#  'cluster_10640': 'scleractinia',
#  'cluster_10641': 'scleractinia',
#  'cluster_10642': 'scleractinia',
#  'cluster_10643': 'scleractinia',
#  'cluster_10644': 'scleractinia',
#  'cluster_10645': 'scleractinia',
#  'cluster_10646': 'scleractinia',
#  'cluster_10647': 'scleractinia',
#  'cluster_10648': 'scleractinia',
#  'cluster_10649': 'scleractinia',
#  'cluster_1065': 'scleractinia',
#  'cluster_10650': 'scleractinia',
#  'cluster_10651': 'scleractinia',
#  'cluster_10652': 'scleractinia',
#  'cluster_10653': 'scleractinia',
#  'cluster_10654': 'scleractinia',
#  'cluster_10655': 'scleractinia',
#  'cluster_10656': 'scleractinia',
#  'cluster_10657': 'scleractinia',
#  'cluster_10658': 'scleractinia',
#  'cluster_10659': 'scleractinia',
#  'cluster_1066': 'hexacorallia',
#  'cluster_10660': 'scleractinia',
#  'cluster_10661': 'scleractinia',
#  'cluster_10662': 'scleractinia',
#  'cluster_10663': 'scleractinia',
#  'cluster_10664': 'scleractinia',
#  'cluster_10665': 'scleractinia',
#  'cluster_10666': 'scleractinia',
#  'cluster_10667': 'scleractinia',
#  'cluster_10668': 'scleractinia',
#  'cluster_10669': 'scleractinia',
#  'cluster_1067': 'scleractinia',
#  'cluster_10670': 'scleractinia',
#  'cluster_10671': 'scleractinia',
#  'cluster_10672': 'scleractinia',
#  'cluster_10673': 'scleractinia',
#  'cluster_10674': 'scleractinia',
#  'cluster_10675': 'scleractinia',
#  'cluster_10676': 'scleractinia',
#  'cluster_10677': 'scleractinia',
#  'cluster_10678': 'scleractinia',
#  'cluster_10679': 'scleractinia',
#  'cluster_10680': 'scleractinia',
#  'cluster_10681': 'scleractinia',
#  'cluster_10682': 'scleractinia',
#  'cluster_10683': 'scleractinia',
#  'cluster_10684': 'scleractinia',
#  'cluster_10685': 'scleractinia',
#  'cluster_10686': 'scleractinia',
#  'cluster_10687': 'scleractinia',
#  'cluster_10688': 'scleractinia',
#  'cluster_10689': 'scleractinia',
#  'cluster_10690': 'scleractinia',
#  'cluster_10691': 'scleractinia',
#  'cluster_10692': 'scleractinia',
#  'cluster_10693': 'scleractinia',
#  'cluster_10694': 'scleractinia',
#  'cluster_10695': 'scleractinia',
#  'cluster_10696': 'scleractinia',
#  'cluster_10697': 'scleractinia',
#  'cluster_10698': 'scleractinia',
#  'cluster_10699': 'scleractinia',
#  'cluster_107': 'scleractinia',
#  'cluster_10700': 'scleractinia',
#  'cluster_10701': 'scleractinia',
#  'cluster_10702': 'scleractinia',
#  'cluster_10703': 'scleractinia',
#  'cluster_10704': 'scleractinia',
#  'cluster_10705': 'scleractinia',
#  'cluster_10706': 'scleractinia',
#  'cluster_10707': 'scleractinia',
#  'cluster_10708': 'scleractinia',
#  'cluster_10709': 'scleractinia',
#  'cluster_1071': 'scleractinia',
#  'cluster_10710': 'scleractinia',
#  'cluster_10711': 'scleractinia',
#  'cluster_10712': 'scleractinia',
#  'cluster_10713': 'scleractinia',
#  'cluster_10714': 'scleractinia',
#  'cluster_10715': 'scleractinia',
#  'cluster_10716': 'scleractinia',
#  'cluster_10717': 'scleractinia',
#  'cluster_10718': 'scleractinia',
#  'cluster_10719': 'scleractinia',
#  'cluster_1072': 'scleractinia',
#  'cluster_10720': 'scleractinia',
#  'cluster_10721': 'scleractinia',
#  'cluster_10722': 'scleractinia',
#  'cluster_10723': 'scleractinia',
#  'cluster_10724': 'scleractinia',
#  'cluster_10725': 'scleractinia',
#  'cluster_10726': 'scleractinia',
#  'cluster_10727': 'scleractinia',
#  'cluster_10728': 'scleractinia',
#  'cluster_10729': 'scleractinia',
#  'cluster_1073': 'scleractinia',
#  'cluster_10730': 'scleractinia',
#  'cluster_10731': 'scleractinia',
#  'cluster_10732': 'scleractinia',
#  'cluster_10733': 'scleractinia',
#  'cluster_10734': 'scleractinia',
#  'cluster_10735': 'scleractinia',
#  'cluster_10736': 'scleractinia',
#  'cluster_10737': 'scleractinia',
#  'cluster_10738': 'scleractinia',
#  'cluster_10739': 'scleractinia',
#  'cluster_10740': 'scleractinia',
#  'cluster_10741': 'scleractinia',
#  'cluster_10742': 'scleractinia',
#  'cluster_10743': 'scleractinia',
#  'cluster_10744': 'scleractinia',
#  'cluster_10745': 'scleractinia',
#  'cluster_10746': 'scleractinia',
#  'cluster_10747': 'scleractinia',
#  'cluster_10748': 'scleractinia',
#  'cluster_10749': 'scleractinia',
#  'cluster_1075': 'scleractinia',
#  'cluster_10750': 'scleractinia',
#  'cluster_10751': 'scleractinia',
#  'cluster_10752': 'scleractinia',
#  'cluster_10753': 'scleractinia',
#  'cluster_10754': 'scleractinia',
#  'cluster_10755': 'scleractinia',
#  'cluster_10756': 'scleractinia',
#  'cluster_10757': 'scleractinia',
#  'cluster_10758': 'cnidaria',
#  'cluster_10759': 'scleractinia',
#  'cluster_1076': 'scleractinia',
#  'cluster_10760': 'scleractinia',
#  'cluster_10762': 'scleractinia',
#  'cluster_10763': 'scleractinia',
#  'cluster_10764': 'scleractinia',
#  'cluster_10765': 'scleractinia',
#  'cluster_10766': 'hexacorallia',
#  'cluster_10767': 'scleractinia',
#  'cluster_10768': 'scleractinia',
#  'cluster_10769': 'scleractinia',
#  'cluster_10770': 'scleractinia',
#  'cluster_10771': 'scleractinia',
#  'cluster_10772': 'scleractinia',
#  'cluster_10773': 'scleractinia',
#  'cluster_10774': 'scleractinia',
#  'cluster_10775': 'scleractinia',
#  'cluster_10776': 'scleractinia',
#  'cluster_10777': 'scleractinia',
#  'cluster_10778': 'scleractinia',
#  'cluster_10779': 'scleractinia',
#  'cluster_10780': 'scleractinia',
#  'cluster_10781': 'scleractinia',
#  'cluster_10782': 'hexacorallia',
#  'cluster_10783': 'scleractinia',
#  'cluster_10784': 'scleractinia',
#  'cluster_10785': 'scleractinia',
#  'cluster_10786': 'scleractinia',
#  'cluster_10787': 'scleractinia',
#  'cluster_10788': 'scleractinia',
#  'cluster_10789': 'scleractinia',
#  'cluster_10790': 'scleractinia',
#  'cluster_10791': 'scleractinia',
#  'cluster_10792': 'scleractinia',
#  'cluster_10793': 'scleractinia',
#  'cluster_10794': 'scleractinia',
#  'cluster_10795': 'scleractinia',
#  'cluster_10796': 'scleractinia',
#  'cluster_10797': 'scleractinia',
#  'cluster_10798': 'scleractinia',
#  'cluster_10799': 'scleractinia',
#  'cluster_108': 'hexacorallia',
#  'cluster_1080': 'scleractinia',
#  'cluster_10800': 'scleractinia',
#  'cluster_10801': 'scleractinia',
#  'cluster_10802': 'scleractinia',
#  'cluster_10803': 'scleractinia',
#  'cluster_10804': 'scleractinia',
#  'cluster_10805': 'scleractinia',
#  'cluster_10806': 'scleractinia',
#  'cluster_10807': 'scleractinia',
#  'cluster_10808': 'scleractinia',
#  'cluster_10809': 'scleractinia',
#  'cluster_10810': 'scleractinia',
#  'cluster_10811': 'scleractinia',
#  'cluster_10812': 'scleractinia',
#  'cluster_10813': 'scleractinia',
#  'cluster_10814': 'scleractinia',
#  'cluster_10815': 'scleractinia',
#  'cluster_10816': 'scleractinia',
#  'cluster_10817': 'scleractinia',
#  'cluster_10818': 'scleractinia',
#  'cluster_10819': 'scleractinia',
#  'cluster_1082': 'scleractinia',
#  'cluster_10820': 'scleractinia',
#  'cluster_10821': 'scleractinia',
#  'cluster_10822': 'scleractinia',
#  'cluster_10823': 'scleractinia',
#  'cluster_10824': 'scleractinia',
#  'cluster_10825': 'scleractinia',
#  'cluster_10826': 'scleractinia',
#  'cluster_10827': 'scleractinia',
#  'cluster_10828': 'scleractinia',
#  'cluster_10829': 'scleractinia',
#  'cluster_1083': 'scleractinia',
#  'cluster_10830': 'scleractinia',
#  'cluster_10831': 'scleractinia',
#  'cluster_10832': 'scleractinia',
#  'cluster_10833': 'scleractinia',
#  'cluster_10834': 'hexacorallia',
#  'cluster_10835': 'scleractinia',
#  'cluster_10836': 'scleractinia',
#  'cluster_10837': 'scleractinia',
#  'cluster_10838': 'scleractinia',
#  'cluster_10839': 'scleractinia',
#  'cluster_1084': 'scleractinia',
#  'cluster_10840': 'scleractinia',
#  'cluster_10841': 'scleractinia',
#  'cluster_10842': 'scleractinia',
#  'cluster_10843': 'scleractinia',
#  'cluster_10844': 'scleractinia',
#  'cluster_10845': 'scleractinia',
#  'cluster_10846': 'scleractinia',
#  'cluster_10847': 'scleractinia',
#  'cluster_10848': 'scleractinia',
#  'cluster_10849': 'scleractinia',
#  'cluster_10850': 'scleractinia',
#  'cluster_10851': 'scleractinia',
#  'cluster_10852': 'scleractinia',
#  'cluster_10853': 'scleractinia',
#  'cluster_10854': 'scleractinia',
#  'cluster_10855': 'scleractinia',
#  'cluster_10856': 'scleractinia',
#  'cluster_10857': 'scleractinia',
#  'cluster_10858': 'scleractinia',
#  'cluster_10859': 'scleractinia',
#  'cluster_1086': 'scleractinia',
#  'cluster_10860': 'scleractinia',
#  'cluster_10861': 'scleractinia',
#  'cluster_10862': 'scleractinia',
#  'cluster_10863': 'scleractinia',
#  'cluster_10864': 'scleractinia',
#  'cluster_10865': 'scleractinia',
#  'cluster_10866': 'scleractinia',
#  'cluster_10867': 'scleractinia',
#  'cluster_10868': 'scleractinia',
#  'cluster_10869': 'scleractinia',
#  'cluster_1087': 'scleractinia',
#  'cluster_10870': 'scleractinia',
#  'cluster_10871': 'scleractinia',
#  'cluster_10872': 'scleractinia',
#  'cluster_10873': 'scleractinia',
#  'cluster_10874': 'scleractinia',
#  'cluster_10875': 'scleractinia',
#  'cluster_10876': 'scleractinia',
#  'cluster_10877': 'scleractinia',
#  'cluster_10878': 'scleractinia',
#  'cluster_10879': 'scleractinia',
#  'cluster_10880': 'scleractinia',
#  'cluster_10881': 'scleractinia',
#  'cluster_10882': 'scleractinia',
#  'cluster_10883': 'scleractinia',
#  'cluster_10884': 'scleractinia',
#  'cluster_10885': 'hexacorallia',
#  'cluster_10886': 'scleractinia',
#  'cluster_10887': 'scleractinia',
#  'cluster_10888': 'scleractinia',
#  'cluster_10889': 'scleractinia',
#  'cluster_1089': 'scleractinia',
#  'cluster_10890': 'scleractinia',
#  'cluster_10891': 'scleractinia',
#  'cluster_10892': 'scleractinia',
#  'cluster_10893': 'scleractinia',
#  'cluster_10894': 'scleractinia',
#  'cluster_10895': 'scleractinia',
#  'cluster_10896': 'scleractinia',
#  'cluster_10897': 'scleractinia',
#  'cluster_10898': 'scleractinia',
#  'cluster_10899': 'scleractinia',
#  'cluster_109': 'hexacorallia',
#  'cluster_1090': 'scleractinia',
#  'cluster_10900': 'scleractinia',
#  'cluster_10901': 'hexacorallia',
#  'cluster_10902': 'scleractinia',
#  'cluster_10903': 'scleractinia',
#  'cluster_10904': 'hexacorallia',
#  'cluster_10905': 'scleractinia',
#  'cluster_10906': 'scleractinia',
#  'cluster_10907': 'scleractinia',
#  'cluster_10908': 'scleractinia',
#  'cluster_10909': 'scleractinia',
#  'cluster_10910': 'scleractinia',
#  'cluster_10911': 'scleractinia',
#  'cluster_10912': 'scleractinia',
#  'cluster_10913': 'scleractinia',
#  'cluster_10914': 'scleractinia',
#  'cluster_10915': 'scleractinia',
#  'cluster_10916': 'scleractinia',
#  'cluster_10917': 'scleractinia',
#  'cluster_10918': 'scleractinia',
#  'cluster_10919': 'scleractinia',
#  'cluster_1092': 'scleractinia',
#  'cluster_10920': 'scleractinia',
#  'cluster_10921': 'scleractinia',
#  'cluster_10922': 'scleractinia',
#  'cluster_10923': 'scleractinia',
#  'cluster_10924': 'scleractinia',
#  ...}

# %%
with open('cluster_lcas.pickle', 'wb') as handle:
    pickle.dump(cluster_lcas, handle)

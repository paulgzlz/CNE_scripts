# %% [markdown]
# ### Goal
#
# Calculate lengths of all CNEs, and output to a file for each species pairwise comparison
#
# ### Input
#
#
#
# ### Output
#
# #### Note: modified from code written by summer student Quinn Hauck

# %%
import pandas as pd
from Bio import SeqIO
import gzip
from Bio.Seq import Seq
from Bio import pairwise2
from statistics import mean
import os
# Out:
# /Users/gonzalezp2/anaconda3/lib/python3.9/site-packages/Bio/pairwise2.py:278: BiopythonDeprecationWarning: Bio.pairwise2 has been deprecated, and we intend to remove it in a future release of Biopython. As an alternative, please consider using Bio.Align.PairwiseAligner as a replacement, and contact the Biopython developers if you still need the Bio.pairwise2 module.
#   warnings.warn(

# %%
#directory that stores CNE output (ex: aaur_vs_adig.out)
paired_cne_dir = '../../cnidaria_final/cnefinder_output/stranded/'
#directory with the filtered CNE coordinates
cne_coord_dir = '../post_parsimony_filtering/'
#matrix with all species on the sides with their most common ancestor as entry in the cells
evolution_matrix_file = 'cnidaria_evol_dist_matrix_no_space.csv'
#output directory
cne_lengths_out_dir = 'cne_lengths_no_enthemonae/'

# %%
species = ['spis', 'hsym', 'aaur', 'dgig', 'chem', 'ofav', 
           'aten', 'mvir','hvul', 'adig', 'pdam', 'nvec', 'epal']

# %%
evo_matrix = pd.read_csv(evolution_matrix_file, index_col=0)
evo_matrix
# Out:
#            aaur          adig          amil          aten          chem  \
# aaur          -      cnidaria      cnidaria      cnidaria     medusozoa
# adig   cnidaria             -      acropora  hexacorallia      cnidaria
# amil   cnidaria      acropora             -  hexacorallia      cnidaria
# aten   cnidaria  hexacorallia  hexacorallia             -      cnidaria
# chem  medusozoa      cnidaria      cnidaria      cnidaria             -
# dgig   cnidaria      anthozoa      anthozoa      anthozoa      cnidaria
# epal   cnidaria  hexacorallia  hexacorallia    enthemonae      cnidaria
# hsym  medusozoa      cnidaria      cnidaria      cnidaria  leptothecata
# hvul  medusozoa      cnidaria      cnidaria      cnidaria      hydrozoa
# mvir  acraspeda      cnidaria      cnidaria      cnidaria     medusozoa
# nvec   cnidaria  hexacorallia  hexacorallia    actiniaria      cnidaria
# ofav   cnidaria  scleractinia  scleractinia  hexacorallia      cnidaria
# pdam   cnidaria  scleractinia  scleractinia  hexacorallia      cnidaria
# spis   cnidaria  scleractinia  scleractinia  hexacorallia      cnidaria
#
#           dgig          epal          hsym       hvul       mvir  \
# aaur  cnidaria      cnidaria     medusozoa  medusozoa  acraspeda
# adig  anthozoa  hexacorallia      cnidaria   cnidaria   cnidaria
# amil  anthozoa  hexacorallia      cnidaria   cnidaria   cnidaria
# aten  anthozoa    enthemonae      cnidaria   cnidaria   cnidaria
# chem  cnidaria      cnidaria  leptothecata   hydrozoa  medusozoa
# dgig         -      anthozoa      cnidaria   cnidaria   cnidaria
# epal  anthozoa             -      cnidaria   cnidaria   cnidaria
# hsym  cnidaria      cnidaria             -   hydrozoa  medusozoa
# hvul  cnidaria      cnidaria      hydrozoa          -  medusozoa
# mvir  cnidaria      cnidaria     medusozoa  medusozoa          -
# nvec  anthozoa    actiniaria      cnidaria   cnidaria   cnidaria
# ofav  anthozoa  hexacorallia      cnidaria   cnidaria   cnidaria
# pdam  anthozoa  hexacorallia      cnidaria   cnidaria   cnidaria
# spis  anthozoa  hexacorallia      cnidaria   cnidaria   cnidaria
#
#               nvec          ofav            pdam            spis
# aaur      cnidaria      cnidaria        cnidaria        cnidaria
# adig  hexacorallia  scleractinia    scleractinia    scleractinia
# amil  hexacorallia  scleractinia    scleractinia    scleractinia
# aten    actiniaria  hexacorallia    hexacorallia    hexacorallia
# chem      cnidaria      cnidaria        cnidaria        cnidaria
# dgig      anthozoa      anthozoa        anthozoa        anthozoa
# epal    actiniaria  hexacorallia    hexacorallia    hexacorallia
# hsym      cnidaria      cnidaria        cnidaria        cnidaria
# hvul      cnidaria      cnidaria        cnidaria        cnidaria
# mvir      cnidaria      cnidaria        cnidaria        cnidaria
# nvec             -  hexacorallia    hexacorallia    hexacorallia
# ofav  hexacorallia             -         robusta         robusta
# pdam  hexacorallia       robusta               -  pocilloporidae
# spis  hexacorallia       robusta  pocilloporidae               -

# %%
# Using Sally's estimates:
evolution_ages = {
    'cnidaria':570,
    'medusozoa':539,
    'acraspeda':466,
    'hexacorallia':341,
    'anthozoa':497,
    'scleractinia':161,
    'enthemonae': 'unknown',
    'actiniaria':242,
    'leptothecata':417,
    'hydrozoa':500,
    'robusta':108,
    'pocilloporidae':56
}

# %%
for species1 in species:
    for species2 in species:
        #dont run on same species and only run once for each set of two species
        if species1 == species2:
            continue
        elif not os.path.exists(paired_cne_dir + species1 + '_vs_' + species2 + '.out'):
            continue
        else:
            print('calculating distance and loading files between ' + species1 + ' and ' + species2)
            #calculate evolutionary distance
            last_known_ancestor = evo_matrix.loc[species1][species2]
            evolutionary_distance = evolution_ages[last_known_ancestor]            
            if evolutionary_distance == 'unknown':
                    print("Ancestor age unknown, skip.")
                    continue
            
            #all cnes found between the two sets with the original lengths
            full_cne_set = pd.read_csv(paired_cne_dir + species1 + '_vs_' + species2 + '.out', sep = '\t') 
            #filtered cnes with coordinates corresponding to merged fasta files used for CNEFinder
            species1_filtered_coords = pd.read_csv(cne_coord_dir + species1 + '_coords_filtered.tsv', sep = '\t', names = ['identifier', 'start', 'end'])
            species2_filtered_coords = pd.read_csv(cne_coord_dir + species2 + '_coords_filtered.tsv', sep = '\t', names = ['identifier', 'start', 'end'])

            #turn it into a dictionary so we can access end coordinates by the start coordinates
            species1_filtered_coords_dict = dict(zip(species1_filtered_coords.start, species1_filtered_coords.end))
            species2_filtered_coords_dict = dict(zip(species2_filtered_coords.start, species2_filtered_coords.end))

            #storage lists
            cne_lengths = []
            evolutionary_distances = []

            print('looping through each cne found between the two species')
            for row in range(len(full_cne_set)):
                #pull coords of CNEs for both species
                sequence_start_species1 = full_cne_set.iloc[row]['ref_start']
                sequence_end_species1 = full_cne_set.iloc[row]['ref_end']
                sequence_start_species2 = full_cne_set.iloc[row]['query_start']
                sequence_end_species2 = full_cne_set.iloc[row]['query_end']

                #this stores whether or not the raw cne made it past the filtering stage
                species1_bool = False
                species2_bool = False

                #test whether the start and end coordinate of our raw sequence is within the filtered coordinates, 
                #we must do this, because actual CNE lengths are from the original outputs, not our filtered outputs
                #if yes, we can set our boolean variables to true, and proceed to length calculation
                for start in species1_filtered_coords_dict:
                    if sequence_start_species1 >= start and sequence_end_species1 <= species1_filtered_coords_dict[start]:
                        species1_bool = True
                        break

                for start in species2_filtered_coords_dict:
                    if sequence_start_species2 >= start and sequence_end_species2 <= species2_filtered_coords_dict[start]:
                        species2_bool = True
                        break

                #if both sequences made it past filtering, we take the lesser length of the two and store it
                if species1_bool and species2_bool:
                    cne_length = min(full_cne_set.iloc[row]['ref_length'], full_cne_set.iloc[row]['query_length'])
                    cne_lengths.append(cne_length)
                    evolutionary_distances.append(evolutionary_distance)

            print('lengths pulled, writing to file')

            #store lengths and evolutionary distances in dataframe and write to a file
            data = {'distance (Mya)': evolutionary_distances, 'length': cne_lengths}
            cne_length_df = pd.DataFrame(data)
            cne_length_df.to_csv(cne_lengths_out_dir + species1 + '_vs_' + species2 + '_cne_lengths.tsv', sep = '\t', index = False)
# Out:
# calculating distance and loading files between spis and aaur
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between hsym and spis
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between hsym and aaur
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between hsym and dgig
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between hsym and chem
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between hsym and ofav
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between hsym and aten
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between hsym and mvir
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between hsym and hvul
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between hsym and adig
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between hsym and pdam
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between hsym and nvec
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between hsym and epal
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between dgig and spis
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between dgig and aaur
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between dgig and chem
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between dgig and pdam
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between chem and spis
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between chem and aaur
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between ofav and spis
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between ofav and aaur
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between ofav and dgig
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between ofav and chem
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between ofav and pdam
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between ofav and nvec
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between ofav and epal
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between aten and spis
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between aten and aaur
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between aten and dgig
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between aten and chem
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between aten and ofav
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between aten and mvir
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between aten and hvul
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between aten and adig
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between aten and pdam
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between aten and nvec
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between aten and epal
# Ancestor age unknown, skip.
# calculating distance and loading files between mvir and spis
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between mvir and aaur
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between mvir and dgig
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between mvir and chem
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between mvir and ofav
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between mvir and hvul
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between mvir and pdam
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between mvir and nvec
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between mvir and epal
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between hvul and spis
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between hvul and aaur
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between hvul and dgig
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between hvul and chem
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between hvul and ofav
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between hvul and pdam
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between hvul and nvec
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between hvul and epal
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between adig and spis
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between adig and aaur
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between adig and dgig
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between adig and chem
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between adig and ofav
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between adig and mvir
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between adig and hvul
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between adig and pdam
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between adig and nvec
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between adig and epal
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between pdam and spis
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between pdam and aaur
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between pdam and chem
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between nvec and spis
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between nvec and aaur
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between nvec and dgig
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between nvec and chem
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between nvec and pdam
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between nvec and epal
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between epal and spis
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between epal and aaur
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between epal and dgig
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between epal and chem
# looping through each cne found between the two species
# lengths pulled, writing to file
# calculating distance and loading files between epal and pdam
# looping through each cne found between the two species
# lengths pulled, writing to file
